# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
housing = pd.read_csv("~/Documents/NYCDSA/Third Project/ML_Ames_Housing/data/Ames_Housing_Price_Data.csv", index_col=0)
housing.head() #OPEN DATA FRAME
pd.set_option('display.max_columns', 500)
housing.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 1  909176150        856     126000          30       RL          NaN     7890
# 2  905476230       1049     139500         120       RL         42.0     4235
# 3  911128020       1001     124900          30  C (all)         60.0     6060
# 4  535377150       1039     114000          70       RL         80.0     8146
# 5  534177230       1665     227000          60       RL         70.0     8400
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 1   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 2   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 4   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 5   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 1        SWISU       Norm       Norm     1Fam     1Story            6
# 2      Edwards       Norm       Norm   TwnhsE     1Story            5
# 3       IDOTRR       Norm       Norm     1Fam     1Story            5
# 4      OldTown       Norm       Norm     1Fam     2Story            4
# 5       NWAmes       Norm       Norm     1Fam     2Story            8
#
#    OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 1            6       1939          1950     Gable  CompShg     Wd Sdng
# 2            5       1984          1984     Gable  CompShg     HdBoard
# 3            9       1930          2007       Hip  CompShg     MetalSd
# 4            8       1900          2003     Gable  CompShg     MetalSd
# 5            6       2001          2001     Gable  CompShg     VinylSd
#
#   Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# 1     Wd Sdng        NaN         0.0        TA        TA     CBlock       TA
# 2     HdBoard    BrkFace       149.0        Gd        TA     CBlock       Gd
# 3     MetalSd        NaN         0.0        Gd        TA     BrkTil       TA
# 4     MetalSd        NaN         0.0        Gd        Gd     BrkTil       Fa
# 5     VinylSd        NaN         0.0        Gd        TA      PConc       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1       TA           No          Rec       238.0          Unf         0.0
# 2       TA           Mn          GLQ       552.0          ALQ       393.0
# 3       TA           No          ALQ       737.0          Unf         0.0
# 4       TA           No          Unf         0.0          Unf         0.0
# 5       TA           No          GLQ       643.0          Unf         0.0
#
#    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  \
# 1      618.0        856.0    GasA        TA          Y      SBrkr       856
# 2      104.0       1049.0    GasA        TA          Y      SBrkr      1049
# 3      100.0        837.0    GasA        Ex          Y      SBrkr      1001
# 4      405.0        405.0    GasA        Gd          Y      SBrkr       717
# 5      167.0        810.0    GasA        Ex          Y      SBrkr       810
#
#    2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 1         0             0           1.0           0.0         1         0
# 2         0             0           1.0           0.0         2         0
# 3         0             0           0.0           0.0         1         0
# 4       322             0           0.0           0.0         1         0
# 5       855             0           1.0           0.0         2         1
#
#    BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 1             2             1          TA             4        Typ
# 2             2             1          Gd             5        Typ
# 3             2             1          Gd             5        Typ
# 4             2             1          TA             6        Typ
# 5             3             1          Gd             6        Typ
#
#    Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 1           1          Gd     Detchd       1939.0          Unf         2.0
# 2           0         NaN     Attchd       1984.0          Fin         1.0
# 3           0         NaN     Detchd       1930.0          Unf         1.0
# 4           0         NaN     Detchd       1940.0          Unf         1.0
# 5           0         NaN     Attchd       2001.0          Fin         2.0
#
#    GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 1       399.0         TA         TA          Y           0            0
# 2       266.0         TA         TA          Y           0          105
# 3       216.0         TA         Po          N         154            0
# 4       281.0         TA         TA          N           0            0
# 5       528.0         TA         TA          Y           0           45
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 1              0          0          166         0    NaN   NaN         NaN
# 2              0          0            0         0    NaN   NaN         NaN
# 3             42         86            0         0    NaN   NaN         NaN
# 4            168          0          111         0    NaN   NaN         NaN
# 5              0          0            0         0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition
# 1        0       3    2010      WD         Normal
# 2        0       2    2009      WD         Normal
# 3        0      11    2007      WD         Normal
# 4        0       5    2009      WD         Normal
# 5        0      11    2009      WD         Normal

# %%
#Create seperate numeric-set
housing_numeric = housing[['PID','GrLivArea','SalePrice','LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                         '2ndFlrSF','LowQualFinSF', 'FullBath', 'HalfBath', 'BedroomAbvGr',
                           'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',  'GarageCars',
                           'GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch',
                           '3SsnPorch','ScreenPorch','PoolArea','MiscVal', "YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd']].copy()
housing_numeric['PID'] = housing_numeric['PID'].astype('str')
housing_numeric['YrSold'] = pd.to_datetime(housing_numeric['YrSold']).dt.strftime('%Y')
housing_numeric['GarageYrBlt'] = pd.to_datetime(housing_numeric['GarageYrBlt']).dt.strftime('%Y')
housing_numeric['YearBuilt'] = pd.to_datetime(housing_numeric['YearBuilt']).dt.strftime('%Y')
housing_numeric['YearRemodAdd'] = pd.to_datetime(housing_numeric['YearRemodAdd']).dt.strftime('%Y')
housing_numeric['MoSold'] = pd.to_datetime(housing_numeric['MoSold'],format='%m').dt.strftime('%m')
housing_numeric['GarageYrBlt'] = housing_numeric['GarageYrBlt'].fillna('1970') #903426160 and 910201180 do have a garage built, but an NA for all others, filled with mode
housing_numeric = housing_numeric.fillna(0)
years = housing_numeric[["YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd']].copy()
housing_numeric.to_pickle('housing_numeric.pkl')
housing_numeric
# Out:
#            PID  GrLivArea  SalePrice  LotFrontage  LotArea  MasVnrArea  \
# 1    909176150        856     126000          0.0     7890         0.0
# 2    905476230       1049     139500         42.0     4235       149.0
# 3    911128020       1001     124900         60.0     6060         0.0
# 4    535377150       1039     114000         80.0     8146         0.0
# 5    534177230       1665     227000         70.0     8400         0.0
# ..         ...        ...        ...          ...      ...         ...
# 759  903205040        952     121000          0.0     8854         0.0
# 760  905402060       1733     139600          0.0    13680         0.0
# 761  909275030       2002     145000         82.0     6270         0.0
# 762  907192040       1842     217500          0.0     8826       144.0
# 763  906223180       1911     215000         80.0     9554       125.0
#
#      BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 1         238.0         0.0      618.0        856.0       856         0
# 2         552.0       393.0      104.0       1049.0      1049         0
# 3         737.0         0.0      100.0        837.0      1001         0
# 4           0.0         0.0      405.0        405.0       717       322
# 5         643.0         0.0      167.0        810.0       810       855
# ..          ...         ...        ...          ...       ...       ...
# 759         0.0         0.0      952.0        952.0       952         0
# 760         0.0         0.0        0.0          0.0      1733         0
# 761       284.0         0.0      717.0       1001.0      1001      1001
# 762       841.0         0.0      144.0        985.0       985       857
# 763       380.0         0.0      397.0        777.0      1065       846
#
#      LowQualFinSF  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 1               0         1         0             2             1
# 2               0         2         0             2             1
# 3               0         1         0             2             1
# 4               0         1         0             2             1
# 5               0         2         1             3             1
# ..            ...       ...       ...           ...           ...
# 759             0         1         0             2             1
# 760             0         2         0             4             1
# 761             0         2         0             4             2
# 762             0         2         1             3             1
# 763             0         2         1             3             1
#
#      TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  WoodDeckSF  \
# 1               4           1         2.0       399.0           0
# 2               5           0         1.0       266.0           0
# 3               5           0         1.0       216.0         154
# 4               6           0         1.0       281.0           0
# 5               6           0         2.0       528.0           0
# ..            ...         ...         ...         ...         ...
# 759             4           1         1.0       192.0           0
# 760             8           1         2.0       452.0           0
# 761             8           0         3.0       871.0           0
# 762             7           1         2.0       486.0         193
# 763             8           1         2.0       471.0         182
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 1              0              0          0          166         0        0
# 2            105              0          0            0         0        0
# 3              0             42         86            0         0        0
# 4              0            168          0          111         0        0
# 5             45              0          0            0         0        0
# ..           ...            ...        ...          ...       ...      ...
# 759           98              0          0           40         0        0
# 760            0              0          0            0         0        0
# 761            0              0          0            0         0        0
# 762           96              0          0            0         0        0
# 763           81              0          0            0         0        0
#
#     YrSold GarageYrBlt MoSold YearBuilt YearRemodAdd
# 1     1970        1970     03      1970         1970
# 2     1970        1970     02      1970         1970
# 3     1970        1970     11      1970         1970
# 4     1970        1970     05      1970         1970
# 5     1970        1970     11      1970         1970
# ..     ...         ...    ...       ...          ...
# 759   1970        1970     05      1970         1970
# 760   1970        1970     06      1970         1970
# 761   1970        1970     08      1970         1970
# 762   1970        1970     07      1970         1970
# 763   1970        1970     09      1970         1970
#
# [2580 rows x 33 columns]

# %%
#Create seperate factor-set
housing_factor = housing.drop(['GrLivArea','SalePrice','LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                         '2ndFlrSF','LowQualFinSF','FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',  'GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal', "YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd'], axis=1)
housing_factor['PavedDrive'] = housing_factor.PavedDrive.apply(lambda Paved: 1 if Paved != "N" else 0)
housing_factor['CentralAir'] = housing_factor.CentralAir.apply(lambda Central: 1 if Central != "N" else 0) #Convert Y/N to Booleon 
housing_factor[['PID','MSSubClass','OverallQual','OverallCond','BsmtFullBath', 'BsmtHalfBath']] = housing_factor[['PID','MSSubClass','OverallQual','OverallCond','BsmtFullBath', 'BsmtHalfBath']].astype(str)
housing_factor[['PavedDrive','CentralAir']] = housing_factor[['PavedDrive','CentralAir']].astype('bool')
housing_factor #transform all integers into categorical variables
housing_factor.dtypes[housing_factor.dtypes == 'int64']
housing_factor
# Out:
#            PID MSSubClass MSZoning Street Alley LotShape LandContour  \
# 1    909176150         30       RL   Pave   NaN      Reg         Lvl
# 2    905476230        120       RL   Pave   NaN      Reg         Lvl
# 3    911128020         30  C (all)   Pave   NaN      Reg         Lvl
# 4    535377150         70       RL   Pave   NaN      Reg         Lvl
# 5    534177230         60       RL   Pave   NaN      Reg         Lvl
# ..         ...        ...      ...    ...   ...      ...         ...
# 759  903205040         30       RL   Pave   NaN      Reg         Lvl
# 760  905402060         20       RL   Pave   NaN      IR1         Lvl
# 761  909275030         90       RH   Pave   NaN      Reg         HLS
# 762  907192040         60       RL   Pave   NaN      Reg         Lvl
# 763  906223180         60       RL   Pave   NaN      IR1         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1      AllPub    Corner       Gtl        SWISU       Norm       Norm     1Fam
# 2      AllPub    Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 3      AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 4      AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 5      AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ..        ...       ...       ...          ...        ...        ...      ...
# 759    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 760    AllPub   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 761    AllPub    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 762    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 763    AllPub    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond RoofStyle RoofMatl Exterior1st  \
# 1       1Story           6           6     Gable  CompShg     Wd Sdng
# 2       1Story           5           5     Gable  CompShg     HdBoard
# 3       1Story           5           9       Hip  CompShg     MetalSd
# 4       2Story           4           8     Gable  CompShg     MetalSd
# 5       2Story           8           6     Gable  CompShg     VinylSd
# ..         ...         ...         ...       ...      ...         ...
# 759     1.5Unf           6           6     Gable  CompShg     Wd Sdng
# 760     1Story           3           5       Hip  CompShg     BrkFace
# 761     2Story           5           6     Gable  CompShg     MetalSd
# 762     2Story           7           5     Gable  CompShg     VinylSd
# 763     2Story           8           5     Gable  CompShg     VinylSd
#
#     Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1       Wd Sdng        NaN        TA        TA     CBlock       TA       TA
# 2       HdBoard    BrkFace        Gd        TA     CBlock       Gd       TA
# 3       MetalSd        NaN        Gd        TA     BrkTil       TA       TA
# 4       MetalSd        NaN        Gd        Gd     BrkTil       Fa       TA
# 5       VinylSd        NaN        Gd        TA      PConc       Gd       TA
# ..          ...        ...       ...       ...        ...      ...      ...
# 759     Wd Sdng        NaN        TA        TA     BrkTil       TA       TA
# 760     Wd Sdng        NaN        TA        TA       Slab      NaN      NaN
# 761     MetalSd        NaN        TA        TA     CBlock       TA       TA
# 762     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 763     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#     BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  CentralAir  \
# 1             No          Rec          Unf    GasA        TA        True
# 2             Mn          GLQ          ALQ    GasA        TA        True
# 3             No          ALQ          Unf    GasA        Ex        True
# 4             No          Unf          Unf    GasA        Gd        True
# 5             No          GLQ          Unf    GasA        Ex        True
# ..           ...          ...          ...     ...       ...         ...
# 759           No          Unf          Unf    Grav        Fa       False
# 760          NaN          NaN          NaN    GasA        Ex        True
# 761           No          BLQ          Unf    GasA        TA       False
# 762           No          GLQ          Unf    GasA        Ex        True
# 763           No          GLQ          Unf    GasA        Ex        True
#
#     Electrical BsmtFullBath BsmtHalfBath KitchenQual Functional FireplaceQu  \
# 1        SBrkr          1.0          0.0          TA        Typ          Gd
# 2        SBrkr          1.0          0.0          Gd        Typ         NaN
# 3        SBrkr          0.0          0.0          Gd        Typ         NaN
# 4        SBrkr          0.0          0.0          TA        Typ         NaN
# 5        SBrkr          1.0          0.0          Gd        Typ         NaN
# ..         ...          ...          ...         ...        ...         ...
# 759      FuseF          0.0          0.0          Fa        Typ          Gd
# 760      FuseA          0.0          0.0          TA       Min2          Gd
# 761      FuseA          0.0          0.0          TA        Typ         NaN
# 762      SBrkr          1.0          0.0          Gd        Typ          TA
# 763      SBrkr          0.0          0.0          Gd        Typ          TA
#
#     GarageType GarageFinish GarageQual GarageCond  PavedDrive PoolQC Fence  \
# 1       Detchd          Unf         TA         TA        True    NaN   NaN
# 2       Attchd          Fin         TA         TA        True    NaN   NaN
# 3       Detchd          Unf         TA         Po       False    NaN   NaN
# 4       Detchd          Unf         TA         TA       False    NaN   NaN
# 5       Attchd          Fin         TA         TA        True    NaN   NaN
# ..         ...          ...        ...        ...         ...    ...   ...
# 759     Detchd          Unf         Fa         Po        True    NaN   NaN
# 760     Attchd          Unf         TA         TA        True    NaN   NaN
# 761     2Types          Unf         TA         TA        True    NaN   NaN
# 762     Attchd          Fin         TA         TA        True    NaN   NaN
# 763     Attchd          RFn         TA         TA        True    NaN   NaN
#
#     MiscFeature SaleType SaleCondition
# 1           NaN      WD         Normal
# 2           NaN      WD         Normal
# 3           NaN      WD         Normal
# 4           NaN      WD         Normal
# 5           NaN      WD         Normal
# ..          ...      ...           ...
# 759         NaN      WD         Normal
# 760         NaN      WD         Normal
# 761         NaN      WD         Normal
# 762         NaN      WD         Normal
# 763         NaN      WD         Normal
#
# [2580 rows x 49 columns]

# %%
#Get rid of all NAs
housing_factor['MiscFeature'] = housing_factor['MiscFeature'].fillna('NoFeature')
housing_factor['PoolQC'] = housing_factor['PoolQC'].fillna('NoPool')
housing_factor['Fence'] = housing_factor['Fence'].fillna('NoFence')
housing_factor['GarageQual'] = housing_factor['GarageQual'].fillna('NoGarage')
housing_factor['GarageCond'] = housing_factor['GarageCond'].fillna('NoGarage')
housing_factor['GarageFinish'] = housing_factor['GarageFinish'].fillna('NoGarage')
housing_factor['GarageType'] = housing_factor['GarageType'].fillna('NoGarage')
housing_factor['FireplaceQu'] = housing_factor['FireplaceQu'].fillna('NoFireplace')
housing_factor['BsmtFinType2'] = housing_factor['BsmtFinType2'].fillna('NoBsmt') #528142130 has a basement, but NA for values
housing_factor['BsmtFinType1'] = housing_factor['BsmtFinType1'].fillna('NoBsmt')
housing_factor['BsmtExposure'] = housing_factor['BsmtExposure'].fillna('NoBsmt')
housing_factor['BsmtCond'] = housing_factor['BsmtCond'].fillna('NoBsmt')
housing_factor['BsmtQual'] = housing_factor['BsmtQual'].fillna('NoBsmt') #916386080 is missing an electrical value  veneer
housing_factor['MasVnrType'] = housing_factor['MasVnrType'].fillna('NoVeneer')
housing_factor['Alley'] = housing_factor['Alley'].fillna('NoAlley')

housing_factor.to_pickle('housing_factor.pkl')
housing_factor
# Out:
#            PID MSSubClass MSZoning Street    Alley LotShape LandContour  \
# 1    909176150         30       RL   Pave  NoAlley      Reg         Lvl
# 2    905476230        120       RL   Pave  NoAlley      Reg         Lvl
# 3    911128020         30  C (all)   Pave  NoAlley      Reg         Lvl
# 4    535377150         70       RL   Pave  NoAlley      Reg         Lvl
# 5    534177230         60       RL   Pave  NoAlley      Reg         Lvl
# ..         ...        ...      ...    ...      ...      ...         ...
# 759  903205040         30       RL   Pave  NoAlley      Reg         Lvl
# 760  905402060         20       RL   Pave  NoAlley      IR1         Lvl
# 761  909275030         90       RH   Pave  NoAlley      Reg         HLS
# 762  907192040         60       RL   Pave  NoAlley      Reg         Lvl
# 763  906223180         60       RL   Pave  NoAlley      IR1         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1      AllPub    Corner       Gtl        SWISU       Norm       Norm     1Fam
# 2      AllPub    Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 3      AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 4      AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 5      AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ..        ...       ...       ...          ...        ...        ...      ...
# 759    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 760    AllPub   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 761    AllPub    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 762    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 763    AllPub    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond RoofStyle RoofMatl Exterior1st  \
# 1       1Story           6           6     Gable  CompShg     Wd Sdng
# 2       1Story           5           5     Gable  CompShg     HdBoard
# 3       1Story           5           9       Hip  CompShg     MetalSd
# 4       2Story           4           8     Gable  CompShg     MetalSd
# 5       2Story           8           6     Gable  CompShg     VinylSd
# ..         ...         ...         ...       ...      ...         ...
# 759     1.5Unf           6           6     Gable  CompShg     Wd Sdng
# 760     1Story           3           5       Hip  CompShg     BrkFace
# 761     2Story           5           6     Gable  CompShg     MetalSd
# 762     2Story           7           5     Gable  CompShg     VinylSd
# 763     2Story           8           5     Gable  CompShg     VinylSd
#
#     Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1       Wd Sdng   NoVeneer        TA        TA     CBlock       TA       TA
# 2       HdBoard    BrkFace        Gd        TA     CBlock       Gd       TA
# 3       MetalSd   NoVeneer        Gd        TA     BrkTil       TA       TA
# 4       MetalSd   NoVeneer        Gd        Gd     BrkTil       Fa       TA
# 5       VinylSd   NoVeneer        Gd        TA      PConc       Gd       TA
# ..          ...        ...       ...       ...        ...      ...      ...
# 759     Wd Sdng   NoVeneer        TA        TA     BrkTil       TA       TA
# 760     Wd Sdng   NoVeneer        TA        TA       Slab   NoBsmt   NoBsmt
# 761     MetalSd   NoVeneer        TA        TA     CBlock       TA       TA
# 762     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 763     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#     BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  CentralAir  \
# 1             No          Rec          Unf    GasA        TA        True
# 2             Mn          GLQ          ALQ    GasA        TA        True
# 3             No          ALQ          Unf    GasA        Ex        True
# 4             No          Unf          Unf    GasA        Gd        True
# 5             No          GLQ          Unf    GasA        Ex        True
# ..           ...          ...          ...     ...       ...         ...
# 759           No          Unf          Unf    Grav        Fa       False
# 760       NoBsmt       NoBsmt       NoBsmt    GasA        Ex        True
# 761           No          BLQ          Unf    GasA        TA       False
# 762           No          GLQ          Unf    GasA        Ex        True
# 763           No          GLQ          Unf    GasA        Ex        True
#
#     Electrical BsmtFullBath BsmtHalfBath KitchenQual Functional  FireplaceQu  \
# 1        SBrkr          1.0          0.0          TA        Typ           Gd
# 2        SBrkr          1.0          0.0          Gd        Typ  NoFireplace
# 3        SBrkr          0.0          0.0          Gd        Typ  NoFireplace
# 4        SBrkr          0.0          0.0          TA        Typ  NoFireplace
# 5        SBrkr          1.0          0.0          Gd        Typ  NoFireplace
# ..         ...          ...          ...         ...        ...          ...
# 759      FuseF          0.0          0.0          Fa        Typ           Gd
# 760      FuseA          0.0          0.0          TA       Min2           Gd
# 761      FuseA          0.0          0.0          TA        Typ  NoFireplace
# 762      SBrkr          1.0          0.0          Gd        Typ           TA
# 763      SBrkr          0.0          0.0          Gd        Typ           TA
#
#     GarageType GarageFinish GarageQual GarageCond  PavedDrive  PoolQC  \
# 1       Detchd          Unf         TA         TA        True  NoPool
# 2       Attchd          Fin         TA         TA        True  NoPool
# 3       Detchd          Unf         TA         Po       False  NoPool
# 4       Detchd          Unf         TA         TA       False  NoPool
# 5       Attchd          Fin         TA         TA        True  NoPool
# ..         ...          ...        ...        ...         ...     ...
# 759     Detchd          Unf         Fa         Po        True  NoPool
# 760     Attchd          Unf         TA         TA        True  NoPool
# 761     2Types          Unf         TA         TA        True  NoPool
# 762     Attchd          Fin         TA         TA        True  NoPool
# 763     Attchd          RFn         TA         TA        True  NoPool
#
#        Fence MiscFeature SaleType SaleCondition
# 1    NoFence   NoFeature      WD         Normal
# 2    NoFence   NoFeature      WD         Normal
# 3    NoFence   NoFeature      WD         Normal
# 4    NoFence   NoFeature      WD         Normal
# 5    NoFence   NoFeature      WD         Normal
# ..       ...         ...      ...           ...
# 759  NoFence   NoFeature      WD         Normal
# 760  NoFence   NoFeature      WD         Normal
# 761  NoFence   NoFeature      WD         Normal
# 762  NoFence   NoFeature      WD         Normal
# 763  NoFence   NoFeature      WD         Normal
#
# [2580 rows x 49 columns]

# %%
from sklearn.preprocessing import LabelEncoder
SalePrice = housing['SalePrice'] #This is the target
housing_factor_dummified1 = housing_factor.drop(['PID'], axis=1)
label_encoder = LabelEncoder()
#housing_factor_dummified1[['MSZoning','Street','Alley',
#'LotShape','LandContour',
#'Utilities','LotConfig','LandSlope','Neighborhood',
#'Condition1','Condition2','BldgType','HouseStyle',
#'RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
#'MasVnrType','ExterQual','ExterCond','Foundation',
#'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
#'BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual',
#'Functional','FireplaceQu','GarageType','GarageFinish',
#'GarageQual','GarageCond','PoolQC','Fence','MiscFeature',
#'SaleType','SaleCondition']] = label_encoder.fit_transform(housing_factor_dummified1[['MSZoning','Street','Alley',
#'LotShape','LandContour',
#'Utilities','LotConfig','LandSlope','Neighborhood',
#'Condition1','Condition2','BldgType','HouseStyle',
#'RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
#'MasVnrType','ExterQual','ExterCond','Foundation',
#'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
#'BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual',
#'Functional','FireplaceQu','GarageType','GarageFinish',
#'GarageQual','GarageCond','PoolQC','Fence','MiscFeature',
#'SaleType','SaleCondition']])

housing_factor_dummified1= housing_factor_dummified1.apply(label_encoder.fit_transform)

housing_factor_dummified1 = pd.get_dummies(housing_factor_dummified1, drop_first = True)
housing_factor_dummified1
# Out:
#      MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 1             6         5       1      1         3            3          0
# 2             0         5       1      1         3            3          0
# 3             6         1       1      1         3            3          0
# 4            11         5       1      1         3            3          0
# 5            10         5       1      1         3            3          0
# ..          ...       ...     ...    ...       ...          ...        ...
# 759           6         5       1      1         3            3          0
# 760           5         5       1      1         0            3          0
# 761          15         4       1      1         3            1          0
# 762          10         5       1      1         3            3          0
# 763          10         5       1      1         0            3          0
#
#      LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 1            0          0            21           2           2         0
# 2            4          0             7           2           2         4
# 3            4          0            11           2           2         0
# 4            0          0            20           2           2         0
# 5            4          0            17           2           2         0
# ..         ...        ...           ...         ...         ...       ...
# 759          4          0             3           2           2         0
# 760          1          0             7           2           2         0
# 761          4          0             6           2           2         2
# 762          4          0             5           2           2         0
# 763          4          0            23           2           2         0
#
#      HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  Exterior1st  \
# 1             2            6            5          1         0           13
# 2             2            5            4          1         0            6
# 3             2            5            8          3         0            8
# 4             5            4            7          1         0            8
# 5             5            8            5          1         0           12
# ..          ...          ...          ...        ...       ...          ...
# 759           1            6            5          1         0           13
# 760           2            3            4          3         0            3
# 761           5            5            5          1         0            8
# 762           5            7            4          1         0           12
# 763           5            8            4          1         0           12
#
#      Exterior2nd  MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  \
# 1             14           2          3          4           1         5
# 2              6           1          2          4           1         2
# 3              8           2          2          4           0         5
# 4              8           2          2          2           0         1
# 5             13           2          2          4           2         2
# ..           ...         ...        ...        ...         ...       ...
# 759           14           2          3          4           0         5
# 760           14           2          3          4           3         3
# 761            8           2          3          4           1         5
# 762           13           1          2          4           2         2
# 763           13           1          2          4           2         2
#
#      BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  HeatingQC  \
# 1           5             3             5             6        1          4
# 2           5             2             2             0        1          4
# 3           5             3             0             6        1          0
# 4           5             3             6             6        1          2
# 5           5             3             2             6        1          0
# ..        ...           ...           ...           ...      ...        ...
# 759         5             3             6             6        3          1
# 760         3             4             4             4        1          0
# 761         5             3             1             6        1          4
# 762         5             3             2             6        1          0
# 763         5             3             2             6        1          0
#
#      CentralAir  Electrical  BsmtFullBath  BsmtHalfBath  KitchenQual  \
# 1             1           3             1             0            4
# 2             1           3             1             0            2
# 3             1           3             0             0            2
# 4             1           3             0             0            4
# 5             1           3             1             0            2
# ..          ...         ...           ...           ...          ...
# 759           0           1             0             0            1
# 760           1           0             0             0            4
# 761           0           0             0             0            4
# 762           1           3             1             0            2
# 763           1           3             0             0            2
#
#      Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 1             6            2           5             3           5
# 2             6            3           1             0           5
# 3             6            3           5             3           5
# 4             6            3           5             3           5
# 5             6            3           1             0           5
# ..          ...          ...         ...           ...         ...
# 759           6            2           5             3           1
# 760           3            2           1             3           5
# 761           6            3           0             3           5
# 762           6            5           1             0           5
# 763           6            5           1             2           5
#
#      GarageCond  PavedDrive  PoolQC  Fence  MiscFeature  SaleType  \
# 1             5           1       3      4            1         9
# 2             5           1       3      4            1         9
# 3             4           0       3      4            1         9
# 4             5           0       3      4            1         9
# 5             5           1       3      4            1         9
# ..          ...         ...     ...    ...          ...       ...
# 759           4           1       3      4            1         9
# 760           5           1       3      4            1         9
# 761           5           1       3      4            1         9
# 762           5           1       3      4            1         9
# 763           5           1       3      4            1         9
#
#      SaleCondition
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# ..             ...
# 759              4
# 760              4
# 761              4
# 762              4
# 763              4
#
# [2580 rows x 48 columns]

# %%
pd.set_option('display.max_rows', 500)
#housing_numeric = pd.concat([housing_numeric, years], axis=1)
housing_numeric.to_pickle('housing_numeric.pkl')
housing_factor_dummified1 = pd.concat([housing_numeric, housing_factor_dummified1], axis=1)
#housing_factor_dummified1 = pd.concat([housing_factor_dummified1,housing_factor[["YrSold",'GarageYrBlt','MoSold','PavedDrive','YearBuilt', 'YearRemodAdd', 'CentralAir']]], axis = 1)
housing_factor_dummified1
# Out:
#            PID  GrLivArea  SalePrice  LotFrontage  LotArea  MasVnrArea  \
# 1    909176150        856     126000          0.0     7890         0.0
# 2    905476230       1049     139500         42.0     4235       149.0
# 3    911128020       1001     124900         60.0     6060         0.0
# 4    535377150       1039     114000         80.0     8146         0.0
# 5    534177230       1665     227000         70.0     8400         0.0
# ..         ...        ...        ...          ...      ...         ...
# 759  903205040        952     121000          0.0     8854         0.0
# 760  905402060       1733     139600          0.0    13680         0.0
# 761  909275030       2002     145000         82.0     6270         0.0
# 762  907192040       1842     217500          0.0     8826       144.0
# 763  906223180       1911     215000         80.0     9554       125.0
#
#      BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 1         238.0         0.0      618.0        856.0       856         0
# 2         552.0       393.0      104.0       1049.0      1049         0
# 3         737.0         0.0      100.0        837.0      1001         0
# 4           0.0         0.0      405.0        405.0       717       322
# 5         643.0         0.0      167.0        810.0       810       855
# ..          ...         ...        ...          ...       ...       ...
# 759         0.0         0.0      952.0        952.0       952         0
# 760         0.0         0.0        0.0          0.0      1733         0
# 761       284.0         0.0      717.0       1001.0      1001      1001
# 762       841.0         0.0      144.0        985.0       985       857
# 763       380.0         0.0      397.0        777.0      1065       846
#
#      LowQualFinSF  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 1               0         1         0             2             1
# 2               0         2         0             2             1
# 3               0         1         0             2             1
# 4               0         1         0             2             1
# 5               0         2         1             3             1
# ..            ...       ...       ...           ...           ...
# 759             0         1         0             2             1
# 760             0         2         0             4             1
# 761             0         2         0             4             2
# 762             0         2         1             3             1
# 763             0         2         1             3             1
#
#      TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  WoodDeckSF  \
# 1               4           1         2.0       399.0           0
# 2               5           0         1.0       266.0           0
# 3               5           0         1.0       216.0         154
# 4               6           0         1.0       281.0           0
# 5               6           0         2.0       528.0           0
# ..            ...         ...         ...         ...         ...
# 759             4           1         1.0       192.0           0
# 760             8           1         2.0       452.0           0
# 761             8           0         3.0       871.0           0
# 762             7           1         2.0       486.0         193
# 763             8           1         2.0       471.0         182
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 1              0              0          0          166         0        0
# 2            105              0          0            0         0        0
# 3              0             42         86            0         0        0
# 4              0            168          0          111         0        0
# 5             45              0          0            0         0        0
# ..           ...            ...        ...          ...       ...      ...
# 759           98              0          0           40         0        0
# 760            0              0          0            0         0        0
# 761            0              0          0            0         0        0
# 762           96              0          0            0         0        0
# 763           81              0          0            0         0        0
#
#     YrSold GarageYrBlt MoSold YearBuilt YearRemodAdd  MSSubClass  MSZoning  \
# 1     1970        1970     03      1970         1970           6         5
# 2     1970        1970     02      1970         1970           0         5
# 3     1970        1970     11      1970         1970           6         1
# 4     1970        1970     05      1970         1970          11         5
# 5     1970        1970     11      1970         1970          10         5
# ..     ...         ...    ...       ...          ...         ...       ...
# 759   1970        1970     05      1970         1970           6         5
# 760   1970        1970     06      1970         1970           5         5
# 761   1970        1970     08      1970         1970          15         4
# 762   1970        1970     07      1970         1970          10         5
# 763   1970        1970     09      1970         1970          10         5
#
#      Street  Alley  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 1         1      1         3            3          0          0          0
# 2         1      1         3            3          0          4          0
# 3         1      1         3            3          0          4          0
# 4         1      1         3            3          0          0          0
# 5         1      1         3            3          0          4          0
# ..      ...    ...       ...          ...        ...        ...        ...
# 759       1      1         3            3          0          4          0
# 760       1      1         0            3          0          1          0
# 761       1      1         3            1          0          4          0
# 762       1      1         3            3          0          4          0
# 763       1      1         0            3          0          4          0
#
#      Neighborhood  Condition1  Condition2  BldgType  HouseStyle  OverallQual  \
# 1              21           2           2         0           2            6
# 2               7           2           2         4           2            5
# 3              11           2           2         0           2            5
# 4              20           2           2         0           5            4
# 5              17           2           2         0           5            8
# ..            ...         ...         ...       ...         ...          ...
# 759             3           2           2         0           1            6
# 760             7           2           2         0           2            3
# 761             6           2           2         2           5            5
# 762             5           2           2         0           5            7
# 763            23           2           2         0           5            8
#
#      OverallCond  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  \
# 1              5          1         0           13           14           2
# 2              4          1         0            6            6           1
# 3              8          3         0            8            8           2
# 4              7          1         0            8            8           2
# 5              5          1         0           12           13           2
# ..           ...        ...       ...          ...          ...         ...
# 759            5          1         0           13           14           2
# 760            4          3         0            3           14           2
# 761            5          1         0            8            8           2
# 762            4          1         0           12           13           1
# 763            4          1         0           12           13           1
#
#      ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  \
# 1            3          4           1         5         5             3
# 2            2          4           1         2         5             2
# 3            2          4           0         5         5             3
# 4            2          2           0         1         5             3
# 5            2          4           2         2         5             3
# ..         ...        ...         ...       ...       ...           ...
# 759          3          4           0         5         5             3
# 760          3          4           3         3         3             4
# 761          3          4           1         5         5             3
# 762          2          4           2         2         5             3
# 763          2          4           2         2         5             3
#
#      BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  Electrical  \
# 1               5             6        1          4           1           3
# 2               2             0        1          4           1           3
# 3               0             6        1          0           1           3
# 4               6             6        1          2           1           3
# 5               2             6        1          0           1           3
# ..            ...           ...      ...        ...         ...         ...
# 759             6             6        3          1           0           1
# 760             4             4        1          0           1           0
# 761             1             6        1          4           0           0
# 762             2             6        1          0           1           3
# 763             2             6        1          0           1           3
#
#      BsmtFullBath  BsmtHalfBath  KitchenQual  Functional  FireplaceQu  \
# 1               1             0            4           6            2
# 2               1             0            2           6            3
# 3               0             0            2           6            3
# 4               0             0            4           6            3
# 5               1             0            2           6            3
# ..            ...           ...          ...         ...          ...
# 759             0             0            1           6            2
# 760             0             0            4           3            2
# 761             0             0            4           6            3
# 762             1             0            2           6            5
# 763             0             0            2           6            5
#
#      GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  \
# 1             5             3           5           5           1       3
# 2             1             0           5           5           1       3
# 3             5             3           5           4           0       3
# 4             5             3           5           5           0       3
# 5             1             0           5           5           1       3
# ..          ...           ...         ...         ...         ...     ...
# 759           5             3           1           4           1       3
# 760           1             3           5           5           1       3
# 761           0             3           5           5           1       3
# 762           1             0           5           5           1       3
# 763           1             2           5           5           1       3
#
#      Fence  MiscFeature  SaleType  SaleCondition
# 1        4            1         9              4
# 2        4            1         9              4
# 3        4            1         9              4
# 4        4            1         9              4
# 5        4            1         9              4
# ..     ...          ...       ...            ...
# 759      4            1         9              4
# 760      4            1         9              4
# 761      4            1         9              4
# 762      4            1         9              4
# 763      4            1         9              4
#
# [2580 rows x 81 columns]

# %%
from sklearn.linear_model import LinearRegression
housing_factor_dummified1 = housing_factor_dummified1.drop(['PID'], axis=1)
lm = LinearRegression()
lm.fit(housing_factor_dummified1, housing['SalePrice'])
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
residuals = SalePrice - lm.predict(housing_factor_dummified1)
plt.hist(residuals)
# Out:
# (array([  3.,   3.,   3.,  13.,  55., 144., 345., 935., 968., 111.]),
#  array([-9.31322575e-10, -8.10541678e-10, -6.89760782e-10, -5.68979885e-10,
#         -4.48198989e-10, -3.27418093e-10, -2.06637196e-10, -8.58562998e-11,
#          3.49245965e-11,  1.55705493e-10,  2.76486389e-10]),
#  <BarContainer object of 10 artists>)

# %%
print('R^2 is equal to %.3f' %(lm.score(housing_factor_dummified1,SalePrice))) #By default, score gives R^2. 
print('RSS is equal to %.3f' %(np.sum(residuals**2)))
print('The intercept is %.3f' %(lm.intercept_))
print('The slopes are %s' %(lm.coef_))
# Out:
# R^2 is equal to 1.000
# RSS is equal to 0.000
# The intercept is -0.000
# The slopes are [ 5.12149074e-14  1.00000000e+00 -2.95666269e-14 -1.31838984e-16
#   2.83280344e-15  2.59306465e-14  7.72054946e-15 -7.42223123e-15
#   2.62282600e-14  3.29467898e-14  5.29958022e-15  1.29381098e-14
#  -1.33422195e-12  9.51408207e-13  1.89593255e-13  9.51071671e-13
#   1.65599241e-13 -7.65241187e-13 -1.92034572e-12  1.04896560e-14
#   9.12356128e-17 -1.11260285e-14  3.33652377e-15 -1.13929692e-14
#  -3.35450932e-14 -2.29138675e-15 -6.21329160e-15 -4.23516474e-21
#   4.02340650e-21  4.19862062e-13 -6.77626358e-21  8.47032947e-22
#  -4.04516000e-14  1.67412269e-13 -4.66076357e-12  1.74771386e-13
#  -1.03693022e-12 -3.85148465e-14 -1.23934785e-12  7.90983162e-13
#  -1.49546588e-12 -5.64396992e-14 -4.82335386e-14 -1.12105459e-12
#  -1.13949984e-13  9.22179229e-14  2.61090352e-13 -8.93222649e-14
#   4.70112198e-13  2.72432461e-13  4.49760570e-14 -1.04296483e-13
#   1.11702427e-12  2.30435761e-12 -5.16100471e-13  6.86828745e-13
#  -6.69633111e-14 -2.37532246e-13 -3.01914414e-13 -4.36360955e-13
#   1.29796790e-12  3.01074829e-13 -9.48992910e-13 -4.46534319e-13
#  -7.63780187e-13 -3.08969763e-12 -1.46643014e-13 -5.82403405e-14
#  -2.52960181e-14  4.74271688e-13 -3.66935762e-13  4.23259089e-13
#  -5.39431348e-13 -1.87784928e-13 -1.34451331e-12  5.26314752e-13
#  -7.13098088e-13  3.16912752e-13 -1.21980657e-13 -4.46941780e-13]

# %%
print('negative slope column names %s' %(housing_factor_dummified1.columns[lm.coef_ < 0]))
print('positive slope column names %s' %(housing_factor_dummified1.columns[lm.coef_ > 0]))
# Out:
# negative slope column names Index(['LotFrontage', 'LotArea', 'BsmtUnfSF', 'FullBath', 'Fireplaces',
#        'GarageCars', 'OpenPorchSF', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'YrSold', 'YearBuilt', 'MSSubClass', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'OverallCond', 'Exterior2nd', 'ExterCond',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'HeatingQC',
#        'CentralAir', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath',
#        'KitchenQual', 'Functional', 'GarageType', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object')
# positive slope column names Index(['GrLivArea', 'SalePrice', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea',
#        'WoodDeckSF', 'EnclosedPorch', 'GarageYrBlt', 'MoSold', 'YearRemodAdd',
#        'MSZoning', 'Alley', 'LotConfig', 'HouseStyle', 'OverallQual',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'MasVnrType', 'ExterQual',
#        'Foundation', 'BsmtFinType2', 'Heating', 'FireplaceQu', 'GarageFinish',
#        'PoolQC', 'MiscFeature'],
#       dtype='object')

# %%
log_SalePrice = np.log(SalePrice) #Take log of DV
lm.fit(housing_factor_dummified1, log_SalePrice) #LM of log of DV
residuals = log_SalePrice - lm.predict(housing_factor_dummified1)
plt.hist(residuals)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 5.000e+00, 1.000e+01,
#         1.130e+02, 1.891e+03, 5.490e+02, 1.000e+01]),
#  array([-1.28794271, -1.12146799, -0.95499327, -0.78851854, -0.62204382,
#         -0.4555691 , -0.28909438, -0.12261966,  0.04385507,  0.21032979,
#          0.37680451]),
#  <BarContainer object of 10 artists>)

# %%
print('R^2 is equal to %.3f' %(lm.score(housing_factor_dummified1,log_SalePrice))) #By default, score gives R^2. 
print('RSS is equal to %.3f' %(np.sum(residuals**2)))
print('The intercept is %.3f' %(lm.intercept_))
print('The slopes are %s' %(lm.coef_))
# Out:
# R^2 is equal to 0.958
# RSS is equal to 16.165
# The intercept is 10.371
# The slopes are [ 2.85610733e-05  3.55765215e-06 -4.24132045e-05  4.78470888e-07
#  -9.38330913e-05  3.40798594e-06  1.94961345e-05  1.04484425e-05
#   3.33525630e-05  3.48696087e-05  7.74379986e-06 -1.40523353e-05
#   2.85112057e-02  1.53904795e-02  6.74948367e-03 -1.65614805e-02
#   2.75584936e-03  7.44446569e-03  2.07222639e-02 -2.46161857e-05
#   1.74102082e-06  2.44844228e-05  5.83395264e-05  7.49401490e-05
#   8.38300518e-05  4.88584407e-05  8.47924990e-07  1.14491749e-16
#  -1.76291273e-16 -1.38272513e-04  1.17961196e-16  5.20417043e-17
#   2.39550856e-03 -1.09400932e-02  5.94178649e-02  1.81388368e-02
#  -2.21865017e-03  2.28592392e-03 -4.26272995e-02  1.85813387e-04
#   1.10102335e-02 -4.96661963e-04  1.65752393e-03 -1.00878600e-02
#   2.26610966e-03 -1.19117044e-04  3.23532306e-02  2.35306536e-02
#  -3.53703193e-03 -4.07793829e-04  5.90938309e-06  2.29751007e-03
#  -7.15886911e-03  1.26186571e-02  7.82972054e-03  1.09715552e-02
#   1.61632333e-03  1.35844441e-03 -3.04541716e-03 -4.46658022e-03
#   1.55749318e-03  8.57784062e-03 -5.62575087e-03  8.16630321e-02
#   6.78453357e-03  1.26139699e-02 -9.07178703e-04 -7.19801867e-04
#   2.35900444e-03  3.07792888e-03 -7.99913254e-03 -3.52724896e-04
#   4.61728206e-03  1.26118119e-02  5.44080768e-02  2.17292085e-02
#   1.45834193e-04 -3.82516869e-03  2.30040046e-03  1.72128608e-02]

# %%
scores = {}
for idx, name1 in enumerate(housing_factor_dummified1.columns):
        myColumns = housing_factor_dummified1.columns[(idx+1):]
        pass

# %%
from itertools import combinations 

scores = {}

combos = combinations(housing_factor_dummified1.columns, 3)

for c in combos:
    X = housing_factor_dummified1[list(c)]
    Y = log_SalePrice
    reg = LinearRegression().fit(X,Y)
    scores[c] = reg.score (X,Y)

# %%
sorted(scores.items(), key=lambda features_score: abs(features_score [1]), reverse = True)
# Out:
# [(('SalePrice', 'OverallQual', 'CentralAir'), 0.9335139587093141),
#  (('SalePrice', 'OverallQual', 'PavedDrive'), 0.9307352599242298),
#  (('SalePrice', 'OverallQual', 'GarageType'), 0.9299464898459083),
#  (('SalePrice', 'OverallQual', 'GarageCond'), 0.9298411132584817),
#  (('SalePrice', 'OverallQual', 'GarageQual'), 0.928336879056669),
#  (('SalePrice', 'OverallQual', 'ExterQual'), 0.9269506262461966),
#  (('SalePrice', 'BedroomAbvGr', 'OverallQual'), 0.9265768921309104),
#  (('SalePrice', 'GarageCars', 'OverallQual'), 0.9261280415016706),
#  (('SalePrice', 'OverallQual', 'OverallCond'), 0.9259767470985246),
#  (('SalePrice', 'OverallQual', 'Electrical'), 0.9257922076690069),
#  (('SalePrice', 'OverallQual', 'BsmtFinType1'), 0.9257661555242438),
#  (('SalePrice', 'FullBath', 'OverallQual'), 0.9257446506807475),
#  (('GrLivArea', 'SalePrice', 'OverallQual'), 0.9257284408135782),
#  (('SalePrice', 'GarageArea', 'OverallQual'), 0.9251465920016113),
#  (('SalePrice', 'TotRmsAbvGrd', 'OverallQual'), 0.9251103023362839),
#  (('SalePrice', 'OverallQual', 'FireplaceQu'), 0.9249817793183956),
#  (('SalePrice', 'MasVnrArea', 'OverallQual'), 0.9249045404792209),
#  (('SalePrice', 'OverallQual', 'BsmtCond'), 0.9247054800688006),
#  (('SalePrice', 'Fireplaces', 'OverallQual'), 0.9245946348030294),
#  (('SalePrice', 'MSSubClass', 'OverallQual'), 0.924476946133351),
#  (('SalePrice', 'OverallQual', 'KitchenQual'), 0.9244531202747281),
#  (('SalePrice', '1stFlrSF', 'OverallQual'), 0.9243334210325969),
#  (('SalePrice', 'HouseStyle', 'OverallQual'), 0.9243069778177165),
#  (('SalePrice', 'HalfBath', 'OverallQual'), 0.9243031396430663),
#  (('SalePrice', 'OverallQual', 'SaleCondition'), 0.9242939604099306),
#  (('SalePrice', 'LotShape', 'OverallQual'), 0.9241453696782453),
#  (('SalePrice', 'OverallQual', 'BsmtQual'), 0.9241271355677704),
#  (('SalePrice', 'TotalBsmtSF', 'OverallQual'), 0.924071208313405),
#  (('SalePrice', 'OverallQual', 'SaleType'), 0.9240421354871892),
#  (('SalePrice', 'OverallQual', 'Foundation'), 0.9240409380703345),
#  (('SalePrice', 'LotArea', 'OverallQual'), 0.9240317787781609),
#  (('SalePrice', 'Alley', 'OverallQual'), 0.9240254861450932),
#  (('SalePrice', 'OverallQual', 'Heating'), 0.9239479845152789),
#  (('SalePrice', 'OverallQual', 'RoofStyle'), 0.9239208617267758),
#  (('SalePrice', 'OverallQual', 'HeatingQC'), 0.9239046879962327),
#  (('SalePrice', 'OverallQual', 'MasVnrType'), 0.9238609054338216),
#  (('SalePrice', '2ndFlrSF', 'OverallQual'), 0.9238321575611667),
#  (('SalePrice', 'WoodDeckSF', 'OverallQual'), 0.9238175815888796),
#  (('SalePrice', 'OverallQual', 'ExterCond'), 0.9237903111121799),
#  (('SalePrice', 'BldgType', 'OverallQual'), 0.9237772091009968),
#  (('SalePrice', 'ScreenPorch', 'OverallQual'), 0.9237735863411793),
#  (('SalePrice', 'OverallQual', 'BsmtFullBath'), 0.9237701590301366),
#  (('SalePrice', 'BsmtFinSF1', 'OverallQual'), 0.9237602706506867),
#  (('SalePrice', 'BsmtFinSF2', 'OverallQual'), 0.9237537905603309),
#  (('SalePrice', 'MSZoning', 'OverallQual'), 0.923750663174368),
#  (('SalePrice', 'Street', 'OverallQual'), 0.9237300652849173),
#  (('SalePrice', 'LandContour', 'OverallQual'), 0.9237037828801556),
#  (('SalePrice', 'Utilities', 'OverallQual'), 0.9237034211387933),
#  (('SalePrice', 'Condition1', 'OverallQual'), 0.9236924267954931),
#  (('SalePrice', 'OpenPorchSF', 'OverallQual'), 0.923691430930265),
#  (('SalePrice', 'EnclosedPorch', 'OverallQual'), 0.9236838473439937),
#  (('SalePrice', 'OverallQual', 'Fence'), 0.9236795419658641),
#  (('SalePrice', 'Neighborhood', 'OverallQual'), 0.9236486719784892),
#  (('SalePrice', 'OverallQual', 'BsmtHalfBath'), 0.9236466501135556),
#  (('SalePrice', 'OverallQual', 'MiscFeature'), 0.9236186051401546),
#  (('SalePrice', 'LotFrontage', 'OverallQual'), 0.9236060741749977),
#  (('SalePrice', 'OverallQual', 'PoolQC'), 0.9235956558141334),
#  (('SalePrice', 'OverallQual', 'BsmtFinType2'), 0.9235679591531516),
#  (('SalePrice', 'OverallQual', 'Exterior1st'), 0.9235502481696303),
#  (('SalePrice', 'OverallQual', 'Exterior2nd'), 0.9235487710829631),
#  (('SalePrice', 'PoolArea', 'OverallQual'), 0.923548312725873),
#  (('SalePrice', '3SsnPorch', 'OverallQual'), 0.9235393312337649),
#  (('SalePrice', 'OverallQual', 'BsmtExposure'), 0.9235343782644281),
#  (('SalePrice', 'MiscVal', 'OverallQual'), 0.923513369848277),
#  (('SalePrice', 'Condition2', 'OverallQual'), 0.9234993239453791),
#  (('SalePrice', 'MoSold', 'OverallQual'), 0.9234976649463634),
#  (('SalePrice', 'LotConfig', 'OverallQual'), 0.9234966517045311),
#  (('SalePrice', 'BsmtUnfSF', 'OverallQual'), 0.9234920988919398),
#  (('SalePrice', 'LandSlope', 'OverallQual'), 0.9234909331274632),
#  (('SalePrice', 'OverallQual', 'Functional'), 0.9234866173509633),
#  (('SalePrice', 'OverallQual', 'GarageFinish'), 0.9234811454949101),
#  (('SalePrice', 'KitchenAbvGr', 'OverallQual'), 0.9234801582145873),
#  (('SalePrice', 'LowQualFinSF', 'OverallQual'), 0.9234790394574252),
#  (('SalePrice', 'OverallQual', 'RoofMatl'), 0.9234790376679257),
#  (('SalePrice', 'YrSold', 'OverallQual'), 0.9234788592804296),
#  (('SalePrice', 'GarageYrBlt', 'OverallQual'), 0.9234788592804296),
#  (('SalePrice', 'YearBuilt', 'OverallQual'), 0.9234788592804296),
#  (('SalePrice', 'YearRemodAdd', 'OverallQual'), 0.9234788592804296),
#  (('SalePrice', 'CentralAir', 'GarageType'), 0.9230333697828177),
#  (('SalePrice', 'FullBath', 'CentralAir'), 0.9229990242919022),
#  (('SalePrice', 'CentralAir', 'GarageCond'), 0.9216405297310728),
#  (('SalePrice', 'CentralAir', 'PavedDrive'), 0.92156464573931),
#  (('SalePrice', 'GarageCars', 'CentralAir'), 0.9207701313761979),
#  (('GrLivArea', 'SalePrice', 'CentralAir'), 0.9204641005042679),
#  (('SalePrice', 'CentralAir', 'GarageQual'), 0.9203642514105792),
#  (('SalePrice', 'GarageType', 'PavedDrive'), 0.9198042184297456),
#  (('SalePrice', 'BedroomAbvGr', 'CentralAir'), 0.9196214911206739),
#  (('SalePrice', 'TotRmsAbvGrd', 'CentralAir'), 0.9193072325153783),
#  (('SalePrice', 'FullBath', 'PavedDrive'), 0.9191826470968374),
#  (('SalePrice', 'Foundation', 'CentralAir'), 0.9185355037536651),
#  (('SalePrice', 'MasVnrArea', 'CentralAir'), 0.9185196050736886),
#  (('SalePrice', 'GarageType', 'GarageCond'), 0.9185153751515301),
#  (('SalePrice', 'HouseStyle', 'CentralAir'), 0.9184871784928812),
#  (('SalePrice', 'GarageArea', 'CentralAir'), 0.9184204759863089),
#  (('SalePrice', 'CentralAir', 'FireplaceQu'), 0.9183035790854749),
#  (('SalePrice', 'FullBath', 'GarageType'), 0.9182624746525189),
#  (('SalePrice', '2ndFlrSF', 'CentralAir'), 0.9181578469050032),
#  (('SalePrice', 'FullBath', 'GarageCond'), 0.918133097764224),
#  (('SalePrice', 'HeatingQC', 'CentralAir'), 0.9180591635136863),
#  (('SalePrice', 'CentralAir', 'Electrical'), 0.9180565621165107),
#  (('SalePrice', 'Fireplaces', 'CentralAir'), 0.9180353988677362),
#  (('SalePrice', 'GarageCond', 'PavedDrive'), 0.918004052236941),
#  (('SalePrice', 'LotShape', 'CentralAir'), 0.9179229982019476),
#  (('SalePrice', 'ExterQual', 'CentralAir'), 0.9177630536370973),
#  (('SalePrice', 'Exterior1st', 'CentralAir'), 0.9177165370286717),
#  (('SalePrice', 'MSSubClass', 'CentralAir'), 0.9177083550160415),
#  (('SalePrice', 'HalfBath', 'CentralAir'), 0.9177066383921122),
#  (('SalePrice', 'Exterior2nd', 'CentralAir'), 0.9176977237276406),
#  (('SalePrice', 'GarageCars', 'PavedDrive'), 0.9176885337891626),
#  (('SalePrice', 'MSZoning', 'CentralAir'), 0.9176719974396359),
#  (('SalePrice', 'CentralAir', 'SaleCondition'), 0.9176315017578871),
#  (('SalePrice', 'OverallCond', 'CentralAir'), 0.9176217291780926),
#  (('SalePrice', 'CentralAir', 'SaleType'), 0.9175363626901132),
#  (('SalePrice', 'Alley', 'CentralAir'), 0.9175256236979523),
#  (('SalePrice', 'OpenPorchSF', 'CentralAir'), 0.9175164127220529),
#  (('SalePrice', 'OverallCond', 'GarageType'), 0.9174589613297286),
#  (('SalePrice', 'GarageQual', 'PavedDrive'), 0.9174559612870467),
#  (('SalePrice', 'GarageType', 'GarageQual'), 0.9174042139554026),
#  (('SalePrice', 'ExterCond', 'CentralAir'), 0.9173973039634755),
#  (('SalePrice', 'BedroomAbvGr', 'GarageType'), 0.917391810103615),
#  (('SalePrice', 'BsmtFinType1', 'CentralAir'), 0.917333337874983),
#  (('SalePrice', 'BsmtUnfSF', 'CentralAir'), 0.9173287106264643),
#  (('SalePrice', 'BsmtCond', 'CentralAir'), 0.9172932614109046),
#  (('SalePrice', 'TotalBsmtSF', 'CentralAir'), 0.9172636936799315),
#  (('SalePrice', 'RoofStyle', 'CentralAir'), 0.9172372836457375),
#  (('SalePrice', 'MasVnrType', 'CentralAir'), 0.9172108942286188),
#  (('SalePrice', '1stFlrSF', 'CentralAir'), 0.9171771051402026),
#  (('SalePrice', 'CentralAir', 'PoolQC'), 0.9171451165631943),
#  (('SalePrice', 'Condition1', 'CentralAir'), 0.9171182503747392),
#  (('GrLivArea', 'SalePrice', 'GarageType'), 0.9170748869725748),
#  (('SalePrice', 'LotFrontage', 'CentralAir'), 0.9170719584182774),
#  (('SalePrice', 'Street', 'CentralAir'), 0.9170576739081472),
#  (('SalePrice', 'CentralAir', 'GarageFinish'), 0.9170249952215376),
#  (('SalePrice', 'WoodDeckSF', 'CentralAir'), 0.9170073754182044),
#  (('SalePrice', 'Utilities', 'CentralAir'), 0.9169661076532162),
#  (('SalePrice', 'KitchenAbvGr', 'CentralAir'), 0.9169576095173604),
#  (('SalePrice', 'CentralAir', 'Functional'), 0.9169277696644027),
#  (('SalePrice', 'Heating', 'CentralAir'), 0.9169189837522883),
#  (('GrLivArea', 'SalePrice', 'PavedDrive'), 0.9169183152089795),
#  (('SalePrice', 'BsmtQual', 'CentralAir'), 0.9168927175394601),
#  (('SalePrice', 'Condition2', 'CentralAir'), 0.9168830959609349),
#  (('SalePrice', 'LotConfig', 'CentralAir'), 0.9168760079100468),
#  (('SalePrice', 'BsmtFinSF1', 'CentralAir'), 0.9168600576456419),
#  (('SalePrice', 'Neighborhood', 'CentralAir'), 0.9168591894359754),
#  (('SalePrice', 'BsmtExposure', 'CentralAir'), 0.916852398029154),
#  (('SalePrice', 'LowQualFinSF', 'CentralAir'), 0.9168443631112482),
#  (('SalePrice', 'RoofMatl', 'CentralAir'), 0.9168425858449104),
#  (('SalePrice', 'EnclosedPorch', 'CentralAir'), 0.916840671434082),
#  (('SalePrice', 'BsmtFinType2', 'CentralAir'), 0.9168388652920654),
#  (('SalePrice', 'MoSold', 'CentralAir'), 0.9168358617956369),
#  (('SalePrice', 'LandContour', 'CentralAir'), 0.9168235642871851),
#  (('SalePrice', '3SsnPorch', 'CentralAir'), 0.9168199117621266),
#  (('SalePrice', 'CentralAir', 'KitchenQual'), 0.916804257743656),
#  (('SalePrice', 'BldgType', 'CentralAir'), 0.916803909244315),
#  (('SalePrice', 'LotArea', 'CentralAir'), 0.9168022248972736),
#  (('SalePrice', 'MiscVal', 'CentralAir'), 0.916797920818313),
#  (('SalePrice', 'LandSlope', 'CentralAir'), 0.916796641790264),
#  (('SalePrice', 'CentralAir', 'BsmtFullBath'), 0.9167960545310627),
#  (('SalePrice', 'BsmtFinSF2', 'CentralAir'), 0.9167928010138111),
#  (('SalePrice', 'PoolArea', 'CentralAir'), 0.9167925473804034),
#  (('SalePrice', 'CentralAir', 'Fence'), 0.9167915204445131),
#  (('SalePrice', 'CentralAir', 'MiscFeature'), 0.9167902828159915),
#  (('SalePrice', 'ScreenPorch', 'CentralAir'), 0.9167901072318407),
#  (('SalePrice', 'CentralAir', 'BsmtHalfBath'), 0.9167878230581952),
#  (('SalePrice', 'YrSold', 'CentralAir'), 0.916787311696189),
#  (('SalePrice', 'GarageYrBlt', 'CentralAir'), 0.916787311696189),
#  (('SalePrice', 'YearBuilt', 'CentralAir'), 0.916787311696189),
#  (('SalePrice', 'YearRemodAdd', 'CentralAir'), 0.916787311696189),
#  (('SalePrice', 'GarageCars', 'GarageType'), 0.9166822790365766),
#  (('SalePrice', 'Electrical', 'GarageType'), 0.9165644172266716),
#  (('SalePrice', 'Electrical', 'PavedDrive'), 0.916437470707849),
#  (('SalePrice', 'BedroomAbvGr', 'PavedDrive'), 0.9162341436519702),
#  (('SalePrice', '2ndFlrSF', 'GarageType'), 0.9161300802276001),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageType'), 0.9159195956998121),
#  (('SalePrice', 'TotRmsAbvGrd', 'PavedDrive'), 0.9157650300390918),
#  (('SalePrice', 'FullBath', 'GarageQual'), 0.9156835576334479),
#  (('SalePrice', 'Electrical', 'GarageCond'), 0.9156712442144225),
#  (('SalePrice', 'OverallCond', 'PavedDrive'), 0.915667318365301),
#  (('SalePrice', 'HeatingQC', 'PavedDrive'), 0.9156180842743475),
#  (('GrLivArea', 'SalePrice', 'GarageCond'), 0.9156000455669219),
#  (('SalePrice', 'HeatingQC', 'GarageType'), 0.9155999543987567),
#  (('SalePrice', 'BedroomAbvGr', 'GarageCond'), 0.9155751992220598),
#  (('SalePrice', 'ExterQual', 'GarageType'), 0.915538363502166),
#  (('SalePrice', 'MasVnrArea', 'PavedDrive'), 0.9155027148979376),
#  (('SalePrice', 'MasVnrArea', 'GarageType'), 0.9154839657140633),
#  (('SalePrice', 'GarageArea', 'PavedDrive'), 0.9152191084625422),
#  (('SalePrice', 'GarageCars', 'GarageCond'), 0.9151931187759582),
#  (('SalePrice', 'HouseStyle', 'GarageType'), 0.9151145499676565),
#  (('SalePrice', 'Exterior1st', 'PavedDrive'), 0.9150800672705839),
#  (('SalePrice', 'HalfBath', 'GarageType'), 0.9150709825891653),
#  (('SalePrice', 'FireplaceQu', 'PavedDrive'), 0.9150498586317269),
#  (('SalePrice', '2ndFlrSF', 'PavedDrive'), 0.915002067633459),
#  (('SalePrice', 'MSSubClass', 'GarageType'), 0.9149928032815017),
#  (('SalePrice', 'HouseStyle', 'PavedDrive'), 0.9149831505332929),
#  (('SalePrice', 'Exterior1st', 'GarageType'), 0.914955789580833),
#  (('SalePrice', 'Foundation', 'PavedDrive'), 0.9149496737858095),
#  (('SalePrice', 'Exterior2nd', 'GarageType'), 0.9149133764738392),
#  (('SalePrice', 'HeatingQC', 'GarageCond'), 0.9148534643441555),
#  (('SalePrice', 'Exterior2nd', 'PavedDrive'), 0.914807099631006),
#  (('SalePrice', 'GarageArea', 'GarageType'), 0.9148008679891473),
#  (('SalePrice', 'Fireplaces', 'PavedDrive'), 0.9147918449686645),
#  (('SalePrice', 'BsmtCond', 'GarageType'), 0.9147712599226604),
#  (('SalePrice', 'ExterQual', 'PavedDrive'), 0.9147646506528464),
#  (('SalePrice', 'HalfBath', 'PavedDrive'), 0.9147098654178284),
#  (('SalePrice', 'PavedDrive', 'SaleCondition'), 0.9146910407387994),
#  (('SalePrice', 'GarageQual', 'GarageCond'), 0.9146891949520614),
#  (('SalePrice', 'FireplaceQu', 'GarageType'), 0.9146054721290208),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageCond'), 0.9145343252413102),
#  (('SalePrice', 'LotShape', 'PavedDrive'), 0.914500466892727),
#  (('SalePrice', 'GarageType', 'SaleCondition'), 0.9144541296732854),
#  (('SalePrice', 'Foundation', 'GarageType'), 0.9144063113525498),
#  (('SalePrice', 'GarageType', 'SaleType'), 0.9143860840903796),
#  (('SalePrice', 'Fireplaces', 'GarageType'), 0.9143853902636943),
#  (('SalePrice', 'HouseStyle', 'GarageCond'), 0.9143846171827467),
#  (('SalePrice', 'BsmtCond', 'PavedDrive'), 0.9143378863692078),
#  (('SalePrice', 'RoofStyle', 'GarageType'), 0.914310064706818),
#  (('SalePrice', 'Alley', 'GarageType'), 0.9142711247001191),
#  (('SalePrice', 'MSSubClass', 'PavedDrive'), 0.9142562049094125),
#  (('SalePrice', 'MasVnrArea', 'GarageCond'), 0.9142444162060552),
#  (('SalePrice', 'BsmtUnfSF', 'PavedDrive'), 0.9142421721265765),
#  (('SalePrice', 'PavedDrive', 'SaleType'), 0.9142371184129224),
#  (('SalePrice', 'BsmtUnfSF', 'GarageType'), 0.9142331397271404),
#  (('SalePrice', 'LotShape', 'GarageType'), 0.9141967021686221),
#  (('SalePrice', 'Foundation', 'GarageCond'), 0.9141833841980144),
#  (('SalePrice', 'OpenPorchSF', 'PavedDrive'), 0.9141755143184347),
#  (('SalePrice', 'ExterCond', 'GarageType'), 0.9141682242562232),
#  (('SalePrice', 'OverallCond', 'GarageCond'), 0.91416221641707),
#  (('SalePrice', 'ExterQual', 'GarageCond'), 0.9141540014605005),
#  (('SalePrice', 'LotFrontage', 'GarageType'), 0.9141456909820894),
#  (('SalePrice', 'RoofStyle', 'PavedDrive'), 0.9141370695082439),
#  (('SalePrice', 'ExterCond', 'PavedDrive'), 0.9141257486602318),
#  (('SalePrice', 'MSZoning', 'PavedDrive'), 0.9140997577163317),
#  (('SalePrice', 'BsmtFinType1', 'GarageType'), 0.9140845602416624),
#  (('SalePrice', 'Heating', 'PavedDrive'), 0.9140226935512837),
#  (('SalePrice', 'Street', 'GarageType'), 0.9140156173200262),
#  (('SalePrice', 'FireplaceQu', 'GarageCond'), 0.9140098125492415),
#  (('SalePrice', 'MSZoning', 'GarageType'), 0.9139969787825146),
#  (('SalePrice', 'Utilities', 'GarageType'), 0.9139911225653308),
#  (('SalePrice', 'OpenPorchSF', 'GarageType'), 0.913981060201688),
#  (('SalePrice', 'GarageType', 'PoolQC'), 0.9139771012166803),
#  (('SalePrice', 'PavedDrive', 'PoolQC'), 0.9139695382797179),
#  (('SalePrice', 'TotalBsmtSF', 'PavedDrive'), 0.9139633483040226),
#  (('SalePrice', 'Heating', 'GarageType'), 0.913943935081585),
#  (('SalePrice', 'Condition1', 'GarageType'), 0.9139398719273772),
#  (('SalePrice', 'Functional', 'GarageType'), 0.9139339782258311),
#  (('SalePrice', 'MasVnrType', 'PavedDrive'), 0.9139014183772216),
#  (('SalePrice', 'BsmtFinSF1', 'GarageType'), 0.9138968438035396),
#  (('SalePrice', 'Alley', 'PavedDrive'), 0.9138812211506095),
#  (('SalePrice', 'Electrical', 'GarageQual'), 0.9138806002423283),
#  (('SalePrice', 'HalfBath', 'GarageCond'), 0.913870211299494),
#  (('SalePrice', 'BsmtFinType1', 'PavedDrive'), 0.9138671048108479),
#  (('SalePrice', 'MasVnrType', 'GarageType'), 0.9138429270877911),
#  (('SalePrice', 'WoodDeckSF', 'PavedDrive'), 0.9138329952876563),
#  (('SalePrice', 'TotalBsmtSF', 'GarageType'), 0.9137966339063865),
#  (('SalePrice', 'LotFrontage', 'PavedDrive'), 0.9137858588353278),
#  (('SalePrice', 'GarageFinish', 'PavedDrive'), 0.9137828391346633),
#  (('SalePrice', '1stFlrSF', 'PavedDrive'), 0.9137796086244173),
#  (('SalePrice', 'Street', 'PavedDrive'), 0.913766082021279),
#  (('SalePrice', 'Condition2', 'GarageType'), 0.9137638575442111),
#  (('GrLivArea', 'SalePrice', 'GarageQual'), 0.9137564415750573),
#  (('SalePrice', 'LandContour', 'PavedDrive'), 0.9137447536733039),
#  (('SalePrice', 'Utilities', 'PavedDrive'), 0.9137444132276035),
#  (('SalePrice', 'Neighborhood', 'GarageType'), 0.9137419302591518),
#  (('SalePrice', 'Condition1', 'PavedDrive'), 0.9137228188072517),
#  (('SalePrice', 'Fireplaces', 'GarageCond'), 0.9137223404451691),
#  (('SalePrice', 'WoodDeckSF', 'GarageType'), 0.9137183193194245),
#  (('SalePrice', 'GarageCars', 'GarageQual'), 0.9137172907831177),
#  (('SalePrice', 'MoSold', 'GarageType'), 0.9137110608359309),
#  (('SalePrice', 'BsmtFinType2', 'GarageType'), 0.9137098100094923),
#  (('SalePrice', 'EnclosedPorch', 'GarageType'), 0.9137059077799078),
#  (('SalePrice', 'BsmtFinSF1', 'PavedDrive'), 0.9137026411404476),
#  (('SalePrice', 'LandContour', 'GarageType'), 0.9136962605957422),
#  (('SalePrice', 'RoofMatl', 'GarageType'), 0.9136953871536057),
#  (('SalePrice', 'Functional', 'PavedDrive'), 0.9136907463159986),
#  (('SalePrice', 'Condition2', 'PavedDrive'), 0.9136852323062103),
#  (('SalePrice', 'LandSlope', 'GarageType'), 0.9136761624264534),
#  (('SalePrice', '2ndFlrSF', 'GarageCond'), 0.9136735187843081),
#  (('SalePrice', '3SsnPorch', 'GarageType'), 0.9136552028253018),
#  (('SalePrice', 'RoofMatl', 'PavedDrive'), 0.9136509170138558),
#  (('SalePrice', 'LotArea', 'GarageType'), 0.9136446030493732),
#  (('SalePrice', 'KitchenQual', 'GarageType'), 0.9136376924760102),
#  (('SalePrice', 'BldgType', 'GarageType'), 0.9136374581388577),
#  (('SalePrice', 'BsmtQual', 'GarageType'), 0.9136353825653362),
#  (('SalePrice', 'LowQualFinSF', 'PavedDrive'), 0.91363239802648),
#  (('SalePrice', 'BsmtExposure', 'GarageType'), 0.9136301501160248),
#  (('SalePrice', 'LotConfig', 'GarageType'), 0.9136299410202944),
#  (('SalePrice', 'BsmtFullBath', 'GarageType'), 0.9136286096685308),
#  (('SalePrice', 'GarageType', 'MiscFeature'), 0.913627946814499),
#  (('SalePrice', 'BsmtHalfBath', 'GarageType'), 0.9136244227917112),
#  (('SalePrice', 'LowQualFinSF', 'GarageType'), 0.9136226550439003),
#  (('SalePrice', 'MiscVal', 'GarageType'), 0.9136221551340143),
#  (('SalePrice', 'BedroomAbvGr', 'GarageQual'), 0.9136216875622009),
#  (('SalePrice', 'GarageType', 'Fence'), 0.9136216804235389),
#  (('SalePrice', '1stFlrSF', 'GarageType'), 0.9136212860497227),
#  (('SalePrice', 'GarageType', 'GarageFinish'), 0.9136208734898504),
#  (('SalePrice', 'PoolArea', 'GarageType'), 0.9136203765083488),
#  (('SalePrice', 'KitchenAbvGr', 'GarageType'), 0.9136202895734505),
#  (('SalePrice', 'ScreenPorch', 'GarageType'), 0.9136201719922888),
#  (('SalePrice', 'BsmtFinSF2', 'GarageType'), 0.9136200169525613),
#  (('SalePrice', 'YrSold', 'GarageType'), 0.9136198371363796),
#  (('SalePrice', 'GarageYrBlt', 'GarageType'), 0.9136198371363796),
#  (('SalePrice', 'YearBuilt', 'GarageType'), 0.9136198371363796),
#  (('SalePrice', 'YearRemodAdd', 'GarageType'), 0.9136198371363796),
#  (('SalePrice', 'LotArea', 'PavedDrive'), 0.9136155849905353),
#  (('SalePrice', 'BsmtExposure', 'PavedDrive'), 0.9136086304202792),
#  (('SalePrice', '3SsnPorch', 'PavedDrive'), 0.9136079135897968),
#  (('SalePrice', 'BsmtQual', 'PavedDrive'), 0.9136051326602271),
#  (('SalePrice', 'BsmtFinType2', 'PavedDrive'), 0.9135917513247916),
#  (('SalePrice', 'LotShape', 'GarageCond'), 0.9135846209355154),
#  (('SalePrice', 'MoSold', 'PavedDrive'), 0.9135828200463414),
#  (('SalePrice', 'LandSlope', 'PavedDrive'), 0.9135821439625352),
#  (('SalePrice', 'LotConfig', 'PavedDrive'), 0.9135697904204272),
#  (('SalePrice', 'MiscVal', 'PavedDrive'), 0.9135690599127164),
#  (('SalePrice', 'PoolArea', 'PavedDrive'), 0.9135658457048901),
#  (('SalePrice', 'EnclosedPorch', 'PavedDrive'), 0.9135651567626473),
#  (('SalePrice', 'Neighborhood', 'PavedDrive'), 0.9135586385584152),
#  (('SalePrice', 'KitchenAbvGr', 'PavedDrive'), 0.9135544471799466),
#  (('SalePrice', 'KitchenQual', 'PavedDrive'), 0.9135461958084607),
#  (('SalePrice', 'ScreenPorch', 'PavedDrive'), 0.9135454244852742),
#  (('SalePrice', 'PavedDrive', 'MiscFeature'), 0.9135434671203471),
#  (('SalePrice', 'BsmtFinSF2', 'PavedDrive'), 0.9135406279334143),
#  (('SalePrice', 'BsmtHalfBath', 'PavedDrive'), 0.913540281107298),
#  (('SalePrice', 'BsmtFullBath', 'PavedDrive'), 0.9135388760869587),
#  (('SalePrice', 'BldgType', 'PavedDrive'), 0.9135387315113042),
#  (('SalePrice', 'PavedDrive', 'Fence'), 0.9135386501418973),
#  (('SalePrice', 'YrSold', 'PavedDrive'), 0.91353806378706),
#  (('SalePrice', 'GarageYrBlt', 'PavedDrive'), 0.91353806378706),
#  (('SalePrice', 'YearBuilt', 'PavedDrive'), 0.91353806378706),
#  (('SalePrice', 'YearRemodAdd', 'PavedDrive'), 0.91353806378706),
#  (('SalePrice', 'Exterior1st', 'GarageCond'), 0.9134559979607547),
#  (('SalePrice', 'BsmtCond', 'GarageCond'), 0.9134332208758494),
#  (('SalePrice', 'ExterCond', 'GarageCond'), 0.9133998682742389),
#  (('SalePrice', 'GarageArea', 'GarageCond'), 0.9133766824717521),
#  (('SalePrice', 'GarageCond', 'SaleCondition'), 0.9133658329680119),
#  (('SalePrice', 'OverallCond', 'GarageQual'), 0.913364210555019),
#  (('SalePrice', 'Exterior2nd', 'GarageCond'), 0.913325609213012),
#  (('SalePrice', 'MSSubClass', 'GarageCond'), 0.9133236532695446),
#  (('SalePrice', 'TotalBsmtSF', 'GarageCond'), 0.9132886910472228),
#  (('SalePrice', 'BsmtFinType1', 'GarageCond'), 0.9132568063291855),
#  (('SalePrice', 'GarageCond', 'SaleType'), 0.9132231289404362),
#  (('SalePrice', 'BsmtUnfSF', 'GarageCond'), 0.9131181347990662),
#  (('SalePrice', 'GarageFinish', 'GarageCond'), 0.9131041430033705),
#  (('SalePrice', 'RoofStyle', 'GarageCond'), 0.9130596933185917),
#  (('SalePrice', 'OpenPorchSF', 'GarageCond'), 0.913055677052408),
#  (('SalePrice', 'Alley', 'GarageCond'), 0.9130549408034828),
#  (('SalePrice', 'MSZoning', 'GarageCond'), 0.9130544697637011),
#  (('SalePrice', 'MasVnrType', 'GarageCond'), 0.9129398730231645),
#  (('SalePrice', 'MasVnrArea', 'GarageQual'), 0.912910804294092),
#  (('SalePrice', 'LotFrontage', 'GarageCond'), 0.9128999362529684),
#  (('SalePrice', 'Heating', 'GarageCond'), 0.9128997078374043),
#  (('SalePrice', 'Utilities', 'GarageCond'), 0.9128982377344246),
#  (('SalePrice', 'Street', 'GarageCond'), 0.9128559581896679),
#  (('SalePrice', 'HeatingQC', 'GarageQual'), 0.9128473340203773),
#  (('SalePrice', '1stFlrSF', 'GarageCond'), 0.9128018444301574),
#  (('SalePrice', 'Condition1', 'GarageCond'), 0.9127691772046813),
#  (('SalePrice', 'LandContour', 'GarageCond'), 0.9127671830173734),
#  (('SalePrice', 'WoodDeckSF', 'GarageCond'), 0.9127617049558847),
#  (('SalePrice', 'Functional', 'GarageCond'), 0.9127602680200191),
#  (('SalePrice', 'Condition2', 'GarageCond'), 0.9127376528220978),
#  (('SalePrice', 'GarageCond', 'PoolQC'), 0.9127296593035104),
#  (('SalePrice', 'BsmtExposure', 'GarageCond'), 0.9126778488414935),
#  (('SalePrice', 'EnclosedPorch', 'GarageCond'), 0.9126629554293652),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageQual'), 0.9126232411955515),
#  (('SalePrice', 'ExterQual', 'GarageQual'), 0.9125810751363062),
#  (('SalePrice', 'Neighborhood', 'GarageCond'), 0.912568054453735),
#  (('SalePrice', 'GarageCond', 'MiscFeature'), 0.9125640771089165),
#  (('SalePrice', '3SsnPorch', 'GarageCond'), 0.9125526657513271),
#  (('SalePrice', 'BsmtQual', 'GarageCond'), 0.9125515878379269),
#  (('SalePrice', 'BsmtFinType2', 'GarageCond'), 0.9125434364654157),
#  (('SalePrice', 'MoSold', 'GarageCond'), 0.9125376293066331),
#  (('SalePrice', 'LandSlope', 'GarageCond'), 0.9125339448418732),
#  (('SalePrice', 'LotConfig', 'GarageCond'), 0.9125326974077017),
#  (('SalePrice', 'BsmtFinSF1', 'GarageCond'), 0.9125283264900453),
#  (('SalePrice', 'LowQualFinSF', 'GarageCond'), 0.912522737397334),
#  (('SalePrice', 'BldgType', 'GarageCond'), 0.9125205745183427),
#  (('SalePrice', 'BsmtFinSF2', 'GarageCond'), 0.9125113689897132),
#  (('SalePrice', 'BsmtFullBath', 'GarageCond'), 0.9125103307141095),
#  (('SalePrice', 'RoofMatl', 'GarageCond'), 0.912507688263636),
#  (('SalePrice', 'MiscVal', 'GarageCond'), 0.9125066014862836),
#  (('SalePrice', 'PoolArea', 'GarageCond'), 0.9125043109034712),
#  (('SalePrice', 'BsmtHalfBath', 'GarageCond'), 0.9124996754854746),
#  (('SalePrice', 'GarageCond', 'Fence'), 0.9124978911950833),
#  (('SalePrice', 'LotArea', 'GarageCond'), 0.9124969007663042),
#  (('SalePrice', 'KitchenAbvGr', 'GarageCond'), 0.9124945935631003),
#  (('SalePrice', 'ScreenPorch', 'GarageCond'), 0.9124942372016493),
#  (('SalePrice', 'KitchenQual', 'GarageCond'), 0.9124934646034021),
#  (('SalePrice', 'YrSold', 'GarageCond'), 0.9124931226685752),
#  (('SalePrice', 'GarageYrBlt', 'GarageCond'), 0.9124931226685752),
#  (('SalePrice', 'YearBuilt', 'GarageCond'), 0.9124931226685752),
#  (('SalePrice', 'YearRemodAdd', 'GarageCond'), 0.9124931226685752),
#  (('SalePrice', 'FireplaceQu', 'GarageQual'), 0.9124223620965531),
#  (('SalePrice', 'HouseStyle', 'GarageQual'), 0.9123264100258296),
#  (('SalePrice', 'FullBath', 'GarageCars'), 0.9121776231637476),
#  (('SalePrice', 'Fireplaces', 'GarageQual'), 0.9121433382669969),
#  (('SalePrice', 'HalfBath', 'GarageQual'), 0.9121405223828238),
#  (('SalePrice', 'GarageCars', 'OverallCond'), 0.9121267963439674),
#  (('SalePrice', '2ndFlrSF', 'GarageQual'), 0.9119844668702242),
#  (('SalePrice', 'BsmtCond', 'GarageQual'), 0.9119521199577159),
#  (('SalePrice', 'GarageCars', 'Electrical'), 0.9118995594645304),
#  (('SalePrice', 'Foundation', 'GarageQual'), 0.9118498608857419),
#  (('SalePrice', 'GarageArea', 'GarageQual'), 0.9118375038627362),
#  (('SalePrice', 'FullBath', 'OverallCond'), 0.9117637424111864),
#  (('SalePrice', 'FullBath', 'Electrical'), 0.9117454679365125),
#  (('SalePrice', 'GarageQual', 'SaleType'), 0.9117400292365865),
#  (('SalePrice', 'LotShape', 'GarageQual'), 0.9117223829564957),
#  (('SalePrice', 'GarageQual', 'SaleCondition'), 0.911695459723481),
#  (('SalePrice', 'Exterior1st', 'GarageQual'), 0.9116943121079247),
#  (('SalePrice', 'Exterior2nd', 'GarageQual'), 0.911611706876397),
#  (('SalePrice', 'ExterCond', 'GarageQual'), 0.9115960821229615),
#  (('SalePrice', 'MSSubClass', 'GarageQual'), 0.9115512853747259),
#  (('SalePrice', 'BsmtUnfSF', 'GarageQual'), 0.9115142978733092),
#  (('SalePrice', 'RoofStyle', 'GarageQual'), 0.911499758963664),
#  (('SalePrice', 'BsmtFinType1', 'GarageQual'), 0.9114421350706747),
#  (('SalePrice', 'TotalBsmtSF', 'GarageQual'), 0.9114224308352962),
#  (('SalePrice', 'OpenPorchSF', 'GarageQual'), 0.9113241458932871),
#  (('SalePrice', 'Alley', 'GarageQual'), 0.9113185035487286),
#  (('SalePrice', 'Heating', 'GarageQual'), 0.9112921222556759),
#  (('SalePrice', 'BedroomAbvGr', 'GarageCars'), 0.9112450372574613),
#  (('SalePrice', 'Street', 'GarageQual'), 0.9111957485093816),
#  (('SalePrice', 'MasVnrType', 'GarageQual'), 0.9111920631985532),
#  (('SalePrice', 'Utilities', 'GarageQual'), 0.9111821570275697),
#  (('SalePrice', 'MSZoning', 'GarageQual'), 0.9111562274225724),
#  (('SalePrice', 'Functional', 'GarageQual'), 0.9111484938870035),
#  (('SalePrice', 'LotFrontage', 'GarageQual'), 0.9111283201496917),
#  (('SalePrice', 'WoodDeckSF', 'GarageQual'), 0.9110758147265893),
#  (('SalePrice', 'GarageQual', 'PoolQC'), 0.9110670653453762),
#  (('SalePrice', 'Condition1', 'GarageQual'), 0.9110474089671614),
#  (('SalePrice', 'GarageFinish', 'GarageQual'), 0.9110407516175377),
#  (('SalePrice', '1stFlrSF', 'GarageQual'), 0.9110248480027475),
#  (('SalePrice', 'LandContour', 'GarageQual'), 0.9109716754588141),
#  (('SalePrice', 'GarageCars', 'ExterQual'), 0.9109708437690581),
#  (('SalePrice', 'Condition2', 'GarageQual'), 0.91095453794856),
#  (('SalePrice', 'FullBath', 'ExterQual'), 0.9109103840328723),
#  (('SalePrice', 'BsmtExposure', 'GarageQual'), 0.9108919446991142),
#  (('SalePrice', 'BsmtFinType2', 'GarageQual'), 0.910880761740498),
#  (('SalePrice', 'EnclosedPorch', 'GarageQual'), 0.9108783833943139),
#  (('SalePrice', 'BsmtFinSF1', 'GarageQual'), 0.9108762991786489),
#  (('SalePrice', 'Neighborhood', 'GarageQual'), 0.9108718014928981),
#  (('SalePrice', '3SsnPorch', 'GarageQual'), 0.9108675231973978),
#  (('SalePrice', 'KitchenAbvGr', 'GarageQual'), 0.9108491640339752),
#  (('SalePrice', 'LandSlope', 'GarageQual'), 0.9108458318835192),
#  (('SalePrice', 'GarageQual', 'MiscFeature'), 0.9108393906641782),
#  (('SalePrice', 'RoofMatl', 'GarageQual'), 0.9108321688726922),
#  (('SalePrice', 'ScreenPorch', 'GarageQual'), 0.9108283981709145),
#  (('SalePrice', 'MoSold', 'GarageQual'), 0.9108163942464064),
#  (('SalePrice', 'LowQualFinSF', 'GarageQual'), 0.910798124021298),
#  (('SalePrice', 'BsmtQual', 'GarageQual'), 0.9107972117523602),
#  (('SalePrice', 'MiscVal', 'GarageQual'), 0.9107952947483499),
#  (('SalePrice', 'LotConfig', 'GarageQual'), 0.9107946879433533),
#  (('SalePrice', 'KitchenQual', 'GarageQual'), 0.9107933531555582),
#  (('SalePrice', 'BsmtHalfBath', 'GarageQual'), 0.9107931181483157),
#  (('SalePrice', 'PoolArea', 'GarageQual'), 0.9107923448396908),
#  (('SalePrice', 'GarageQual', 'Fence'), 0.9107905988955294),
#  (('SalePrice', 'BsmtFinSF2', 'GarageQual'), 0.9107882504290461),
#  (('SalePrice', 'BldgType', 'GarageQual'), 0.9107876211729825),
#  (('SalePrice', 'LotArea', 'GarageQual'), 0.9107857504014584),
#  (('SalePrice', 'BsmtFullBath', 'GarageQual'), 0.9107845393392671),
#  (('SalePrice', 'YrSold', 'GarageQual'), 0.9107838929885431),
#  (('SalePrice', 'GarageYrBlt', 'GarageQual'), 0.9107838929885431),
#  (('SalePrice', 'YearBuilt', 'GarageQual'), 0.9107838929885431),
#  (('SalePrice', 'YearRemodAdd', 'GarageQual'), 0.9107838929885431),
#  (('SalePrice', 'MasVnrArea', 'GarageCars'), 0.9106339377747132),
#  (('SalePrice', 'FullBath', 'BsmtFinType1'), 0.9105657114478575),
#  (('GrLivArea', 'SalePrice', 'GarageCars'), 0.9104774673572094),
#  (('SalePrice', 'FullBath', 'BsmtCond'), 0.9104441730125065),
#  (('SalePrice', 'FullBath', 'GarageArea'), 0.9104044778276149),
#  (('SalePrice', 'GarageCars', 'BsmtCond'), 0.9103119491136832),
#  (('SalePrice', 'GarageCars', 'FireplaceQu'), 0.9102667136630351),
#  (('SalePrice', 'GarageCars', 'HeatingQC'), 0.910232504288731),
#  (('SalePrice', 'GarageCars', 'BsmtFinType1'), 0.910148687673882),
#  (('SalePrice', 'Fireplaces', 'GarageCars'), 0.9101456830950135),
#  (('SalePrice', 'FullBath', 'Fireplaces'), 0.9099830049357067),
#  (('SalePrice', 'GarageCars', 'HouseStyle'), 0.9099777094300193),
#  (('SalePrice', 'GarageCars', 'Foundation'), 0.9097918114563281),
#  (('SalePrice', 'MasVnrArea', 'FullBath'), 0.9097874152537018),
#  (('SalePrice', 'HalfBath', 'GarageCars'), 0.9097698363899076),
#  (('GrLivArea', 'SalePrice', 'Electrical'), 0.9097005575501819),
#  (('SalePrice', 'GarageCars', 'LotShape'), 0.9096957728606131),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageCars'), 0.9096904161059416),
#  (('SalePrice', 'FullBath', 'KitchenAbvGr'), 0.9095723905197203),
#  (('SalePrice', 'GarageCars', 'Alley'), 0.9095705701798634),
#  (('SalePrice', 'FullBath', 'HalfBath'), 0.9095695162661293),
#  (('SalePrice', 'BedroomAbvGr', 'Electrical'), 0.9095309322524853),
#  (('SalePrice', 'FullBath', 'FireplaceQu'), 0.9095120833398714),
#  (('SalePrice', 'GarageCars', 'SaleType'), 0.9094925078129547),
#  (('SalePrice', 'GarageCars', 'SaleCondition'), 0.9094617556319701),
#  (('SalePrice', 'GarageCars', 'ExterCond'), 0.9094384917082946),
#  (('SalePrice', 'FullBath', 'LotShape'), 0.909411407265322),
#  (('SalePrice', 'FullBath', 'ExterCond'), 0.9094075548380824),
#  (('SalePrice', 'FullBath', 'HeatingQC'), 0.9093987980182042),
#  (('SalePrice', 'GarageCars', 'Heating'), 0.9093771037980339),
#  (('SalePrice', 'GarageArea', 'Electrical'), 0.9093188272064701),
#  (('SalePrice', '2ndFlrSF', 'GarageCars'), 0.9093154997432717),
#  (('SalePrice', 'FullBath', 'SaleCondition'), 0.9093132489271102),
#  (('SalePrice', 'TotalBsmtSF', 'GarageCars'), 0.9092959239063992),
#  (('SalePrice', 'FullBath', 'HouseStyle'), 0.9092393451634299),
#  (('SalePrice', 'GarageCars', 'Exterior1st'), 0.9092254746728446),
#  (('SalePrice', 'ExterQual', 'Electrical'), 0.9092247795040876),
#  (('SalePrice', 'FullBath', 'Heating'), 0.9091864216946004),
#  (('SalePrice', 'GarageCars', 'RoofStyle'), 0.9091815913345033),
#  (('SalePrice', 'GarageCars', 'MasVnrType'), 0.9091700277005759),
#  (('SalePrice', 'GarageCars', 'Street'), 0.9091589512542508),
#  (('SalePrice', 'TotalBsmtSF', 'FullBath'), 0.9091487746797318),
#  (('SalePrice', 'GarageCars', 'MSZoning'), 0.9091066783778283),
#  (('SalePrice', 'FullBath', 'Foundation'), 0.9090987704892977),
#  (('SalePrice', 'LotFrontage', 'GarageCars'), 0.9090946953213183),
#  (('SalePrice', 'GarageCars', 'Exterior2nd'), 0.9090733654986421),
#  (('SalePrice', 'GarageCars', 'Functional'), 0.9090521451803238),
#  (('SalePrice', 'GarageCars', 'OpenPorchSF'), 0.9090387347479914),
#  (('SalePrice', 'FullBath', 'Alley'), 0.9090371876015024),
#  (('SalePrice', 'FullBath', 'BedroomAbvGr'), 0.9089561767739582),
#  (('SalePrice', 'GarageCars', 'Utilities'), 0.908955850587126),
#  (('SalePrice', 'GarageCars', 'GarageFinish'), 0.9089161239219208),
#  (('SalePrice', 'KitchenAbvGr', 'GarageCars'), 0.9089158771229644),
#  (('SalePrice', 'FullBath', 'SaleType'), 0.9088881095253595),
#  (('SalePrice', 'GarageCars', 'WoodDeckSF'), 0.9088853501483634),
#  (('SalePrice', 'GarageCars', 'MSSubClass'), 0.9088740016326275),
#  (('SalePrice', 'GarageCars', 'Condition1'), 0.9088716517032348),
#  (('SalePrice', 'GarageCars', 'EnclosedPorch'), 0.908845650490475),
#  (('SalePrice', 'GarageCars', 'PoolQC'), 0.9088395588298307),
#  (('SalePrice', 'GarageCars', 'Condition2'), 0.9088161591108519),
#  (('SalePrice', 'GarageCars', 'Neighborhood'), 0.9087899582902188),
#  (('SalePrice', 'FullBath', 'Exterior1st'), 0.9087857169035437),
#  (('SalePrice', 'BsmtUnfSF', 'GarageCars'), 0.908771281918454),
#  (('SalePrice', 'GarageCars', 'GarageArea'), 0.9087672778954603),
#  (('SalePrice', '1stFlrSF', 'GarageCars'), 0.9087513176684208),
#  (('SalePrice', 'FullBath', 'MasVnrType'), 0.9087256149694111),
#  (('SalePrice', 'GarageCars', 'BsmtExposure'), 0.9087147653944465),
#  (('SalePrice', 'GarageCars', 'LandContour'), 0.9087033695437657),
#  (('SalePrice', 'OverallCond', 'Electrical'), 0.90869335785508),
#  (('SalePrice', 'FullBath', 'BsmtExposure'), 0.9086921125177255),
#  (('SalePrice', 'MasVnrArea', 'Electrical'), 0.9086889491241281),
#  (('SalePrice', 'BsmtFinSF2', 'GarageCars'), 0.9086685521842414),
#  (('SalePrice', 'GarageCars', 'BsmtFullBath'), 0.9086583986872768),
#  (('SalePrice', 'FullBath', 'BsmtFullBath'), 0.9086493933820151),
#  (('SalePrice', 'GarageCars', 'Fence'), 0.9086389841343125),
#  (('SalePrice', 'GarageCars', 'KitchenQual'), 0.9086388420250431),
#  (('SalePrice', 'GarageCars', 'MiscFeature'), 0.9086377482509888),
#  (('SalePrice', 'GarageCars', 'ScreenPorch'), 0.908634918491375),
#  (('SalePrice', 'GarageCars', 'BsmtQual'), 0.9086334129890266),
#  (('SalePrice', 'GarageCars', '3SsnPorch'), 0.9086305285147781),
#  (('SalePrice', 'FullBath', 'Exterior2nd'), 0.9086279576591352),
#  (('SalePrice', 'GarageCars', 'BsmtHalfBath'), 0.9086271854679923),
#  (('SalePrice', 'GarageCars', 'RoofMatl'), 0.9086233483887696),
#  (('SalePrice', 'GarageCars', 'MiscVal'), 0.9086181235353256),
#  (('SalePrice', 'FullBath', 'Functional'), 0.9086152430120448),
#  (('SalePrice', 'LowQualFinSF', 'GarageCars'), 0.9086112576925336),
#  (('SalePrice', 'Foundation', 'Electrical'), 0.9086071633359898),
#  (('SalePrice', 'Electrical', 'FireplaceQu'), 0.9085906188054993),
#  (('SalePrice', 'GarageCars', 'BldgType'), 0.9085859913070838),
#  (('SalePrice', 'GarageCars', 'LandSlope'), 0.9085837187882325),
#  (('SalePrice', 'GarageCars', 'MoSold'), 0.9085821699962492),
#  (('SalePrice', 'TotRmsAbvGrd', 'Electrical'), 0.9085816635324778),
#  (('SalePrice', 'GarageCars', 'PoolArea'), 0.9085745793231721),
#  (('SalePrice', 'BsmtFinSF1', 'GarageCars'), 0.9085728509995714),
#  (('SalePrice', 'GarageCars', 'BsmtFinType2'), 0.908571536710509),
#  (('SalePrice', 'GarageCars', 'LotConfig'), 0.9085685780606227),
#  (('SalePrice', 'LotArea', 'GarageCars'), 0.908568400651486),
#  (('SalePrice', 'GarageCars', 'YrSold'), 0.9085678342966236),
#  (('SalePrice', 'GarageCars', 'GarageYrBlt'), 0.9085678342966236),
#  (('SalePrice', 'GarageCars', 'YearBuilt'), 0.9085678342966236),
#  (('SalePrice', 'GarageCars', 'YearRemodAdd'), 0.9085678342966236),
#  (('SalePrice', 'Fireplaces', 'Electrical'), 0.9085653751703875),
#  (('SalePrice', 'FullBath', 'WoodDeckSF'), 0.9085388026562511),
#  (('SalePrice', 'HeatingQC', 'Electrical'), 0.9085332165009302),
#  (('SalePrice', 'BsmtCond', 'Electrical'), 0.9085261215211972),
#  (('SalePrice', 'FullBath', 'Street'), 0.9085251065209273),
#  (('SalePrice', 'LotFrontage', 'FullBath'), 0.9084871776534218),
#  (('SalePrice', 'FullBath', 'Condition1'), 0.9084871379439285),
#  (('SalePrice', 'GarageArea', 'OverallCond'), 0.9084526741081581),
#  (('SalePrice', 'FullBath', 'EnclosedPorch'), 0.9084309815940725),
#  (('SalePrice', 'FullBath', 'PoolQC'), 0.9084302033452637),
#  (('SalePrice', 'FullBath', 'Utilities'), 0.9084275751264386),
#  (('GrLivArea', 'SalePrice', 'FullBath'), 0.9084268835417417),
#  (('SalePrice', 'FullBath', 'MSZoning'), 0.9084203612940615),
#  (('SalePrice', 'BedroomAbvGr', 'GarageArea'), 0.9083998642839763),
#  (('SalePrice', 'FullBath', 'RoofStyle'), 0.9083921415623605),
#  (('SalePrice', 'BsmtFinSF2', 'FullBath'), 0.9083649200477787),
#  (('SalePrice', 'FullBath', 'Fence'), 0.9083648545142194),
#  (('SalePrice', 'FullBath', 'Condition2'), 0.9083522441814055),
#  (('SalePrice', 'HouseStyle', 'Electrical'), 0.9083514066254343),
#  (('SalePrice', 'FullBath', 'KitchenQual'), 0.9083440783336177),
#  (('SalePrice', 'BsmtFinSF1', 'FullBath'), 0.9083410004528654),
#  (('SalePrice', 'OverallCond', 'Foundation'), 0.9083367968699726),
#  (('SalePrice', '1stFlrSF', 'FullBath'), 0.9083254022014149),
#  (('SalePrice', 'FullBath', 'OpenPorchSF'), 0.9082862660614269),
#  (('SalePrice', 'FullBath', 'BsmtQual'), 0.9082644062396118),
#  (('SalePrice', 'FullBath', 'LandContour'), 0.9082621641274498),
#  (('SalePrice', 'FullBath', 'Neighborhood'), 0.9082598019396715),
#  (('SalePrice', 'FullBath', 'TotRmsAbvGrd'), 0.9082502081540262),
#  (('SalePrice', 'LowQualFinSF', 'FullBath'), 0.9082439288768729),
#  (('SalePrice', 'HalfBath', 'Electrical'), 0.9082401465526333),
#  (('SalePrice', 'FullBath', 'ScreenPorch'), 0.9082401171407992),
#  (('SalePrice', 'FullBath', '3SsnPorch'), 0.9081788492828777),
#  (('SalePrice', 'FullBath', 'BsmtHalfBath'), 0.9081780676054572),
#  (('SalePrice', 'FullBath', 'MSSubClass'), 0.9081722645163327),
#  (('SalePrice', 'FullBath', 'LotConfig'), 0.9081569114530399),
#  (('SalePrice', 'FullBath', 'MiscVal'), 0.9081453375042899),
#  (('SalePrice', 'FullBath', 'MiscFeature'), 0.9081451506354383),
#  (('SalePrice', 'FullBath', 'RoofMatl'), 0.9081418118463085),
#  (('SalePrice', 'FullBath', 'MoSold'), 0.9081405807001419),
#  (('SalePrice', 'BsmtUnfSF', 'FullBath'), 0.9081404691246511),
#  (('SalePrice', 'FullBath', 'GarageFinish'), 0.9081397794496193),
#  (('SalePrice', '2ndFlrSF', 'FullBath'), 0.908138068002289),
#  (('SalePrice', 'FullBath', 'PoolArea'), 0.9081363578221799),
#  (('SalePrice', 'ExterCond', 'Electrical'), 0.9081309317719),
#  (('SalePrice', 'LotArea', 'FullBath'), 0.9081267930718928),
#  (('SalePrice', 'FullBath', 'BldgType'), 0.9081238267877266),
#  (('SalePrice', 'FullBath', 'BsmtFinType2'), 0.9081206506809337),
#  (('SalePrice', 'FullBath', 'LandSlope'), 0.9081186416135685),
#  (('SalePrice', 'FullBath', 'YrSold'), 0.9081186371921138),
#  (('SalePrice', 'FullBath', 'GarageYrBlt'), 0.9081186371921138),
#  (('SalePrice', 'FullBath', 'YearBuilt'), 0.9081186371921138),
#  (('SalePrice', 'FullBath', 'YearRemodAdd'), 0.9081186371921138),
#  (('SalePrice', 'LotShape', 'Electrical'), 0.9081031872942049),
#  (('SalePrice', 'ExterQual', 'Foundation'), 0.9080840621469868),
#  (('SalePrice', 'ExterQual', 'HeatingQC'), 0.9080210096502253),
#  (('SalePrice', 'GarageArea', 'ExterQual'), 0.9079125618988549),
#  (('SalePrice', 'BedroomAbvGr', 'Foundation'), 0.9078942982812992),
#  (('SalePrice', 'Electrical', 'SaleCondition'), 0.907889395572837),
#  (('SalePrice', 'Exterior1st', 'Electrical'), 0.9078854122062816),
#  (('SalePrice', 'BsmtFinType1', 'Electrical'), 0.9078760643694077),
#  (('SalePrice', '2ndFlrSF', 'Electrical'), 0.9078235404602477),
#  (('SalePrice', 'Exterior2nd', 'Electrical'), 0.9077780204003493),
#  (('SalePrice', 'Electrical', 'SaleType'), 0.9077764651143192),
#  (('GrLivArea', 'SalePrice', 'GarageArea'), 0.9077713722559533),
#  (('SalePrice', 'Alley', 'Electrical'), 0.9077406917336206),
#  (('SalePrice', 'BedroomAbvGr', 'HeatingQC'), 0.9077195294043899),
#  (('SalePrice', 'TotalBsmtSF', 'Electrical'), 0.9076867050553904),
#  (('SalePrice', 'MasVnrArea', 'GarageArea'), 0.9076009087164252),
#  (('GrLivArea', 'SalePrice', 'BsmtFinType1'), 0.9075904880182549),
#  (('SalePrice', 'GarageArea', 'FireplaceQu'), 0.9075855635446743),
#  (('SalePrice', 'GarageArea', 'HeatingQC'), 0.9075833378433426),
#  (('SalePrice', 'GarageArea', 'HouseStyle'), 0.9075329683635717),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtFinType1'), 0.9074812644290762),
#  (('SalePrice', 'MSZoning', 'Electrical'), 0.9074559251123206),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtCond'), 0.9074548594176757),
#  (('SalePrice', 'RoofStyle', 'Electrical'), 0.9074462506842154),
#  (('SalePrice', 'GarageArea', 'BsmtCond'), 0.9074350511981534),
#  (('SalePrice', 'BsmtUnfSF', 'Electrical'), 0.9074296092222786),
#  (('GrLivArea', 'SalePrice', 'Foundation'), 0.907424784165194),
#  (('SalePrice', 'MasVnrType', 'Electrical'), 0.9074203038197346),
#  (('SalePrice', 'Fireplaces', 'GarageArea'), 0.9074202627614876),
#  (('SalePrice', 'Street', 'Electrical'), 0.9074148357239702),
#  (('SalePrice', 'MSSubClass', 'Electrical'), 0.9074071077009506),
#  (('SalePrice', 'OpenPorchSF', 'Electrical'), 0.9073919324618402),
#  (('GrLivArea', 'SalePrice', 'BsmtCond'), 0.9073860285076801),
#  (('SalePrice', 'BedroomAbvGr', 'OverallCond'), 0.9073694161346042),
#  (('SalePrice', 'GarageArea', 'Foundation'), 0.907334351439157),
#  (('SalePrice', 'MasVnrArea', 'BedroomAbvGr'), 0.9073218305345228),
#  (('SalePrice', '1stFlrSF', 'Electrical'), 0.9073162922259438),
#  (('SalePrice', 'Electrical', 'PoolQC'), 0.907303195955458),
#  (('SalePrice', 'TotalBsmtSF', 'HouseStyle'), 0.9072882130371426),
#  (('SalePrice', 'Heating', 'Electrical'), 0.9072644331363768),
#  (('GrLivArea', 'SalePrice', 'OverallCond'), 0.90724728877605),
#  (('SalePrice', 'LotFrontage', 'Electrical'), 0.907244988470191),
#  (('SalePrice', 'HalfBath', 'GarageArea'), 0.9072303393636955),
#  (('SalePrice', 'Electrical', 'Functional'), 0.9072154220873693),
#  (('SalePrice', 'BedroomAbvGr', 'FireplaceQu'), 0.9071912683543503),
#  (('SalePrice', 'Condition1', 'Electrical'), 0.9071795042852332),
#  (('SalePrice', 'WoodDeckSF', 'Electrical'), 0.9071452019847052),
#  (('SalePrice', 'LandContour', 'Electrical'), 0.9071146654024108),
#  (('SalePrice', 'Condition2', 'Electrical'), 0.9071103159671127),
#  (('SalePrice', 'EnclosedPorch', 'Electrical'), 0.9071016403879242),
#  (('SalePrice', 'Fireplaces', 'Foundation'), 0.9070974957854857),
#  (('GrLivArea', 'SalePrice', 'HeatingQC'), 0.9070859799356742),
#  (('SalePrice', 'OverallCond', 'ExterCond'), 0.9070637941386891),
#  (('SalePrice', 'Utilities', 'Electrical'), 0.907051180642487),
#  (('SalePrice', 'GarageArea', 'BsmtFinType1'), 0.9070480020387537),
#  (('SalePrice', 'Neighborhood', 'Electrical'), 0.9070238413034832),
#  (('SalePrice', 'Electrical', 'GarageFinish'), 0.9069983746648063),
#  (('SalePrice', 'BedroomAbvGr', 'Fireplaces'), 0.9069976922706715),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageArea'), 0.9069938099600092),
#  (('SalePrice', 'RoofMatl', 'Electrical'), 0.9069930152821494),
#  (('SalePrice', 'Electrical', 'KitchenQual'), 0.9069841776914876),
#  (('SalePrice', 'KitchenAbvGr', 'Electrical'), 0.9069811780560265),
#  (('SalePrice', 'BsmtExposure', 'Electrical'), 0.9069801956302896),
#  (('SalePrice', 'LowQualFinSF', 'Electrical'), 0.9069780472785066),
#  (('SalePrice', 'MasVnrArea', 'MasVnrType'), 0.9069720131431372),
#  (('SalePrice', 'OverallCond', 'FireplaceQu'), 0.9069639423930218),
#  (('SalePrice', '3SsnPorch', 'Electrical'), 0.9069575416064519),
#  (('SalePrice', 'MoSold', 'Electrical'), 0.9069537367770937),
#  (('SalePrice', 'LandSlope', 'Electrical'), 0.9069491167715485),
#  (('SalePrice', 'ScreenPorch', 'Electrical'), 0.9069441394665634),
#  (('SalePrice', 'HouseStyle', 'OverallCond'), 0.9069428179739363),
#  (('SalePrice', 'BsmtFinSF2', 'Electrical'), 0.90694260147007),
#  (('SalePrice', 'Electrical', 'MiscFeature'), 0.906935872574977),
#  (('SalePrice', 'Electrical', 'BsmtHalfBath'), 0.9069339825158571),
#  (('SalePrice', 'LotConfig', 'Electrical'), 0.9069316083299779),
#  (('SalePrice', 'Foundation', 'BsmtCond'), 0.9069292291488611),
#  (('SalePrice', 'BedroomAbvGr', 'LotShape'), 0.9069282589966992),
#  (('GrLivArea', 'SalePrice', 'MasVnrArea'), 0.9069252842539323),
#  (('SalePrice', 'GarageArea', 'LotShape'), 0.9069250988619151),
#  (('SalePrice', 'BsmtFinSF1', 'Electrical'), 0.9069243364028371),
#  (('SalePrice', 'BsmtFinType2', 'Electrical'), 0.906924226175449),
#  (('SalePrice', 'Electrical', 'BsmtFullBath'), 0.9069229534635741),
#  (('SalePrice', 'Electrical', 'Fence'), 0.9069206274041279),
#  (('SalePrice', 'MiscVal', 'Electrical'), 0.9069115875355835),
#  (('SalePrice', 'LotArea', 'Electrical'), 0.9069091446378788),
#  (('SalePrice', 'PoolArea', 'Electrical'), 0.9069061161555043),
#  (('SalePrice', 'BldgType', 'Electrical'), 0.9069052900619193),
#  (('SalePrice', 'BsmtQual', 'Electrical'), 0.9069001539001607),
#  (('SalePrice', 'YrSold', 'Electrical'), 0.9069001514321949),
#  (('SalePrice', 'GarageYrBlt', 'Electrical'), 0.9069001514321949),
#  (('SalePrice', 'YearBuilt', 'Electrical'), 0.9069001514321949),
#  (('SalePrice', 'YearRemodAdd', 'Electrical'), 0.9069001514321949),
#  (('SalePrice', 'BedroomAbvGr', 'ExterCond'), 0.9068962758843389),
#  (('SalePrice', 'HouseStyle', 'ExterQual'), 0.9068836525283959),
#  (('SalePrice', 'BedroomAbvGr', 'HouseStyle'), 0.9068407242301507),
#  (('SalePrice', 'BedroomAbvGr', 'Alley'), 0.9068162117337384),
#  (('SalePrice', 'GarageArea', 'ExterCond'), 0.9068129247687199),
#  (('SalePrice', 'MasVnrArea', 'HouseStyle'), 0.9067712537988409),
#  (('SalePrice', 'BedroomAbvGr', 'ExterQual'), 0.9067508092955077),
#  (('SalePrice', 'HeatingQC', 'FireplaceQu'), 0.9067378247897295),
#  (('SalePrice', 'OverallCond', 'HeatingQC'), 0.9066992343284888),
#  (('SalePrice', 'GarageArea', 'Alley'), 0.9066887155304004),
#  (('SalePrice', 'BedroomAbvGr', 'SaleCondition'), 0.9066542707523841),
#  (('SalePrice', 'HouseStyle', 'BsmtCond'), 0.9066263775981404),
#  (('SalePrice', 'Foundation', 'FireplaceQu'), 0.9066173015096676),
#  (('GrLivArea', 'SalePrice', 'ExterQual'), 0.9066169172217423),
#  (('SalePrice', '2ndFlrSF', 'GarageArea'), 0.9066126954649104),
#  (('SalePrice', 'Fireplaces', 'HeatingQC'), 0.9065993751644914),
#  (('SalePrice', 'HouseStyle', 'HeatingQC'), 0.9065983375844103),
#  (('SalePrice', 'OverallCond', 'BsmtCond'), 0.9065958434901303),
#  (('SalePrice', 'ExterQual', 'BsmtCond'), 0.9065904951436436),
#  (('SalePrice', 'BsmtCond', 'FireplaceQu'), 0.9065885654351086),
#  (('SalePrice', 'GarageArea', 'SaleType'), 0.9065868456938961),
#  (('GrLivArea', 'SalePrice', 'LotShape'), 0.9065780616545488),
#  (('SalePrice', 'GarageArea', 'SaleCondition'), 0.9065730051004257),
#  (('GrLivArea', 'SalePrice', 'ExterCond'), 0.9065628471807128),
#  (('SalePrice', 'BsmtCond', 'HeatingQC'), 0.9065460746700212),
#  (('SalePrice', 'MasVnrArea', 'BsmtCond'), 0.9065407589636924),
#  (('SalePrice', 'HalfBath', 'OverallCond'), 0.9065370051712033),
# ...
#  (('SalePrice', 'LotShape', 'OverallCond'), 0.9063070971284051),
#  (('SalePrice', 'BsmtUnfSF', 'BsmtFinType1'), 0.9063007627979296),
#  (('SalePrice', 'GarageArea', 'RoofStyle'), 0.9062707158615992),
#  (('SalePrice', 'HouseStyle', 'FireplaceQu'), 0.906264342491952),
#  (('SalePrice', 'TotalBsmtSF', '2ndFlrSF'), 0.9062582051402163),
#  (('GrLivArea', 'SalePrice', 'SaleCondition'), 0.9062546923508769),
#  (('SalePrice', 'Alley', 'OverallCond'), 0.9062520693016908),
#  (('SalePrice', 'HalfBath', 'ExterQual'), 0.9062520618155333),
#  (('SalePrice', 'BedroomAbvGr', 'MSZoning'), 0.906247465070358),
#  (('SalePrice', 'LotShape', 'ExterQual'), 0.9062456048071982),
#  (('SalePrice', '1stFlrSF', 'HouseStyle'), 0.9062438417236158),
#  (('SalePrice', 'LotFrontage', 'GarageArea'), 0.9062421372569581),
#  (('SalePrice', 'GarageArea', 'Exterior2nd'), 0.9062310110430561),
#  (('SalePrice', 'BedroomAbvGr', 'Heating'), 0.9062247003501825),
#  (('SalePrice', 'TotRmsAbvGrd', 'OverallCond'), 0.9062164031916322),
#  (('SalePrice', 'TotalBsmtSF', 'GarageArea'), 0.9062120517439466),
#  (('SalePrice', 'Alley', 'ExterQual'), 0.9062099364917781),
#  (('SalePrice', 'GarageArea', 'Street'), 0.9062066540995771),
#  (('SalePrice', 'MasVnrArea', 'HalfBath'), 0.90620631188988),
#  (('SalePrice', 'HalfBath', 'BedroomAbvGr'), 0.906194814192919),
#  (('GrLivArea', 'SalePrice', 'TotalBsmtSF'), 0.9061931849758094),
#  (('SalePrice', 'HouseStyle', 'BsmtFinType1'), 0.9061749602982815),
#  (('SalePrice', 'LotFrontage', 'BedroomAbvGr'), 0.9061291972605704),
#  (('SalePrice', 'TotRmsAbvGrd', 'HeatingQC'), 0.9061223028189958),
#  (('SalePrice', 'TotalBsmtSF', 'Foundation'), 0.9061206429526779),
#  (('SalePrice', 'GarageArea', 'MSZoning'), 0.9061081886405904),
#  (('SalePrice', 'MasVnrArea', 'HeatingQC'), 0.9061071920381127),
#  (('SalePrice', 'BedroomAbvGr', 'SaleType'), 0.9060942775579255),
#  (('SalePrice', 'LotShape', 'Foundation'), 0.9060862384249209),
#  (('SalePrice', 'GarageArea', 'GarageFinish'), 0.9060844539241287),
#  (('SalePrice', 'LotShape', 'HeatingQC'), 0.9060814636168143),
#  (('SalePrice', 'BedroomAbvGr', 'Exterior2nd'), 0.9060801490082371),
#  (('SalePrice', 'MasVnrArea', 'OverallCond'), 0.9060783462654622),
#  (('SalePrice', 'GarageArea', 'Functional'), 0.9060744383647088),
#  (('SalePrice', 'HalfBath', 'Foundation'), 0.9060717946921132),
#  (('SalePrice', 'MasVnrArea', 'Fireplaces'), 0.9060655610365568),
#  (('SalePrice', 'BedroomAbvGr', 'EnclosedPorch'), 0.9060439803825625),
#  (('GrLivArea', 'SalePrice', 'Fireplaces'), 0.9060378286374582),
#  (('SalePrice', 'Fireplaces', 'ExterQual'), 0.9060342429214019),
#  (('SalePrice', 'ExterQual', 'SaleCondition'), 0.9060299372260978),
#  (('SalePrice', 'TotalBsmtSF', 'OverallCond'), 0.9060255025770324),
#  (('SalePrice', 'HalfBath', 'BsmtCond'), 0.9060245399772165),
#  (('SalePrice', 'ExterCond', 'FireplaceQu'), 0.9060178560739882),
#  (('SalePrice', 'Exterior1st', 'ExterQual'), 0.90601697816335),
#  (('SalePrice', 'LotShape', 'BsmtCond'), 0.9060117676604813),
#  (('SalePrice', 'BedroomAbvGr', 'RoofStyle'), 0.9060081966495057),
#  (('SalePrice', 'GarageArea', 'OpenPorchSF'), 0.9060070162290234),
#  (('SalePrice', 'GarageArea', 'Condition1'), 0.9060057212158181),
#  (('SalePrice', 'ExterCond', 'HeatingQC'), 0.9060008512914772),
#  (('SalePrice', 'BsmtFinType1', 'FireplaceQu'), 0.9059988557694798),
#  (('SalePrice', 'MasVnrArea', 'BsmtFinType1'), 0.9059969129937749),
#  (('SalePrice', 'ExterQual', 'BsmtFinType1'), 0.9059965917220572),
#  (('SalePrice', 'GarageArea', 'EnclosedPorch'), 0.9059861240338178),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtExposure'), 0.9059828190908115),
#  (('SalePrice', 'ExterQual', 'ExterCond'), 0.905980675471556),
#  (('SalePrice', 'Foundation', 'HeatingQC'), 0.9059786754141071),
#  (('GrLivArea', 'SalePrice', 'Heating'), 0.9059710748403792),
#  (('SalePrice', 'HalfBath', 'HeatingQC'), 0.905969871707688),
#  (('SalePrice', 'GarageArea', 'Utilities'), 0.9059668529246012),
#  (('SalePrice', 'LotShape', 'HouseStyle'), 0.9059586261356428),
#  (('SalePrice', 'TotRmsAbvGrd', 'FireplaceQu'), 0.9059544287814191),
#  (('SalePrice', 'GarageArea', 'MSSubClass'), 0.9059459395099595),
#  (('SalePrice', 'GarageArea', 'WoodDeckSF'), 0.905945269969324),
#  (('SalePrice', 'BsmtCond', 'BsmtFinType1'), 0.905944285752947),
#  (('SalePrice', 'HalfBath', 'BsmtFinType1'), 0.9059418650997804),
#  (('SalePrice', 'HouseStyle', 'ExterCond'), 0.905940034330043),
#  (('SalePrice', 'GarageArea', 'PoolQC'), 0.9059351568618688),
#  (('SalePrice', 'BedroomAbvGr', 'MasVnrType'), 0.9059334613929281),
#  (('SalePrice', 'OverallCond', 'BsmtFinType1'), 0.9059327676089279),
#  (('SalePrice', 'MSZoning', 'ExterQual'), 0.9059070089898696),
#  (('SalePrice', 'TotRmsAbvGrd', 'ExterQual'), 0.9059054901563414),
#  (('SalePrice', 'Fireplaces', 'FireplaceQu'), 0.9059052900391538),
#  (('GrLivArea', 'SalePrice', 'Functional'), 0.9059048868292292),
#  (('SalePrice', 'MasVnrArea', 'TotRmsAbvGrd'), 0.905902773586378),
#  (('GrLivArea', 'SalePrice', 'KitchenAbvGr'), 0.9058986979202993),
#  (('SalePrice', 'BedroomAbvGr', 'BldgType'), 0.9058944499882086),
#  (('SalePrice', 'BsmtUnfSF', 'GarageArea'), 0.9058910492957761),
#  (('SalePrice', 'MSZoning', 'OverallCond'), 0.9058827895201426),
#  (('SalePrice', 'LotShape', 'FireplaceQu'), 0.9058745624370799),
#  (('GrLivArea', 'SalePrice', 'Exterior1st'), 0.9058687860511955),
#  (('SalePrice', 'BedroomAbvGr', 'WoodDeckSF'), 0.9058654652951845),
#  (('SalePrice', 'KitchenAbvGr', 'GarageArea'), 0.9058620286194226),
#  (('SalePrice', 'GarageArea', 'Condition2'), 0.9058555150331177),
#  (('SalePrice', 'BedroomAbvGr', 'Functional'), 0.9058535430691794),
#  (('SalePrice', 'GarageArea', 'Neighborhood'), 0.9058534140044867),
#  (('SalePrice', 'BedroomAbvGr', 'Condition1'), 0.9058488252908419),
#  (('SalePrice', 'HouseStyle', 'Exterior1st'), 0.9058423621619507),
#  (('GrLivArea', 'SalePrice', 'MSZoning'), 0.9058303897741451),
#  (('SalePrice', 'FireplaceQu', 'SaleCondition'), 0.9058282571583505),
#  (('SalePrice', 'HouseStyle', 'SaleCondition'), 0.9058112346698447),
#  (('SalePrice', 'BedroomAbvGr', 'Street'), 0.9058109433248946),
#  (('SalePrice', 'HalfBath', 'FireplaceQu'), 0.9057899411443169),
#  (('GrLivArea', 'SalePrice', 'BedroomAbvGr'), 0.9057856417969974),
#  (('SalePrice', 'GarageArea', 'LandContour'), 0.9057819869680458),
#  (('SalePrice', 'TotalBsmtSF', 'FireplaceQu'), 0.9057816925215878),
#  (('SalePrice', 'BedroomAbvGr', 'OpenPorchSF'), 0.905780310353324),
#  (('SalePrice', 'Alley', 'HouseStyle'), 0.9057724408579471),
#  (('SalePrice', 'Alley', 'FireplaceQu'), 0.9057650734614048),
#  (('SalePrice', 'BedroomAbvGr', 'PoolQC'), 0.9057616307644557),
#  (('SalePrice', 'TotalBsmtSF', 'ExterQual'), 0.9057561148777062),
#  (('GrLivArea', 'SalePrice', 'EnclosedPorch'), 0.9057522635543649),
#  (('GrLivArea', 'SalePrice', 'SaleType'), 0.9057481853785668),
#  (('SalePrice', 'MasVnrArea', 'ExterCond'), 0.9057398050794125),
#  (('SalePrice', 'GarageArea', 'BsmtExposure'), 0.9057290339790234),
#  (('SalePrice', 'MasVnrArea', 'LotShape'), 0.9057233965647115),
#  (('SalePrice', 'Exterior2nd', 'ExterQual'), 0.9057228607280591),
#  (('GrLivArea', 'SalePrice', 'BsmtExposure'), 0.9057216674546756),
#  (('SalePrice', '1stFlrSF', 'GarageArea'), 0.9057177112444214),
#  (('SalePrice', 'BedroomAbvGr', 'GarageFinish'), 0.905714099344511),
#  (('SalePrice', 'Fireplaces', 'ExterCond'), 0.905708110994748),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtFullBath'), 0.9057065088452065),
#  (('SalePrice', 'Foundation', 'SaleCondition'), 0.9057046225441111),
#  (('SalePrice', 'GarageArea', 'BldgType'), 0.9056937828809797),
#  (('SalePrice', 'BedroomAbvGr', 'Utilities'), 0.9056860332672486),
#  (('SalePrice', 'BsmtCond', 'SaleCondition'), 0.9056837872289434),
#  (('SalePrice', 'Alley', 'HeatingQC'), 0.9056824478943545),
#  (('SalePrice', 'GarageArea', 'RoofMatl'), 0.9056734437537648),
#  (('SalePrice', 'HalfBath', 'Fireplaces'), 0.9056689962452515),
#  (('SalePrice', 'Exterior1st', 'FireplaceQu'), 0.9056683141861454),
#  (('SalePrice', 'BedroomAbvGr', 'LandContour'), 0.9056672902607982),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtQual'), 0.9056671385928121),
#  (('SalePrice', 'MasVnrArea', 'Alley'), 0.9056665118052456),
#  (('SalePrice', 'ExterCond', 'Foundation'), 0.9056656667801692),
#  (('SalePrice', 'GarageArea', 'KitchenQual'), 0.9056636142299196),
#  (('SalePrice', 'BsmtFinSF2', 'GarageArea'), 0.9056611707649598),
#  (('SalePrice', 'LowQualFinSF', 'GarageArea'), 0.9056610881148544),
#  (('SalePrice', 'Alley', 'BsmtCond'), 0.9056599848384219),
#  (('SalePrice', 'TotRmsAbvGrd', 'HouseStyle'), 0.9056593633006561),
#  (('SalePrice', 'OverallCond', 'SaleCondition'), 0.9056579529507836),
#  (('SalePrice', 'GarageArea', '3SsnPorch'), 0.9056541776884748),
#  (('SalePrice', 'GarageArea', 'MiscFeature'), 0.905646550967383),
#  (('SalePrice', 'GarageArea', 'BsmtFullBath'), 0.9056444344623876),
#  (('SalePrice', 'TotalBsmtSF', 'HeatingQC'), 0.905643193144851),
#  (('SalePrice', 'Foundation', 'Heating'), 0.905641245680919),
#  (('SalePrice', 'ExterQual', 'Heating'), 0.9056400974732751),
#  (('SalePrice', 'GarageArea', 'BsmtHalfBath'), 0.9056394351409907),
#  (('SalePrice', '1stFlrSF', 'BedroomAbvGr'), 0.9056361429286788),
#  (('SalePrice', 'GarageArea', 'LandSlope'), 0.9056342663203166),
#  (('GrLivArea', 'SalePrice', 'Exterior2nd'), 0.9056341594803121),
#  (('SalePrice', 'GarageArea', 'ScreenPorch'), 0.9056278111155915),
#  (('SalePrice', 'GarageArea', 'Fence'), 0.9056266807964074),
#  (('SalePrice', 'GarageArea', 'MiscVal'), 0.9056258163972325),
#  (('SalePrice', 'TotRmsAbvGrd', 'LotShape'), 0.9056242121567883),
#  (('SalePrice', 'GarageArea', 'MoSold'), 0.9056238267367783),
#  (('SalePrice', 'GarageArea', 'BsmtFinType2'), 0.9056143213962873),
#  (('SalePrice', 'HouseStyle', 'Exterior2nd'), 0.9056105832084376),
#  (('SalePrice', 'BsmtUnfSF', 'HouseStyle'), 0.9056061271212329),
#  (('SalePrice', 'GarageArea', 'PoolArea'), 0.9056035969551819),
#  (('SalePrice', 'BsmtFinSF1', 'GarageArea'), 0.9056007955154987),
#  (('SalePrice', 'GarageArea', 'LotConfig'), 0.9056002476831022),
#  (('SalePrice', 'LotArea', 'GarageArea'), 0.9055982435704351),
#  (('SalePrice', 'GarageArea', 'BsmtQual'), 0.9055981525724901),
#  (('SalePrice', 'GarageArea', 'YrSold'), 0.905597157756543),
#  (('SalePrice', 'GarageArea', 'GarageYrBlt'), 0.905597157756543),
#  (('SalePrice', 'GarageArea', 'YearBuilt'), 0.905597157756543),
#  (('SalePrice', 'GarageArea', 'YearRemodAdd'), 0.905597157756543),
#  (('SalePrice', 'Alley', 'Foundation'), 0.9055950123070694),
#  (('SalePrice', 'BsmtUnfSF', 'ExterQual'), 0.9055887473676566),
#  (('SalePrice', '1stFlrSF', 'HalfBath'), 0.9055881059906752),
#  (('SalePrice', 'Fireplaces', 'BsmtFinType1'), 0.9055826428703773),
#  (('SalePrice', '2ndFlrSF', 'Foundation'), 0.9055797362468025),
#  (('SalePrice', '2ndFlrSF', 'BsmtCond'), 0.9055740985666831),
#  (('SalePrice', 'BedroomAbvGr', 'Condition2'), 0.9055647252245685),
#  (('SalePrice', 'OverallCond', 'Exterior1st'), 0.9055588007322067),
#  (('SalePrice', 'Fireplaces', 'LotShape'), 0.9055513534950734),
#  (('SalePrice', 'TotRmsAbvGrd', 'Alley'), 0.9055502258183479),
#  (('SalePrice', 'Exterior1st', 'BsmtCond'), 0.9055451442484599),
#  (('GrLivArea', 'SalePrice', 'MasVnrType'), 0.9055412342624969),
#  (('SalePrice', 'HalfBath', 'LotShape'), 0.9055409861609328),
#  (('SalePrice', 'OverallCond', 'MasVnrType'), 0.9055396867398471),
#  (('GrLivArea', 'SalePrice', 'HalfBath'), 0.9055310696147437),
#  (('SalePrice', 'LowQualFinSF', 'BedroomAbvGr'), 0.9055287867159779),
#  (('SalePrice', 'TotRmsAbvGrd', 'ExterCond'), 0.9055280538970781),
#  (('SalePrice', 'Foundation', 'SaleType'), 0.9055276927806235),
#  (('GrLivArea', 'SalePrice', 'LotFrontage'), 0.9055257887578719),
#  (('SalePrice', 'ExterQual', 'SaleType'), 0.9055252378885584),
#  (('SalePrice', '2ndFlrSF', 'BsmtFinType1'), 0.9055189236771297),
#  (('SalePrice', 'MasVnrType', 'Foundation'), 0.9055168291071177),
#  (('SalePrice', 'BsmtUnfSF', 'BedroomAbvGr'), 0.9055108378116555),
#  (('SalePrice', 'BedroomAbvGr', 'Neighborhood'), 0.9055095194717839),
#  (('SalePrice', '2ndFlrSF', 'ExterQual'), 0.9055079004950423),
#  (('SalePrice', 'BedroomAbvGr', '3SsnPorch'), 0.9055026009579339),
#  (('SalePrice', 'BsmtFinSF2', 'BedroomAbvGr'), 0.9055022094840495),
#  (('SalePrice', 'ExterCond', 'BsmtCond'), 0.9055011984157423),
#  (('SalePrice', 'Exterior2nd', 'FireplaceQu'), 0.9055010193611222),
#  (('SalePrice', 'Fireplaces', 'Alley'), 0.9055000738373403),
#  (('SalePrice', 'OpenPorchSF', 'ExterQual'), 0.9054985046201692),
#  (('SalePrice', 'Exterior1st', 'Foundation'), 0.9054983449961421),
#  (('SalePrice', 'TotRmsAbvGrd', 'Fireplaces'), 0.9054956050393476),
#  (('GrLivArea', 'SalePrice', 'Condition1'), 0.9054892561526661),
#  (('GrLivArea', 'SalePrice', 'RoofStyle'), 0.9054818812127999),
#  (('SalePrice', 'HeatingQC', 'SaleCondition'), 0.9054797550446199),
#  (('SalePrice', 'BsmtFinSF1', 'BedroomAbvGr'), 0.9054775882820881),
#  (('SalePrice', 'BedroomAbvGr', 'RoofMatl'), 0.9054700233178269),
#  (('SalePrice', 'HouseStyle', 'Heating'), 0.9054680635986792),
#  (('SalePrice', 'ExterCond', 'BsmtFinType1'), 0.9054581739330567),
#  (('SalePrice', 'RoofStyle', 'ExterQual'), 0.9054459908760224),
#  (('SalePrice', 'Heating', 'FireplaceQu'), 0.9054449117833516),
#  (('SalePrice', 'MasVnrType', 'ExterQual'), 0.9054409286691415),
#  (('SalePrice', 'MasVnrType', 'HeatingQC'), 0.9054362594213141),
#  (('SalePrice', 'HalfBath', 'ExterCond'), 0.9054254484128874),
#  (('SalePrice', 'EnclosedPorch', 'ExterQual'), 0.9054221020465478),
#  (('SalePrice', 'BedroomAbvGr', 'MSSubClass'), 0.9054215324958125),
#  (('SalePrice', 'HouseStyle', 'SaleType'), 0.9054169364139365),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtHalfBath'), 0.9054152608405893),
#  (('SalePrice', 'LotArea', 'BedroomAbvGr'), 0.9054129111712497),
#  (('SalePrice', 'BedroomAbvGr', 'ScreenPorch'), 0.9054096305351721),
#  (('SalePrice', 'BedroomAbvGr', 'MoSold'), 0.9054088737647582),
#  (('SalePrice', 'BedroomAbvGr', 'LandSlope'), 0.9054060938261641),
#  (('SalePrice', 'BedroomAbvGr', 'MiscFeature'), 0.9054059585091381),
#  (('SalePrice', 'Fireplaces', 'SaleCondition'), 0.9054052640057965),
#  (('SalePrice', '2ndFlrSF', 'BedroomAbvGr'), 0.9054033123239655),
#  (('SalePrice', 'BedroomAbvGr', 'LotConfig'), 0.90540316949437),
#  (('SalePrice', 'BedroomAbvGr', 'MiscVal'), 0.9054011929253117),
#  (('SalePrice', 'BedroomAbvGr', 'Fence'), 0.9054004854609783),
#  (('SalePrice', 'Heating', 'HeatingQC'), 0.9053995615554462),
#  (('SalePrice', 'BedroomAbvGr', 'PoolArea'), 0.9053966219941454),
#  (('SalePrice', 'BedroomAbvGr', 'KitchenQual'), 0.9053933163576139),
#  (('SalePrice', 'LotFrontage', 'ExterQual'), 0.905392614221981),
#  (('SalePrice', '2ndFlrSF', 'OverallCond'), 0.9053917368769039),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtFinType2'), 0.905390820085242),
#  (('SalePrice', 'BedroomAbvGr', 'TotRmsAbvGrd'), 0.9053906979745512),
#  (('SalePrice', 'BedroomAbvGr', 'YrSold'), 0.9053906503151964),
#  (('SalePrice', 'BedroomAbvGr', 'GarageYrBlt'), 0.9053906503151964),
#  (('SalePrice', 'BedroomAbvGr', 'YearBuilt'), 0.9053906503151964),
#  (('SalePrice', 'BedroomAbvGr', 'YearRemodAdd'), 0.9053906503151964),
#  (('GrLivArea', 'SalePrice', 'Street'), 0.9053896429329795),
#  (('SalePrice', 'MasVnrArea', 'TotalBsmtSF'), 0.9053879182019726),
#  (('SalePrice', 'FireplaceQu', 'SaleType'), 0.9053850211218372),
#  (('GrLivArea', 'SalePrice', 'PoolQC'), 0.9053769372341417),
#  (('SalePrice', 'LotShape', 'BsmtFinType1'), 0.9053693598062025),
#  (('SalePrice', 'BsmtCond', 'SaleType'), 0.9053686913802039),
#  (('SalePrice', 'Condition1', 'ExterQual'), 0.9053647294096323),
#  (('GrLivArea', 'SalePrice', 'WoodDeckSF'), 0.9053623898166608),
#  (('SalePrice', 'Exterior2nd', 'BsmtCond'), 0.9053586061417803),
#  (('GrLivArea', 'SalePrice', 'LandContour'), 0.9053541926280836),
#  (('SalePrice', 'MSZoning', 'FireplaceQu'), 0.9053509894778105),
#  (('SalePrice', 'OverallCond', 'Exterior2nd'), 0.9053466024061805),
#  (('SalePrice', 'HeatingQC', 'SaleType'), 0.9053409970104348),
#  (('SalePrice', 'LotShape', 'ExterCond'), 0.9053349762979844),
#  (('SalePrice', 'OverallCond', 'RoofStyle'), 0.9053340187694345),
#  (('SalePrice', 'MSSubClass', 'Foundation'), 0.9053281249886287),
#  (('SalePrice', 'ExterQual', 'PoolQC'), 0.9053256405711725),
#  ...]

# %%
import statsmodels.api as sm
x = sm.add_constant(housing_factor_dummified1)
model = sm.OLS(log_SalePrice, x.astype(float))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     776.4
# Date:                Fri, 17 May 2024   Prob (F-statistic):               0.00
# Time:                        02:01:24   Log-Likelihood:                 2882.9
# No. Observations:                2580   AIC:                            -5616.
# Df Residuals:                    2505   BIC:                            -5177.
# Df Model:                          74
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          6.681e-07   4.44e-09    150.508      0.000    6.59e-07    6.77e-07
# GrLivArea      2.856e-05    1.1e-05      2.585      0.010     6.9e-06    5.02e-05
# SalePrice      3.558e-06   6.17e-08     57.643      0.000    3.44e-06    3.68e-06
# LotFrontage   -4.241e-05    5.4e-05     -0.785      0.433      -0.000    6.36e-05
# LotArea        4.785e-07   2.42e-07      1.978      0.048    4.07e-09    9.53e-07
# MasVnrArea    -9.383e-05   1.21e-05     -7.750      0.000      -0.000   -7.01e-05
# BsmtFinSF1     3.408e-06   5.57e-06      0.612      0.540   -7.51e-06    1.43e-05
# BsmtFinSF2      1.95e-05   1.02e-05      1.909      0.056   -5.29e-07    3.95e-05
# BsmtUnfSF      1.045e-05   5.25e-06      1.991      0.047    1.58e-07    2.07e-05
# TotalBsmtSF    3.335e-05   6.35e-06      5.250      0.000    2.09e-05    4.58e-05
# 1stFlrSF       3.487e-05   1.14e-05      3.061      0.002    1.25e-05    5.72e-05
# 2ndFlrSF       7.744e-06   1.06e-05      0.732      0.464    -1.3e-05    2.85e-05
# LowQualFinSF  -1.405e-05   2.81e-05     -0.500      0.617   -6.91e-05     4.1e-05
# FullBath          0.0285      0.005      5.913      0.000       0.019       0.038
# HalfBath          0.0154      0.005      3.274      0.001       0.006       0.025
# BedroomAbvGr      0.0067      0.003      2.120      0.034       0.001       0.013
# KitchenAbvGr     -0.0166      0.011     -1.479      0.139      -0.039       0.005
# TotRmsAbvGrd      0.0028      0.002      1.233      0.218      -0.002       0.007
# Fireplaces        0.0074      0.003      2.371      0.018       0.001       0.014
# GarageCars        0.0207      0.005      3.945      0.000       0.010       0.031
# GarageArea    -2.462e-05   1.82e-05     -1.350      0.177   -6.04e-05    1.11e-05
# WoodDeckSF     1.741e-06   1.39e-05      0.125      0.901   -2.56e-05    2.91e-05
# OpenPorchSF    2.448e-05   2.68e-05      0.914      0.361    -2.8e-05     7.7e-05
# EnclosedPorch  5.834e-05   2.69e-05      2.166      0.030    5.53e-06       0.000
# 3SsnPorch      7.494e-05   6.35e-05      1.181      0.238   -4.95e-05       0.000
# ScreenPorch    8.383e-05   2.96e-05      2.836      0.005    2.59e-05       0.000
# PoolArea       4.886e-05   5.92e-05      0.825      0.409   -6.73e-05       0.000
# MiscVal        8.479e-07   3.32e-06      0.256      0.798   -5.66e-06    7.35e-06
# YrSold            0.0013   8.74e-06    150.508      0.000       0.001       0.001
# GarageYrBlt       0.0013   8.74e-06    150.508      0.000       0.001       0.001
# MoSold           -0.0001      0.001     -0.229      0.819      -0.001       0.001
# YearBuilt         0.0013   8.74e-06    150.508      0.000       0.001       0.001
# YearRemodAdd      0.0013   8.74e-06    150.508      0.000       0.001       0.001
# MSSubClass        0.0024      0.001      3.081      0.002       0.001       0.004
# MSZoning         -0.0109      0.002     -4.807      0.000      -0.015      -0.006
# Street            0.0594      0.027      2.172      0.030       0.006       0.113
# Alley             0.0181      0.007      2.600      0.009       0.004       0.032
# LotShape         -0.0022      0.001     -1.701      0.089      -0.005       0.000
# LandContour       0.0023      0.003      0.863      0.388      -0.003       0.007
# Utilities        -0.0426      0.060     -0.715      0.475      -0.160       0.074
# LotConfig         0.0002      0.001      0.178      0.859      -0.002       0.002
# LandSlope         0.0110      0.008      1.401      0.161      -0.004       0.026
# Neighborhood     -0.0005      0.000     -2.000      0.046      -0.001   -9.81e-06
# Condition1        0.0017      0.002      0.854      0.393      -0.002       0.005
# Condition2       -0.0101      0.008     -1.302      0.193      -0.025       0.005
# BldgType          0.0023      0.002      1.091      0.275      -0.002       0.006
# HouseStyle       -0.0001      0.001     -0.097      0.923      -0.003       0.002
# OverallQual       0.0324      0.002     19.769      0.000       0.029       0.036
# OverallCond       0.0235      0.002     13.470      0.000       0.020       0.027
# RoofStyle        -0.0035      0.002     -1.618      0.106      -0.008       0.001
# RoofMatl         -0.0004      0.003     -0.132      0.895      -0.006       0.006
# Exterior1st    5.909e-06      0.001      0.006      0.995      -0.002       0.002
# Exterior2nd       0.0023      0.001      2.549      0.011       0.001       0.004
# MasVnrType       -0.0072      0.003     -2.273      0.023      -0.013      -0.001
# ExterQual         0.0126      0.004      3.325      0.001       0.005       0.020
# ExterCond         0.0078      0.002      3.484      0.001       0.003       0.012
# Foundation        0.0110      0.003      3.753      0.000       0.005       0.017
# BsmtQual          0.0016      0.001      1.157      0.247      -0.001       0.004
# BsmtCond          0.0014      0.002      0.762      0.446      -0.002       0.005
# BsmtExposure     -0.0030      0.002     -1.718      0.086      -0.007       0.000
# BsmtFinType1     -0.0045      0.001     -4.559      0.000      -0.006      -0.003
# BsmtFinType2      0.0016      0.002      0.864      0.388      -0.002       0.005
# Heating           0.0086      0.007      1.196      0.232      -0.005       0.023
# HeatingQC        -0.0056      0.001     -4.984      0.000      -0.008      -0.003
# CentralAir        0.0817      0.008      9.662      0.000       0.065       0.098
# Electrical        0.0068      0.002      2.969      0.003       0.002       0.011
# BsmtFullBath      0.0126      0.004      3.009      0.003       0.004       0.021
# BsmtHalfBath     -0.0009      0.007     -0.138      0.890      -0.014       0.012
# KitchenQual      -0.0007      0.002     -0.382      0.702      -0.004       0.003
# Functional        0.0024      0.002      1.258      0.208      -0.001       0.006
# FireplaceQu       0.0031      0.001      2.103      0.036       0.000       0.006
# GarageType       -0.0080      0.001     -7.157      0.000      -0.010      -0.006
# GarageFinish     -0.0004      0.002     -0.216      0.829      -0.004       0.003
# GarageQual        0.0046      0.002      2.182      0.029       0.000       0.009
# GarageCond        0.0126      0.003      4.897      0.000       0.008       0.018
# PavedDrive        0.0544      0.008      7.207      0.000       0.040       0.069
# PoolQC            0.0217      0.016      1.332      0.183      -0.010       0.054
# Fence             0.0001      0.002      0.095      0.924      -0.003       0.003
# MiscFeature      -0.0038      0.005     -0.848      0.396      -0.013       0.005
# SaleType          0.0023      0.001      2.224      0.026       0.000       0.004
# SaleCondition     0.0172      0.003      6.833      0.000       0.012       0.022
# ==============================================================================
# Omnibus:                     1963.713   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131114.689
# Skew:                          -3.015   Prob(JB):                         0.00
# Kurtosis:                      37.399   Cond. No.                     7.61e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.67e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
pValues = results.pvalues
print('The significant coefficients')
pValues[pValues < .05].sort_values()
# Out:
# The significant coefficients
# const            0.000000e+00
# SalePrice        0.000000e+00
# YearRemodAdd     0.000000e+00
# YearBuilt        0.000000e+00
# GarageYrBlt      0.000000e+00
# YrSold           0.000000e+00
# OverallQual      5.920069e-81
# OverallCond      5.577631e-40
# CentralAir       1.035978e-21
# MasVnrArea       1.329458e-14
# PavedDrive       7.531266e-13
# GarageType       1.081757e-12
# SaleCondition    1.043782e-11
# FullBath         3.817228e-09
# TotalBsmtSF      1.646532e-07
# HeatingQC        6.655345e-07
# GarageCond       1.037555e-06
# MSZoning         1.619790e-06
# BsmtFinType1     5.389562e-06
# GarageCars       8.196979e-05
# Foundation       1.790091e-04
# ExterCond        5.033064e-04
# ExterQual        8.967568e-04
# HalfBath         1.075941e-03
# MSSubClass       2.084107e-03
# 1stFlrSF         2.225772e-03
# BsmtFullBath     2.643063e-03
# Electrical       3.014733e-03
# ScreenPorch      4.604397e-03
# Alley            9.364588e-03
# GrLivArea        9.783960e-03
# Exterior2nd      1.084907e-02
# Fireplaces       1.783841e-02
# MasVnrType       2.308972e-02
# SaleType         2.621376e-02
# GarageQual       2.919667e-02
# Street           2.992846e-02
# EnclosedPorch    3.038432e-02
# BedroomAbvGr     3.406230e-02
# FireplaceQu      3.554646e-02
# Neighborhood     4.556265e-02
# BsmtUnfSF        4.658641e-02
# LotArea          4.807026e-02
# dtype: float64

# %%
print('The insignificant coefficients')
pValues[pValues > .05]
# Out:
# The insignificant coefficients
# LotFrontage     0.432668
# BsmtFinSF1      0.540385
# BsmtFinSF2      0.056367
# 2ndFlrSF        0.463962
# LowQualFinSF    0.616787
# KitchenAbvGr    0.139303
# TotRmsAbvGrd    0.217533
# GarageArea      0.177063
# WoodDeckSF      0.900585
# OpenPorchSF     0.360768
# 3SsnPorch       0.237693
# PoolArea        0.409365
# MiscVal         0.798250
# MoSold          0.818503
# LotShape        0.089087
# LandContour     0.388032
# Utilities       0.474568
# LotConfig       0.858762
# LandSlope       0.161194
# Condition1      0.393255
# Condition2      0.193154
# BldgType        0.275329
# HouseStyle      0.922981
# RoofStyle       0.105854
# RoofMatl        0.895183
# Exterior1st     0.995281
# BsmtQual        0.247273
# BsmtCond        0.446050
# BsmtExposure    0.085964
# BsmtFinType2    0.387753
# Heating         0.231822
# BsmtHalfBath    0.889972
# KitchenQual     0.702128
# Functional      0.208400
# GarageFinish    0.829100
# PoolQC          0.182911
# Fence           0.924301
# MiscFeature     0.396294
# dtype: float64
