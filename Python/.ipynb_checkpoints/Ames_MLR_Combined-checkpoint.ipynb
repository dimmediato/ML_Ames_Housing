# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
housing = pd.read_csv("~/Documents/NYCDSA/Third Project/ML_Ames_Housing/data/Ames_Housing_Price_Data.csv", index_col=0)
housing.head() #OPEN DATA FRAME
pd.set_option('display.max_columns', 500)
housing.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 1  909176150        856     126000          30       RL          NaN     7890
# 2  905476230       1049     139500         120       RL         42.0     4235
# 3  911128020       1001     124900          30  C (all)         60.0     6060
# 4  535377150       1039     114000          70       RL         80.0     8146
# 5  534177230       1665     227000          60       RL         70.0     8400
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 1   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 2   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 4   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 5   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 1        SWISU       Norm       Norm     1Fam     1Story            6
# 2      Edwards       Norm       Norm   TwnhsE     1Story            5
# 3       IDOTRR       Norm       Norm     1Fam     1Story            5
# 4      OldTown       Norm       Norm     1Fam     2Story            4
# 5       NWAmes       Norm       Norm     1Fam     2Story            8
#
#    OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 1            6       1939          1950     Gable  CompShg     Wd Sdng
# 2            5       1984          1984     Gable  CompShg     HdBoard
# 3            9       1930          2007       Hip  CompShg     MetalSd
# 4            8       1900          2003     Gable  CompShg     MetalSd
# 5            6       2001          2001     Gable  CompShg     VinylSd
#
#   Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# 1     Wd Sdng        NaN         0.0        TA        TA     CBlock       TA
# 2     HdBoard    BrkFace       149.0        Gd        TA     CBlock       Gd
# 3     MetalSd        NaN         0.0        Gd        TA     BrkTil       TA
# 4     MetalSd        NaN         0.0        Gd        Gd     BrkTil       Fa
# 5     VinylSd        NaN         0.0        Gd        TA      PConc       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1       TA           No          Rec       238.0          Unf         0.0
# 2       TA           Mn          GLQ       552.0          ALQ       393.0
# 3       TA           No          ALQ       737.0          Unf         0.0
# 4       TA           No          Unf         0.0          Unf         0.0
# 5       TA           No          GLQ       643.0          Unf         0.0
#
#    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  \
# 1      618.0        856.0    GasA        TA          Y      SBrkr       856
# 2      104.0       1049.0    GasA        TA          Y      SBrkr      1049
# 3      100.0        837.0    GasA        Ex          Y      SBrkr      1001
# 4      405.0        405.0    GasA        Gd          Y      SBrkr       717
# 5      167.0        810.0    GasA        Ex          Y      SBrkr       810
#
#    2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 1         0             0           1.0           0.0         1         0
# 2         0             0           1.0           0.0         2         0
# 3         0             0           0.0           0.0         1         0
# 4       322             0           0.0           0.0         1         0
# 5       855             0           1.0           0.0         2         1
#
#    BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 1             2             1          TA             4        Typ
# 2             2             1          Gd             5        Typ
# 3             2             1          Gd             5        Typ
# 4             2             1          TA             6        Typ
# 5             3             1          Gd             6        Typ
#
#    Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 1           1          Gd     Detchd       1939.0          Unf         2.0
# 2           0         NaN     Attchd       1984.0          Fin         1.0
# 3           0         NaN     Detchd       1930.0          Unf         1.0
# 4           0         NaN     Detchd       1940.0          Unf         1.0
# 5           0         NaN     Attchd       2001.0          Fin         2.0
#
#    GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 1       399.0         TA         TA          Y           0            0
# 2       266.0         TA         TA          Y           0          105
# 3       216.0         TA         Po          N         154            0
# 4       281.0         TA         TA          N           0            0
# 5       528.0         TA         TA          Y           0           45
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 1              0          0          166         0    NaN   NaN         NaN
# 2              0          0            0         0    NaN   NaN         NaN
# 3             42         86            0         0    NaN   NaN         NaN
# 4            168          0          111         0    NaN   NaN         NaN
# 5              0          0            0         0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition
# 1        0       3    2010      WD         Normal
# 2        0       2    2009      WD         Normal
# 3        0      11    2007      WD         Normal
# 4        0       5    2009      WD         Normal
# 5        0      11    2009      WD         Normal

# %%
#Create seperate numeric-set
housing_numeric = housing[['GrLivArea','SalePrice','LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                         '2ndFlrSF','LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
                           'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',  'GarageCars',
                           'GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch',
                           '3SsnPorch','ScreenPorch','PoolArea','MiscVal', "YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd']].copy()
#housing_numeric['PID'] = housing_numeric['PID'].astype('str')
#housing_numeric['YrSold'] = pd.to_datetime(housing_numeric['YrSold']).dt.strftime('%Y')
#housing_numeric['GarageYrBlt'] = pd.to_datetime(housing_numeric['GarageYrBlt']).dt.strftime('%Y')
#housing_numeric['YearBuilt'] = pd.to_datetime(housing_numeric['YearBuilt']).dt.strftime('%Y')
#housing_numeric['YearRemodAdd'] = pd.to_datetime(housing_numeric['YearRemodAdd']).dt.strftime('%Y')
#housing_numeric['MoSold'] = pd.to_datetime(housing_numeric['MoSold'],format='%m').dt.strftime('%m')
#housing_numeric['GarageYrBlt'] = housing_numeric['GarageYrBlt'].fillna('1970') #903426160 and 910201180 do have a garage built, but an NA for all others, filled with mode
housing_numeric.fillna(housing_numeric.mean(), inplace=True)
years = housing_numeric[["YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd']].copy()
housing_numeric.to_pickle('housing_numeric.pkl')
housing_numeric['TotalSF'] = housing_numeric['TotalBsmtSF'] + housing_numeric['1stFlrSF'] + housing_numeric['2ndFlrSF']
housing_numeric['TotalBath'] = housing_numeric['BsmtFullBath'] + (housing_numeric['BsmtHalfBath']*0.5) + housing_numeric['FullBath'] + (housing_numeric['HalfBath']*0.5)
housing_numeric
# Out:
#      GrLivArea  SalePrice  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  \
# 1          856     126000    68.516053     7890         0.0       238.0
# 2         1049     139500    42.000000     4235       149.0       552.0
# 3         1001     124900    60.000000     6060         0.0       737.0
# 4         1039     114000    80.000000     8146         0.0         0.0
# 5         1665     227000    70.000000     8400         0.0       643.0
# ..         ...        ...          ...      ...         ...         ...
# 759        952     121000    68.516053     8854         0.0         0.0
# 760       1733     139600    68.516053    13680         0.0         0.0
# 761       2002     145000    82.000000     6270         0.0       284.0
# 762       1842     217500    68.516053     8826       144.0       841.0
# 763       1911     215000    80.000000     9554       125.0       380.0
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1           0.0      618.0        856.0       856         0             0
# 2         393.0      104.0       1049.0      1049         0             0
# 3           0.0      100.0        837.0      1001         0             0
# 4           0.0      405.0        405.0       717       322             0
# 5           0.0      167.0        810.0       810       855             0
# ..          ...        ...          ...       ...       ...           ...
# 759         0.0      952.0        952.0       952         0             0
# 760         0.0        0.0          0.0      1733         0             0
# 761         0.0      717.0       1001.0      1001      1001             0
# 762         0.0      144.0        985.0       985       857             0
# 763         0.0      397.0        777.0      1065       846             0
#
#      BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 1             1.0           0.0         1         0             2
# 2             1.0           0.0         2         0             2
# 3             0.0           0.0         1         0             2
# 4             0.0           0.0         1         0             2
# 5             1.0           0.0         2         1             3
# ..            ...           ...       ...       ...           ...
# 759           0.0           0.0         1         0             2
# 760           0.0           0.0         2         0             4
# 761           0.0           0.0         2         0             4
# 762           1.0           0.0         2         1             3
# 763           0.0           0.0         2         1             3
#
#      KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  \
# 1               1             4           1         2.0       399.0
# 2               1             5           0         1.0       266.0
# 3               1             5           0         1.0       216.0
# 4               1             6           0         1.0       281.0
# 5               1             6           0         2.0       528.0
# ..            ...           ...         ...         ...         ...
# 759             1             4           1         1.0       192.0
# 760             1             8           1         2.0       452.0
# 761             2             8           0         3.0       871.0
# 762             1             7           1         2.0       486.0
# 763             1             8           1         2.0       471.0
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 1             0            0              0          0          166         0
# 2             0          105              0          0            0         0
# 3           154            0             42         86            0         0
# 4             0            0            168          0          111         0
# 5             0           45              0          0            0         0
# ..          ...          ...            ...        ...          ...       ...
# 759           0           98              0          0           40         0
# 760           0            0              0          0            0         0
# 761           0            0              0          0            0         0
# 762         193           96              0          0            0         0
# 763         182           81              0          0            0         0
#
#      MiscVal  YrSold  GarageYrBlt  MoSold  YearBuilt  YearRemodAdd  TotalSF  \
# 1          0    2010       1939.0       3       1939          1950   1712.0
# 2          0    2009       1984.0       2       1984          1984   2098.0
# 3          0    2007       1930.0      11       1930          2007   1838.0
# 4          0    2009       1940.0       5       1900          2003   1444.0
# 5          0    2009       2001.0      11       2001          2001   2475.0
# ..       ...     ...          ...     ...        ...           ...      ...
# 759        0    2009       1916.0       5       1916          1950   1904.0
# 760        0    2009       1955.0       6       1955          1955   1733.0
# 761        0    2007       1949.0       8       1949          1950   3003.0
# 762        0    2007       2000.0       7       2000          2000   2827.0
# 763        0    2006       1993.0       9       1993          1994   2688.0
#
#      TotalBath
# 1          2.0
# 2          3.0
# 3          1.0
# 4          1.0
# 5          3.5
# ..         ...
# 759        1.0
# 760        2.0
# 761        2.0
# 762        3.5
# 763        2.5
#
# [2580 rows x 36 columns]

# %%
#Create seperate factor-set
housing_factor = housing.drop(['GrLivArea','SalePrice','LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                         '2ndFlrSF','LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath','FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',  'GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal', "YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd'], axis=1)
housing_factor['PavedDrive'] = housing_factor.PavedDrive.apply(lambda Paved: 1 if Paved != "N" else 0)
housing_factor['CentralAir'] = housing_factor.CentralAir.apply(lambda Central: 1 if Central != "N" else 0) #Convert Y/N to Booleon 
housing_factor[['PID','MSSubClass','OverallQual','OverallCond']] = housing_factor[['PID','MSSubClass','OverallQual','OverallCond']].astype(str)
housing_factor[['PavedDrive','CentralAir']] = housing_factor[['PavedDrive','CentralAir']].astype('bool')
housing_factor #transform all integers into categorical variables
housing_factor.dtypes[housing_factor.dtypes == 'int64']
housing_factor
# Out:
#            PID MSSubClass MSZoning Street Alley LotShape LandContour  \
# 1    909176150         30       RL   Pave   NaN      Reg         Lvl
# 2    905476230        120       RL   Pave   NaN      Reg         Lvl
# 3    911128020         30  C (all)   Pave   NaN      Reg         Lvl
# 4    535377150         70       RL   Pave   NaN      Reg         Lvl
# 5    534177230         60       RL   Pave   NaN      Reg         Lvl
# ..         ...        ...      ...    ...   ...      ...         ...
# 759  903205040         30       RL   Pave   NaN      Reg         Lvl
# 760  905402060         20       RL   Pave   NaN      IR1         Lvl
# 761  909275030         90       RH   Pave   NaN      Reg         HLS
# 762  907192040         60       RL   Pave   NaN      Reg         Lvl
# 763  906223180         60       RL   Pave   NaN      IR1         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1      AllPub    Corner       Gtl        SWISU       Norm       Norm     1Fam
# 2      AllPub    Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 3      AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 4      AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 5      AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ..        ...       ...       ...          ...        ...        ...      ...
# 759    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 760    AllPub   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 761    AllPub    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 762    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 763    AllPub    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond RoofStyle RoofMatl Exterior1st  \
# 1       1Story           6           6     Gable  CompShg     Wd Sdng
# 2       1Story           5           5     Gable  CompShg     HdBoard
# 3       1Story           5           9       Hip  CompShg     MetalSd
# 4       2Story           4           8     Gable  CompShg     MetalSd
# 5       2Story           8           6     Gable  CompShg     VinylSd
# ..         ...         ...         ...       ...      ...         ...
# 759     1.5Unf           6           6     Gable  CompShg     Wd Sdng
# 760     1Story           3           5       Hip  CompShg     BrkFace
# 761     2Story           5           6     Gable  CompShg     MetalSd
# 762     2Story           7           5     Gable  CompShg     VinylSd
# 763     2Story           8           5     Gable  CompShg     VinylSd
#
#     Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1       Wd Sdng        NaN        TA        TA     CBlock       TA       TA
# 2       HdBoard    BrkFace        Gd        TA     CBlock       Gd       TA
# 3       MetalSd        NaN        Gd        TA     BrkTil       TA       TA
# 4       MetalSd        NaN        Gd        Gd     BrkTil       Fa       TA
# 5       VinylSd        NaN        Gd        TA      PConc       Gd       TA
# ..          ...        ...       ...       ...        ...      ...      ...
# 759     Wd Sdng        NaN        TA        TA     BrkTil       TA       TA
# 760     Wd Sdng        NaN        TA        TA       Slab      NaN      NaN
# 761     MetalSd        NaN        TA        TA     CBlock       TA       TA
# 762     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 763     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#     BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  CentralAir  \
# 1             No          Rec          Unf    GasA        TA        True
# 2             Mn          GLQ          ALQ    GasA        TA        True
# 3             No          ALQ          Unf    GasA        Ex        True
# 4             No          Unf          Unf    GasA        Gd        True
# 5             No          GLQ          Unf    GasA        Ex        True
# ..           ...          ...          ...     ...       ...         ...
# 759           No          Unf          Unf    Grav        Fa       False
# 760          NaN          NaN          NaN    GasA        Ex        True
# 761           No          BLQ          Unf    GasA        TA       False
# 762           No          GLQ          Unf    GasA        Ex        True
# 763           No          GLQ          Unf    GasA        Ex        True
#
#     Electrical KitchenQual Functional FireplaceQu GarageType GarageFinish  \
# 1        SBrkr          TA        Typ          Gd     Detchd          Unf
# 2        SBrkr          Gd        Typ         NaN     Attchd          Fin
# 3        SBrkr          Gd        Typ         NaN     Detchd          Unf
# 4        SBrkr          TA        Typ         NaN     Detchd          Unf
# 5        SBrkr          Gd        Typ         NaN     Attchd          Fin
# ..         ...         ...        ...         ...        ...          ...
# 759      FuseF          Fa        Typ          Gd     Detchd          Unf
# 760      FuseA          TA       Min2          Gd     Attchd          Unf
# 761      FuseA          TA        Typ         NaN     2Types          Unf
# 762      SBrkr          Gd        Typ          TA     Attchd          Fin
# 763      SBrkr          Gd        Typ          TA     Attchd          RFn
#
#     GarageQual GarageCond  PavedDrive PoolQC Fence MiscFeature SaleType  \
# 1           TA         TA        True    NaN   NaN         NaN      WD
# 2           TA         TA        True    NaN   NaN         NaN      WD
# 3           TA         Po       False    NaN   NaN         NaN      WD
# 4           TA         TA       False    NaN   NaN         NaN      WD
# 5           TA         TA        True    NaN   NaN         NaN      WD
# ..         ...        ...         ...    ...   ...         ...      ...
# 759         Fa         Po        True    NaN   NaN         NaN      WD
# 760         TA         TA        True    NaN   NaN         NaN      WD
# 761         TA         TA        True    NaN   NaN         NaN      WD
# 762         TA         TA        True    NaN   NaN         NaN      WD
# 763         TA         TA        True    NaN   NaN         NaN      WD
#
#     SaleCondition
# 1          Normal
# 2          Normal
# 3          Normal
# 4          Normal
# 5          Normal
# ..            ...
# 759        Normal
# 760        Normal
# 761        Normal
# 762        Normal
# 763        Normal
#
# [2580 rows x 47 columns]

# %%
#Get rid of all NAs
housing_factor['MiscFeature'] = housing_factor['MiscFeature'].fillna('NoFeature')
housing_factor['PoolQC'] = housing_factor['PoolQC'].fillna('NoPool')
housing_factor['Fence'] = housing_factor['Fence'].fillna('NoFence')
housing_factor['GarageQual'] = housing_factor['GarageQual'].fillna('NoGarage')
housing_factor['GarageCond'] = housing_factor['GarageCond'].fillna('NoGarage')
housing_factor['GarageFinish'] = housing_factor['GarageFinish'].fillna('NoGarage')
housing_factor['GarageType'] = housing_factor['GarageType'].fillna('NoGarage')
housing_factor['FireplaceQu'] = housing_factor['FireplaceQu'].fillna('NoFireplace')
housing_factor['BsmtFinType2'] = housing_factor['BsmtFinType2'].fillna('NoBsmt') #528142130 has a basement, but NA for values
housing_factor['BsmtFinType1'] = housing_factor['BsmtFinType1'].fillna('NoBsmt')
housing_factor['BsmtExposure'] = housing_factor['BsmtExposure'].fillna('NoBsmt')
housing_factor['BsmtCond'] = housing_factor['BsmtCond'].fillna('NoBsmt')
housing_factor['BsmtQual'] = housing_factor['BsmtQual'].fillna('NoBsmt') #916386080 is missing an electrical value  veneer
housing_factor['MasVnrType'] = housing_factor['MasVnrType'].fillna('NoVeneer')
housing_factor['Alley'] = housing_factor['Alley'].fillna('NoAlley')

housing_factor.to_pickle('housing_factor.pkl')
housing_factor['MixedExterior'] = housing_factor['Exterior1st'] + ' - ' + housing_factor['Exterior2nd']
housing_factor
# Out:
#            PID MSSubClass MSZoning Street    Alley LotShape LandContour  \
# 1    909176150         30       RL   Pave  NoAlley      Reg         Lvl
# 2    905476230        120       RL   Pave  NoAlley      Reg         Lvl
# 3    911128020         30  C (all)   Pave  NoAlley      Reg         Lvl
# 4    535377150         70       RL   Pave  NoAlley      Reg         Lvl
# 5    534177230         60       RL   Pave  NoAlley      Reg         Lvl
# ..         ...        ...      ...    ...      ...      ...         ...
# 759  903205040         30       RL   Pave  NoAlley      Reg         Lvl
# 760  905402060         20       RL   Pave  NoAlley      IR1         Lvl
# 761  909275030         90       RH   Pave  NoAlley      Reg         HLS
# 762  907192040         60       RL   Pave  NoAlley      Reg         Lvl
# 763  906223180         60       RL   Pave  NoAlley      IR1         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1      AllPub    Corner       Gtl        SWISU       Norm       Norm     1Fam
# 2      AllPub    Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 3      AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 4      AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 5      AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ..        ...       ...       ...          ...        ...        ...      ...
# 759    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 760    AllPub   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 761    AllPub    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 762    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 763    AllPub    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond RoofStyle RoofMatl Exterior1st  \
# 1       1Story           6           6     Gable  CompShg     Wd Sdng
# 2       1Story           5           5     Gable  CompShg     HdBoard
# 3       1Story           5           9       Hip  CompShg     MetalSd
# 4       2Story           4           8     Gable  CompShg     MetalSd
# 5       2Story           8           6     Gable  CompShg     VinylSd
# ..         ...         ...         ...       ...      ...         ...
# 759     1.5Unf           6           6     Gable  CompShg     Wd Sdng
# 760     1Story           3           5       Hip  CompShg     BrkFace
# 761     2Story           5           6     Gable  CompShg     MetalSd
# 762     2Story           7           5     Gable  CompShg     VinylSd
# 763     2Story           8           5     Gable  CompShg     VinylSd
#
#     Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1       Wd Sdng   NoVeneer        TA        TA     CBlock       TA       TA
# 2       HdBoard    BrkFace        Gd        TA     CBlock       Gd       TA
# 3       MetalSd   NoVeneer        Gd        TA     BrkTil       TA       TA
# 4       MetalSd   NoVeneer        Gd        Gd     BrkTil       Fa       TA
# 5       VinylSd   NoVeneer        Gd        TA      PConc       Gd       TA
# ..          ...        ...       ...       ...        ...      ...      ...
# 759     Wd Sdng   NoVeneer        TA        TA     BrkTil       TA       TA
# 760     Wd Sdng   NoVeneer        TA        TA       Slab   NoBsmt   NoBsmt
# 761     MetalSd   NoVeneer        TA        TA     CBlock       TA       TA
# 762     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 763     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#     BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  CentralAir  \
# 1             No          Rec          Unf    GasA        TA        True
# 2             Mn          GLQ          ALQ    GasA        TA        True
# 3             No          ALQ          Unf    GasA        Ex        True
# 4             No          Unf          Unf    GasA        Gd        True
# 5             No          GLQ          Unf    GasA        Ex        True
# ..           ...          ...          ...     ...       ...         ...
# 759           No          Unf          Unf    Grav        Fa       False
# 760       NoBsmt       NoBsmt       NoBsmt    GasA        Ex        True
# 761           No          BLQ          Unf    GasA        TA       False
# 762           No          GLQ          Unf    GasA        Ex        True
# 763           No          GLQ          Unf    GasA        Ex        True
#
#     Electrical KitchenQual Functional  FireplaceQu GarageType GarageFinish  \
# 1        SBrkr          TA        Typ           Gd     Detchd          Unf
# 2        SBrkr          Gd        Typ  NoFireplace     Attchd          Fin
# 3        SBrkr          Gd        Typ  NoFireplace     Detchd          Unf
# 4        SBrkr          TA        Typ  NoFireplace     Detchd          Unf
# 5        SBrkr          Gd        Typ  NoFireplace     Attchd          Fin
# ..         ...         ...        ...          ...        ...          ...
# 759      FuseF          Fa        Typ           Gd     Detchd          Unf
# 760      FuseA          TA       Min2           Gd     Attchd          Unf
# 761      FuseA          TA        Typ  NoFireplace     2Types          Unf
# 762      SBrkr          Gd        Typ           TA     Attchd          Fin
# 763      SBrkr          Gd        Typ           TA     Attchd          RFn
#
#     GarageQual GarageCond  PavedDrive  PoolQC    Fence MiscFeature SaleType  \
# 1           TA         TA        True  NoPool  NoFence   NoFeature      WD
# 2           TA         TA        True  NoPool  NoFence   NoFeature      WD
# 3           TA         Po       False  NoPool  NoFence   NoFeature      WD
# 4           TA         TA       False  NoPool  NoFence   NoFeature      WD
# 5           TA         TA        True  NoPool  NoFence   NoFeature      WD
# ..         ...        ...         ...     ...      ...         ...      ...
# 759         Fa         Po        True  NoPool  NoFence   NoFeature      WD
# 760         TA         TA        True  NoPool  NoFence   NoFeature      WD
# 761         TA         TA        True  NoPool  NoFence   NoFeature      WD
# 762         TA         TA        True  NoPool  NoFence   NoFeature      WD
# 763         TA         TA        True  NoPool  NoFence   NoFeature      WD
#
#     SaleCondition      MixedExterior
# 1          Normal  Wd Sdng - Wd Sdng
# 2          Normal  HdBoard - HdBoard
# 3          Normal  MetalSd - MetalSd
# 4          Normal  MetalSd - MetalSd
# 5          Normal  VinylSd - VinylSd
# ..            ...                ...
# 759        Normal  Wd Sdng - Wd Sdng
# 760        Normal  BrkFace - Wd Sdng
# 761        Normal  MetalSd - MetalSd
# 762        Normal  VinylSd - VinylSd
# 763        Normal  VinylSd - VinylSd
#
# [2580 rows x 48 columns]

# %%
from sklearn.preprocessing import LabelEncoder
SalePrice = housing['SalePrice'] #This is the target
housing_factor_dummified1 = housing_factor.drop(['PID'], axis=1)
label_encoder = LabelEncoder()
#housing_factor_dummified1[['MSZoning','Street','Alley',
#'LotShape','LandContour',
#'Utilities','LotConfig','LandSlope','Neighborhood',
#'Condition1','Condition2','BldgType','HouseStyle',
#'RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
#'MasVnrType','ExterQual','ExterCond','Foundation',
#'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
#'BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual',
#'Functional','FireplaceQu','GarageType','GarageFinish',
#'GarageQual','GarageCond','PoolQC','Fence','MiscFeature',
#'SaleType','SaleCondition']] = label_encoder.fit_transform(housing_factor_dummified1[['MSZoning','Street','Alley',
#'LotShape','LandContour',
#'Utilities','LotConfig','LandSlope','Neighborhood',
#'Condition1','Condition2','BldgType','HouseStyle',
#'RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
#'MasVnrType','ExterQual','ExterCond','Foundation',
#'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
#'BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual',
#'Functional','FireplaceQu','GarageType','GarageFinish',
#'GarageQual','GarageCond','PoolQC','Fence','MiscFeature',
#'SaleType','SaleCondition']])

housing_factor_dummified1= housing_factor_dummified1.apply(label_encoder.fit_transform)

housing_factor_dummified1 = pd.get_dummies(housing_factor_dummified1, drop_first = True)
housing_factor_dummified1
# Out:
#      MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 1             6         5       1      1         3            3          0
# 2             0         5       1      1         3            3          0
# 3             6         1       1      1         3            3          0
# 4            11         5       1      1         3            3          0
# 5            10         5       1      1         3            3          0
# ..          ...       ...     ...    ...       ...          ...        ...
# 759           6         5       1      1         3            3          0
# 760           5         5       1      1         0            3          0
# 761          15         4       1      1         3            1          0
# 762          10         5       1      1         3            3          0
# 763          10         5       1      1         0            3          0
#
#      LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 1            0          0            21           2           2         0
# 2            4          0             7           2           2         4
# 3            4          0            11           2           2         0
# 4            0          0            20           2           2         0
# 5            4          0            17           2           2         0
# ..         ...        ...           ...         ...         ...       ...
# 759          4          0             3           2           2         0
# 760          1          0             7           2           2         0
# 761          4          0             6           2           2         2
# 762          4          0             5           2           2         0
# 763          4          0            23           2           2         0
#
#      HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  Exterior1st  \
# 1             2            6            5          1         0           13
# 2             2            5            4          1         0            6
# 3             2            5            8          3         0            8
# 4             5            4            7          1         0            8
# 5             5            8            5          1         0           12
# ..          ...          ...          ...        ...       ...          ...
# 759           1            6            5          1         0           13
# 760           2            3            4          3         0            3
# 761           5            5            5          1         0            8
# 762           5            7            4          1         0           12
# 763           5            8            4          1         0           12
#
#      Exterior2nd  MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  \
# 1             14           2          3          4           1         5
# 2              6           1          2          4           1         2
# 3              8           2          2          4           0         5
# 4              8           2          2          2           0         1
# 5             13           2          2          4           2         2
# ..           ...         ...        ...        ...         ...       ...
# 759           14           2          3          4           0         5
# 760           14           2          3          4           3         3
# 761            8           2          3          4           1         5
# 762           13           1          2          4           2         2
# 763           13           1          2          4           2         2
#
#      BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  HeatingQC  \
# 1           5             3             5             6        1          4
# 2           5             2             2             0        1          4
# 3           5             3             0             6        1          0
# 4           5             3             6             6        1          2
# 5           5             3             2             6        1          0
# ..        ...           ...           ...           ...      ...        ...
# 759         5             3             6             6        3          1
# 760         3             4             4             4        1          0
# 761         5             3             1             6        1          4
# 762         5             3             2             6        1          0
# 763         5             3             2             6        1          0
#
#      CentralAir  Electrical  KitchenQual  Functional  FireplaceQu  GarageType  \
# 1             1           3            4           6            2           5
# 2             1           3            2           6            3           1
# 3             1           3            2           6            3           5
# 4             1           3            4           6            3           5
# 5             1           3            2           6            3           1
# ..          ...         ...          ...         ...          ...         ...
# 759           0           1            1           6            2           5
# 760           1           0            4           3            2           1
# 761           0           0            4           6            3           0
# 762           1           3            2           6            5           1
# 763           1           3            2           6            5           1
#
#      GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# 1               3           5           5           1       3      4
# 2               0           5           5           1       3      4
# 3               3           5           4           0       3      4
# 4               3           5           5           0       3      4
# 5               0           5           5           1       3      4
# ..            ...         ...         ...         ...     ...    ...
# 759             3           1           4           1       3      4
# 760             3           5           5           1       3      4
# 761             3           5           5           1       3      4
# 762             0           5           5           1       3      4
# 763             2           5           5           1       3      4
#
#      MiscFeature  SaleType  SaleCondition  MixedExterior
# 1              1         9              4             73
# 2              1         9              4             24
# 3              1         9              4             35
# 4              1         9              4             35
# 5              1         9              4             62
# ..           ...       ...            ...            ...
# 759            1         9              4             73
# 760            1         9              4             16
# 761            1         9              4             35
# 762            1         9              4             62
# 763            1         9              4             62
#
# [2580 rows x 47 columns]

# %%
pd.set_option('display.max_rows', 500)
#housing_numeric = pd.concat([housing_numeric, years], axis=1)
housing_numeric.to_pickle('housing_numeric.pkl')
housing_factor_dummified1 = pd.concat([housing_numeric, housing_factor_dummified1], axis=1)
#housing_factor_dummified1 = pd.concat([housing_factor_dummified1,housing_factor[["YrSold",'GarageYrBlt','MoSold','PavedDrive','YearBuilt', 'YearRemodAdd', 'CentralAir']]], axis = 1)
housing_factor_dummified1
# Out:
#      GrLivArea  SalePrice  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  \
# 1          856     126000    68.516053     7890         0.0       238.0
# 2         1049     139500    42.000000     4235       149.0       552.0
# 3         1001     124900    60.000000     6060         0.0       737.0
# 4         1039     114000    80.000000     8146         0.0         0.0
# 5         1665     227000    70.000000     8400         0.0       643.0
# ..         ...        ...          ...      ...         ...         ...
# 759        952     121000    68.516053     8854         0.0         0.0
# 760       1733     139600    68.516053    13680         0.0         0.0
# 761       2002     145000    82.000000     6270         0.0       284.0
# 762       1842     217500    68.516053     8826       144.0       841.0
# 763       1911     215000    80.000000     9554       125.0       380.0
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1           0.0      618.0        856.0       856         0             0
# 2         393.0      104.0       1049.0      1049         0             0
# 3           0.0      100.0        837.0      1001         0             0
# 4           0.0      405.0        405.0       717       322             0
# 5           0.0      167.0        810.0       810       855             0
# ..          ...        ...          ...       ...       ...           ...
# 759         0.0      952.0        952.0       952         0             0
# 760         0.0        0.0          0.0      1733         0             0
# 761         0.0      717.0       1001.0      1001      1001             0
# 762         0.0      144.0        985.0       985       857             0
# 763         0.0      397.0        777.0      1065       846             0
#
#      BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 1             1.0           0.0         1         0             2
# 2             1.0           0.0         2         0             2
# 3             0.0           0.0         1         0             2
# 4             0.0           0.0         1         0             2
# 5             1.0           0.0         2         1             3
# ..            ...           ...       ...       ...           ...
# 759           0.0           0.0         1         0             2
# 760           0.0           0.0         2         0             4
# 761           0.0           0.0         2         0             4
# 762           1.0           0.0         2         1             3
# 763           0.0           0.0         2         1             3
#
#      KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  \
# 1               1             4           1         2.0       399.0
# 2               1             5           0         1.0       266.0
# 3               1             5           0         1.0       216.0
# 4               1             6           0         1.0       281.0
# 5               1             6           0         2.0       528.0
# ..            ...           ...         ...         ...         ...
# 759             1             4           1         1.0       192.0
# 760             1             8           1         2.0       452.0
# 761             2             8           0         3.0       871.0
# 762             1             7           1         2.0       486.0
# 763             1             8           1         2.0       471.0
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 1             0            0              0          0          166         0
# 2             0          105              0          0            0         0
# 3           154            0             42         86            0         0
# 4             0            0            168          0          111         0
# 5             0           45              0          0            0         0
# ..          ...          ...            ...        ...          ...       ...
# 759           0           98              0          0           40         0
# 760           0            0              0          0            0         0
# 761           0            0              0          0            0         0
# 762         193           96              0          0            0         0
# 763         182           81              0          0            0         0
#
#      MiscVal  YrSold  GarageYrBlt  MoSold  YearBuilt  YearRemodAdd  TotalSF  \
# 1          0    2010       1939.0       3       1939          1950   1712.0
# 2          0    2009       1984.0       2       1984          1984   2098.0
# 3          0    2007       1930.0      11       1930          2007   1838.0
# 4          0    2009       1940.0       5       1900          2003   1444.0
# 5          0    2009       2001.0      11       2001          2001   2475.0
# ..       ...     ...          ...     ...        ...           ...      ...
# 759        0    2009       1916.0       5       1916          1950   1904.0
# 760        0    2009       1955.0       6       1955          1955   1733.0
# 761        0    2007       1949.0       8       1949          1950   3003.0
# 762        0    2007       2000.0       7       2000          2000   2827.0
# 763        0    2006       1993.0       9       1993          1994   2688.0
#
#      TotalBath  MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  \
# 1          2.0           6         5       1      1         3            3
# 2          3.0           0         5       1      1         3            3
# 3          1.0           6         1       1      1         3            3
# 4          1.0          11         5       1      1         3            3
# 5          3.5          10         5       1      1         3            3
# ..         ...         ...       ...     ...    ...       ...          ...
# 759        1.0           6         5       1      1         3            3
# 760        2.0           5         5       1      1         0            3
# 761        2.0          15         4       1      1         3            1
# 762        3.5          10         5       1      1         3            3
# 763        2.5          10         5       1      1         0            3
#
#      Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 1            0          0          0            21           2           2
# 2            0          4          0             7           2           2
# 3            0          4          0            11           2           2
# 4            0          0          0            20           2           2
# 5            0          4          0            17           2           2
# ..         ...        ...        ...           ...         ...         ...
# 759          0          4          0             3           2           2
# 760          0          1          0             7           2           2
# 761          0          4          0             6           2           2
# 762          0          4          0             5           2           2
# 763          0          4          0            23           2           2
#
#      BldgType  HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  \
# 1           0           2            6            5          1         0
# 2           4           2            5            4          1         0
# 3           0           2            5            8          3         0
# 4           0           5            4            7          1         0
# 5           0           5            8            5          1         0
# ..        ...         ...          ...          ...        ...       ...
# 759         0           1            6            5          1         0
# 760         0           2            3            4          3         0
# 761         2           5            5            5          1         0
# 762         0           5            7            4          1         0
# 763         0           5            8            4          1         0
#
#      Exterior1st  Exterior2nd  MasVnrType  ExterQual  ExterCond  Foundation  \
# 1             13           14           2          3          4           1
# 2              6            6           1          2          4           1
# 3              8            8           2          2          4           0
# 4              8            8           2          2          2           0
# 5             12           13           2          2          4           2
# ..           ...          ...         ...        ...        ...         ...
# 759           13           14           2          3          4           0
# 760            3           14           2          3          4           3
# 761            8            8           2          3          4           1
# 762           12           13           1          2          4           2
# 763           12           13           1          2          4           2
#
#      BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  \
# 1           5         5             3             5             6        1
# 2           2         5             2             2             0        1
# 3           5         5             3             0             6        1
# 4           1         5             3             6             6        1
# 5           2         5             3             2             6        1
# ..        ...       ...           ...           ...           ...      ...
# 759         5         5             3             6             6        3
# 760         3         3             4             4             4        1
# 761         5         5             3             1             6        1
# 762         2         5             3             2             6        1
# 763         2         5             3             2             6        1
#
#      HeatingQC  CentralAir  Electrical  KitchenQual  Functional  FireplaceQu  \
# 1            4           1           3            4           6            2
# 2            4           1           3            2           6            3
# 3            0           1           3            2           6            3
# 4            2           1           3            4           6            3
# 5            0           1           3            2           6            3
# ..         ...         ...         ...          ...         ...          ...
# 759          1           0           1            1           6            2
# 760          0           1           0            4           3            2
# 761          4           0           0            4           6            3
# 762          0           1           3            2           6            5
# 763          0           1           3            2           6            5
#
#      GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  \
# 1             5             3           5           5           1       3
# 2             1             0           5           5           1       3
# 3             5             3           5           4           0       3
# 4             5             3           5           5           0       3
# 5             1             0           5           5           1       3
# ..          ...           ...         ...         ...         ...     ...
# 759           5             3           1           4           1       3
# 760           1             3           5           5           1       3
# 761           0             3           5           5           1       3
# 762           1             0           5           5           1       3
# 763           1             2           5           5           1       3
#
#      Fence  MiscFeature  SaleType  SaleCondition  MixedExterior
# 1        4            1         9              4             73
# 2        4            1         9              4             24
# 3        4            1         9              4             35
# 4        4            1         9              4             35
# 5        4            1         9              4             62
# ..     ...          ...       ...            ...            ...
# 759      4            1         9              4             73
# 760      4            1         9              4             16
# 761      4            1         9              4             35
# 762      4            1         9              4             62
# 763      4            1         9              4             62
#
# [2580 rows x 83 columns]

# %%
from sklearn.linear_model import LinearRegression
#housing_factor_dummified1 = housing_factor_dummified1.drop(['PID'], axis=1)
lm = LinearRegression()
lm.fit(housing_factor_dummified1, housing['SalePrice'])
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
residuals = SalePrice - lm.predict(housing_factor_dummified1)
plt.hist(residuals)
# Out:
# (array([  17.,    0.,  160.,  301.,  545., 1063.,  389.,   74.,   29.,
#            2.]),
#  array([-2.32830644e-10, -1.86264515e-10, -1.39698386e-10, -9.31322575e-11,
#         -4.65661287e-11,  0.00000000e+00,  4.65661287e-11,  9.31322575e-11,
#          1.39698386e-10,  1.86264515e-10,  2.32830644e-10]),
#  <BarContainer object of 10 artists>)

# %%
print('R^2 is equal to %.3f' %(lm.score(housing_factor_dummified1,SalePrice))) #By default, score gives R^2. 
print('RSS is equal to %.3f' %(np.sum(residuals**2)))
print('The intercept is %.3f' %(lm.intercept_))
print('The slopes are %s' %(lm.coef_))
# Out:
# R^2 is equal to 1.000
# RSS is equal to 0.000
# The intercept is 0.000
# The slopes are [ 3.65747549e-14  1.00000000e+00  5.95704042e-14  1.11022302e-16
#  -4.26975079e-15  3.08750421e-14  8.42381720e-15 -7.10186033e-14
#  -3.17104741e-14  2.49886917e-15  7.13188189e-16  3.33662676e-14
#  -1.80783016e-12 -2.76405666e-13 -4.81700960e-13  9.72109031e-13
#   1.73797037e-13  1.46368355e-12  1.56780300e-13 -4.32387482e-13
#  -2.04518998e-12  5.35400717e-15  2.48011247e-16  5.03553633e-15
#  -1.08551135e-14 -8.84564638e-15 -2.59021388e-14 -2.09462100e-15
#   5.79328269e-15 -7.26296309e-13  5.17392119e-14  3.52182570e-13
#   3.12060490e-14  4.42136020e-14 -2.85047593e-14 -1.94167982e-12
#   6.92497139e-14  3.76704936e-13 -4.86270955e-12  8.70428068e-13
#  -6.53890873e-13 -4.12296329e-13 -2.94883413e-12  7.06544611e-13
#  -7.53836904e-13 -2.61405582e-14 -2.31540755e-13 -1.47053612e-12
#  -4.40931732e-13  2.96464852e-14  9.99002923e-14  7.92645311e-14
#   5.65049456e-13  4.89741274e-13  1.51897393e-12  2.56754745e-14
#   1.19782513e-12  1.60895293e-12 -5.51301254e-13 -3.02236745e-13
#  -1.34190493e-13 -1.40321883e-13 -1.15629680e-13 -3.83487867e-13
#   1.35462021e-12  5.05651372e-13 -8.41215359e-13 -1.79489587e-12
#  -8.81288222e-13  2.30258563e-13 -8.04369744e-14  3.23429947e-13
#  -4.10748272e-13  5.74572330e-13 -4.52490671e-13 -8.92112756e-14
#  -2.76099107e-12  8.02834237e-13 -7.01252537e-13  4.68239091e-13
#  -1.51099567e-13 -3.95912785e-13 -2.61486674e-13]

# %%
print('negative slope column names %s' %(housing_factor_dummified1.columns[lm.coef_ < 0]))
print('positive slope column names %s' %(housing_factor_dummified1.columns[lm.coef_ > 0]))
# Out:
# negative slope column names Index(['MasVnrArea', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'Fireplaces', 'GarageCars', 'EnclosedPorch',
#        '3SsnPorch', 'ScreenPorch', 'PoolArea', 'YrSold', 'TotalSF',
#        'TotalBath', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'HeatingQC', 'CentralAir', 'Electrical', 'Functional',
#        'GarageType', 'GarageQual', 'GarageCond', 'PavedDrive', 'Fence',
#        'SaleType', 'SaleCondition', 'MixedExterior'],
#       dtype='object')
# positive slope column names Index(['GrLivArea', 'SalePrice', 'LotFrontage', 'LotArea', 'BsmtFinSF1',
#        'BsmtFinSF2', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'MiscVal', 'GarageYrBlt', 'MoSold',
#        'YearBuilt', 'YearRemodAdd', 'MSSubClass', 'MSZoning', 'Alley',
#        'LotConfig', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'BsmtFinType2', 'Heating', 'KitchenQual', 'FireplaceQu', 'GarageFinish',
#        'PoolQC', 'MiscFeature'],
#       dtype='object')

# %%
log_SalePrice = np.log(SalePrice) #Take log of DV
lm.fit(housing_factor_dummified1, log_SalePrice) #LM of log of DV
residuals = log_SalePrice - lm.predict(housing_factor_dummified1)
plt.hist(residuals)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 4.000e+00, 1.100e+01,
#         1.070e+02, 1.877e+03, 5.700e+02, 9.000e+00]),
#  array([-1.28403876, -1.11817403, -0.95230929, -0.78644456, -0.62057983,
#         -0.45471509, -0.28885036, -0.12298562,  0.04287911,  0.20874385,
#          0.37460858]),
#  <BarContainer object of 10 artists>)

# %%
print('R^2 is equal to %.3f' %(lm.score(housing_factor_dummified1,log_SalePrice))) #By default, score gives R^2. 
print('RSS is equal to %.3f' %(np.sum(residuals**2)))
print('The intercept is %.3f' %(lm.intercept_))
print('The slopes are %s' %(lm.coef_))
# Out:
# R^2 is equal to 0.959
# RSS is equal to 15.686
# The intercept is 12.006
# The slopes are [ 2.85248987e-05  3.45732865e-06  2.45680270e-04  4.90706982e-07
#  -9.32950933e-05 -6.09186796e-06  1.20592180e-05  1.25014517e-07
#   6.09236460e-06  2.38127609e-05  2.74307325e-07  4.43783050e-06
#   3.77883359e-03  1.69949746e-03  6.94581098e-03  1.90437193e-03
#   5.58830359e-03 -1.67461883e-02  2.45439422e-03  1.13567184e-02
#   1.92334131e-02 -2.99568610e-05 -1.92585194e-06  2.29364460e-05
#   1.03365831e-04  7.44426040e-05  1.04657409e-04  3.10533470e-06
#   1.10072329e-06 -2.08621224e-03  1.99185929e-04 -3.09823843e-04
#   6.92153139e-04  4.14627028e-04  3.01794328e-05  1.25265793e-02
#   2.70356905e-03 -9.42585013e-03  5.44470746e-02  1.30367484e-02
#  -2.11422210e-03  4.22396880e-04 -4.68906670e-02  9.82545470e-05
#   1.06308828e-02 -4.33856607e-04  1.24083575e-03 -1.20940216e-02
#   3.16529690e-03 -1.68570955e-03  3.11450846e-02  2.56481267e-02
#  -2.65052012e-03  4.31525292e-05  4.81914643e-03  2.37605603e-03
#  -6.50794160e-03  1.39236166e-02  7.37579190e-03  3.22805300e-03
#   3.61396129e-03  8.52491261e-04 -1.76324958e-03 -3.81276926e-03
#   1.88662307e-03  1.09726174e-02 -4.56821560e-03  7.15996410e-02
#   3.81759950e-03  1.16160850e-03  2.77673679e-03  2.13945709e-03
#  -6.81754676e-03  2.13564369e-03  3.27046041e-03  1.20123918e-02
#   4.54620201e-02  1.88060055e-02 -2.48588350e-04 -3.26037218e-03
#   2.12885778e-03  1.77003064e-02 -8.23289196e-04]

# %%
scores = {}
for idx, name1 in enumerate(housing_factor_dummified1.columns):
        myColumns = housing_factor_dummified1.columns[(idx+1):]
        pass

# %%
from itertools import combinations 

scores = {}

combos = combinations(housing_factor_dummified1.columns, 3)

for c in combos:
    X = housing_factor_dummified1[list(c)]
    Y = log_SalePrice
    reg = LinearRegression().fit(X,Y)
    scores[c] = reg.score (X,Y)

# %%
sorted(scores.items(), key=lambda features_score: abs(features_score [1]), reverse = True)
# Out:
# [(('SalePrice', 'OverallQual', 'CentralAir'), 0.9335139587093141),
#  (('SalePrice', 'OverallQual', 'PavedDrive'), 0.9307352599242298),
#  (('SalePrice', 'OverallQual', 'GarageType'), 0.9299464898459083),
#  (('SalePrice', 'OverallQual', 'GarageCond'), 0.9298411132584817),
#  (('SalePrice', 'OverallQual', 'GarageQual'), 0.928336879056669),
#  (('SalePrice', 'TotalBath', 'OverallQual'), 0.9276014309563658),
#  (('SalePrice', 'OverallQual', 'ExterQual'), 0.9269506262461966),
#  (('SalePrice', 'BedroomAbvGr', 'OverallQual'), 0.9265768921309104),
#  (('SalePrice', 'TotalSF', 'OverallQual'), 0.9264297027962236),
#  (('SalePrice', 'YearBuilt', 'OverallQual'), 0.9264065033411554),
#  (('SalePrice', 'GarageCars', 'OverallQual'), 0.9261605385536777),
#  (('SalePrice', 'OverallQual', 'OverallCond'), 0.9259767470985246),
#  (('SalePrice', 'YearRemodAdd', 'OverallQual'), 0.9258634770691817),
#  (('SalePrice', 'OverallQual', 'Electrical'), 0.9257922076690069),
#  (('SalePrice', 'OverallQual', 'BsmtFinType1'), 0.9257661555242438),
#  (('SalePrice', 'FullBath', 'OverallQual'), 0.9257446506807475),
#  (('GrLivArea', 'SalePrice', 'OverallQual'), 0.9257284408135782),
#  (('SalePrice', 'GarageArea', 'OverallQual'), 0.9251694345301212),
#  (('SalePrice', 'TotRmsAbvGrd', 'OverallQual'), 0.9251103023362839),
#  (('SalePrice', 'OverallQual', 'FireplaceQu'), 0.9249817793183956),
#  (('SalePrice', 'MasVnrArea', 'OverallQual'), 0.924898310293201),
#  (('SalePrice', 'OverallQual', 'BsmtCond'), 0.9247054800688006),
#  (('SalePrice', 'Fireplaces', 'OverallQual'), 0.9245946348030294),
#  (('SalePrice', 'LotFrontage', 'OverallQual'), 0.9244963119962532),
#  (('SalePrice', 'MSSubClass', 'OverallQual'), 0.924476946133351),
#  (('SalePrice', 'OverallQual', 'KitchenQual'), 0.9244531202747281),
#  (('SalePrice', 'GarageYrBlt', 'OverallQual'), 0.9243789819161392),
#  (('SalePrice', '1stFlrSF', 'OverallQual'), 0.9243334210325969),
#  (('SalePrice', 'HouseStyle', 'OverallQual'), 0.9243069778177165),
#  (('SalePrice', 'HalfBath', 'OverallQual'), 0.9243031396430663),
#  (('SalePrice', 'OverallQual', 'SaleCondition'), 0.9242939604099306),
#  (('SalePrice', 'LotShape', 'OverallQual'), 0.9241453696782453),
#  (('SalePrice', 'OverallQual', 'BsmtQual'), 0.9241271355677704),
#  (('SalePrice', 'OverallQual', 'SaleType'), 0.9240421354871892),
#  (('SalePrice', 'OverallQual', 'Foundation'), 0.9240409380703345),
#  (('SalePrice', 'TotalBsmtSF', 'OverallQual'), 0.924039493991932),
#  (('SalePrice', 'LotArea', 'OverallQual'), 0.9240317787781609),
#  (('SalePrice', 'Alley', 'OverallQual'), 0.9240254861450932),
#  (('SalePrice', 'OverallQual', 'Heating'), 0.9239479845152789),
#  (('SalePrice', 'OverallQual', 'RoofStyle'), 0.9239208617267758),
#  (('SalePrice', 'OverallQual', 'HeatingQC'), 0.9239046879962327),
#  (('SalePrice', 'OverallQual', 'MasVnrType'), 0.9238609054338216),
#  (('SalePrice', '2ndFlrSF', 'OverallQual'), 0.9238321575611667),
#  (('SalePrice', 'WoodDeckSF', 'OverallQual'), 0.9238175815888796),
#  (('SalePrice', 'BsmtFullBath', 'OverallQual'), 0.9238013878420743),
#  (('SalePrice', 'OverallQual', 'ExterCond'), 0.9237903111121799),
#  (('SalePrice', 'BldgType', 'OverallQual'), 0.9237772091009968),
#  (('SalePrice', 'ScreenPorch', 'OverallQual'), 0.9237735863411793),
#  (('SalePrice', 'BsmtFinSF1', 'OverallQual'), 0.9237521855778527),
#  (('SalePrice', 'BsmtFinSF2', 'OverallQual'), 0.9237517112898054),
#  (('SalePrice', 'MSZoning', 'OverallQual'), 0.923750663174368),
#  (('SalePrice', 'Street', 'OverallQual'), 0.9237300652849173),
#  (('SalePrice', 'LandContour', 'OverallQual'), 0.9237037828801556),
#  (('SalePrice', 'Utilities', 'OverallQual'), 0.9237034211387933),
#  (('SalePrice', 'Condition1', 'OverallQual'), 0.9236924267954931),
#  (('SalePrice', 'BsmtHalfBath', 'OverallQual'), 0.9236918659531909),
#  (('SalePrice', 'OpenPorchSF', 'OverallQual'), 0.923691430930265),
#  (('SalePrice', 'EnclosedPorch', 'OverallQual'), 0.9236838473439937),
#  (('SalePrice', 'OverallQual', 'Fence'), 0.9236795419658641),
#  (('SalePrice', 'Neighborhood', 'OverallQual'), 0.9236486719784892),
#  (('SalePrice', 'OverallQual', 'MiscFeature'), 0.9236186051401546),
#  (('SalePrice', 'OverallQual', 'PoolQC'), 0.9235956558141334),
#  (('SalePrice', 'OverallQual', 'BsmtFinType2'), 0.9235679591531516),
#  (('SalePrice', 'OverallQual', 'Exterior1st'), 0.9235502481696303),
#  (('SalePrice', 'OverallQual', 'Exterior2nd'), 0.9235487710829631),
#  (('SalePrice', 'PoolArea', 'OverallQual'), 0.923548312725873),
#  (('SalePrice', '3SsnPorch', 'OverallQual'), 0.9235393312337649),
#  (('SalePrice', 'OverallQual', 'BsmtExposure'), 0.9235343782644281),
#  (('SalePrice', 'MiscVal', 'OverallQual'), 0.923513369848277),
#  (('SalePrice', 'OverallQual', 'MixedExterior'), 0.9235050739496813),
#  (('SalePrice', 'YrSold', 'OverallQual'), 0.9234995116613407),
#  (('SalePrice', 'Condition2', 'OverallQual'), 0.9234993239453791),
#  (('SalePrice', 'MoSold', 'OverallQual'), 0.9234976649463634),
#  (('SalePrice', 'LotConfig', 'OverallQual'), 0.9234966517045311),
#  (('SalePrice', 'BsmtUnfSF', 'OverallQual'), 0.9234941349559221),
#  (('SalePrice', 'LandSlope', 'OverallQual'), 0.9234909331274632),
#  (('SalePrice', 'OverallQual', 'Functional'), 0.9234866173509633),
#  (('SalePrice', 'OverallQual', 'GarageFinish'), 0.9234811454949101),
#  (('SalePrice', 'KitchenAbvGr', 'OverallQual'), 0.9234801582145873),
#  (('SalePrice', 'LowQualFinSF', 'OverallQual'), 0.9234790394574252),
#  (('SalePrice', 'OverallQual', 'RoofMatl'), 0.9234790376679257),
#  (('SalePrice', 'CentralAir', 'GarageType'), 0.9230333697828177),
#  (('SalePrice', 'FullBath', 'CentralAir'), 0.9229990242919022),
#  (('SalePrice', 'TotalBath', 'CentralAir'), 0.9225345198136381),
#  (('SalePrice', 'CentralAir', 'GarageCond'), 0.9216405297310728),
#  (('SalePrice', 'CentralAir', 'PavedDrive'), 0.92156464573931),
#  (('SalePrice', 'YearRemodAdd', 'CentralAir'), 0.9214787826024174),
#  (('SalePrice', 'YearBuilt', 'CentralAir'), 0.9210269785891592),
#  (('SalePrice', 'GarageCars', 'CentralAir'), 0.9207931957148143),
#  (('SalePrice', 'TotalSF', 'CentralAir'), 0.9207779376978165),
#  (('GrLivArea', 'SalePrice', 'CentralAir'), 0.9204641005042679),
#  (('SalePrice', 'CentralAir', 'GarageQual'), 0.9203642514105792),
#  (('SalePrice', 'YearBuilt', 'OverallCond'), 0.9203050537190545),
#  (('SalePrice', 'YearRemodAdd', 'PavedDrive'), 0.9202181768866609),
#  (('SalePrice', 'GarageType', 'PavedDrive'), 0.9198042184297456),
#  (('SalePrice', 'BedroomAbvGr', 'CentralAir'), 0.9196214911206739),
#  (('SalePrice', 'YearRemodAdd', 'GarageType'), 0.9195243751200506),
#  (('SalePrice', 'TotRmsAbvGrd', 'CentralAir'), 0.9193072325153783),
#  (('SalePrice', 'FullBath', 'PavedDrive'), 0.9191826470968374),
#  (('SalePrice', 'GarageYrBlt', 'CentralAir'), 0.9190910955579704),
#  (('SalePrice', 'YearRemodAdd', 'GarageCond'), 0.9188987334022984),
#  (('SalePrice', 'TotalBath', 'PavedDrive'), 0.918896571563129),
#  (('SalePrice', 'Foundation', 'CentralAir'), 0.9185355037536651),
#  (('SalePrice', 'GarageType', 'GarageCond'), 0.9185153751515301),
#  (('SalePrice', 'MasVnrArea', 'CentralAir'), 0.9184881434002174),
#  (('SalePrice', 'HouseStyle', 'CentralAir'), 0.9184871784928812),
#  (('SalePrice', 'TotalBath', 'GarageCond'), 0.918434720248535),
#  (('SalePrice', 'GarageArea', 'CentralAir'), 0.9184314774802249),
#  (('SalePrice', 'CentralAir', 'FireplaceQu'), 0.9183035790854749),
#  (('SalePrice', 'FullBath', 'GarageType'), 0.9182624746525189),
#  (('SalePrice', 'YearBuilt', 'GarageCond'), 0.9181994670968125),
#  (('SalePrice', '2ndFlrSF', 'CentralAir'), 0.9181578469050032),
#  (('SalePrice', 'FullBath', 'GarageCond'), 0.918133097764224),
#  (('SalePrice', 'HeatingQC', 'CentralAir'), 0.9180591635136863),
#  (('SalePrice', 'CentralAir', 'Electrical'), 0.9180565621165107),
#  (('SalePrice', 'Fireplaces', 'CentralAir'), 0.9180353988677362),
#  (('SalePrice', 'TotalBath', 'GarageType'), 0.9180294792864916),
#  (('SalePrice', 'GarageCond', 'PavedDrive'), 0.918004052236941),
#  (('SalePrice', 'LotShape', 'CentralAir'), 0.9179229982019476),
#  (('GrLivArea', 'SalePrice', 'YearBuilt'), 0.9178564885809728),
#  (('SalePrice', 'ExterQual', 'CentralAir'), 0.9177630536370973),
#  (('SalePrice', 'Exterior1st', 'CentralAir'), 0.9177165370286717),
#  (('SalePrice', 'GarageCars', 'PavedDrive'), 0.9177129852983117),
#  (('SalePrice', 'MSSubClass', 'CentralAir'), 0.9177083550160415),
#  (('SalePrice', 'HalfBath', 'CentralAir'), 0.9177066383921122),
#  (('SalePrice', 'Exterior2nd', 'CentralAir'), 0.9176977237276406),
#  (('SalePrice', 'MSZoning', 'CentralAir'), 0.9176719974396359),
#  (('SalePrice', 'CentralAir', 'SaleCondition'), 0.9176315017578871),
#  (('SalePrice', 'OverallCond', 'CentralAir'), 0.9176217291780926),
#  (('SalePrice', 'CentralAir', 'MixedExterior'), 0.9175972033466779),
#  (('SalePrice', 'CentralAir', 'SaleType'), 0.9175363626901132),
#  (('SalePrice', 'Alley', 'CentralAir'), 0.9175256236979523),
#  (('SalePrice', 'OpenPorchSF', 'CentralAir'), 0.9175164127220529),
#  (('SalePrice', 'OverallCond', 'GarageType'), 0.9174589613297286),
#  (('SalePrice', 'GarageQual', 'PavedDrive'), 0.9174559612870467),
#  (('SalePrice', 'YearBuilt', 'PavedDrive'), 0.9174384553790589),
#  (('SalePrice', 'GarageType', 'GarageQual'), 0.9174042139554026),
#  (('SalePrice', 'ExterCond', 'CentralAir'), 0.9173973039634755),
#  (('SalePrice', 'BedroomAbvGr', 'GarageType'), 0.917391810103615),
#  (('SalePrice', 'YearBuilt', 'TotalSF'), 0.9173503957293285),
#  (('SalePrice', 'BsmtFinType1', 'CentralAir'), 0.917333337874983),
#  (('SalePrice', 'BsmtUnfSF', 'CentralAir'), 0.9173123251669977),
#  (('SalePrice', 'BsmtCond', 'CentralAir'), 0.9172932614109046),
#  (('SalePrice', 'RoofStyle', 'CentralAir'), 0.9172372836457375),
#  (('SalePrice', 'TotalBsmtSF', 'CentralAir'), 0.9172252208657435),
#  (('SalePrice', 'MasVnrType', 'CentralAir'), 0.9172108942286188),
#  (('SalePrice', 'TotalSF', 'PavedDrive'), 0.9172074377083018),
#  (('SalePrice', '1stFlrSF', 'CentralAir'), 0.9171771051402026),
#  (('SalePrice', 'CentralAir', 'PoolQC'), 0.9171451165631943),
#  (('SalePrice', 'LotFrontage', 'CentralAir'), 0.917143922127891),
#  (('SalePrice', 'Condition1', 'CentralAir'), 0.9171182503747392),
#  (('GrLivArea', 'SalePrice', 'GarageType'), 0.9170748869725748),
#  (('SalePrice', 'YearBuilt', 'GarageType'), 0.9170678887892062),
#  (('SalePrice', 'Street', 'CentralAir'), 0.9170576739081472),
#  (('SalePrice', 'CentralAir', 'GarageFinish'), 0.9170249952215376),
#  (('SalePrice', 'WoodDeckSF', 'CentralAir'), 0.9170073754182044),
#  (('SalePrice', 'YearRemodAdd', 'GarageQual'), 0.9169865592169955),
#  (('SalePrice', 'Utilities', 'CentralAir'), 0.9169661076532162),
#  (('SalePrice', 'KitchenAbvGr', 'CentralAir'), 0.9169576095173604),
#  (('SalePrice', 'CentralAir', 'Functional'), 0.9169277696644027),
#  (('SalePrice', 'Heating', 'CentralAir'), 0.9169189837522883),
#  (('GrLivArea', 'SalePrice', 'PavedDrive'), 0.9169183152089795),
#  (('SalePrice', 'BsmtQual', 'CentralAir'), 0.9168927175394601),
#  (('SalePrice', 'Condition2', 'CentralAir'), 0.9168830959609349),
#  (('SalePrice', 'LotConfig', 'CentralAir'), 0.9168760079100468),
#  (('SalePrice', 'BsmtFinSF1', 'CentralAir'), 0.9168657277908865),
#  (('SalePrice', 'Neighborhood', 'CentralAir'), 0.9168591894359754),
#  (('SalePrice', 'BsmtExposure', 'CentralAir'), 0.916852398029154),
#  (('SalePrice', 'LowQualFinSF', 'CentralAir'), 0.9168443631112482),
#  (('SalePrice', 'RoofMatl', 'CentralAir'), 0.9168425858449104),
#  (('SalePrice', 'EnclosedPorch', 'CentralAir'), 0.916840671434082),
#  (('SalePrice', 'BsmtFinType2', 'CentralAir'), 0.9168388652920654),
#  (('SalePrice', 'MoSold', 'CentralAir'), 0.9168358617956369),
#  (('SalePrice', 'LandContour', 'CentralAir'), 0.9168235642871851),
#  (('SalePrice', '3SsnPorch', 'CentralAir'), 0.9168199117621266),
#  (('SalePrice', 'BsmtFullBath', 'CentralAir'), 0.9168105746815925),
#  (('SalePrice', 'CentralAir', 'KitchenQual'), 0.916804257743656),
#  (('SalePrice', 'BldgType', 'CentralAir'), 0.916803909244315),
#  (('SalePrice', 'LotArea', 'CentralAir'), 0.9168022248972736),
#  (('SalePrice', 'BsmtHalfBath', 'CentralAir'), 0.9168016260709783),
#  (('SalePrice', 'MiscVal', 'CentralAir'), 0.916797920818313),
#  (('SalePrice', 'LandSlope', 'CentralAir'), 0.916796641790264),
#  (('SalePrice', 'PoolArea', 'CentralAir'), 0.9167925473804034),
#  (('SalePrice', 'BsmtFinSF2', 'CentralAir'), 0.9167924082476494),
#  (('SalePrice', 'YrSold', 'CentralAir'), 0.9167922421316609),
#  (('SalePrice', 'CentralAir', 'Fence'), 0.9167915204445131),
#  (('SalePrice', 'CentralAir', 'MiscFeature'), 0.9167902828159915),
#  (('SalePrice', 'ScreenPorch', 'CentralAir'), 0.9167901072318407),
#  (('SalePrice', 'GarageCars', 'GarageType'), 0.916723126992834),
#  (('SalePrice', 'TotalSF', 'GarageType'), 0.9166088669661678),
#  (('SalePrice', 'TotalSF', 'GarageCond'), 0.9165880152826981),
#  (('SalePrice', 'Electrical', 'GarageType'), 0.9165644172266716),
#  (('SalePrice', 'Electrical', 'PavedDrive'), 0.916437470707849),
#  (('SalePrice', 'BedroomAbvGr', 'YearBuilt'), 0.916432770022998),
#  (('SalePrice', 'BedroomAbvGr', 'PavedDrive'), 0.9162341436519702),
#  (('SalePrice', 'YearBuilt', 'ExterQual'), 0.9162153768837317),
#  (('SalePrice', '2ndFlrSF', 'GarageType'), 0.9161300802276001),
#  (('SalePrice', 'GarageYrBlt', 'GarageType'), 0.9160815086619867),
#  (('SalePrice', 'GarageYrBlt', 'PavedDrive'), 0.9159612800034191),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageType'), 0.9159195956998121),
#  (('SalePrice', 'TotalBath', 'GarageQual'), 0.9157973182006697),
#  (('SalePrice', 'YearBuilt', 'GarageQual'), 0.9157670346583753),
#  (('SalePrice', 'TotRmsAbvGrd', 'PavedDrive'), 0.9157650300390918),
#  (('SalePrice', 'FullBath', 'GarageQual'), 0.9156835576334479),
#  (('SalePrice', 'Electrical', 'GarageCond'), 0.9156712442144225),
#  (('SalePrice', 'OverallCond', 'PavedDrive'), 0.915667318365301),
#  (('SalePrice', 'HeatingQC', 'PavedDrive'), 0.9156180842743475),
#  (('GrLivArea', 'SalePrice', 'GarageCond'), 0.9156000455669219),
#  (('SalePrice', 'HeatingQC', 'GarageType'), 0.9155999543987567),
#  (('SalePrice', 'BedroomAbvGr', 'GarageCond'), 0.9155751992220598),
#  (('SalePrice', 'TotRmsAbvGrd', 'YearBuilt'), 0.9155640417546556),
#  (('SalePrice', 'ExterQual', 'GarageType'), 0.915538363502166),
#  (('SalePrice', 'MasVnrArea', 'PavedDrive'), 0.9154602607173077),
#  (('SalePrice', 'MasVnrArea', 'GarageType'), 0.9154524671337769),
#  (('SalePrice', 'YearRemodAdd', 'TotalSF'), 0.9153415805796086),
#  (('SalePrice', 'GarageYrBlt', 'GarageCond'), 0.9153172715738123),
#  (('SalePrice', 'GarageCars', 'GarageCond'), 0.9152403951261431),
#  (('SalePrice', 'GarageArea', 'PavedDrive'), 0.915230739033149),
#  (('SalePrice', 'HouseStyle', 'GarageType'), 0.9151145499676565),
#  (('SalePrice', 'Exterior1st', 'PavedDrive'), 0.9150800672705839),
#  (('SalePrice', 'HalfBath', 'GarageType'), 0.9150709825891653),
#  (('SalePrice', 'FireplaceQu', 'PavedDrive'), 0.9150498586317269),
#  (('SalePrice', '2ndFlrSF', 'PavedDrive'), 0.915002067633459),
#  (('SalePrice', 'MSSubClass', 'GarageType'), 0.9149928032815017),
#  (('SalePrice', 'HouseStyle', 'PavedDrive'), 0.9149831505332929),
#  (('SalePrice', 'Exterior1st', 'GarageType'), 0.914955789580833),
#  (('SalePrice', 'Foundation', 'PavedDrive'), 0.9149496737858095),
#  (('SalePrice', 'Exterior2nd', 'GarageType'), 0.9149133764738392),
#  (('SalePrice', 'HeatingQC', 'GarageCond'), 0.9148534643441555),
#  (('SalePrice', 'GarageArea', 'GarageType'), 0.9148230244953834),
#  (('SalePrice', 'PavedDrive', 'MixedExterior'), 0.9148154910399495),
#  (('SalePrice', 'Exterior2nd', 'PavedDrive'), 0.914807099631006),
#  (('SalePrice', 'Fireplaces', 'PavedDrive'), 0.9147918449686645),
#  (('SalePrice', 'BsmtCond', 'GarageType'), 0.9147712599226604),
#  (('SalePrice', 'ExterQual', 'PavedDrive'), 0.9147646506528464),
#  (('SalePrice', 'HalfBath', 'PavedDrive'), 0.9147098654178284),
#  (('SalePrice', 'PavedDrive', 'SaleCondition'), 0.9146910407387994),
#  (('SalePrice', 'GarageQual', 'GarageCond'), 0.9146891949520614),
#  (('SalePrice', 'YearBuilt', 'TotalBath'), 0.9146888591490517),
#  (('SalePrice', 'GarageCars', 'YearRemodAdd'), 0.9146862319299387),
#  (('SalePrice', 'GarageType', 'MixedExterior'), 0.9146730328546191),
#  (('SalePrice', 'FullBath', 'YearBuilt'), 0.9146437524735681),
#  (('SalePrice', 'Fireplaces', 'YearBuilt'), 0.9146396766057622),
#  (('SalePrice', 'GarageCars', 'YearBuilt'), 0.9146229847953793),
#  (('SalePrice', 'FireplaceQu', 'GarageType'), 0.9146054721290208),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageCond'), 0.9145343252413102),
#  (('SalePrice', 'LotShape', 'PavedDrive'), 0.914500466892727),
#  (('SalePrice', 'YearRemodAdd', 'ExterQual'), 0.9144663271532151),
#  (('SalePrice', 'TotalSF', 'GarageQual'), 0.9144655674983267),
#  (('SalePrice', 'GarageType', 'SaleCondition'), 0.9144541296732854),
#  (('SalePrice', 'Foundation', 'GarageType'), 0.9144063113525498),
#  (('SalePrice', 'GarageType', 'SaleType'), 0.9143860840903796),
#  (('SalePrice', 'Fireplaces', 'GarageType'), 0.9143853902636943),
#  (('SalePrice', 'HouseStyle', 'GarageCond'), 0.9143846171827467),
#  (('SalePrice', 'BsmtCond', 'PavedDrive'), 0.9143378863692078),
#  (('SalePrice', 'YearBuilt', 'YearRemodAdd'), 0.9143347592714937),
#  (('SalePrice', 'RoofStyle', 'GarageType'), 0.914310064706818),
#  (('SalePrice', 'Alley', 'GarageType'), 0.9142711247001191),
#  (('SalePrice', 'MSSubClass', 'PavedDrive'), 0.9142562049094125),
#  (('SalePrice', 'YearRemodAdd', 'TotalBath'), 0.9142497500713807),
#  (('SalePrice', 'PavedDrive', 'SaleType'), 0.9142371184129224),
#  (('SalePrice', 'BsmtUnfSF', 'PavedDrive'), 0.9142236757699754),
#  (('SalePrice', 'BsmtUnfSF', 'GarageType'), 0.914219619489329),
#  (('SalePrice', 'MasVnrArea', 'GarageCond'), 0.9142075003837346),
#  (('SalePrice', 'LotShape', 'GarageType'), 0.9141967021686221),
#  (('SalePrice', 'Foundation', 'GarageCond'), 0.9141833841980144),
#  (('SalePrice', 'OpenPorchSF', 'PavedDrive'), 0.9141755143184347),
#  (('SalePrice', 'ExterCond', 'GarageType'), 0.9141682242562232),
#  (('SalePrice', 'OverallCond', 'GarageCond'), 0.91416221641707),
#  (('SalePrice', 'ExterQual', 'GarageCond'), 0.9141540014605005),
#  (('SalePrice', 'RoofStyle', 'PavedDrive'), 0.9141370695082439),
#  (('SalePrice', 'ExterCond', 'PavedDrive'), 0.9141257486602318),
#  (('SalePrice', 'MSZoning', 'PavedDrive'), 0.9140997577163317),
#  (('SalePrice', 'BsmtFinType1', 'GarageType'), 0.9140845602416624),
#  (('SalePrice', 'Heating', 'PavedDrive'), 0.9140226935512837),
#  (('SalePrice', 'Street', 'GarageType'), 0.9140156173200262),
#  (('SalePrice', 'FireplaceQu', 'GarageCond'), 0.9140098125492415),
#  (('SalePrice', 'MSZoning', 'GarageType'), 0.9139969787825146),
#  (('SalePrice', 'Utilities', 'GarageType'), 0.9139911225653308),
#  (('SalePrice', 'OpenPorchSF', 'GarageType'), 0.913981060201688),
#  (('SalePrice', 'GarageType', 'PoolQC'), 0.9139771012166803),
#  (('SalePrice', 'PavedDrive', 'PoolQC'), 0.9139695382797179),
#  (('SalePrice', 'Heating', 'GarageType'), 0.913943935081585),
#  (('SalePrice', 'Condition1', 'GarageType'), 0.9139398719273772),
#  (('SalePrice', 'Functional', 'GarageType'), 0.9139339782258311),
#  (('SalePrice', 'TotalBsmtSF', 'PavedDrive'), 0.9139273794725021),
#  (('SalePrice', 'BsmtFinSF1', 'GarageType'), 0.913905385588626),
#  (('SalePrice', 'MasVnrType', 'PavedDrive'), 0.9139014183772216),
#  (('SalePrice', 'BedroomAbvGr', 'YearRemodAdd'), 0.9138908436949433),
#  (('SalePrice', 'Alley', 'PavedDrive'), 0.9138812211506095),
#  (('SalePrice', 'Electrical', 'GarageQual'), 0.9138806002423283),
#  (('SalePrice', 'LotFrontage', 'PavedDrive'), 0.9138792546305717),
#  (('SalePrice', 'HalfBath', 'GarageCond'), 0.913870211299494),
#  (('SalePrice', 'BsmtFinType1', 'PavedDrive'), 0.9138671048108479),
#  (('SalePrice', 'MasVnrType', 'GarageType'), 0.9138429270877911),
#  (('SalePrice', 'WoodDeckSF', 'PavedDrive'), 0.9138329952876563),
#  (('SalePrice', 'MasVnrArea', 'YearBuilt'), 0.9138310089002905),
#  (('SalePrice', 'GarageFinish', 'PavedDrive'), 0.9137828391346633),
#  (('SalePrice', '1stFlrSF', 'PavedDrive'), 0.9137796086244173),
#  (('SalePrice', 'TotalBsmtSF', 'GarageType'), 0.9137781787965855),
#  (('SalePrice', 'Street', 'PavedDrive'), 0.913766082021279),
#  (('SalePrice', 'Condition2', 'GarageType'), 0.9137638575442111),
#  (('SalePrice', 'GarageCars', 'GarageQual'), 0.9137597617798987),
#  (('GrLivArea', 'SalePrice', 'GarageQual'), 0.9137564415750573),
#  (('SalePrice', 'LandContour', 'PavedDrive'), 0.9137447536733039),
#  (('SalePrice', 'Utilities', 'PavedDrive'), 0.9137444132276035),
#  (('SalePrice', 'Neighborhood', 'GarageType'), 0.9137419302591518),
#  (('SalePrice', 'Condition1', 'PavedDrive'), 0.9137228188072517),
#  (('SalePrice', 'Fireplaces', 'GarageCond'), 0.9137223404451691),
#  (('SalePrice', 'WoodDeckSF', 'GarageType'), 0.9137183193194245),
#  (('SalePrice', 'MoSold', 'GarageType'), 0.9137110608359309),
#  (('SalePrice', 'BsmtFinSF1', 'PavedDrive'), 0.913711054644631),
#  (('SalePrice', 'BsmtFinType2', 'GarageType'), 0.9137098100094923),
#  (('SalePrice', 'EnclosedPorch', 'GarageType'), 0.9137059077799078),
#  (('SalePrice', 'LandContour', 'GarageType'), 0.9136962605957422),
#  (('SalePrice', 'RoofMatl', 'GarageType'), 0.9136953871536057),
#  (('SalePrice', 'Functional', 'PavedDrive'), 0.9136907463159986),
#  (('SalePrice', 'Condition2', 'PavedDrive'), 0.9136852323062103),
#  (('SalePrice', 'LandSlope', 'GarageType'), 0.9136761624264534),
#  (('SalePrice', '2ndFlrSF', 'GarageCond'), 0.9136735187843081),
#  (('SalePrice', '2ndFlrSF', 'YearBuilt'), 0.9136660960513432),
#  (('SalePrice', '3SsnPorch', 'GarageType'), 0.9136552028253018),
#  (('SalePrice', 'RoofMatl', 'PavedDrive'), 0.9136509170138558),
#  (('SalePrice', 'LotArea', 'GarageType'), 0.9136446030493732),
#  (('SalePrice', 'BsmtHalfBath', 'GarageType'), 0.9136418711889268),
#  (('SalePrice', 'KitchenQual', 'GarageType'), 0.9136376924760102),
#  (('SalePrice', 'BldgType', 'GarageType'), 0.9136374581388577),
#  (('SalePrice', 'BsmtQual', 'GarageType'), 0.9136353825653362),
#  (('SalePrice', 'LowQualFinSF', 'PavedDrive'), 0.91363239802648),
#  (('SalePrice', 'BsmtExposure', 'GarageType'), 0.9136301501160248),
#  (('SalePrice', 'LotConfig', 'GarageType'), 0.9136299410202944),
#  (('SalePrice', 'GarageType', 'MiscFeature'), 0.913627946814499),
#  (('SalePrice', 'LowQualFinSF', 'GarageType'), 0.9136226550439003),
#  (('SalePrice', 'BsmtFullBath', 'GarageType'), 0.9136222754500326),
#  (('SalePrice', 'MiscVal', 'GarageType'), 0.9136221551340143),
#  (('SalePrice', 'LotFrontage', 'GarageType'), 0.9136221052023821),
#  (('SalePrice', 'BedroomAbvGr', 'GarageQual'), 0.9136216875622009),
#  (('SalePrice', 'GarageType', 'Fence'), 0.9136216804235389),
#  (('SalePrice', '1stFlrSF', 'GarageType'), 0.9136212860497227),
#  (('SalePrice', 'GarageType', 'GarageFinish'), 0.9136208734898504),
#  (('SalePrice', 'PoolArea', 'GarageType'), 0.9136203765083488),
#  (('SalePrice', 'KitchenAbvGr', 'GarageType'), 0.9136202895734505),
#  (('SalePrice', 'ScreenPorch', 'GarageType'), 0.9136201719922888),
#  (('SalePrice', 'BsmtFinSF2', 'GarageType'), 0.9136199648970417),
#  (('SalePrice', 'YrSold', 'GarageType'), 0.91361993794775),
#  (('SalePrice', 'LotArea', 'PavedDrive'), 0.9136155849905353),
#  (('SalePrice', 'BsmtExposure', 'PavedDrive'), 0.9136086304202792),
#  (('SalePrice', '3SsnPorch', 'PavedDrive'), 0.9136079135897968),
#  (('SalePrice', 'YearBuilt', 'MSSubClass'), 0.9136054531045035),
#  (('SalePrice', 'BsmtQual', 'PavedDrive'), 0.9136051326602271),
#  (('SalePrice', 'BsmtFinType2', 'PavedDrive'), 0.9135917513247916),
#  (('SalePrice', 'LotShape', 'GarageCond'), 0.9135846209355154),
#  (('SalePrice', 'MoSold', 'PavedDrive'), 0.9135828200463414),
#  (('SalePrice', 'LandSlope', 'PavedDrive'), 0.9135821439625352),
#  (('SalePrice', 'LotConfig', 'PavedDrive'), 0.9135697904204272),
#  (('SalePrice', 'MiscVal', 'PavedDrive'), 0.9135690599127164),
#  (('SalePrice', 'PoolArea', 'PavedDrive'), 0.9135658457048901),
#  (('SalePrice', 'EnclosedPorch', 'PavedDrive'), 0.9135651567626473),
#  (('SalePrice', 'BsmtHalfBath', 'PavedDrive'), 0.9135590621426067),
#  (('SalePrice', 'Neighborhood', 'PavedDrive'), 0.9135586385584152),
#  (('SalePrice', 'KitchenAbvGr', 'PavedDrive'), 0.9135544471799466),
#  (('SalePrice', 'YrSold', 'PavedDrive'), 0.913547164609788),
#  (('SalePrice', 'KitchenQual', 'PavedDrive'), 0.9135461958084607),
#  (('SalePrice', 'BsmtFullBath', 'PavedDrive'), 0.913545455970791),
#  (('SalePrice', 'ScreenPorch', 'PavedDrive'), 0.9135454244852742),
#  (('SalePrice', 'PavedDrive', 'MiscFeature'), 0.9135434671203471),
#  (('SalePrice', 'BsmtFinSF2', 'PavedDrive'), 0.9135403645148136),
#  (('SalePrice', 'BldgType', 'PavedDrive'), 0.9135387315113042),
#  (('SalePrice', 'PavedDrive', 'Fence'), 0.9135386501418973),
#  (('SalePrice', 'YearBuilt', 'Electrical'), 0.9135167494174585),
#  (('SalePrice', 'GarageCars', 'TotalBath'), 0.9134600029394295),
#  (('SalePrice', 'Exterior1st', 'GarageCond'), 0.9134559979607547),
#  (('SalePrice', 'BsmtCond', 'GarageCond'), 0.9134332208758494),
#  (('SalePrice', 'GarageArea', 'GarageCond'), 0.9134011235740852),
#  (('SalePrice', 'ExterCond', 'GarageCond'), 0.9133998682742389),
#  (('SalePrice', 'GarageCond', 'SaleCondition'), 0.9133658329680119),
#  (('SalePrice', 'OverallCond', 'GarageQual'), 0.913364210555019),
#  (('SalePrice', 'Exterior2nd', 'GarageCond'), 0.913325609213012),
#  (('SalePrice', 'MSSubClass', 'GarageCond'), 0.9133236532695446),
#  (('GrLivArea', 'SalePrice', 'YearRemodAdd'), 0.9133235075948539),
#  (('SalePrice', 'YearBuilt', 'BsmtQual'), 0.9133197113627365),
#  (('SalePrice', 'BsmtFinType1', 'GarageCond'), 0.9132568063291855),
#  (('SalePrice', 'GarageCond', 'MixedExterior'), 0.9132412970976044),
#  (('SalePrice', 'TotalBsmtSF', 'GarageCond'), 0.9132397901146088),
#  (('SalePrice', 'GarageCond', 'SaleType'), 0.9132231289404362),
#  (('SalePrice', 'FullBath', 'YearRemodAdd'), 0.9131704063364703),
#  (('SalePrice', 'GarageArea', 'YearBuilt'), 0.9131641808441299),
#  (('SalePrice', 'Fireplaces', 'YearRemodAdd'), 0.9131160714601292),
#  (('SalePrice', 'GarageFinish', 'GarageCond'), 0.9131041430033705),
#  (('SalePrice', 'BsmtUnfSF', 'GarageCond'), 0.913100792182495),
#  (('SalePrice', 'RoofStyle', 'GarageCond'), 0.9130596933185917),
#  (('SalePrice', 'OpenPorchSF', 'GarageCond'), 0.913055677052408),
#  (('SalePrice', 'Alley', 'GarageCond'), 0.9130549408034828),
#  (('SalePrice', 'MSZoning', 'GarageCond'), 0.9130544697637011),
#  (('SalePrice', 'MasVnrType', 'GarageCond'), 0.9129398730231645),
#  (('SalePrice', 'Heating', 'GarageCond'), 0.9128997078374043),
#  (('SalePrice', 'Utilities', 'GarageCond'), 0.9128982377344246),
#  (('SalePrice', 'YearBuilt', 'FireplaceQu'), 0.9128964197246194),
#  (('SalePrice', 'MasVnrArea', 'GarageQual'), 0.9128730878788307),
#  (('SalePrice', 'Street', 'GarageCond'), 0.9128559581896679),
#  (('SalePrice', 'HeatingQC', 'GarageQual'), 0.9128473340203773),
#  (('SalePrice', '1stFlrSF', 'GarageCond'), 0.9128018444301574),
#  (('SalePrice', 'GarageYrBlt', 'GarageQual'), 0.9127769076563418),
#  (('SalePrice', 'Condition1', 'GarageCond'), 0.9127691772046813),
#  (('SalePrice', 'LandContour', 'GarageCond'), 0.9127671830173734),
#  (('SalePrice', 'WoodDeckSF', 'GarageCond'), 0.9127617049558847),
#  (('SalePrice', 'Functional', 'GarageCond'), 0.9127602680200191),
#  (('SalePrice', 'Condition2', 'GarageCond'), 0.9127376528220978),
#  (('SalePrice', 'TotalBath', 'OverallCond'), 0.9127334351895208),
#  (('SalePrice', 'GarageCond', 'PoolQC'), 0.9127296593035104),
#  (('SalePrice', 'BsmtExposure', 'GarageCond'), 0.9126778488414935),
#  (('SalePrice', 'GarageArea', 'YearRemodAdd'), 0.9126653969874733),
#  (('SalePrice', 'EnclosedPorch', 'GarageCond'), 0.9126629554293652),
#  (('SalePrice', 'LotFrontage', 'GarageCond'), 0.9126598960672248),
#  (('SalePrice', 'YearBuilt', 'BsmtCond'), 0.9126315573827987),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageQual'), 0.9126232411955515),
#  (('SalePrice', 'ExterQual', 'GarageQual'), 0.9125810751363062),
#  (('SalePrice', 'Neighborhood', 'GarageCond'), 0.912568054453735),
#  (('SalePrice', 'GarageCond', 'MiscFeature'), 0.9125640771089165),
#  (('SalePrice', '3SsnPorch', 'GarageCond'), 0.9125526657513271),
#  (('SalePrice', 'BsmtQual', 'GarageCond'), 0.9125515878379269),
#  (('SalePrice', 'BsmtFinType2', 'GarageCond'), 0.9125434364654157),
#  (('SalePrice', 'MoSold', 'GarageCond'), 0.9125376293066331),
#  (('SalePrice', 'LandSlope', 'GarageCond'), 0.9125339448418732),
#  (('SalePrice', 'LotConfig', 'GarageCond'), 0.9125326974077017),
#  (('SalePrice', 'BsmtFinSF1', 'GarageCond'), 0.9125322370987745),
#  (('SalePrice', 'BsmtFullBath', 'GarageCond'), 0.9125294252845977),
#  (('SalePrice', 'BsmtHalfBath', 'GarageCond'), 0.9125256859282129),
#  (('SalePrice', 'LowQualFinSF', 'GarageCond'), 0.912522737397334),
#  (('SalePrice', 'BldgType', 'GarageCond'), 0.9125205745183427),
#  (('SalePrice', 'YearBuilt', 'SaleType'), 0.9125187980314472),
#  (('SalePrice', 'YearBuilt', 'SaleCondition'), 0.9125149731296454),
#  (('SalePrice', 'BsmtFinSF2', 'GarageCond'), 0.9125106586650179),
#  (('SalePrice', 'RoofMatl', 'GarageCond'), 0.912507688263636),
#  (('SalePrice', 'MiscVal', 'GarageCond'), 0.9125066014862836),
#  (('SalePrice', 'YrSold', 'GarageCond'), 0.9125044081090264),
#  (('SalePrice', 'PoolArea', 'GarageCond'), 0.9125043109034712),
#  (('SalePrice', 'YearBuilt', 'Exterior1st'), 0.9125039365439219),
#  (('SalePrice', 'GarageCond', 'Fence'), 0.9124978911950833),
#  (('SalePrice', 'LotArea', 'GarageCond'), 0.9124969007663042),
#  (('SalePrice', 'KitchenAbvGr', 'GarageCond'), 0.9124945935631003),
#  (('SalePrice', 'ScreenPorch', 'GarageCond'), 0.9124942372016493),
#  (('SalePrice', 'KitchenQual', 'GarageCond'), 0.9124934646034021),
#  (('SalePrice', 'FireplaceQu', 'GarageQual'), 0.9124223620965531),
#  (('SalePrice', 'YearBuilt', 'MixedExterior'), 0.9124134598052228),
#  (('SalePrice', 'YearBuilt', 'HeatingQC'), 0.912399372741231),
#  (('SalePrice', 'HalfBath', 'YearBuilt'), 0.9123835546595989),
#  (('SalePrice', '1stFlrSF', 'YearBuilt'), 0.9123630606172194),
#  (('SalePrice', 'YearBuilt', 'Exterior2nd'), 0.9123620652109141),
#  (('SalePrice', 'LotFrontage', 'YearBuilt'), 0.9123358873010833),
#  (('SalePrice', 'HouseStyle', 'GarageQual'), 0.9123264100258296),
#  (('SalePrice', 'YearBuilt', 'HouseStyle'), 0.9123130000304533),
#  (('SalePrice', 'YearBuilt', 'LotShape'), 0.9122873137221497),
#  (('SalePrice', 'TotalBath', 'Electrical'), 0.9122806675664729),
#  (('SalePrice', 'YearBuilt', 'BsmtFinType1'), 0.9122691448762364),
#  (('SalePrice', 'FullBath', 'GarageCars'), 0.9121963463655895),
#  (('SalePrice', 'YearBuilt', 'KitchenQual'), 0.9121933243725928),
#  (('SalePrice', 'YearBuilt', 'BldgType'), 0.9121909265420279),
#  (('SalePrice', 'TotalBsmtSF', 'YearBuilt'), 0.912171372373295),
#  (('SalePrice', 'GarageCars', 'OverallCond'), 0.9121694543686305),
#  (('SalePrice', 'Fireplaces', 'GarageQual'), 0.9121433382669969),
#  (('SalePrice', 'HalfBath', 'GarageQual'), 0.9121405223828238),
#  (('SalePrice', 'OpenPorchSF', 'YearBuilt'), 0.9121066939194593),
#  (('SalePrice', 'YearRemodAdd', 'Electrical'), 0.9120999837430176),
#  (('SalePrice', 'BsmtUnfSF', 'YearBuilt'), 0.912087870149927),
#  (('SalePrice', 'YearBuilt', 'Street'), 0.9120758854737294),
#  (('SalePrice', 'TotRmsAbvGrd', 'YearRemodAdd'), 0.9120566784096884),
#  (('SalePrice', 'YearBuilt', 'MasVnrType'), 0.9120303955276143),
#  (('SalePrice', 'YearBuilt', 'RoofStyle'), 0.9120240254985307),
#  (('SalePrice', 'YearBuilt', 'PoolQC'), 0.912010764359094),
#  (('SalePrice', 'YearBuilt', 'Heating'), 0.9120103360252179),
#  (('SalePrice', 'LotArea', 'YearBuilt'), 0.9119915479778387),
#  (('SalePrice', '2ndFlrSF', 'GarageQual'), 0.9119844668702242),
#  (('SalePrice', 'ScreenPorch', 'YearBuilt'), 0.911980220146514),
#  (('SalePrice', 'YearBuilt', 'Utilities'), 0.9119618720681747),
#  (('SalePrice', 'YearBuilt', 'Fence'), 0.9119580359699968),
#  (('SalePrice', 'BsmtCond', 'GarageQual'), 0.9119521199577159),
#  (('SalePrice', 'GarageCars', 'Electrical'), 0.9119300286597943),
#  (('SalePrice', 'WoodDeckSF', 'YearBuilt'), 0.9119273120777405),
#  (('SalePrice', 'YearBuilt', 'Condition2'), 0.9119092314189381),
#  (('SalePrice', 'YearBuilt', 'GarageFinish'), 0.911904451400002),
#  (('SalePrice', 'GarageArea', 'GarageQual'), 0.9118601058739589),
#  (('SalePrice', 'EnclosedPorch', 'YearBuilt'), 0.9118563352549175),
#  (('SalePrice', 'YearBuilt', 'ExterCond'), 0.9118525888964154),
#  (('SalePrice', 'Foundation', 'GarageQual'), 0.9118498608857419),
#  (('SalePrice', 'BsmtHalfBath', 'YearBuilt'), 0.9118140512648469),
#  (('SalePrice', 'BsmtFinSF2', 'YearBuilt'), 0.9118063640310887),
#  (('SalePrice', 'YearRemodAdd', 'FireplaceQu'), 0.9118017757660987),
#  (('SalePrice', 'YearBuilt', 'MiscFeature'), 0.9117931651759258),
#  (('SalePrice', 'YearBuilt', 'LotConfig'), 0.9117857190661393),
#  (('SalePrice', 'YearBuilt', 'Condition1'), 0.9117789360856087),
#  (('SalePrice', 'YearBuilt', 'Functional'), 0.9117730183947488),
#  (('SalePrice', 'MoSold', 'YearBuilt'), 0.9117707860662243),
#  (('SalePrice', '3SsnPorch', 'YearBuilt'), 0.9117705647891909),
#  (('SalePrice', 'BsmtFinSF1', 'YearBuilt'), 0.9117671760702943),
#  (('SalePrice', 'FullBath', 'OverallCond'), 0.9117637424111864),
#  (('SalePrice', 'YearBuilt', 'Alley'), 0.911756696207151),
#  (('SalePrice', 'YearBuilt', 'Neighborhood'), 0.9117500849274679),
#  (('SalePrice', 'FullBath', 'Electrical'), 0.9117454679365125),
#  (('SalePrice', 'GarageQual', 'SaleType'), 0.9117400292365865),
#  (('SalePrice', 'MiscVal', 'YearBuilt'), 0.9117320421528896),
#  (('SalePrice', 'KitchenAbvGr', 'YearBuilt'), 0.9117273756350283),
#  (('SalePrice', 'GarageYrBlt', 'YearBuilt'), 0.9117232926660095),
#  (('SalePrice', 'LotShape', 'GarageQual'), 0.9117223829564957),
#  (('SalePrice', 'YearBuilt', 'Foundation'), 0.9117188539243016),
#  (('SalePrice', 'PoolArea', 'YearBuilt'), 0.911713480417838),
#  (('SalePrice', 'LowQualFinSF', 'YearBuilt'), 0.9117115840039045),
#  (('SalePrice', 'YrSold', 'YearBuilt'), 0.911709293989222),
#  (('SalePrice', 'YearBuilt', 'MSZoning'), 0.9117006835245646),
#  (('SalePrice', 'YearBuilt', 'BsmtFinType2'), 0.9116982460074723),
#  (('SalePrice', 'YearBuilt', 'RoofMatl'), 0.9116982058875465),
#  (('SalePrice', 'YearBuilt', 'BsmtExposure'), 0.9116973219214457),
#  (('SalePrice', 'GarageQual', 'SaleCondition'), 0.911695459723481),
#  (('SalePrice', 'YearBuilt', 'LandContour'), 0.9116943162612855),
#  (('SalePrice', 'Exterior1st', 'GarageQual'), 0.9116943121079247),
#  (('SalePrice', 'YearBuilt', 'LandSlope'), 0.9116940480440299),
#  (('SalePrice', 'BsmtFullBath', 'YearBuilt'), 0.9116940265609457),
#  (('SalePrice', 'YearRemodAdd', 'BsmtCond'), 0.9116374412979178),
#  (('SalePrice', 'Exterior2nd', 'GarageQual'), 0.911611706876397),
#  (('SalePrice', 'ExterCond', 'GarageQual'), 0.9115960821229615),
#  (('SalePrice', 'GarageYrBlt', 'TotalSF'), 0.9115609707121817),
#  (('SalePrice', 'MSSubClass', 'GarageQual'), 0.9115512853747259),
#  (('SalePrice', 'GarageYrBlt', 'OverallCond'), 0.91153812586707),
#  (('SalePrice', 'GarageArea', 'TotalBath'), 0.9115140344950262),
#  (('SalePrice', 'GarageCars', 'TotalSF'), 0.9115131241934645),
#  (('SalePrice', 'RoofStyle', 'GarageQual'), 0.911499758963664),
#  (('SalePrice', 'BsmtUnfSF', 'GarageQual'), 0.9114956971949787),
#  (('SalePrice', 'GarageQual', 'MixedExterior'), 0.9114868732129447),
#  (('SalePrice', 'YearRemodAdd', 'BsmtFinType1'), 0.9114847860707093),
#  (('SalePrice', 'BsmtFinType1', 'GarageQual'), 0.9114421350706747),
#  (('SalePrice', 'YearRemodAdd', 'KitchenQual'), 0.9114275639347404),
#  (('SalePrice', 'TotalBsmtSF', 'GarageQual'), 0.9113790092070446),
#  (('SalePrice', 'TotalBsmtSF', 'YearRemodAdd'), 0.9113300868700536),
#  (('SalePrice', 'OpenPorchSF', 'GarageQual'), 0.9113241458932871),
#  (('SalePrice', 'YearRemodAdd', 'ExterCond'), 0.9113191770928926),
#  (('SalePrice', 'Alley', 'GarageQual'), 0.9113185035487286),
#  (('SalePrice', 'GarageYrBlt', 'ExterQual'), 0.9113174533045969),
#  (('SalePrice', 'Heating', 'GarageQual'), 0.9112921222556759),
#  (('SalePrice', 'BedroomAbvGr', 'GarageCars'), 0.9112808766327362),
#  (('SalePrice', 'YearRemodAdd', 'LotShape'), 0.9112047354197217),
#  (('SalePrice', 'Street', 'GarageQual'), 0.9111957485093816),
#  (('SalePrice', 'MasVnrType', 'GarageQual'), 0.9111920631985532),
#  (('SalePrice', 'Utilities', 'GarageQual'), 0.9111821570275697),
#  (('SalePrice', 'MSZoning', 'GarageQual'), 0.9111562274225724),
#  (('SalePrice', 'TotalBath', 'ExterQual'), 0.9111536928919568),
#  (('SalePrice', 'Functional', 'GarageQual'), 0.9111484938870035),
#  (('SalePrice', 'GarageYrBlt', 'TotalBath'), 0.9111171193941455),
#  (('SalePrice', 'YearRemodAdd', 'OverallCond'), 0.9111046259278855),
#  (('SalePrice', 'WoodDeckSF', 'GarageQual'), 0.9110758147265893),
#  (('SalePrice', 'GarageQual', 'PoolQC'), 0.9110670653453762),
#  (('SalePrice', 'HalfBath', 'YearRemodAdd'), 0.9110632870521179),
#  (('SalePrice', 'Condition1', 'GarageQual'), 0.9110474089671614),
#  (('SalePrice', 'GarageFinish', 'GarageQual'), 0.9110407516175377),
#  (('SalePrice', 'TotalSF', 'TotalBath'), 0.9110278646177447),
#  (('SalePrice', '1stFlrSF', 'GarageQual'), 0.9110248480027475),
#  (('SalePrice', '1stFlrSF', 'YearRemodAdd'), 0.9110182632050857),
#  (('SalePrice', 'GarageCars', 'ExterQual'), 0.911005098105678),
#  (('SalePrice', 'YearRemodAdd', 'HouseStyle'), 0.9110009671422974),
#  (('SalePrice', 'MasVnrArea', 'YearRemodAdd'), 0.9109945013216924),
#  (('SalePrice', 'LandContour', 'GarageQual'), 0.9109716754588141),
#  (('SalePrice', 'Condition2', 'GarageQual'), 0.91095453794856),
#  (('SalePrice', 'BsmtFullBath', 'TotalBath'), 0.9109460640225876),
#  (('SalePrice', 'YearRemodAdd', 'MasVnrType'), 0.9109381596716017),
#  (('SalePrice', 'LotFrontage', 'GarageQual'), 0.9109179080797429),
#  (('SalePrice', 'BsmtUnfSF', 'TotalBath'), 0.9109178863632812),
#  (('SalePrice', 'FullBath', 'ExterQual'), 0.9109103840328723),
#  (('SalePrice', 'BsmtExposure', 'GarageQual'), 0.9108919446991142),
#  (('SalePrice', 'TotalBath', 'BsmtCond'), 0.9108869981858216),
#  (('SalePrice', 'BsmtFinSF1', 'GarageQual'), 0.9108825304835214),
#  (('SalePrice', 'BsmtFinType2', 'GarageQual'), 0.910880761740498),
#  (('SalePrice', 'EnclosedPorch', 'GarageQual'), 0.9108783833943139),
#  (('SalePrice', 'Neighborhood', 'GarageQual'), 0.9108718014928981),
#  (('SalePrice', '3SsnPorch', 'GarageQual'), 0.9108675231973978),
#  (('SalePrice', 'KitchenAbvGr', 'GarageQual'), 0.9108491640339752),
#  (('SalePrice', 'LandSlope', 'GarageQual'), 0.9108458318835192),
#  (('SalePrice', 'GarageQual', 'MiscFeature'), 0.9108393906641782),
#  (('SalePrice', 'RoofMatl', 'GarageQual'), 0.9108321688726922),
#  (('SalePrice', 'ScreenPorch', 'GarageQual'), 0.9108283981709145),
#  (('SalePrice', 'MasVnrArea', 'TotalBath'), 0.9108243205429737),
#  (('SalePrice', 'BsmtHalfBath', 'GarageQual'), 0.9108225137230075),
#  (('SalePrice', 'MoSold', 'GarageQual'), 0.9108163942464064),
#  (('SalePrice', 'YrSold', 'GarageQual'), 0.9108092956619837),
#  (('SalePrice', 'LowQualFinSF', 'GarageQual'), 0.910798124021298),
#  (('SalePrice', 'BsmtQual', 'GarageQual'), 0.9107972117523602),
#  (('SalePrice', 'YearRemodAdd', 'MSSubClass'), 0.910797057389525),
#  (('SalePrice', 'MiscVal', 'GarageQual'), 0.9107952947483499),
#  (('SalePrice', 'LotConfig', 'GarageQual'), 0.9107946879433533),
#  (('SalePrice', 'KitchenQual', 'GarageQual'), 0.9107933531555582),
#  (('SalePrice', 'PoolArea', 'GarageQual'), 0.9107923448396908),
#  (('SalePrice', 'BsmtFullBath', 'GarageQual'), 0.91079076404961),
#  (('SalePrice', 'GarageQual', 'Fence'), 0.9107905988955294),
#  (('SalePrice', 'BsmtFinSF2', 'GarageQual'), 0.9107879094258993),
#  (('SalePrice', 'BldgType', 'GarageQual'), 0.9107876211729825),
#  (('SalePrice', 'GarageCars', 'GarageYrBlt'), 0.9107862605069571),
#  (('SalePrice', 'LotArea', 'GarageQual'), 0.9107857504014584),
#  (('SalePrice', 'TotalSF', 'Electrical'), 0.91077988122131),
#  (('SalePrice', 'YearRemodAdd', 'SaleCondition'), 0.9107619756770574),
#  (('SalePrice', 'GarageYrBlt', 'YearRemodAdd'), 0.9107305687084848),
#  (('SalePrice', 'LotFrontage', 'YearRemodAdd'), 0.9106595698704808),
#  (('SalePrice', 'YearRemodAdd', 'Alley'), 0.9106502365830911),
#  (('SalePrice', 'TotalBath', 'HeatingQC'), 0.9106440877602385),
#  (('SalePrice', 'MasVnrArea', 'GarageCars'), 0.9106330100583195),
#  (('SalePrice', 'BedroomAbvGr', 'GarageYrBlt'), 0.9106092360447158),
#  (('SalePrice', '2ndFlrSF', 'YearRemodAdd'), 0.9106004915958409),
#  (('SalePrice', 'Fireplaces', 'TotalBath'), 0.910596609328304),
#  (('SalePrice', 'FullBath', 'BsmtFinType1'), 0.9105657114478575),
#  (('SalePrice', 'BedroomAbvGr', 'TotalBath'), 0.9105443551478242),
#  (('SalePrice', 'TotalBath', 'SaleCondition'), 0.9105221324905874),
#  (('GrLivArea', 'SalePrice', 'GarageCars'), 0.91050333127227),
#  (('SalePrice', 'YearRemodAdd', 'SaleType'), 0.9104894570593155),
#  (('GrLivArea', 'SalePrice', 'GarageYrBlt'), 0.9104830813115343),
#  (('SalePrice', 'YearRemodAdd', 'Foundation'), 0.9104662323171316),
#  (('SalePrice', 'FullBath', 'BsmtCond'), 0.9104441730125065),
#  (('SalePrice', 'YearRemodAdd', 'BsmtQual'), 0.9104195230633443),
#  (('SalePrice', 'FullBath', 'GarageArea'), 0.9104137929975894),
#  (('SalePrice', 'YearRemodAdd', 'Heating'), 0.9103774058672083),
#  (('SalePrice', 'GarageCars', 'BsmtCond'), 0.9103465233227781),
#  (('SalePrice', 'TotalBath', 'ExterCond'), 0.9103404773029498),
#  (('SalePrice', 'GarageCars', 'FireplaceQu'), 0.9103045552727798),
#  (('SalePrice', 'YearRemodAdd', 'PoolQC'), 0.910277688744896),
#  (('SalePrice', 'GarageCars', 'HeatingQC'), 0.9102613731998526),
#  (('SalePrice', 'YearRemodAdd', 'Street'), 0.9102510816494961),
#  (('SalePrice', 'YearRemodAdd', 'Functional'), 0.9102402751234296),
#  (('SalePrice', 'FullBath', 'GarageYrBlt'), 0.9102365836722063),
#  (('SalePrice', 'TotalBath', 'LotShape'), 0.9102322236237282),
#  (('SalePrice', 'FullBath', 'TotalBath'), 0.9102241059838617),
#  (('SalePrice', 'YearRemodAdd', 'MSZoning'), 0.9102113756141591),
#  (('SalePrice', 'YearRemodAdd', 'HeatingQC'), 0.9101996603545981),
#  (('SalePrice', 'YearRemodAdd', 'Condition1'), 0.9101953048920642),
#  (('SalePrice', 'WoodDeckSF', 'YearRemodAdd'), 0.9101940275245431),
#  (('SalePrice', 'YearRemodAdd', 'Utilities'), 0.9101912957224138),
#  (('SalePrice', 'Fireplaces', 'GarageCars'), 0.9101901868426436),
#  (('SalePrice', 'BsmtUnfSF', 'YearRemodAdd'), 0.910182669187641),
#  (('SalePrice', 'GarageCars', 'BsmtFinType1'), 0.910176886032132),
#  (('SalePrice', 'ScreenPorch', 'YearRemodAdd'), 0.9101699988764349),
#  (('SalePrice', 'YearRemodAdd', 'Exterior1st'), 0.9101604407140547),
#  (('SalePrice', 'OpenPorchSF', 'YearRemodAdd'), 0.9101576255889848),
#  (('SalePrice', 'YearRemodAdd', 'RoofStyle'), 0.9101567574846526),
#  (('SalePrice', 'LotArea', 'YearRemodAdd'), 0.9101558522098264),
#  (('SalePrice', 'BsmtFinSF2', 'YearRemodAdd'), 0.9101504856275336),
#  (('SalePrice', 'YearRemodAdd', 'Condition2'), 0.9101386480106571),
#  (('SalePrice', 'BsmtHalfBath', 'YearRemodAdd'), 0.9101096234333781),
#  (('SalePrice', 'YearRemodAdd', 'Fence'), 0.9101084128567845),
#  (('SalePrice', 'TotalBath', 'Foundation'), 0.9100940341237573),
#  (('SalePrice', 'YearRemodAdd', 'Exterior2nd'), 0.9100851888559642),
#  (('SalePrice', 'TotalBath', 'FireplaceQu'), 0.9100759743632993),
#  (('SalePrice', 'YearRemodAdd', 'MixedExterior'), 0.9100745277349995),
#  (('SalePrice', 'YearRemodAdd', 'Neighborhood'), 0.9100293746494529),
#  (('SalePrice', 'YearRemodAdd', 'LandContour'), 0.9100266172282581),
#  (('SalePrice', 'BsmtFullBath', 'YearRemodAdd'), 0.9100212745273504),
#  (('SalePrice', 'YearRemodAdd', 'BsmtExposure'), 0.9100201058649037),
#  (('SalePrice', 'YrSold', 'YearRemodAdd'), 0.9100166805972154),
#  (('SalePrice', 'TotalBath', 'Exterior1st'), 0.910008869611149),
#  (('SalePrice', 'GarageCars', 'HouseStyle'), 0.9100059389712839),
#  (('SalePrice', 'EnclosedPorch', 'YearRemodAdd'), 0.9100004569747651),
#  (('SalePrice', 'YearRemodAdd', 'LotConfig'), 0.9100002566246038),
#  (('SalePrice', 'MoSold', 'YearRemodAdd'), 0.9099997791992168),
#  (('SalePrice', 'BsmtFinSF1', 'YearRemodAdd'), 0.909996960043589),
#  (('SalePrice', 'YearRemodAdd', 'MiscFeature'), 0.9099949915444642),
#  (('SalePrice', '3SsnPorch', 'YearRemodAdd'), 0.909987378537283),
#  (('SalePrice', 'PoolArea', 'YearRemodAdd'), 0.9099857066208655),
#  (('SalePrice', 'FullBath', 'Fireplaces'), 0.9099830049357067),
#  (('SalePrice', 'KitchenAbvGr', 'YearRemodAdd'), 0.9099751716139702),
#  (('SalePrice', 'YearRemodAdd', 'BldgType'), 0.9099742044172788),
#  (('SalePrice', 'KitchenAbvGr', 'TotalBath'), 0.9099689643098406),
#  (('SalePrice', 'MiscVal', 'YearRemodAdd'), 0.9099673606131332),
#  (('SalePrice', 'LowQualFinSF', 'YearRemodAdd'), 0.9099606703113355),
#  (('SalePrice', 'TotalBath', 'Heating'), 0.9099554659756681),
#  (('SalePrice', 'YearRemodAdd', 'BsmtFinType2'), 0.9099498191938704),
#  (('SalePrice', 'YearRemodAdd', 'RoofMatl'), 0.9099455416377333),
#  (('SalePrice', 'YearRemodAdd', 'GarageFinish'), 0.9099448286056623),
#  (('SalePrice', 'YearRemodAdd', 'LandSlope'), 0.9099441062253151),
#  (('SalePrice', 'Fireplaces', 'GarageYrBlt'), 0.9099227315743089),
#  (('SalePrice', 'TotalBsmtSF', 'TotalBath'), 0.9099124434463806),
#  (('GrLivArea', 'SalePrice', 'TotalBath'), 0.9098709328664378),
#  (('SalePrice', 'TotalBath', 'Exterior2nd'), 0.9098472913875801),
#  (('SalePrice', 'GarageCars', 'Foundation'), 0.9098380169686465),
#  (('SalePrice', 'HalfBath', 'GarageCars'), 0.9098110174269951),
#  (('SalePrice', 'TotalBath', 'MixedExterior'), 0.9097671851243965),
#  (('SalePrice', 'MasVnrArea', 'FullBath'), 0.9097595000975158),
#  (('SalePrice', 'TotalBath', 'Alley'), 0.9097544547370509),
#  (('SalePrice', 'GarageCars', 'LotShape'), 0.9097369967530775),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageCars'), 0.9097281205846419),
#  (('GrLivArea', 'SalePrice', 'Electrical'), 0.9097005575501819),
#  (('SalePrice', 'TotalBath', 'HouseStyle'), 0.9096954170059761),
#  (('SalePrice', 'TotRmsAbvGrd', 'TotalBath'), 0.9096659672264216),
#  (('SalePrice', 'TotalBath', 'SaleType'), 0.9096602072392067),
#  (('SalePrice', 'BsmtFinSF1', 'TotalBath'), 0.909619538342136),
#  (('SalePrice', 'GarageCars', 'Alley'), 0.9096079344918815),
#  (('SalePrice', 'FullBath', 'TotalSF'), 0.9095841396113451),
#  (('SalePrice', 'FullBath', 'KitchenAbvGr'), 0.9095723905197203),
#  (('SalePrice', 'FullBath', 'HalfBath'), 0.9095695162661293),
#  (('SalePrice', 'TotalBath', 'Street'), 0.9095672980042862),
#  (('SalePrice', 'GarageYrBlt', 'Electrical'), 0.909551577685787),
#  (('SalePrice', 'TotalBath', 'Functional'), 0.9095478273132115),
#  (('SalePrice', 'BedroomAbvGr', 'Electrical'), 0.9095309322524853),
#  (('SalePrice', 'GarageCars', 'SaleType'), 0.9095301634882946),
#  (('SalePrice', 'GarageCars', 'SaleCondition'), 0.9095157219715542),
#  (('SalePrice', '1stFlrSF', 'TotalBath'), 0.9095152735674024),
#  (('SalePrice', 'FullBath', 'FireplaceQu'), 0.9095120833398714),
#  (('SalePrice', 'TotalBath', 'PoolQC'), 0.9094972609487679),
#  (('SalePrice', 'GarageCars', 'ExterCond'), 0.909472869405968),
#  (('SalePrice', 'TotalBath', 'RoofStyle'), 0.9094600456103539),
#  (('SalePrice', 'TotalBath', 'BsmtFinType1'), 0.9094546237171014),
#  (('SalePrice', 'TotalBath', 'MasVnrType'), 0.9094486397613133),
#  (('SalePrice', 'LotFrontage', 'TotalBath'), 0.9094469263709901),
#  (('SalePrice', 'TotalBath', 'Condition1'), 0.909438566377732),
#  (('SalePrice', 'GarageCars', 'Heating'), 0.9094151055659839),
#  (('SalePrice', 'FullBath', 'LotShape'), 0.909411407265322),
#  (('SalePrice', 'FullBath', 'ExterCond'), 0.9094075548380824),
#  (('SalePrice', 'FullBath', 'HeatingQC'), 0.9093987980182042),
#  (('SalePrice', 'HalfBath', 'TotalBath'), 0.9093972469108783),
#  (('SalePrice', 'TotalBath', 'MSZoning'), 0.909362748818619),
#  (('SalePrice', '2ndFlrSF', 'GarageCars'), 0.9093465517223658),
#  (('SalePrice', 'GarageArea', 'Electrical'), 0.9093352994619681),
#  (('SalePrice', 'TotalBath', 'Utilities'), 0.9093334270146431),
#  (('SalePrice', 'TotalBath', 'Condition2'), 0.9093177075994021),
#  (('SalePrice', 'FullBath', 'SaleCondition'), 0.9093132489271102),
#  (('SalePrice', 'TotalBsmtSF', 'GarageCars'), 0.9092935864042929),
#  (('SalePrice', 'TotalSF', 'Foundation'), 0.9092638677192217),
#  (('SalePrice', 'EnclosedPorch', 'TotalBath'), 0.9092589239816109),
#  (('SalePrice', 'GarageCars', 'Exterior1st'), 0.9092578534248554),
#  (('SalePrice', 'FullBath', 'HouseStyle'), 0.9092393451634299),
#  (('SalePrice', 'WoodDeckSF', 'TotalBath'), 0.9092326050866714),
#  (('SalePrice', 'TotalBath', 'Neighborhood'), 0.9092320703260338),
#  (('SalePrice', 'ExterQual', 'Electrical'), 0.9092247795040876),
#  (('SalePrice', 'OpenPorchSF', 'TotalBath'), 0.9092244266877523),
#  (('SalePrice', 'GarageCars', 'RoofStyle'), 0.9092181950592644),
#  (('SalePrice', 'TotalBath', 'BsmtExposure'), 0.9092117619457173),
#  (('SalePrice', 'GarageCars', 'MasVnrType'), 0.909209713023752),
#  (('SalePrice', 'TotalBath', 'LandContour'), 0.9092049023652627),
# ...
#  (('SalePrice', 'GarageCars', 'Functional'), 0.9090899533816794),
#  (('SalePrice', 'GarageCars', 'OpenPorchSF'), 0.9090798318800397),
#  (('SalePrice', 'TotalBath', 'MiscFeature'), 0.9090758308161633),
#  (('SalePrice', 'BsmtFinSF2', 'TotalBath'), 0.9090752619606243),
#  (('SalePrice', 'PoolArea', 'TotalBath'), 0.9090696447663207),
#  (('SalePrice', 'LotArea', 'TotalBath'), 0.909067915372847),
#  (('SalePrice', 'TotalBath', 'GarageFinish'), 0.9090672435268268),
#  (('SalePrice', 'GarageCars', 'MixedExterior'), 0.9090637531508194),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageYrBlt'), 0.9090524612647608),
#  (('SalePrice', 'FullBath', 'Alley'), 0.9090371876015024),
#  (('SalePrice', 'TotalSF', 'HouseStyle'), 0.9089949992452907),
#  (('SalePrice', 'GarageCars', 'Utilities'), 0.9089945862326038),
#  (('SalePrice', 'FullBath', 'BedroomAbvGr'), 0.9089561767739582),
#  (('SalePrice', 'KitchenAbvGr', 'GarageCars'), 0.9089544404868397),
#  (('SalePrice', 'GarageCars', 'GarageFinish'), 0.9089519987785224),
#  (('SalePrice', 'GarageCars', 'WoodDeckSF'), 0.9089209943944531),
#  (('SalePrice', 'GarageCars', 'Condition1'), 0.9089096294372389),
#  (('SalePrice', 'GarageCars', 'MSSubClass'), 0.908908916188246),
#  (('SalePrice', 'GarageCars', 'EnclosedPorch'), 0.9088924572557402),
#  (('SalePrice', 'FullBath', 'SaleType'), 0.9088881095253595),
#  (('SalePrice', 'GarageCars', 'PoolQC'), 0.9088775339595361),
#  (('SalePrice', 'GarageCars', 'Condition2'), 0.9088550203145711),
#  (('SalePrice', 'GarageCars', 'Neighborhood'), 0.9088280846137229),
#  (('SalePrice', 'GarageCars', 'GarageArea'), 0.90880367007412),
#  (('SalePrice', 'BsmtUnfSF', 'GarageCars'), 0.9088015609451358),
#  (('SalePrice', '1stFlrSF', 'GarageCars'), 0.9087904474796117),
#  (('SalePrice', 'FullBath', 'Exterior1st'), 0.9087857169035437),
#  (('SalePrice', 'BsmtFullBath', 'FullBath'), 0.9087751024633233),
#  (('SalePrice', 'GarageCars', 'BsmtExposure'), 0.9087542515767143),
#  (('SalePrice', 'GarageCars', 'LandContour'), 0.9087406914439753),
#  (('SalePrice', 'BsmtFullBath', 'GarageCars'), 0.9087323851926198),
#  (('SalePrice', 'FullBath', 'MasVnrType'), 0.9087256149694111),
#  (('SalePrice', 'BsmtHalfBath', 'GarageCars'), 0.9087178153327867),
#  (('SalePrice', 'BsmtFinSF2', 'GarageCars'), 0.9087064404190899),
#  (('SalePrice', 'OverallCond', 'Electrical'), 0.90869335785508),
#  (('SalePrice', 'FullBath', 'BsmtExposure'), 0.9086921125177255),
#  (('SalePrice', 'GarageCars', 'KitchenQual'), 0.9086792471323683),
#  (('SalePrice', 'GarageCars', 'MiscFeature'), 0.9086768536211052),
#  (('SalePrice', 'GarageCars', 'Fence'), 0.9086759441309182),
#  (('SalePrice', 'GarageCars', 'BsmtQual'), 0.9086747568312337),
#  (('SalePrice', 'GarageCars', 'ScreenPorch'), 0.9086742401227426),
#  (('SalePrice', 'GarageCars', '3SsnPorch'), 0.9086693094681363),
#  (('SalePrice', 'GarageCars', 'RoofMatl'), 0.9086617128110146),
#  (('SalePrice', 'LotFrontage', 'GarageCars'), 0.9086594524562408),
#  (('SalePrice', 'GarageCars', 'MiscVal'), 0.9086571036765032),
#  (('SalePrice', 'MasVnrArea', 'Electrical'), 0.9086555415606838),
#  (('SalePrice', 'LowQualFinSF', 'GarageCars'), 0.9086496311845178),
#  (('SalePrice', 'FullBath', 'Exterior2nd'), 0.9086279576591352),
#  (('SalePrice', 'GarageArea', 'TotalSF'), 0.9086259666114797),
#  (('SalePrice', 'GarageCars', 'BldgType'), 0.9086248218454058),
#  (('SalePrice', 'TotalSF', 'HeatingQC'), 0.9086221155603526),
#  (('SalePrice', 'GarageCars', 'LandSlope'), 0.9086220687586811),
#  (('SalePrice', 'GarageCars', 'MoSold'), 0.9086215315128052),
#  (('SalePrice', 'FullBath', 'Functional'), 0.9086152430120448),
#  (('SalePrice', 'GarageCars', 'PoolArea'), 0.9086132392647273),
#  (('SalePrice', 'GarageCars', 'YrSold'), 0.9086103475148855),
#  (('SalePrice', 'BsmtFinSF1', 'GarageCars'), 0.9086102076724627),
#  (('SalePrice', 'GarageCars', 'BsmtFinType2'), 0.9086100263030453),
#  (('SalePrice', 'GarageCars', 'LotConfig'), 0.9086071845118083),
#  (('SalePrice', 'Foundation', 'Electrical'), 0.9086071633359898),
#  (('SalePrice', 'LotArea', 'GarageCars'), 0.9086070552071185),
#  (('SalePrice', 'Electrical', 'FireplaceQu'), 0.9085906188054993),
#  (('SalePrice', 'TotRmsAbvGrd', 'Electrical'), 0.9085816635324778),
#  (('SalePrice', 'FullBath', 'MixedExterior'), 0.9085716811737342),
#  (('SalePrice', 'Fireplaces', 'Electrical'), 0.9085653751703875),
#  (('SalePrice', 'FullBath', 'WoodDeckSF'), 0.9085388026562511),
#  (('SalePrice', 'HeatingQC', 'Electrical'), 0.9085332165009302),
#  (('SalePrice', 'BsmtCond', 'Electrical'), 0.9085261215211972),
#  (('SalePrice', 'FullBath', 'Street'), 0.9085251065209273),
#  (('SalePrice', 'FullBath', 'Condition1'), 0.9084871379439285),
#  (('SalePrice', 'GarageArea', 'OverallCond'), 0.9084764598611883),
#  (('SalePrice', 'GarageYrBlt', 'FireplaceQu'), 0.9084650373173309),
#  (('SalePrice', 'GarageArea', 'GarageYrBlt'), 0.9084625714197246),
#  (('SalePrice', 'MasVnrArea', 'GarageYrBlt'), 0.9084463439475396),
#  (('SalePrice', 'FullBath', 'EnclosedPorch'), 0.9084309815940725),
#  (('SalePrice', 'FullBath', 'PoolQC'), 0.9084302033452637),
#  (('SalePrice', 'FullBath', 'Utilities'), 0.9084275751264386),
#  (('GrLivArea', 'SalePrice', 'FullBath'), 0.9084268835417417),
#  (('SalePrice', 'FullBath', 'MSZoning'), 0.9084203612940615),
#  (('SalePrice', 'BedroomAbvGr', 'GarageArea'), 0.9084203139120675),
#  (('SalePrice', 'LotFrontage', 'FullBath'), 0.9084077601353037),
#  (('SalePrice', 'FullBath', 'RoofStyle'), 0.9083921415623605),
#  (('SalePrice', 'FullBath', 'Fence'), 0.9083648545142194),
#  (('SalePrice', 'BsmtFinSF2', 'FullBath'), 0.9083626191731023),
#  (('SalePrice', 'FullBath', 'Condition2'), 0.9083522441814055),
#  (('SalePrice', 'HouseStyle', 'Electrical'), 0.9083514066254343),
#  (('SalePrice', 'FullBath', 'KitchenQual'), 0.9083440783336177),
#  (('SalePrice', 'OverallCond', 'Foundation'), 0.9083367968699726),
#  (('SalePrice', 'MasVnrArea', 'TotalSF'), 0.9083364664850523),
#  (('SalePrice', 'BsmtFinSF1', 'FullBath'), 0.9083325144559212),
#  (('SalePrice', '1stFlrSF', 'FullBath'), 0.9083254022014149),
#  (('SalePrice', 'FullBath', 'OpenPorchSF'), 0.9082862660614269),
#  (('SalePrice', 'FullBath', 'BsmtQual'), 0.9082644062396118),
#  (('SalePrice', 'FullBath', 'LandContour'), 0.9082621641274498),
#  (('SalePrice', 'FullBath', 'Neighborhood'), 0.9082598019396715),
#  (('SalePrice', 'BsmtHalfBath', 'FullBath'), 0.9082515099252857),
#  (('SalePrice', 'FullBath', 'TotRmsAbvGrd'), 0.9082502081540262),
#  (('SalePrice', 'GarageYrBlt', 'BsmtCond'), 0.9082487110047708),
#  (('SalePrice', 'LowQualFinSF', 'FullBath'), 0.9082439288768729),
#  (('SalePrice', 'HalfBath', 'Electrical'), 0.9082401465526333),
#  (('SalePrice', 'FullBath', 'ScreenPorch'), 0.9082401171407992),
#  (('SalePrice', 'TotalSF', 'BsmtFinType1'), 0.9081895881838876),
#  (('SalePrice', 'FullBath', '3SsnPorch'), 0.9081788492828777),
#  (('SalePrice', 'FullBath', 'MSSubClass'), 0.9081722645163327),
#  (('SalePrice', 'FullBath', 'LotConfig'), 0.9081569114530399),
#  (('SalePrice', 'FullBath', 'MiscVal'), 0.9081453375042899),
#  (('SalePrice', 'FullBath', 'MiscFeature'), 0.9081451506354383),
#  (('SalePrice', 'FullBath', 'RoofMatl'), 0.9081418118463085),
#  (('SalePrice', 'FullBath', 'MoSold'), 0.9081405807001419),
#  (('SalePrice', 'FullBath', 'GarageFinish'), 0.9081397794496193),
#  (('SalePrice', '2ndFlrSF', 'FullBath'), 0.908138068002289),
#  (('SalePrice', 'BsmtUnfSF', 'FullBath'), 0.9081376202164209),
#  (('SalePrice', 'FullBath', 'YrSold'), 0.9081364832905132),
#  (('SalePrice', 'FullBath', 'PoolArea'), 0.9081363578221799),
#  (('SalePrice', 'ExterCond', 'Electrical'), 0.9081309317719),
#  (('SalePrice', 'LotArea', 'FullBath'), 0.9081267930718928),
#  (('SalePrice', 'FullBath', 'BldgType'), 0.9081238267877266),
#  (('SalePrice', 'FullBath', 'BsmtFinType2'), 0.9081206506809337),
#  (('SalePrice', 'FullBath', 'LandSlope'), 0.9081186416135685),
#  (('SalePrice', 'LotShape', 'Electrical'), 0.9081031872942049),
#  (('SalePrice', 'ExterQual', 'Foundation'), 0.9080840621469868),
#  (('SalePrice', 'GarageYrBlt', 'BsmtFinType1'), 0.9080526280705297),
#  (('SalePrice', 'ExterQual', 'HeatingQC'), 0.9080210096502253),
#  (('SalePrice', 'TotalSF', 'FireplaceQu'), 0.9080184432399823),
#  (('SalePrice', 'GarageYrBlt', 'HouseStyle'), 0.9080129697159309),
#  (('SalePrice', 'TotalSF', 'BsmtCond'), 0.9079518855020027),
#  (('SalePrice', 'GarageArea', 'ExterQual'), 0.9079314676978385),
#  (('SalePrice', 'BedroomAbvGr', 'Foundation'), 0.9078942982812992),
#  (('SalePrice', 'HalfBath', 'GarageYrBlt'), 0.9078933235835845),
#  (('SalePrice', 'Electrical', 'SaleCondition'), 0.907889395572837),
#  (('SalePrice', 'Exterior1st', 'Electrical'), 0.9078854122062816),
#  (('SalePrice', 'BsmtFinType1', 'Electrical'), 0.9078760643694077),
#  (('SalePrice', 'TotalSF', 'ExterQual'), 0.90787366237436),
#  (('SalePrice', '2ndFlrSF', 'Electrical'), 0.9078235404602477),
#  (('SalePrice', '2ndFlrSF', 'GarageYrBlt'), 0.9078195261821853),
#  (('SalePrice', 'GarageYrBlt', 'LotShape'), 0.907815069490737),
#  (('SalePrice', 'GarageYrBlt', 'MSSubClass'), 0.9077905125235706),
#  (('GrLivArea', 'SalePrice', 'GarageArea'), 0.907784693627013),
#  (('SalePrice', 'Exterior2nd', 'Electrical'), 0.9077780204003493),
#  (('SalePrice', 'Electrical', 'SaleType'), 0.9077764651143192),
#  (('SalePrice', 'Alley', 'Electrical'), 0.9077406917336206),
#  (('SalePrice', 'TotalSF', 'LotShape'), 0.9077345654865192),
#  (('SalePrice', 'BedroomAbvGr', 'HeatingQC'), 0.9077195294043899),
#  (('SalePrice', 'HalfBath', 'TotalSF'), 0.9076691910233765),
#  (('SalePrice', 'TotalBsmtSF', 'Electrical'), 0.9076576126259225),
#  (('SalePrice', 'GarageYrBlt', 'HeatingQC'), 0.9076525529881162),
#  (('SalePrice', 'Electrical', 'MixedExterior'), 0.907646929731609),
#  (('SalePrice', 'GarageYrBlt', 'SaleCondition'), 0.9076401780220338),
#  (('SalePrice', 'TotalSF', 'SaleCondition'), 0.9076163465698615),
#  (('SalePrice', 'GarageArea', 'FireplaceQu'), 0.9076077354746996),
#  (('SalePrice', 'TotalBsmtSF', 'GarageYrBlt'), 0.907604989891588),
#  (('SalePrice', 'GarageArea', 'HeatingQC'), 0.9075990754705987),
#  (('SalePrice', 'TotalSF', 'Alley'), 0.9075934204111578),
#  (('GrLivArea', 'SalePrice', 'BsmtFinType1'), 0.9075904880182549),
#  (('SalePrice', 'MasVnrArea', 'GarageArea'), 0.9075803009175776),
#  (('SalePrice', 'TotalSF', 'ExterCond'), 0.9075733151441404),
#  (('SalePrice', 'GarageYrBlt', 'SaleType'), 0.9075533372590752),
#  (('SalePrice', 'GarageArea', 'HouseStyle'), 0.9075480859413554),
#  (('SalePrice', 'GarageYrBlt', 'ExterCond'), 0.9074974809667202),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtFinType1'), 0.9074812644290762),
#  (('SalePrice', 'MSZoning', 'Electrical'), 0.9074559251123206),
#  (('SalePrice', 'BedroomAbvGr', 'BsmtCond'), 0.9074548594176757),
#  (('SalePrice', 'GarageArea', 'BsmtCond'), 0.9074541918250587),
#  (('SalePrice', 'GarageYrBlt', 'MasVnrType'), 0.9074522008072942),
#  (('SalePrice', '1stFlrSF', 'GarageYrBlt'), 0.9074479579626699),
#  (('SalePrice', 'Fireplaces', 'GarageArea'), 0.9074476940214827),
#  (('SalePrice', 'RoofStyle', 'Electrical'), 0.9074462506842154),
#  (('GrLivArea', 'SalePrice', 'Foundation'), 0.907424784165194),
#  (('SalePrice', 'MasVnrType', 'Electrical'), 0.9074203038197346),
#  (('SalePrice', 'BsmtUnfSF', 'Electrical'), 0.9074201789774701),
#  (('SalePrice', 'Street', 'Electrical'), 0.9074148357239702),
#  (('SalePrice', 'MSSubClass', 'Electrical'), 0.9074071077009506),
#  (('SalePrice', 'OpenPorchSF', 'Electrical'), 0.9073919324618402),
#  (('GrLivArea', 'SalePrice', 'BsmtCond'), 0.9073860285076801),
#  (('SalePrice', 'GarageYrBlt', 'BsmtQual'), 0.9073836731987863),
#  (('SalePrice', 'LotFrontage', 'GarageYrBlt'), 0.9073733925000077),
#  (('SalePrice', 'BedroomAbvGr', 'OverallCond'), 0.9073694161346042),
#  (('SalePrice', 'GarageArea', 'Foundation'), 0.9073633168015799),
#  (('SalePrice', 'GarageYrBlt', 'Heating'), 0.907330181672088),
#  (('SalePrice', 'GarageYrBlt', 'Exterior1st'), 0.9073211455978469),
#  (('SalePrice', '1stFlrSF', 'Electrical'), 0.9073162922259438),
#  (('SalePrice', 'GarageYrBlt', 'Alley'), 0.9073152341143442),
#  (('SalePrice', 'Electrical', 'PoolQC'), 0.907303195955458),
#  (('SalePrice', 'TotalSF', 'Exterior1st'), 0.9072971905147406),
#  (('SalePrice', 'KitchenAbvGr', 'TotalSF'), 0.9072853182022369),
#  (('SalePrice', 'MasVnrArea', 'BedroomAbvGr'), 0.9072807892974987),
#  (('SalePrice', 'GarageYrBlt', 'KitchenQual'), 0.9072721879303324),
#  (('SalePrice', 'Heating', 'Electrical'), 0.9072644331363768),
#  (('SalePrice', 'Fireplaces', 'TotalSF'), 0.907256925035255),
#  (('SalePrice', 'HalfBath', 'GarageArea'), 0.9072559774441499),
#  (('GrLivArea', 'SalePrice', 'OverallCond'), 0.90724728877605),
#  (('SalePrice', 'GarageYrBlt', 'Street'), 0.9072352049163476),
#  (('SalePrice', 'Electrical', 'Functional'), 0.9072154220873693),
#  (('SalePrice', 'TotalBsmtSF', 'HouseStyle'), 0.9072067044910309),
#  (('SalePrice', 'BedroomAbvGr', 'FireplaceQu'), 0.9071912683543503),
#  (('SalePrice', 'GarageYrBlt', 'Exterior2nd'), 0.9071827638620634),
#  (('SalePrice', 'Condition1', 'Electrical'), 0.9071795042852332),
#  (('SalePrice', 'GarageYrBlt', 'MixedExterior'), 0.9071786612550121),
#  (('SalePrice', 'LotFrontage', 'Electrical'), 0.9071778469884015),
#  (('SalePrice', 'WoodDeckSF', 'Electrical'), 0.9071452019847052),
#  (('SalePrice', 'GarageYrBlt', 'PoolQC'), 0.9071305062188166),
#  (('SalePrice', 'GarageYrBlt', 'RoofStyle'), 0.9071289486088351),
#  (('SalePrice', 'GarageYrBlt', 'Utilities'), 0.9071190676970364),
#  (('SalePrice', 'LandContour', 'Electrical'), 0.9071146654024108),
#  (('SalePrice', 'TotalSF', 'MSZoning'), 0.9071142041749343),
#  (('SalePrice', 'Condition2', 'Electrical'), 0.9071103159671127),
#  (('SalePrice', 'TotalSF', 'SaleType'), 0.907109374791972),
#  (('SalePrice', 'EnclosedPorch', 'Electrical'), 0.9071016403879242),
#  (('SalePrice', 'Fireplaces', 'Foundation'), 0.9070974957854857),
#  (('SalePrice', 'GarageYrBlt', 'Foundation'), 0.9070974613266872),
#  (('SalePrice', 'OpenPorchSF', 'GarageYrBlt'), 0.907089053130796),
#  (('GrLivArea', 'SalePrice', 'HeatingQC'), 0.9070859799356742),
#  (('SalePrice', 'TotalSF', 'RoofStyle'), 0.9070809489013514),
#  (('SalePrice', 'TotalSF', 'Exterior2nd'), 0.9070737662051295),
#  (('SalePrice', 'OverallCond', 'ExterCond'), 0.9070637941386891),
#  (('SalePrice', 'GarageArea', 'BsmtFinType1'), 0.9070628636581182),
#  (('SalePrice', 'Utilities', 'Electrical'), 0.907051180642487),
#  (('SalePrice', 'BsmtUnfSF', 'GarageYrBlt'), 0.9070472834753056),
#  (('SalePrice', 'WoodDeckSF', 'GarageYrBlt'), 0.9070376751459815),
#  (('SalePrice', 'Neighborhood', 'Electrical'), 0.9070238413034832),
#  (('SalePrice', 'TotRmsAbvGrd', 'GarageArea'), 0.9070159081192066),
#  (('SalePrice', 'TotalSF', 'Heating'), 0.9070078011037622),
#  (('SalePrice', 'GarageYrBlt', 'Condition1'), 0.9070068662991551),
#  (('SalePrice', 'Electrical', 'GarageFinish'), 0.9069983746648063),
#  (('SalePrice', 'BedroomAbvGr', 'Fireplaces'), 0.9069976922706715),
#  (('SalePrice', 'RoofMatl', 'Electrical'), 0.9069930152821494),
#  (('SalePrice', 'Electrical', 'KitchenQual'), 0.9069841776914876),
#  (('SalePrice', 'BedroomAbvGr', 'TotalSF'), 0.9069837437186241),
#  (('SalePrice', 'KitchenAbvGr', 'Electrical'), 0.9069811780560265),
#  (('SalePrice', 'BsmtExposure', 'Electrical'), 0.9069801956302896),
#  (('SalePrice', 'TotalSF', 'Functional'), 0.9069800605014268),
#  (('SalePrice', 'LowQualFinSF', 'Electrical'), 0.9069780472785066),
#  (('SalePrice', 'GarageYrBlt', 'Functional'), 0.9069722984428424),
#  (('SalePrice', 'ScreenPorch', 'GarageYrBlt'), 0.9069697736876701),
#  (('SalePrice', 'GarageYrBlt', 'Condition2'), 0.9069670074532967),
#  (('SalePrice', 'OverallCond', 'FireplaceQu'), 0.9069639423930218),
#  (('SalePrice', 'GarageYrBlt', 'Fence'), 0.9069616035570278),
#  (('SalePrice', 'BsmtHalfBath', 'Electrical'), 0.9069615934121349),
#  (('SalePrice', '3SsnPorch', 'Electrical'), 0.9069575416064519),
#  (('SalePrice', 'MoSold', 'Electrical'), 0.9069537367770937),
#  (('SalePrice', 'GarageYrBlt', 'MSZoning'), 0.906951181626459),
#  (('SalePrice', 'GarageArea', 'LotShape'), 0.9069493859465665),
#  (('SalePrice', 'LandSlope', 'Electrical'), 0.9069491167715485),
#  (('SalePrice', 'LotArea', 'GarageYrBlt'), 0.9069465476375768),
#  (('SalePrice', 'ScreenPorch', 'Electrical'), 0.9069441394665634),
#  ...]

# %%
import statsmodels.api as sm
x = sm.add_constant(housing_factor_dummified1)
model = sm.OLS(log_SalePrice, x.astype(float))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     748.9
# Date:                Wed, 29 May 2024   Prob (F-statistic):               0.00
# Time:                        03:03:44   Log-Likelihood:                 2921.7
# No. Observations:                2580   AIC:                            -5683.
# Df Residuals:                    2500   BIC:                            -5215.
# Df Model:                          79
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            12.0056      2.478      4.846      0.000       7.147      16.864
# GrLivArea      2.852e-05   1.37e-05      2.088      0.037    1.73e-06    5.53e-05
# SalePrice      3.457e-06   6.19e-08     55.889      0.000    3.34e-06    3.58e-06
# LotFrontage       0.0002      0.000      2.423      0.015    4.68e-05       0.000
# LotArea        4.907e-07    2.4e-07      2.043      0.041    1.97e-08    9.62e-07
# MasVnrArea     -9.33e-05    1.2e-05     -7.769      0.000      -0.000   -6.97e-05
# BsmtFinSF1    -6.092e-06   5.84e-06     -1.043      0.297   -1.75e-05    5.36e-06
# BsmtFinSF2     1.206e-05   9.98e-06      1.208      0.227   -7.51e-06    3.16e-05
# BsmtUnfSF       1.25e-07   5.62e-06      0.022      0.982   -1.09e-05    1.11e-05
# TotalBsmtSF    6.092e-06   7.37e-06      0.826      0.409   -8.37e-06    2.06e-05
# 1stFlrSF       2.381e-05   8.65e-06      2.753      0.006    6.85e-06    4.08e-05
# 2ndFlrSF       2.743e-07   7.33e-06      0.037      0.970   -1.41e-05    1.46e-05
# LowQualFinSF   4.438e-06   2.45e-05      0.181      0.856   -4.36e-05    5.25e-05
# BsmtFullBath      0.0038      0.003      1.147      0.252      -0.003       0.010
# BsmtHalfBath      0.0017      0.006      0.265      0.791      -0.011       0.014
# FullBath          0.0069      0.004      1.885      0.060      -0.000       0.014
# HalfBath          0.0019      0.004      0.444      0.657      -0.007       0.010
# BedroomAbvGr      0.0056      0.003      1.769      0.077      -0.001       0.012
# KitchenAbvGr     -0.0167      0.011     -1.512      0.131      -0.038       0.005
# TotRmsAbvGrd      0.0025      0.002      1.112      0.266      -0.002       0.007
# Fireplaces        0.0114      0.003      3.621      0.000       0.005       0.018
# GarageCars        0.0192      0.005      3.684      0.000       0.009       0.029
# GarageArea    -2.996e-05   1.84e-05     -1.626      0.104   -6.61e-05    6.16e-06
# WoodDeckSF    -1.926e-06   1.38e-05     -0.140      0.889    -2.9e-05    2.51e-05
# OpenPorchSF    2.294e-05   2.65e-05      0.866      0.386    -2.9e-05    7.48e-05
# EnclosedPorch     0.0001   2.72e-05      3.797      0.000       5e-05       0.000
# 3SsnPorch      7.444e-05   6.26e-05      1.189      0.235   -4.83e-05       0.000
# ScreenPorch       0.0001   2.93e-05      3.575      0.000    4.72e-05       0.000
# PoolArea       3.105e-06   5.87e-05      0.053      0.958      -0.000       0.000
# MiscVal        1.101e-06   3.27e-06      0.336      0.737   -5.32e-06    7.52e-06
# YrSold           -0.0021      0.001     -1.697      0.090      -0.004       0.000
# GarageYrBlt       0.0002      0.000      1.560      0.119   -5.12e-05       0.000
# MoSold           -0.0003      0.001     -0.515      0.606      -0.001       0.001
# YearBuilt         0.0007      0.000      4.715      0.000       0.000       0.001
# YearRemodAdd      0.0004      0.000      3.337      0.001       0.000       0.001
# TotalSF        3.018e-05   7.34e-06      4.110      0.000    1.58e-05    4.46e-05
# TotalBath         0.0125      0.003      4.597      0.000       0.007       0.018
# MSSubClass        0.0027      0.001      3.496      0.000       0.001       0.004
# MSZoning         -0.0094      0.002     -4.181      0.000      -0.014      -0.005
# Street            0.0544      0.027      2.010      0.045       0.001       0.108
# Alley             0.0130      0.007      1.882      0.060      -0.001       0.027
# LotShape         -0.0021      0.001     -1.696      0.090      -0.005       0.000
# LandContour       0.0004      0.003      0.161      0.872      -0.005       0.006
# Utilities        -0.0469      0.059     -0.797      0.426      -0.162       0.069
# LotConfig      9.825e-05      0.001      0.095      0.924      -0.002       0.002
# LandSlope         0.0106      0.008      1.371      0.170      -0.005       0.026
# Neighborhood     -0.0004      0.000     -1.767      0.077      -0.001    4.75e-05
# Condition1        0.0012      0.002      0.647      0.518      -0.003       0.005
# Condition2       -0.0121      0.008     -1.580      0.114      -0.027       0.003
# BldgType          0.0032      0.002      1.504      0.133      -0.001       0.007
# HouseStyle       -0.0017      0.001     -1.370      0.171      -0.004       0.001
# OverallQual       0.0311      0.002     19.148      0.000       0.028       0.034
# OverallCond       0.0256      0.002     13.050      0.000       0.022       0.030
# RoofStyle        -0.0027      0.002     -1.224      0.221      -0.007       0.002
# RoofMatl       4.315e-05      0.003      0.014      0.989      -0.006       0.006
# Exterior1st       0.0048      0.004      1.215      0.224      -0.003       0.013
# Exterior2nd       0.0024      0.001      2.341      0.019       0.000       0.004
# MasVnrType       -0.0065      0.003     -2.096      0.036      -0.013      -0.000
# ExterQual         0.0139      0.004      3.694      0.000       0.007       0.021
# ExterCond         0.0074      0.002      3.313      0.001       0.003       0.012
# Foundation        0.0032      0.003      1.052      0.293      -0.003       0.009
# BsmtQual          0.0036      0.001      2.583      0.010       0.001       0.006
# BsmtCond          0.0009      0.002      0.484      0.629      -0.003       0.004
# BsmtExposure     -0.0018      0.002     -1.005      0.315      -0.005       0.002
# BsmtFinType1     -0.0038      0.001     -3.922      0.000      -0.006      -0.002
# BsmtFinType2      0.0019      0.002      1.059      0.290      -0.002       0.005
# Heating           0.0110      0.007      1.550      0.121      -0.003       0.025
# HeatingQC        -0.0046      0.001     -4.051      0.000      -0.007      -0.002
# CentralAir        0.0716      0.008      8.448      0.000       0.055       0.088
# Electrical        0.0038      0.002      1.669      0.095      -0.001       0.008
# KitchenQual       0.0012      0.002      0.617      0.537      -0.003       0.005
# Functional        0.0028      0.002      1.496      0.135      -0.001       0.006
# FireplaceQu       0.0021      0.001      1.479      0.139      -0.001       0.005
# GarageType       -0.0068      0.001     -5.949      0.000      -0.009      -0.005
# GarageFinish      0.0021      0.002      1.289      0.197      -0.001       0.005
# GarageQual        0.0033      0.002      1.554      0.120      -0.001       0.007
# GarageCond        0.0120      0.003      4.729      0.000       0.007       0.017
# PavedDrive        0.0455      0.008      5.908      0.000       0.030       0.061
# PoolQC            0.0188      0.016      1.166      0.244      -0.013       0.050
# Fence            -0.0002      0.002     -0.164      0.870      -0.003       0.003
# MiscFeature      -0.0033      0.004     -0.731      0.465      -0.012       0.005
# SaleType          0.0021      0.001      2.084      0.037       0.000       0.004
# SaleCondition     0.0177      0.002      7.135      0.000       0.013       0.023
# MixedExterior    -0.0008      0.001     -1.198      0.231      -0.002       0.001
# ==============================================================================
# Omnibus:                     1987.736   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           142316.296
# Skew:                          -3.051   Prob(JB):                         0.00
# Kurtosis:                      38.870   Cond. No.                     1.09e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.2e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
pValues = results.pvalues
print('The significant coefficients')
pValues[pValues < .05].sort_values()
# Out:
# The significant coefficients
# SalePrice        0.000000e+00
# OverallQual      2.268112e-76
# OverallCond      1.058637e-37
# CentralAir       4.969362e-17
# MasVnrArea       1.148624e-14
# SaleCondition    1.264361e-12
# GarageType       3.073673e-09
# PavedDrive       3.925223e-09
# const            1.340098e-06
# GarageCond       2.382933e-06
# YearBuilt        2.550228e-06
# TotalBath        4.509162e-06
# MSZoning         2.997287e-05
# TotalSF          4.078382e-05
# HeatingQC        5.250337e-05
# BsmtFinType1     9.011027e-05
# EnclosedPorch    1.501720e-04
# ExterQual        2.255062e-04
# GarageCars       2.344733e-04
# Fireplaces       2.991505e-04
# ScreenPorch      3.571623e-04
# MSSubClass       4.802068e-04
# YearRemodAdd     8.595968e-04
# ExterCond        9.360913e-04
# 1stFlrSF         5.954999e-03
# BsmtQual         9.853439e-03
# LotFrontage      1.546749e-02
# Exterior2nd      1.933406e-02
# MasVnrType       3.621488e-02
# GrLivArea        3.692258e-02
# SaleType         3.726737e-02
# LotArea          4.117458e-02
# Street           4.450284e-02
# dtype: float64

# %%
print('The insignificant coefficients')
pValues[pValues > .05]
# Out:
# The insignificant coefficients
# BsmtFinSF1       0.296849
# BsmtFinSF2       0.227012
# BsmtUnfSF        0.982239
# TotalBsmtSF      0.408768
# 2ndFlrSF         0.970146
# LowQualFinSF     0.856239
# BsmtFullBath     0.251553
# BsmtHalfBath     0.791243
# FullBath         0.059602
# HalfBath         0.657008
# BedroomAbvGr     0.077034
# KitchenAbvGr     0.130757
# TotRmsAbvGrd     0.266384
# GarageArea       0.104022
# WoodDeckSF       0.888912
# OpenPorchSF      0.386362
# 3SsnPorch        0.234607
# PoolArea         0.957802
# MiscVal          0.736691
# YrSold           0.089748
# GarageYrBlt      0.118949
# MoSold           0.606472
# Alley            0.060002
# LotShape         0.089942
# LandContour      0.872119
# Utilities        0.425776
# LotConfig        0.924303
# LandSlope        0.170492
# Neighborhood     0.077281
# Condition1       0.517713
# Condition2       0.114318
# BldgType         0.132807
# HouseStyle       0.170840
# RoofStyle        0.220970
# RoofMatl         0.988768
# Exterior1st      0.224387
# Foundation       0.293114
# BsmtCond         0.628738
# BsmtExposure     0.315114
# BsmtFinType2     0.289670
# Heating          0.121327
# Electrical       0.095256
# KitchenQual      0.537241
# Functional       0.134684
# FireplaceQu      0.139384
# GarageFinish     0.197448
# GarageQual       0.120423
# PoolQC           0.243586
# Fence            0.869690
# MiscFeature      0.464832
# MixedExterior    0.231212
# dtype: float64
