# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.model_selection as ms
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

housing_numeric = pd.read_pickle("housing_numeric.pkl")
housing_factor = pd.read_pickle("housing_factor.pkl")
housing_factor = housing_factor.apply(label_encoder.fit_transform)
housing_combined = pd.concat([housing_numeric, housing_factor], axis=1)
housing_combined  = housing_combined.drop(['PID', 'SalePrice'], axis=1)
housing_numeric  = housing_numeric.drop(['PID', 'SalePrice'], axis=1)

# %%
SalePrice = housing_combined.iloc[:, 3]

# %%
X_train, X_test, y_train, y_test = train_test_split(housing_numeric, SalePrice, test_size=0.2, random_state=0)
X_train2, X_test2, y_train2, y_test2 = train_test_split(housing_factor, SalePrice, test_size=0.2, random_state=0)
X_train3, X_test3, y_train3, y_test3 = train_test_split(housing_combined, SalePrice, test_size=0.2, random_state=0)

# %%
def get_error(X_train, y_train, X_test, y_test, model, show = True):
    model.fit(X_train, y_train)
    train_error = 1 - model.score(X_train, y_train)
    test_error  = 1 - model.score(X_test, y_test)
    if show:
        print("The training error is: %.5f" %train_error)
        print("The test     error is: %.5f" %test_error)
    return [train_error, test_error]

# %%
from sklearn import tree

tree_model = tree.DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
get_error(X_train,y_train,X_test,y_test,tree_model)
# Out:
# The training error is: 0.00000
# The test     error is: 0.20155
# [0.0, 0.20155038759689925]

# %%
grid_para_tree = [
    {'max_depth': range(1, 31)}
]

tree_model.set_params(random_state=0)
grid_search_tree = ms.GridSearchCV(tree_model, grid_para_tree, scoring='accuracy', cv=5, n_jobs=-1, return_train_score=True)

grid_search_tree.fit(X_train, y_train)
# Out:
# C:\Users\immed\Programming\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid=[{'max_depth': range(1, 31)}], return_train_score=True,
#              scoring='accuracy')

# %%
test_error_range  = [1 - x for x in grid_search_tree.cv_results_['mean_test_score']]
train_error_range = [1 - x for x in grid_search_tree.cv_results_['mean_train_score']]

# %%
plt.plot(range(1,31), test_error_range,
        c='blue', label='test error')
plt.plot(range(1,31), train_error_range,
        c='red', label='train error')
plt.xlabel('Max_depth')
plt.ylabel('Error rate')
plt.legend()
plt.show()

# %%
depth  = range(1, 30)
tree_train = []
tree_test = []
for i in depth:
    tree_model.set_params(max_depth = i)
    error = get_error(X_train, y_train, X_test, y_test, tree_model, show=False)
    tree_train.append(error[0])
    tree_test.append(error[1])


plt.plot(depth, tree_train, c = 'blue', label='training error')
plt.plot(depth, tree_test, c = 'red', label='test error')
plt.legend(loc=7)
plt.xlabel('depth')
# Out:
# Text(0.5, 0, 'depth')

# %%
grid_search_tree.best_estimator_
grid_search_tree.best_score_ 
grid_search_tree.best_params_
# Out:
# {'max_depth': 25}

# %%
grid_para_tree = {'criterion': ['gini', 'entropy'], 'max_depth': range(1, 31)}
grid_search_tree = ms.GridSearchCV(tree_model, grid_para_tree, cv=5, scoring='accuracy').fit(X_train, y_train)
print('The best score is %.4f' %grid_search_tree.best_score_)
print('The training error is %.4f' %(1 - grid_search_tree.best_estimator_.score(X_train, y_train)))
print('The testing error is %.4f' %(1 - grid_search_tree.best_estimator_.score(X_test, y_test)))
# Out:
# C:\Users\immed\Programming\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# The best score is 0.7873
# The training error is 0.0000
# The testing error is 0.1880

# %%
print('Best parameters: '+ str(grid_search_tree.best_params_))
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': 11}

# %%
tree_final = grid_search_tree.best_estimator_
feature_importance = pd.Series(tree_final.feature_importances_, index= X_train.columns).sort_values(ascending=False)
feature_importance
# Out:
# MasVnrArea       0.891748
# OpenPorchSF      0.007687
# WoodDeckSF       0.006805
# GarageArea       0.006798
# Neighborhood     0.005694
#                    ...
# Utilities        0.000000
# 3SsnPorch        0.000000
# Alley            0.000000
# Street           0.000000
# SaleCondition    0.000000
# Length: 79, dtype: float64

# %%
plt.figure(figsize=(12, 8))
feature_importance.plot(kind='barh')
plt.title(f'Features Ordered by Importance in RandomForestRegressor Model')
plt.xlabel('Importance')
plt.ylabel('Feature Name')
plt.gca().invert_yaxis()

# %%
from sklearn import ensemble 
randomForest = ensemble.RandomForestClassifier()
randomForest.set_params(random_state=0)

randomForest.fit(X_train, y_train) 

print("The training error is: %.5f" % (1 - randomForest.score(X_train, y_train))) 
print("The test     error is: %.5f" % (1 - randomForest.score(X_test, y_test)))
# Out:
# The training error is: 0.00000
# The test     error is: 0.36240

# %%
randomForest.fit(X_train2, y_train2) 

print("The training error is: %.5f" % (1 - randomForest.score(X_train2, y_train2))) 
print("The test     error is: %.5f" % (1 - randomForest.score(X_test2, y_test2)))
# Out:
# The training error is: 0.00000
# The test     error is: 0.39147

# %%
randomForest.fit(X_train3, y_train3) 

print("The training error is: %.5f" % (1 - randomForest.score(X_train3, y_train3))) 
print("The test     error is: %.5f" % (1 - randomForest.score(X_test3, y_test3)))
# Out:
# The training error is: 0.00000
# The test     error is: 0.37597

# %%
grid_para_forest = {
    'criterion': ['gini', 'entropy'],
    'max_depth': range(1, 31),
    'n_estimators': range(10, 110, 10)
}

# %%
grid_search_forest = ms.GridSearchCV(randomForest, grid_para_forest, scoring='accuracy', cv=5, n_jobs=-1)
# %time grid_search_forest.fit(X_train, y_train)
# Out:
# C:\Users\immed\Programming\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CPU times: total: 4.88 s
# Wall time: 14min 22s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 31),
#                          'n_estimators': range(10, 110, 10)},
#              scoring='accuracy')

# %%
grid_search_forest = ms.GridSearchCV(randomForest, grid_para_forest, scoring='accuracy', cv=5, n_jobs=-1)
# %time grid_search_forest.fit(X_train2, y_train2)
# Out:
# C:\Users\immed\Programming\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CPU times: total: 6.02 s
# Wall time: 6min 59s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 31),
#                          'n_estimators': range(10, 110, 10)},
#              scoring='accuracy')

# %%
grid_search_forest = ms.GridSearchCV(randomForest, grid_para_forest, scoring='accuracy', cv=5, n_jobs=-1)
# %time grid_search_forest.fit(X_train3, y_train3)
# Out:
# C:\Users\immed\Programming\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CPU times: total: 7.02 s
# Wall time: 11min 12s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 31),
#                          'n_estimators': range(10, 110, 10)},
#              scoring='accuracy')

# %%
grid_search_forest.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 17, 'n_estimators': 50}

# %%
grid_search_forest.best_score_
# Out:
# 0.6395331343002891

# %%
print("The training error is: %.5f" % (1 - grid_search_forest.best_estimator_.score(X_train, y_train)))
print("The test     error is: %.5f" % (1 - grid_search_forest.best_estimator_.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 print("The training error is: %.5f" % (1 - grid_search_forest.best_estimator_.score(X_train, y_train)))
#       2 print("The test     error is: %.5f" % (1 - grid_search_forest.best_estimator_.score(X_test, y_test)))
#
# File ~\Programming\Anaconda\Lib\site-packages\sklearn\base.py:668, in ClassifierMixin.score(self, X, y, sample_weight)
#     643 """
#     644 Return the mean accuracy on the given test data and labels.
#     645
#    (...)
#     664     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     665 """
#     666 from .metrics import accuracy_score
# --> 668 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\Programming\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:820, in ForestClassifier.predict(self, X)
#     799 def predict(self, X):
#     800     """
#     801     Predict class for X.
#     802
#    (...)
#     818         The predicted classes.
#     819     """
# --> 820     proba = self.predict_proba(X)
#     822     if self.n_outputs_ == 1:
#     823         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\Programming\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:862, in ForestClassifier.predict_proba(self, X)
#     860 check_is_fitted(self)
#     861 # Check data
# --> 862 X = self._validate_X_predict(X)
#     864 # Assign chunk of trees to jobs
#     865 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\Programming\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py:602, in BaseForest._validate_X_predict(self, X)
#     599 """
#     600 Validate X whenever one tries to predict, apply, predict_proba."""
#     601 check_is_fitted(self)
# --> 602 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     604     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\Programming\Anaconda\Lib\site-packages\sklearn\base.py:548, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     483 def _validate_data(
#     484     self,
#     485     X="no_validation",
#    (...)
#     489     **check_params,
#     490 ):
#     491     """Validate input data and set or check the `n_features_in_` attribute.
#     492
#     493     Parameters
#    (...)
#     546         validated.
#     547     """
# --> 548     self._check_feature_names(X, reset=reset)
#     550     if y is None and self._get_tags()["requires_y"]:
#     551         raise ValueError(
#     552             f"This {self.__class__.__name__} estimator "
#     553             "requires y to be passed, but the target y is None."
#     554         )
#
# File ~\Programming\Anaconda\Lib\site-packages\sklearn\base.py:481, in BaseEstimator._check_feature_names(self, X, reset)
#     476 if not missing_names and not unexpected_names:
#     477     message += (
#     478         "Feature names must be in the same order as they were in fit.\n"
#     479     )
# --> 481 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - Alley
# - BldgType
# - BsmtCond
# - BsmtExposure
# - BsmtFinType1
# - ...

# %%
best_estimator = grid_search_forest.best_estimator_
feature_importance = pd.Series(best_estimator.feature_importances_, index= X_train.columns).sort_values(ascending=False)
feature_importance[:5]
# Out:
# MasVnrArea     0.354389
# 1stFlrSF       0.058121
# GarageArea     0.055442
# TotalBsmtSF    0.054980
# LotArea        0.053582
# dtype: float64

# %%
best_estimator = grid_search_forest.best_estimator_
feature_importance = pd.Series(best_estimator.feature_importances_, index= X_train2.columns).sort_values(ascending=False)
feature_importance[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 best_estimator = grid_search_forest.best_estimator_
# ----> 2 feature_importance = pd.Series(best_estimator.feature_importances_, index= X_train2.columns).sort_values(ascending=False)
#       3 feature_importance[:5]
#
# File ~\Programming\Anaconda\Lib\site-packages\pandas\core\series.py:503, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     501     index = default_index(len(data))
#     502 elif is_list_like(data):
# --> 503     com.require_length_match(data, index)
#     505 # create/copy the manager
#     506 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~\Programming\Anaconda\Lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (79) does not match length of index (54)

# %%
best_estimator = grid_search_forest.best_estimator_
feature_importance = pd.Series(best_estimator.feature_importances_, index= X_train3.columns).sort_values(ascending=False)
feature_importance[:5]
# Out:
# MasVnrArea     0.240022
# MasVnrType     0.167110
# GarageArea     0.030740
# TotalBsmtSF    0.028649
# 1stFlrSF       0.027700
# dtype: float64

# %%
plt.figure(figsize=(12, 8))
feature_importance.plot(kind='barh')
plt.title(f'Features Ordered by Importance in RandomForestRegressor Model')
plt.xlabel('Importance')
plt.ylabel('Feature Name')
plt.gca().invert_yaxis()
