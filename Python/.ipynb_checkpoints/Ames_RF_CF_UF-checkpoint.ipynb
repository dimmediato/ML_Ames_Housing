# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.model_selection as ms
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn import ensemble
from sklearn.preprocessing import LabelEncoder
pd.set_option('display.max_columns', 500)
label_encoder = LabelEncoder()

housing_numeric = pd.read_pickle("housing_numeric.pkl")
housing_factor = pd.read_pickle("housing_factor.pkl")
housing_factor = housing_factor.apply(label_encoder.fit_transform)
housing_combined = pd.concat([housing_numeric, housing_factor], axis=1)
housing_combined = housing_combined.apply(label_encoder.fit_transform)
housing_combined  = housing_combined.drop(['PID', 'SalePrice'], axis=1)
housing_combined
# Out:
#      GrLivArea  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 1           70           45      459           0         120           0
# 2          197           18      134         108         367         133
# 3          160           36      237           0         514           0
# 4          188           57      511           0           0           0
# 5          704           47      563           0         437           0
# ..         ...          ...      ...         ...         ...         ...
# 759        132           45      663           0           0           0
# 760        756           45     1463           0           0           0
# 761        928           59      250           0         156           0
# 762        826           45      655         103         596           0
# 763        868           57      809          88         231           0
#
#      BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  \
# 1          519          251       189         0             0             2
# 2           64          404       362         0             0             2
# 3           61          234       319         0             0             0
# 4          336           26        87        24             0             0
# 5          119          211       152       340             0             2
# ..         ...          ...       ...       ...           ...           ...
# 759        760          322       273         0             0             0
# 760          0            0       886         0             0             0
# 761        592          364       319       435             0             0
# 762        101          351       304       341             0             2
# 763        329          184       378       335             0             0
#
#      BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 1               0         1         0             2             1
# 2               0         2         0             2             1
# 3               0         1         0             2             1
# 4               0         1         0             2             1
# 5               0         2         1             3             1
# ..            ...       ...       ...           ...           ...
# 759             0         1         0             2             1
# 760             0         2         0             4             1
# 761             0         2         0             4             2
# 762             0         2         1             3             1
# 763             0         2         1             3             1
#
#      TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  WoodDeckSF  \
# 1               2           1           3         145           0
# 2               3           0           1          48           0
# 3               3           0           1          21         109
# 4               4           0           1          57           0
# 5               4           0           3         261           0
# ..            ...         ...         ...         ...         ...
# 759             2           1           1          10           0
# 760             6           1           3         188           0
# 761             6           0           4         506           0
# 762             5           1           3         223         147
# 763             6           1           3         208         136
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 1              0              0          0           51         0        0
# 2             93              0          0            0         0        0
# 3              0             16          1            0         0        0
# 4              0             93          0           16         0        0
# 5             35              0          0            0         0        0
# ..           ...            ...        ...          ...       ...      ...
# 759           86              0          0            1         0        0
# 760            0              0          0            0         0        0
# 761            0              0          0            0         0        0
# 762           84              0          0            0         0        0
# 763           69              0          0            0         0        0
#
#      YrSold  GarageYrBlt  MoSold  YearBuilt  YearRemodAdd  MSSubClass  \
# 1         4           29       2         44             0           6
# 2         3           74       1         87            34           0
# 3         1           20      10         36            57           6
# 4         3           30       4         11            53          11
# 5         3           91      10        104            51          10
# ..      ...          ...     ...        ...           ...         ...
# 759       3            7       4         22             0           6
# 760       3           44       5         58             5           5
# 761       1           38       7         52             0          15
# 762       1           90       6        103            50          10
# 763       0           83       8         96            44          10
#
#      MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 1           5       1      1         3            3          0          0
# 2           5       1      1         3            3          0          4
# 3           1       1      1         3            3          0          4
# 4           5       1      1         3            3          0          0
# 5           5       1      1         3            3          0          4
# ..        ...     ...    ...       ...          ...        ...        ...
# 759         5       1      1         3            3          0          4
# 760         5       1      1         0            3          0          1
# 761         4       1      1         3            1          0          4
# 762         5       1      1         3            3          0          4
# 763         5       1      1         0            3          0          4
#
#      LandSlope  Neighborhood  Condition1  Condition2  BldgType  HouseStyle  \
# 1            0            21           2           2         0           2
# 2            0             7           2           2         4           2
# 3            0            11           2           2         0           2
# 4            0            20           2           2         0           5
# 5            0            17           2           2         0           5
# ..         ...           ...         ...         ...       ...         ...
# 759          0             3           2           2         0           1
# 760          0             7           2           2         0           2
# 761          0             6           2           2         2           5
# 762          0             5           2           2         0           5
# 763          0            23           2           2         0           5
#
#      OverallQual  OverallCond  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 1              6            5          1         0           13           14
# 2              5            4          1         0            6            6
# 3              5            8          3         0            8            8
# 4              4            7          1         0            8            8
# 5              8            5          1         0           12           13
# ..           ...          ...        ...       ...          ...          ...
# 759            6            5          1         0           13           14
# 760            3            4          3         0            3           14
# 761            5            5          1         0            8            8
# 762            7            4          1         0           12           13
# 763            8            4          1         0           12           13
#
#      MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  BsmtCond  \
# 1             2          3          4           1         5         5
# 2             1          2          4           1         2         5
# 3             2          2          4           0         5         5
# 4             2          2          2           0         1         5
# 5             2          2          4           2         2         5
# ..          ...        ...        ...         ...       ...       ...
# 759           2          3          4           0         5         5
# 760           2          3          4           3         3         3
# 761           2          3          4           1         5         5
# 762           1          2          4           2         2         5
# 763           1          2          4           2         2         5
#
#      BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  HeatingQC  CentralAir  \
# 1               3             5             6        1          4           1
# 2               2             2             0        1          4           1
# 3               3             0             6        1          0           1
# 4               3             6             6        1          2           1
# 5               3             2             6        1          0           1
# ..            ...           ...           ...      ...        ...         ...
# 759             3             6             6        3          1           0
# 760             4             4             4        1          0           1
# 761             3             1             6        1          4           0
# 762             3             2             6        1          0           1
# 763             3             2             6        1          0           1
#
#      Electrical  KitchenQual  Functional  FireplaceQu  GarageType  \
# 1             3            4           6            2           5
# 2             3            2           6            3           1
# 3             3            2           6            3           5
# 4             3            4           6            3           5
# 5             3            2           6            3           1
# ..          ...          ...         ...          ...         ...
# 759           1            1           6            2           5
# 760           0            4           3            2           1
# 761           0            4           6            3           0
# 762           3            2           6            5           1
# 763           3            2           6            5           1
#
#      GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# 1               3           5           5           1       3      4
# 2               0           5           5           1       3      4
# 3               3           5           4           0       3      4
# 4               3           5           5           0       3      4
# 5               0           5           5           1       3      4
# ..            ...         ...         ...         ...     ...    ...
# 759             3           1           4           1       3      4
# 760             3           5           5           1       3      4
# 761             3           5           5           1       3      4
# 762             0           5           5           1       3      4
# 763             2           5           5           1       3      4
#
#      MiscFeature  SaleType  SaleCondition
# 1              1         9              4
# 2              1         9              4
# 3              1         9              4
# 4              1         9              4
# 5              1         9              4
# ..           ...       ...            ...
# 759            1         9              4
# 760            1         9              4
# 761            1         9              4
# 762            1         9              4
# 763            1         9              4
#
# [2580 rows x 79 columns]

# %%
SalePrice = housing_numeric['SalePrice']

randomForest = ensemble.RandomForestRegressor(random_state=42) #random state is not necessary
grid_para_forest = [{
    'n_estimators': [50, 60, 70], 
    'max_depth': [9, 10, 11], 
    'max_features': [1,2], 
    'min_samples_leaf': [1,2], 
    'min_samples_split': [2,3,4]}]
grid_search_forest = GridSearchCV(randomForest, grid_para_forest, scoring = 'r2', cv= 5, n_jobs = -1) #accuracy is default scoring method
# %time grid_search_forest.fit(housing_combined, SalePrice)
# Out:
# CPU times: total: 1.05 s
# Wall time: 7.83 s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid=[{'max_depth': [9, 10, 11], 'max_features': [1, 2],
#                           'min_samples_leaf': [1, 2],
#                           'min_samples_split': [2, 3, 4],
#                           'n_estimators': [50, 60, 70]}],
#              scoring='r2')

# %%
grid_search_forest.best_score_
# Out:
# 0.8504800016529017

# %%
print(grid_search_forest.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=11, max_features=2, min_samples_split=3,
#                       n_estimators=50, random_state=42)

# %%
best_estimator = grid_search_forest.best_estimator_
feature_importance = pd.Series(best_estimator.feature_importances_, index= housing_combined.columns).sort_values(ascending=False).head(28)
feature_importance
# Out:
# GrLivArea       0.084778
# TotalBsmtSF     0.051372
# GarageCars      0.048719
# OverallQual     0.047731
# BsmtFinSF1      0.043468
# ExterQual       0.036927
# GarageArea      0.036610
# BsmtQual        0.035892
# YearBuilt       0.035417
# GarageYrBlt     0.031717
# 1stFlrSF        0.029819
# FullBath        0.028677
# Fireplaces      0.025559
# YearRemodAdd    0.025273
# Foundation      0.024018
# KitchenQual     0.023010
# LotFrontage     0.022890
# LotArea         0.022617
# OpenPorchSF     0.019411
# GarageType      0.018259
# WoodDeckSF      0.017937
# MasVnrArea      0.016162
# 2ndFlrSF        0.015744
# Neighborhood    0.014852
# TotRmsAbvGrd    0.014439
# FireplaceQu     0.011965
# BedroomAbvGr    0.011612
# BsmtExposure    0.011130
# dtype: float64

# %%
plt.figure(figsize=(12, 8))
feature_importance.plot(kind='barh')
plt.title(f'Features Ordered by Importance in RandomForestRegressor Model, Unrefined')
plt.xlabel('Importance')
plt.ylabel('Feature Name')
plt.gca().invert_yaxis()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(housing_combined, SalePrice, test_size=0.2, random_state=42)

# %%
def get_error(X_train, y_train, X_test, y_test, model, show = True):
    model.fit(X_train, y_train)
    train_error = 1 - model.score(X_train, y_train)
    test_error  = 1 - model.score(X_test, y_test)
    if show:
        print("The training error is: %.5f" %train_error)
        print("The test error is: %.5f" %test_error)
    return [train_error, test_error]

# %%
tree_model = tree.DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
get_error(X_train,y_train,X_test,y_test,tree_model)
# Out:
# The training error is: 0.00048
# The test error is: 0.98837
# [0.0004844961240310086, 0.9883720930232558]

# %%
grid_para_tree = [
    { 
    'max_depth': [9, 10, 11], 
    'max_features': [1,2], 
    'min_samples_leaf': [1,2], 
    'min_samples_split': [2,3,4]}
]

tree_model.set_params(random_state=0)
grid_search_tree = ms.GridSearchCV(tree_model, grid_para_tree, scoring='accuracy', cv=5, n_jobs=-1, return_train_score=True)

grid_search_tree.fit(X_train, y_train)
# Out:
# C:\Users\immed\Programming\Anaconda\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid=[{'max_depth': [9, 10, 11], 'max_features': [1, 2],
#                           'min_samples_leaf': [1, 2],
#                           'min_samples_split': [2, 3, 4]}],
#              return_train_score=True, scoring='accuracy')

# %%
depth  = range(1, 11)
tree_train = []
tree_test = []
for i in depth:
    tree_model.set_params(max_depth = i)
    error = get_error(X_train, y_train, X_test, y_test, tree_model, show=False)
    tree_train.append(error[0])
    tree_test.append(error[1])


plt.plot(depth, tree_train, c = 'red', label='Training Error')
plt.plot(depth, tree_test, c = 'blue', label='Test Error')
plt.xlabel('Depth')
plt.ylabel('Error Rate')
plt.legend(loc=7)
