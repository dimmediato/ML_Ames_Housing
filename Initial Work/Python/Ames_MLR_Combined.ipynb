# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
housing = pd.read_csv("~/Documents/NYCDSA/Third Project/ML_Ames_Housing/data/Ames_Housing_Price_Data.csv", index_col=0)
housing.head() #OPEN DATA FRAME
pd.set_option('display.max_columns', 500)
housing.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 1  909176150        856     126000          30       RL          NaN     7890
# 2  905476230       1049     139500         120       RL         42.0     4235
# 3  911128020       1001     124900          30  C (all)         60.0     6060
# 4  535377150       1039     114000          70       RL         80.0     8146
# 5  534177230       1665     227000          60       RL         70.0     8400
#
#   Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 1   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 2   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 3   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 4   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 5   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 1        SWISU       Norm       Norm     1Fam     1Story            6
# 2      Edwards       Norm       Norm   TwnhsE     1Story            5
# 3       IDOTRR       Norm       Norm     1Fam     1Story            5
# 4      OldTown       Norm       Norm     1Fam     2Story            4
# 5       NWAmes       Norm       Norm     1Fam     2Story            8
#
#    OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 1            6       1939          1950     Gable  CompShg     Wd Sdng
# 2            5       1984          1984     Gable  CompShg     HdBoard
# 3            9       1930          2007       Hip  CompShg     MetalSd
# 4            8       1900          2003     Gable  CompShg     MetalSd
# 5            6       2001          2001     Gable  CompShg     VinylSd
#
#   Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# 1     Wd Sdng        NaN         0.0        TA        TA     CBlock       TA
# 2     HdBoard    BrkFace       149.0        Gd        TA     CBlock       Gd
# 3     MetalSd        NaN         0.0        Gd        TA     BrkTil       TA
# 4     MetalSd        NaN         0.0        Gd        Gd     BrkTil       Fa
# 5     VinylSd        NaN         0.0        Gd        TA      PConc       Gd
#
#   BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1       TA           No          Rec       238.0          Unf         0.0
# 2       TA           Mn          GLQ       552.0          ALQ       393.0
# 3       TA           No          ALQ       737.0          Unf         0.0
# 4       TA           No          Unf         0.0          Unf         0.0
# 5       TA           No          GLQ       643.0          Unf         0.0
#
#    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  \
# 1      618.0        856.0    GasA        TA          Y      SBrkr       856
# 2      104.0       1049.0    GasA        TA          Y      SBrkr      1049
# 3      100.0        837.0    GasA        Ex          Y      SBrkr      1001
# 4      405.0        405.0    GasA        Gd          Y      SBrkr       717
# 5      167.0        810.0    GasA        Ex          Y      SBrkr       810
#
#    2ndFlrSF  LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 1         0             0           1.0           0.0         1         0
# 2         0             0           1.0           0.0         2         0
# 3         0             0           0.0           0.0         1         0
# 4       322             0           0.0           0.0         1         0
# 5       855             0           1.0           0.0         2         1
#
#    BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 1             2             1          TA             4        Typ
# 2             2             1          Gd             5        Typ
# 3             2             1          Gd             5        Typ
# 4             2             1          TA             6        Typ
# 5             3             1          Gd             6        Typ
#
#    Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  \
# 1           1          Gd     Detchd       1939.0          Unf         2.0
# 2           0         NaN     Attchd       1984.0          Fin         1.0
# 3           0         NaN     Detchd       1930.0          Unf         1.0
# 4           0         NaN     Detchd       1940.0          Unf         1.0
# 5           0         NaN     Attchd       2001.0          Fin         2.0
#
#    GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 1       399.0         TA         TA          Y           0            0
# 2       266.0         TA         TA          Y           0          105
# 3       216.0         TA         Po          N         154            0
# 4       281.0         TA         TA          N           0            0
# 5       528.0         TA         TA          Y           0           45
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 1              0          0          166         0    NaN   NaN         NaN
# 2              0          0            0         0    NaN   NaN         NaN
# 3             42         86            0         0    NaN   NaN         NaN
# 4            168          0          111         0    NaN   NaN         NaN
# 5              0          0            0         0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition
# 1        0       3    2010      WD         Normal
# 2        0       2    2009      WD         Normal
# 3        0      11    2007      WD         Normal
# 4        0       5    2009      WD         Normal
# 5        0      11    2009      WD         Normal

# %%
housing.shape
# Out:
# (2580, 81)

# %%
# Select numerical columns without missing values
numerical_data = housing.select_dtypes(include=[np.number]).dropna(axis=1)

# %%
numerical_data
# Out:
#            PID  GrLivArea  SalePrice  MSSubClass  LotArea  OverallQual  \
# 1    909176150        856     126000          30     7890            6
# 2    905476230       1049     139500         120     4235            5
# 3    911128020       1001     124900          30     6060            5
# 4    535377150       1039     114000          70     8146            4
# 5    534177230       1665     227000          60     8400            8
# ..         ...        ...        ...         ...      ...          ...
# 759  903205040        952     121000          30     8854            6
# 760  905402060       1733     139600          20    13680            3
# 761  909275030       2002     145000          90     6270            5
# 762  907192040       1842     217500          60     8826            7
# 763  906223180       1911     215000          60     9554            8
#
#      OverallCond  YearBuilt  YearRemodAdd  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1              6       1939          1950       856         0             0
# 2              5       1984          1984      1049         0             0
# 3              9       1930          2007      1001         0             0
# 4              8       1900          2003       717       322             0
# 5              6       2001          2001       810       855             0
# ..           ...        ...           ...       ...       ...           ...
# 759            6       1916          1950       952         0             0
# 760            5       1955          1955      1733         0             0
# 761            6       1949          1950      1001      1001             0
# 762            5       2000          2000       985       857             0
# 763            5       1993          1994      1065       846             0
#
#      FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 1           1         0             2             1             4           1
# 2           2         0             2             1             5           0
# 3           1         0             2             1             5           0
# 4           1         0             2             1             6           0
# 5           2         1             3             1             6           0
# ..        ...       ...           ...           ...           ...         ...
# 759         1         0             2             1             4           1
# 760         2         0             4             1             8           1
# 761         2         0             4             2             8           0
# 762         2         1             3             1             7           1
# 763         2         1             3             1             8           1
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 1             0            0              0          0          166         0
# 2             0          105              0          0            0         0
# 3           154            0             42         86            0         0
# 4             0            0            168          0          111         0
# 5             0           45              0          0            0         0
# ..          ...          ...            ...        ...          ...       ...
# 759           0           98              0          0           40         0
# 760           0            0              0          0            0         0
# 761           0            0              0          0            0         0
# 762         193           96              0          0            0         0
# 763         182           81              0          0            0         0
#
#      MiscVal  MoSold  YrSold
# 1          0       3    2010
# 2          0       2    2009
# 3          0      11    2007
# 4          0       5    2009
# 5          0      11    2009
# ..       ...     ...     ...
# 759        0       5    2009
# 760        0       6    2009
# 761        0       8    2007
# 762        0       7    2007
# 763        0       9    2006
#
# [2580 rows x 27 columns]

# %%
# Calculate the matrix rank
rank = np.linalg.matrix_rank(numerical_data.values)

# %%
rank
# Out:
# 26

# %%
def find_redundant_features(data):
    """
    Identifies and returns redundant features in a dataset based on matrix rank.
    A feature is considered redundant if removing it does not decrease the rank of the dataset,
    indicating that it can be expressed as a linear combination of other features.
    Parameters:
        data (DataFrame): The numerical dataset to analyze.
    Returns:
        list: A list of redundant feature names.
    """
    # Calculate the matrix rank of the original dataset
    original_rank = np.linalg.matrix_rank(data)
    redundant_features = []
    for column in data.columns:
        # Create a new dataset without this column
        temp_data = data.drop(column, axis=1)
        # Calculate the rank of the new dataset
        temp_rank = np.linalg.matrix_rank(temp_data)
        # If the rank does not decrease, the removed column is redundant
        if temp_rank == original_rank:
            redundant_features.append(column)
    return redundant_features

# %%
redundant_features = find_redundant_features(numerical_data)
print("Redundant features:", redundant_features)
# Out:
# Redundant features: ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF']

# %%
#Create seperate numeric-set
housing_numeric = housing[['GrLivArea','SalePrice','LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                         '2ndFlrSF','LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
                           'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',  'GarageCars',
                           'GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch',
                           '3SsnPorch','ScreenPorch','PoolArea','MiscVal', "YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd']].copy()
#housing_numeric['PID'] = housing_numeric['PID'].astype('str')
#housing_numeric['YrSold'] = pd.to_datetime(housing_numeric['YrSold']).dt.strftime('%Y')
#housing_numeric['GarageYrBlt'] = pd.to_datetime(housing_numeric['GarageYrBlt']).dt.strftime('%Y')
#housing_numeric['YearBuilt'] = pd.to_datetime(housing_numeric['YearBuilt']).dt.strftime('%Y')
#housing_numeric['YearRemodAdd'] = pd.to_datetime(housing_numeric['YearRemodAdd']).dt.strftime('%Y')
#housing_numeric['MoSold'] = pd.to_datetime(housing_numeric['MoSold'],format='%m').dt.strftime('%m')
#housing_numeric['GarageYrBlt'] = housing_numeric['GarageYrBlt'].fillna('1970') #903426160 and 910201180 do have a garage built, but an NA for all others, filled with mode
housing_numeric.fillna(housing_numeric.mean(), inplace=True)
years = housing_numeric[["YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd']].copy()
housing_numeric.to_pickle('housing_numeric.pkl')
housing_numeric
# Out:
#      GrLivArea  SalePrice  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  \
# 1          856     126000    68.516053     7890         0.0       238.0
# 2         1049     139500    42.000000     4235       149.0       552.0
# 3         1001     124900    60.000000     6060         0.0       737.0
# 4         1039     114000    80.000000     8146         0.0         0.0
# 5         1665     227000    70.000000     8400         0.0       643.0
# ..         ...        ...          ...      ...         ...         ...
# 759        952     121000    68.516053     8854         0.0         0.0
# 760       1733     139600    68.516053    13680         0.0         0.0
# 761       2002     145000    82.000000     6270         0.0       284.0
# 762       1842     217500    68.516053     8826       144.0       841.0
# 763       1911     215000    80.000000     9554       125.0       380.0
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1           0.0      618.0        856.0       856         0             0
# 2         393.0      104.0       1049.0      1049         0             0
# 3           0.0      100.0        837.0      1001         0             0
# 4           0.0      405.0        405.0       717       322             0
# 5           0.0      167.0        810.0       810       855             0
# ..          ...        ...          ...       ...       ...           ...
# 759         0.0      952.0        952.0       952         0             0
# 760         0.0        0.0          0.0      1733         0             0
# 761         0.0      717.0       1001.0      1001      1001             0
# 762         0.0      144.0        985.0       985       857             0
# 763         0.0      397.0        777.0      1065       846             0
#
#      BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 1             1.0           0.0         1         0             2
# 2             1.0           0.0         2         0             2
# 3             0.0           0.0         1         0             2
# 4             0.0           0.0         1         0             2
# 5             1.0           0.0         2         1             3
# ..            ...           ...       ...       ...           ...
# 759           0.0           0.0         1         0             2
# 760           0.0           0.0         2         0             4
# 761           0.0           0.0         2         0             4
# 762           1.0           0.0         2         1             3
# 763           0.0           0.0         2         1             3
#
#      KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  \
# 1               1             4           1         2.0       399.0
# 2               1             5           0         1.0       266.0
# 3               1             5           0         1.0       216.0
# 4               1             6           0         1.0       281.0
# 5               1             6           0         2.0       528.0
# ..            ...           ...         ...         ...         ...
# 759             1             4           1         1.0       192.0
# 760             1             8           1         2.0       452.0
# 761             2             8           0         3.0       871.0
# 762             1             7           1         2.0       486.0
# 763             1             8           1         2.0       471.0
#
#      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 1             0            0              0          0          166         0
# 2             0          105              0          0            0         0
# 3           154            0             42         86            0         0
# 4             0            0            168          0          111         0
# 5             0           45              0          0            0         0
# ..          ...          ...            ...        ...          ...       ...
# 759           0           98              0          0           40         0
# 760           0            0              0          0            0         0
# 761           0            0              0          0            0         0
# 762         193           96              0          0            0         0
# 763         182           81              0          0            0         0
#
#      MiscVal  YrSold  GarageYrBlt  MoSold  YearBuilt  YearRemodAdd
# 1          0    2010       1939.0       3       1939          1950
# 2          0    2009       1984.0       2       1984          1984
# 3          0    2007       1930.0      11       1930          2007
# 4          0    2009       1940.0       5       1900          2003
# 5          0    2009       2001.0      11       2001          2001
# ..       ...     ...          ...     ...        ...           ...
# 759        0    2009       1916.0       5       1916          1950
# 760        0    2009       1955.0       6       1955          1955
# 761        0    2007       1949.0       8       1949          1950
# 762        0    2007       2000.0       7       2000          2000
# 763        0    2006       1993.0       9       1993          1994
#
# [2580 rows x 34 columns]

# %%
# Calculate the matrix rank
rank2 = np.linalg.matrix_rank(housing_numeric.values)

# %%
rank2
# Out:
# 32

# %%
def find_redundant_features(data):
    """
    Identifies and returns redundant features in a dataset based on matrix rank.
    A feature is considered redundant if removing it does not decrease the rank of the dataset,
    indicating that it can be expressed as a linear combination of other features.
    Parameters:
        data (DataFrame): The numerical dataset to analyze.
    Returns:
        list: A list of redundant feature names.
    """
    # Calculate the matrix rank of the original dataset
    original_rank = np.linalg.matrix_rank(data)
    redundant_features = []
    for column in data.columns:
        # Create a new dataset without this column
        temp_data = data.drop(column, axis=1)
        # Calculate the rank of the new dataset
        temp_rank = np.linalg.matrix_rank(temp_data)
        # If the rank does not decrease, the removed column is redundant
        if temp_rank == original_rank:
            redundant_features.append(column)
    return redundant_features

# %%
redundant_features2 = find_redundant_features(housing_numeric)
print("Redundant features:", redundant_features2)
# Out:
# Redundant features: ['GrLivArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF']

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
# Load the data
Ames = pd.read_csv('~/Documents/NYCDSA/Third Project/ML_Ames_Housing/data/Ames_Housing_Price_Data.csv')
features = ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF']
X = Ames[features]
y = Ames['SalePrice']

# %%
X
# Out:
#       GrLivArea  1stFlrSF  2ndFlrSF  LowQualFinSF
# 0           856       856         0             0
# 1          1049      1049         0             0
# 2          1001      1001         0             0
# 3          1039       717       322             0
# 4          1665       810       855             0
# ...         ...       ...       ...           ...
# 2575        952       952         0             0
# 2576       1733      1733         0             0
# 2577       2002      1001      1001             0
# 2578       1842       985       857             0
# 2579       1911      1065       846             0
#
# [2580 rows x 4 columns]

# %%
# Initialize a K-Fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=1)
# Collect coefficients and CV scores
coefficients = []
cv_scores = []

# %%
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    # Initialize and fit the linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    coefficients.append(model.coef_)
    # Calculate R^2 score using the model's score method
    score = model.score(X_test, y_test)
    # print(score)
    cv_scores.append(score)

# %%
# Plotting the coefficients
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot(np.array(coefficients), labels=features)
plt.title('Box Plot of Coefficients Across Folds (MLR)')
plt.xlabel('Features')
plt.ylabel('Coefficient Value')
plt.grid(True)

# %%
# Plotting the CV scores
plt.subplot(1, 2, 2)
plt.plot(range(1, 6), cv_scores, marker='o', linestyle='-')  # Adjusted x-axis to start from 1
plt.title('Cross-Validation R² Scores (MLR)')
plt.xlabel('Fold')
plt.xticks(range(1, 6))  # Set x-ticks to match fold numbers
plt.ylabel('R² Score')
plt.ylim(min(cv_scores) - 0.05, max(cv_scores) + 0.05)  # Dynamically adjust y-axis limits
plt.grid(True)
# Annotate mean R² score
mean_r2 = np.mean(cv_scores)
plt.annotate(f'Mean CV R²: {mean_r2:.3f}', xy=(1.25, 0.65), color='red', fontsize=14),
plt.tight_layout()
plt.show()

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
# Load the data
Ames = pd.read_csv('~/Documents/NYCDSA/Third Project/ML_Ames_Housing/data/Ames_Housing_Price_Data.csv')
features = ['GrLivArea', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF']
X = Ames[features]
y = Ames['SalePrice']

# %%
# Initialize a K-Fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=1)
# Prepare to collect results
results = {}
for alpha in [1, 2]:  # Loop through both alpha values
    coefficients = []
    cv_scores = []
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        # Scale features
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        # Initialize and fit the Lasso regression model
        lasso_model = Lasso(alpha=alpha, max_iter=20000)
        lasso_model.fit(X_train_scaled, y_train)
        coefficients.append(lasso_model.coef_)
        # Calculate R^2 score using the model's score method
        score = lasso_model.score(X_test_scaled, y_test)
        cv_scores.append(score)
    results[alpha] = (coefficients, cv_scores)

# %%
# Plotting the results
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
alphas = [1, 2]
for i, alpha in enumerate(alphas):
    coefficients, cv_scores = results[alpha]
    # Plotting the coefficients
    axes[i, 0].boxplot(np.array(coefficients), labels=features)
    axes[i, 0].set_title(f'Box Plot of Coefficients (Lasso with alpha={alpha})')
    axes[i, 0].set_xlabel('Features')
    axes[i, 0].set_ylabel('Coefficient Value')
    axes[i, 0].grid(True)
    # Plotting the CV scores
    axes[i, 1].plot(range(1, 6), cv_scores, marker='o', linestyle='-')
    axes[i, 1].set_title(f'Cross-Validation R² Scores (Lasso with alpha={alpha})')
    axes[i, 1].set_xlabel('Fold')
    axes[i, 1].set_xticks(range(1, 6))
    axes[i, 1].set_ylabel('R² Score')
    axes[i, 1].set_ylim(min(cv_scores) - 0.05, max(cv_scores) + 0.05)
    axes[i, 1].grid(True)
    mean_r2 = np.mean(cv_scores)
    axes[i, 1].annotate(f'Mean CV R²: {mean_r2:.3f}', xy=(1.25, 0.65), color='red', fontsize=12)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Load the data
Ames = pd.read_csv('~/Documents/NYCDSA/Third Project/ML_Ames_Housing/data/Ames_Housing_Price_Data.csv')
features = ['GrLivArea', '1stFlrSF', 'LowQualFinSF']  # Remove '2ndFlrSF' after running Lasso
X = Ames[features]
y = Ames['SalePrice']

# %%
X
# Out:
#       GrLivArea  1stFlrSF  LowQualFinSF
# 0           856       856             0
# 1          1049      1049             0
# 2          1001      1001             0
# 3          1039       717             0
# 4          1665       810             0
# ...         ...       ...           ...
# 2575        952       952             0
# 2576       1733      1733             0
# 2577       2002      1001             0
# 2578       1842       985             0
# 2579       1911      1065             0
#
# [2580 rows x 3 columns]

# %%
# Initialize a K-Fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=1)
# Collect coefficients and CV scores
coefficients = []
cv_scores = []
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    # Initialize and fit the linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    coefficients.append(model.coef_)
    # Calculate R^2 score using the model's score method
    score = model.score(X_test, y_test)
    # print(score)
    cv_scores.append(score)

# %%
# Plotting the coefficients
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot(np.array(coefficients), labels=features)
plt.title('Box Plot of Coefficients Across Folds (MLR)')
plt.xlabel('Features')
plt.ylabel('Coefficient Value')
plt.grid(True)

# %%
# Plotting the CV scores
plt.subplot(1, 2, 2)
plt.plot(range(1, 6), cv_scores, marker='o', linestyle='-')  # Adjusted x-axis to start from 1
plt.title('Cross-Validation R² Scores (MLR)')
plt.xlabel('Fold')
plt.xticks(range(1, 6))  # Set x-ticks to match fold numbers
plt.ylabel('R² Score')
plt.ylim(min(cv_scores) - 0.05, max(cv_scores) + 0.05)  # Dynamically adjust y-axis limits
plt.grid(True)
# Annotate mean R² score
mean_r2 = np.mean(cv_scores)
plt.annotate(f'Mean CV R²: {mean_r2:.3f}', xy=(1.25, 0.65), color='red', fontsize=14),
plt.tight_layout()
plt.show()

# %%
#Create seperate factor-set
housing_factor = housing.drop(['GrLivArea','SalePrice','LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                         '2ndFlrSF','LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath','FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',  'GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal', "YrSold",'GarageYrBlt','MoSold','YearBuilt', 'YearRemodAdd'], axis=1)
housing_factor['PavedDrive'] = housing_factor.PavedDrive.apply(lambda Paved: 1 if Paved != "N" else 0)
housing_factor['CentralAir'] = housing_factor.CentralAir.apply(lambda Central: 1 if Central != "N" else 0) #Convert Y/N to Booleon 
housing_factor[['PID','MSSubClass','OverallQual','OverallCond']] = housing_factor[['PID','MSSubClass','OverallQual','OverallCond']].astype(str)
housing_factor[['PavedDrive','CentralAir']] = housing_factor[['PavedDrive','CentralAir']].astype('bool')
housing_factor #transform all integers into categorical variables
housing_factor.dtypes[housing_factor.dtypes == 'int64']
housing_factor
# Out:
#            PID MSSubClass MSZoning Street Alley LotShape LandContour  \
# 1    909176150         30       RL   Pave   NaN      Reg         Lvl
# 2    905476230        120       RL   Pave   NaN      Reg         Lvl
# 3    911128020         30  C (all)   Pave   NaN      Reg         Lvl
# 4    535377150         70       RL   Pave   NaN      Reg         Lvl
# 5    534177230         60       RL   Pave   NaN      Reg         Lvl
# ..         ...        ...      ...    ...   ...      ...         ...
# 759  903205040         30       RL   Pave   NaN      Reg         Lvl
# 760  905402060         20       RL   Pave   NaN      IR1         Lvl
# 761  909275030         90       RH   Pave   NaN      Reg         HLS
# 762  907192040         60       RL   Pave   NaN      Reg         Lvl
# 763  906223180         60       RL   Pave   NaN      IR1         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1      AllPub    Corner       Gtl        SWISU       Norm       Norm     1Fam
# 2      AllPub    Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 3      AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 4      AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 5      AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ..        ...       ...       ...          ...        ...        ...      ...
# 759    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 760    AllPub   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 761    AllPub    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 762    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 763    AllPub    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond RoofStyle RoofMatl Exterior1st  \
# 1       1Story           6           6     Gable  CompShg     Wd Sdng
# 2       1Story           5           5     Gable  CompShg     HdBoard
# 3       1Story           5           9       Hip  CompShg     MetalSd
# 4       2Story           4           8     Gable  CompShg     MetalSd
# 5       2Story           8           6     Gable  CompShg     VinylSd
# ..         ...         ...         ...       ...      ...         ...
# 759     1.5Unf           6           6     Gable  CompShg     Wd Sdng
# 760     1Story           3           5       Hip  CompShg     BrkFace
# 761     2Story           5           6     Gable  CompShg     MetalSd
# 762     2Story           7           5     Gable  CompShg     VinylSd
# 763     2Story           8           5     Gable  CompShg     VinylSd
#
#     Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1       Wd Sdng        NaN        TA        TA     CBlock       TA       TA
# 2       HdBoard    BrkFace        Gd        TA     CBlock       Gd       TA
# 3       MetalSd        NaN        Gd        TA     BrkTil       TA       TA
# 4       MetalSd        NaN        Gd        Gd     BrkTil       Fa       TA
# 5       VinylSd        NaN        Gd        TA      PConc       Gd       TA
# ..          ...        ...       ...       ...        ...      ...      ...
# 759     Wd Sdng        NaN        TA        TA     BrkTil       TA       TA
# 760     Wd Sdng        NaN        TA        TA       Slab      NaN      NaN
# 761     MetalSd        NaN        TA        TA     CBlock       TA       TA
# 762     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 763     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#     BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  CentralAir  \
# 1             No          Rec          Unf    GasA        TA        True
# 2             Mn          GLQ          ALQ    GasA        TA        True
# 3             No          ALQ          Unf    GasA        Ex        True
# 4             No          Unf          Unf    GasA        Gd        True
# 5             No          GLQ          Unf    GasA        Ex        True
# ..           ...          ...          ...     ...       ...         ...
# 759           No          Unf          Unf    Grav        Fa       False
# 760          NaN          NaN          NaN    GasA        Ex        True
# 761           No          BLQ          Unf    GasA        TA       False
# 762           No          GLQ          Unf    GasA        Ex        True
# 763           No          GLQ          Unf    GasA        Ex        True
#
#     Electrical KitchenQual Functional FireplaceQu GarageType GarageFinish  \
# 1        SBrkr          TA        Typ          Gd     Detchd          Unf
# 2        SBrkr          Gd        Typ         NaN     Attchd          Fin
# 3        SBrkr          Gd        Typ         NaN     Detchd          Unf
# 4        SBrkr          TA        Typ         NaN     Detchd          Unf
# 5        SBrkr          Gd        Typ         NaN     Attchd          Fin
# ..         ...         ...        ...         ...        ...          ...
# 759      FuseF          Fa        Typ          Gd     Detchd          Unf
# 760      FuseA          TA       Min2          Gd     Attchd          Unf
# 761      FuseA          TA        Typ         NaN     2Types          Unf
# 762      SBrkr          Gd        Typ          TA     Attchd          Fin
# 763      SBrkr          Gd        Typ          TA     Attchd          RFn
#
#     GarageQual GarageCond  PavedDrive PoolQC Fence MiscFeature SaleType  \
# 1           TA         TA        True    NaN   NaN         NaN      WD
# 2           TA         TA        True    NaN   NaN         NaN      WD
# 3           TA         Po       False    NaN   NaN         NaN      WD
# 4           TA         TA       False    NaN   NaN         NaN      WD
# 5           TA         TA        True    NaN   NaN         NaN      WD
# ..         ...        ...         ...    ...   ...         ...      ...
# 759         Fa         Po        True    NaN   NaN         NaN      WD
# 760         TA         TA        True    NaN   NaN         NaN      WD
# 761         TA         TA        True    NaN   NaN         NaN      WD
# 762         TA         TA        True    NaN   NaN         NaN      WD
# 763         TA         TA        True    NaN   NaN         NaN      WD
#
#     SaleCondition
# 1          Normal
# 2          Normal
# 3          Normal
# 4          Normal
# 5          Normal
# ..            ...
# 759        Normal
# 760        Normal
# 761        Normal
# 762        Normal
# 763        Normal
#
# [2580 rows x 47 columns]

# %%
#Get rid of all NAs
housing_factor['MiscFeature'] = housing_factor['MiscFeature'].fillna('NoFeature')
housing_factor['PoolQC'] = housing_factor['PoolQC'].fillna('NoPool')
housing_factor['Fence'] = housing_factor['Fence'].fillna('NoFence')
housing_factor['GarageQual'] = housing_factor['GarageQual'].fillna('NoGarage')
housing_factor['GarageCond'] = housing_factor['GarageCond'].fillna('NoGarage')
housing_factor['GarageFinish'] = housing_factor['GarageFinish'].fillna('NoGarage')
housing_factor['GarageType'] = housing_factor['GarageType'].fillna('NoGarage')
housing_factor['FireplaceQu'] = housing_factor['FireplaceQu'].fillna('NoFireplace')
housing_factor['BsmtFinType2'] = housing_factor['BsmtFinType2'].fillna('NoBsmt') #528142130 has a basement, but NA for values
housing_factor['BsmtFinType1'] = housing_factor['BsmtFinType1'].fillna('NoBsmt')
housing_factor['BsmtExposure'] = housing_factor['BsmtExposure'].fillna('NoBsmt')
housing_factor['BsmtCond'] = housing_factor['BsmtCond'].fillna('NoBsmt')
housing_factor['BsmtQual'] = housing_factor['BsmtQual'].fillna('NoBsmt') #916386080 is missing an electrical value  veneer
housing_factor['MasVnrType'] = housing_factor['MasVnrType'].fillna('NoVeneer')
housing_factor['Alley'] = housing_factor['Alley'].fillna('NoAlley')

housing_factor.to_pickle('housing_factor.pkl')
housing_factor
# Out:
#            PID MSSubClass MSZoning Street    Alley LotShape LandContour  \
# 1    909176150         30       RL   Pave  NoAlley      Reg         Lvl
# 2    905476230        120       RL   Pave  NoAlley      Reg         Lvl
# 3    911128020         30  C (all)   Pave  NoAlley      Reg         Lvl
# 4    535377150         70       RL   Pave  NoAlley      Reg         Lvl
# 5    534177230         60       RL   Pave  NoAlley      Reg         Lvl
# ..         ...        ...      ...    ...      ...      ...         ...
# 759  903205040         30       RL   Pave  NoAlley      Reg         Lvl
# 760  905402060         20       RL   Pave  NoAlley      IR1         Lvl
# 761  909275030         90       RH   Pave  NoAlley      Reg         HLS
# 762  907192040         60       RL   Pave  NoAlley      Reg         Lvl
# 763  906223180         60       RL   Pave  NoAlley      IR1         Lvl
#
#     Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1      AllPub    Corner       Gtl        SWISU       Norm       Norm     1Fam
# 2      AllPub    Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 3      AllPub    Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 4      AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam
# 5      AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ..        ...       ...       ...          ...        ...        ...      ...
# 759    AllPub    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 760    AllPub   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 761    AllPub    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 762    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 763    AllPub    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#     HouseStyle OverallQual OverallCond RoofStyle RoofMatl Exterior1st  \
# 1       1Story           6           6     Gable  CompShg     Wd Sdng
# 2       1Story           5           5     Gable  CompShg     HdBoard
# 3       1Story           5           9       Hip  CompShg     MetalSd
# 4       2Story           4           8     Gable  CompShg     MetalSd
# 5       2Story           8           6     Gable  CompShg     VinylSd
# ..         ...         ...         ...       ...      ...         ...
# 759     1.5Unf           6           6     Gable  CompShg     Wd Sdng
# 760     1Story           3           5       Hip  CompShg     BrkFace
# 761     2Story           5           6     Gable  CompShg     MetalSd
# 762     2Story           7           5     Gable  CompShg     VinylSd
# 763     2Story           8           5     Gable  CompShg     VinylSd
#
#     Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1       Wd Sdng   NoVeneer        TA        TA     CBlock       TA       TA
# 2       HdBoard    BrkFace        Gd        TA     CBlock       Gd       TA
# 3       MetalSd   NoVeneer        Gd        TA     BrkTil       TA       TA
# 4       MetalSd   NoVeneer        Gd        Gd     BrkTil       Fa       TA
# 5       VinylSd   NoVeneer        Gd        TA      PConc       Gd       TA
# ..          ...        ...       ...       ...        ...      ...      ...
# 759     Wd Sdng   NoVeneer        TA        TA     BrkTil       TA       TA
# 760     Wd Sdng   NoVeneer        TA        TA       Slab   NoBsmt   NoBsmt
# 761     MetalSd   NoVeneer        TA        TA     CBlock       TA       TA
# 762     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
# 763     VinylSd    BrkFace        Gd        TA      PConc       Gd       TA
#
#     BsmtExposure BsmtFinType1 BsmtFinType2 Heating HeatingQC  CentralAir  \
# 1             No          Rec          Unf    GasA        TA        True
# 2             Mn          GLQ          ALQ    GasA        TA        True
# 3             No          ALQ          Unf    GasA        Ex        True
# 4             No          Unf          Unf    GasA        Gd        True
# 5             No          GLQ          Unf    GasA        Ex        True
# ..           ...          ...          ...     ...       ...         ...
# 759           No          Unf          Unf    Grav        Fa       False
# 760       NoBsmt       NoBsmt       NoBsmt    GasA        Ex        True
# 761           No          BLQ          Unf    GasA        TA       False
# 762           No          GLQ          Unf    GasA        Ex        True
# 763           No          GLQ          Unf    GasA        Ex        True
#
#     Electrical KitchenQual Functional  FireplaceQu GarageType GarageFinish  \
# 1        SBrkr          TA        Typ           Gd     Detchd          Unf
# 2        SBrkr          Gd        Typ  NoFireplace     Attchd          Fin
# 3        SBrkr          Gd        Typ  NoFireplace     Detchd          Unf
# 4        SBrkr          TA        Typ  NoFireplace     Detchd          Unf
# 5        SBrkr          Gd        Typ  NoFireplace     Attchd          Fin
# ..         ...         ...        ...          ...        ...          ...
# 759      FuseF          Fa        Typ           Gd     Detchd          Unf
# 760      FuseA          TA       Min2           Gd     Attchd          Unf
# 761      FuseA          TA        Typ  NoFireplace     2Types          Unf
# 762      SBrkr          Gd        Typ           TA     Attchd          Fin
# 763      SBrkr          Gd        Typ           TA     Attchd          RFn
#
#     GarageQual GarageCond  PavedDrive  PoolQC    Fence MiscFeature SaleType  \
# 1           TA         TA        True  NoPool  NoFence   NoFeature      WD
# 2           TA         TA        True  NoPool  NoFence   NoFeature      WD
# 3           TA         Po       False  NoPool  NoFence   NoFeature      WD
# 4           TA         TA       False  NoPool  NoFence   NoFeature      WD
# 5           TA         TA        True  NoPool  NoFence   NoFeature      WD
# ..         ...        ...         ...     ...      ...         ...      ...
# 759         Fa         Po        True  NoPool  NoFence   NoFeature      WD
# 760         TA         TA        True  NoPool  NoFence   NoFeature      WD
# 761         TA         TA        True  NoPool  NoFence   NoFeature      WD
# 762         TA         TA        True  NoPool  NoFence   NoFeature      WD
# 763         TA         TA        True  NoPool  NoFence   NoFeature      WD
#
#     SaleCondition
# 1          Normal
# 2          Normal
# 3          Normal
# 4          Normal
# 5          Normal
# ..            ...
# 759        Normal
# 760        Normal
# 761        Normal
# 762        Normal
# 763        Normal
#
# [2580 rows x 47 columns]

# %%
from sklearn.preprocessing import LabelEncoder
SalePrice = housing['SalePrice'] #This is the target
housing_factor_dummified1 = housing_factor.drop(['PID'], axis=1)
label_encoder = LabelEncoder()
#housing_factor_dummified1[['MSZoning','Street','Alley',
#'LotShape','LandContour',
#'Utilities','LotConfig','LandSlope','Neighborhood',
#'Condition1','Condition2','BldgType','HouseStyle',
#'RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
#'MasVnrType','ExterQual','ExterCond','Foundation',
#'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
#'BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual',
#'Functional','FireplaceQu','GarageType','GarageFinish',
#'GarageQual','GarageCond','PoolQC','Fence','MiscFeature',
#'SaleType','SaleCondition']] = label_encoder.fit_transform(housing_factor_dummified1[['MSZoning','Street','Alley',
#'LotShape','LandContour',
#'Utilities','LotConfig','LandSlope','Neighborhood',
#'Condition1','Condition2','BldgType','HouseStyle',
#'RoofStyle','RoofMatl','Exterior1st','Exterior2nd',
#'MasVnrType','ExterQual','ExterCond','Foundation',
#'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
#'BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual',
#'Functional','FireplaceQu','GarageType','GarageFinish',
#'GarageQual','GarageCond','PoolQC','Fence','MiscFeature',
#'SaleType','SaleCondition']])

housing_factor_dummified1= housing_factor_dummified1.apply(label_encoder.fit_transform)

housing_factor_dummified1 = pd.get_dummies(housing_factor_dummified1, drop_first = True)
housing_factor_dummified1
# Out:
#      MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 1             6         5       1      1         3            3          0
# 2             0         5       1      1         3            3          0
# 3             6         1       1      1         3            3          0
# 4            11         5       1      1         3            3          0
# 5            10         5       1      1         3            3          0
# ..          ...       ...     ...    ...       ...          ...        ...
# 759           6         5       1      1         3            3          0
# 760           5         5       1      1         0            3          0
# 761          15         4       1      1         3            1          0
# 762          10         5       1      1         3            3          0
# 763          10         5       1      1         0            3          0
#
#      LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 1            0          0            21           2           2         0
# 2            4          0             7           2           2         4
# 3            4          0            11           2           2         0
# 4            0          0            20           2           2         0
# 5            4          0            17           2           2         0
# ..         ...        ...           ...         ...         ...       ...
# 759          4          0             3           2           2         0
# 760          1          0             7           2           2         0
# 761          4          0             6           2           2         2
# 762          4          0             5           2           2         0
# 763          4          0            23           2           2         0
#
#      HouseStyle  OverallQual  OverallCond  RoofStyle  RoofMatl  Exterior1st  \
# 1             2            6            5          1         0           13
# 2             2            5            4          1         0            6
# 3             2            5            8          3         0            8
# 4             5            4            7          1         0            8
# 5             5            8            5          1         0           12
# ..          ...          ...          ...        ...       ...          ...
# 759           1            6            5          1         0           13
# 760           2            3            4          3         0            3
# 761           5            5            5          1         0            8
# 762           5            7            4          1         0           12
# 763           5            8            4          1         0           12
#
#      Exterior2nd  MasVnrType  ExterQual  ExterCond  Foundation  BsmtQual  \
# 1             14           2          3          4           1         5
# 2              6           1          2          4           1         2
# 3              8           2          2          4           0         5
# 4              8           2          2          2           0         1
# 5             13           2          2          4           2         2
# ..           ...         ...        ...        ...         ...       ...
# 759           14           2          3          4           0         5
# 760           14           2          3          4           3         3
# 761            8           2          3          4           1         5
# 762           13           1          2          4           2         2
# 763           13           1          2          4           2         2
#
#      BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinType2  Heating  HeatingQC  \
# 1           5             3             5             6        1          4
# 2           5             2             2             0        1          4
# 3           5             3             0             6        1          0
# 4           5             3             6             6        1          2
# 5           5             3             2             6        1          0
# ..        ...           ...           ...           ...      ...        ...
# 759         5             3             6             6        3          1
# 760         3             4             4             4        1          0
# 761         5             3             1             6        1          4
# 762         5             3             2             6        1          0
# 763         5             3             2             6        1          0
#
#      CentralAir  Electrical  KitchenQual  Functional  FireplaceQu  GarageType  \
# 1             1           3            4           6            2           5
# 2             1           3            2           6            3           1
# 3             1           3            2           6            3           5
# 4             1           3            4           6            3           5
# 5             1           3            2           6            3           1
# ..          ...         ...          ...         ...          ...         ...
# 759           0           1            1           6            2           5
# 760           1           0            4           3            2           1
# 761           0           0            4           6            3           0
# 762           1           3            2           6            5           1
# 763           1           3            2           6            5           1
#
#      GarageFinish  GarageQual  GarageCond  PavedDrive  PoolQC  Fence  \
# 1               3           5           5           1       3      4
# 2               0           5           5           1       3      4
# 3               3           5           4           0       3      4
# 4               3           5           5           0       3      4
# 5               0           5           5           1       3      4
# ..            ...         ...         ...         ...     ...    ...
# 759             3           1           4           1       3      4
# 760             3           5           5           1       3      4
# 761             3           5           5           1       3      4
# 762             0           5           5           1       3      4
# 763             2           5           5           1       3      4
#
#      MiscFeature  SaleType  SaleCondition
# 1              1         9              4
# 2              1         9              4
# 3              1         9              4
# 4              1         9              4
# 5              1         9              4
# ..           ...       ...            ...
# 759            1         9              4
# 760            1         9              4
# 761            1         9              4
# 762            1         9              4
# 763            1         9              4
#
# [2580 rows x 46 columns]

# %%
pd.set_option('display.max_rows', 500)
#housing_numeric = pd.concat([housing_numeric, years], axis=1)
housing_numeric.to_pickle('housing_numeric.pkl')
housing_factor_dummified1 = pd.concat([housing_numeric, housing_factor_dummified1], axis=1)
#housing_factor_dummified1 = pd.concat([housing_factor_dummified1,housing_factor[["YrSold",'GarageYrBlt','MoSold','PavedDrive','YearBuilt', 'YearRemodAdd', 'CentralAir']]], axis = 1)
housing_factor_dummified1 = housing_factor_dummified1.drop(['SalePrice'], axis=1)

# %%
from sklearn.linear_model import LinearRegression
#housing_factor_dummified1 = housing_factor_dummified1.drop(['PID'], axis=1)
lm = LinearRegression()
lm.fit(housing_factor_dummified1, housing['SalePrice'])
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
residuals = SalePrice - lm.predict(housing_factor_dummified1)
plt.hist(residuals)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 7.100e+01,
#         2.126e+03, 3.610e+02, 1.400e+01, 6.000e+00]),
#  array([-409735.45392211, -348518.7805513 , -287302.1071805 ,
#         -226085.4338097 , -164868.76043889, -103652.08706809,
#          -42435.41369729,   18781.25967351,   79997.93304432,
#          141214.60641512,  202431.27978592]),
#  <BarContainer object of 10 artists>)

# %%
print('R^2 is equal to %.3f' %(lm.score(housing_factor_dummified1,SalePrice))) #By default, score gives R^2. 
print('RSS is equal to %.3f' %(np.sum(residuals**2)))
print('The intercept is %.3f' %(lm.intercept_))
print('The slopes are %s' %(lm.coef_))
# Out:
# R^2 is equal to 0.887
# RSS is equal to 1640120835476.257
# The intercept is 705143.934
# The slopes are [ 3.77004876e+01  5.23138939e+01  4.79107987e-01  3.79449252e+01
#   1.80212636e+01  5.98065442e+00 -2.34523070e+00  2.16566873e+01
#   2.45651400e+01  2.11365020e+01 -8.00115445e+00  2.42859615e+03
#  -5.79403462e+02 -1.27972530e+03  4.54760340e+02 -7.42228216e+03
#  -1.87361280e+04  2.48308740e+03  6.79043582e+03  3.06297046e+03
#   2.18889721e+01  1.16107581e+01 -7.32288388e+00  2.43905617e+01
#   3.60207038e-01  4.37516547e+01 -4.45132012e+01  7.85494066e-04
#  -7.51989715e+02  1.12936443e+01 -2.18892187e+02  3.62473495e+02
#   7.36805548e+01  6.56443159e+01 -8.61281450e+02  2.18358019e+04
#   1.45370398e+03 -7.84621598e+02 -1.13660729e+03 -4.15259305e+03
#   3.70155265e+02 -6.63133835e+02  1.53400102e+02 -2.19475262e+02
#  -5.24629735e+03 -2.98212111e+03 -6.87567917e+02  1.86952859e+03
#   6.75352862e+03  1.65139430e+03  2.59663843e+03 -8.11745263e+02
#   7.30218372e+02  4.56544374e+03 -1.43322229e+04  2.06444813e+03
#   9.33341177e+02 -2.61462377e+03  8.85930283e+00 -2.28904368e+03
#   4.21689581e+02 -3.70230150e+02  1.64001294e+03 -8.57271095e+02
#   1.25098434e+03 -5.96845343e+02 -3.91160981e+03  4.74352693e+03
#  -1.83274134e+03  1.27310778e+03 -1.58985823e+03 -1.72093900e+03
#   1.36809890e+03  2.87611521e+03 -2.07726788e+04 -2.33954214e+02
#  -2.18785460e+03 -5.07672911e+02  4.45054338e+03]

# %%
print('negative slope column names %s' %(housing_factor_dummified1.columns[lm.coef_ < 0]))
print('positive slope column names %s' %(housing_factor_dummified1.columns[lm.coef_ > 0]))
# Out:
# negative slope column names Index(['BsmtUnfSF', 'LowQualFinSF', 'BsmtHalfBath', 'FullBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'OpenPorchSF', 'PoolArea', 'YrSold', 'MoSold',
#        'MSZoning', 'LotShape', 'LandContour', 'Utilities', 'LandSlope',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'Exterior1st',
#        'ExterQual', 'BsmtQual', 'BsmtExposure', 'BsmtFinType2', 'HeatingQC',
#        'Electrical', 'KitchenQual', 'FireplaceQu', 'GarageFinish',
#        'GarageQual', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType'],
#       dtype='object')
# positive slope column names Index(['GrLivArea', 'LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'BsmtFullBath',
#        'HalfBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea',
#        'WoodDeckSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal',
#        'GarageYrBlt', 'YearBuilt', 'YearRemodAdd', 'MSSubClass', 'Street',
#        'Alley', 'LotConfig', 'Neighborhood', 'OverallQual', 'OverallCond',
#        'RoofStyle', 'RoofMatl', 'Exterior2nd', 'MasVnrType', 'ExterCond',
#        'Foundation', 'BsmtCond', 'BsmtFinType1', 'Heating', 'CentralAir',
#        'Functional', 'GarageType', 'GarageCond', 'PavedDrive',
#        'SaleCondition'],
#       dtype='object')

# %%
log_SalePrice = np.log(SalePrice) #Take log of DV
lm.fit(housing_factor_dummified1, log_SalePrice) #LM of log of DV
residuals = log_SalePrice - lm.predict(housing_factor_dummified1)
plt.hist(residuals)
# Out:
# (array([   2.,    0.,    0.,    4.,    3.,   44., 1044., 1386.,   89.,
#            8.]),
#  array([-1.48988122, -1.27916357, -1.06844591, -0.85772826, -0.6470106 ,
#         -0.43629295, -0.22557529, -0.01485764,  0.19586002,  0.40657767,
#          0.61729533]),
#  <BarContainer object of 10 artists>)

# %%
print('R^2 is equal to %.3f' %(lm.score(housing_factor_dummified1,log_SalePrice))) #By default, score gives R^2. 
print('RSS is equal to %.3f' %(np.sum(residuals**2)))
print('The intercept is %.3f' %(lm.intercept_))
print('The slopes are %s' %(lm.coef_))
# Out:
# R^2 is equal to 0.909
# RSS is equal to 35.315
# The intercept is 14.418
# The slopes are [ 1.73710615e-04  4.28054993e-04  2.13522986e-06  3.89876089e-05
#   6.42629333e-05  3.95998404e-05 -1.12582445e-07  1.03750191e-04
#   1.23084673e-04  8.83325432e-05 -3.77066015e-05  2.47485838e-02
#   5.86289834e-03  1.52703220e-02  9.83069018e-03 -2.00503445e-02
#  -8.23095056e-02  1.10670322e-02  3.46341700e-02  3.00415136e-02
#   4.54786906e-05  3.79746260e-05 -2.76608591e-06  1.87427945e-04
#   7.45745700e-05  2.54640079e-04 -1.49699671e-04  1.17822974e-06
#  -4.69256359e-03  2.44495228e-04 -1.08650406e-03  1.96018561e-03
#   6.73172676e-04  2.94893558e-03 -1.24915378e-02  1.28397151e-01
#   1.82073540e-02 -4.82119427e-03 -3.50585221e-03 -6.34949521e-02
#   1.36498602e-03  8.61959799e-03  1.01929302e-04  4.98999384e-04
#  -3.00257738e-02 -7.14522831e-03 -4.06383276e-03  3.75818633e-02
#   4.91385520e-02  2.98193236e-03  8.87639824e-03 -2.58781410e-03
#   4.32024880e-03  9.25097956e-03 -3.54671353e-02  1.43653631e-02
#   6.54638693e-03 -5.44297401e-03  9.06629927e-04 -9.62116077e-03
#  -2.31430828e-03  5.52634658e-04  1.65281081e-02 -7.53473817e-03
#   7.67653304e-02  1.73530927e-03 -1.23577638e-02  1.91641226e-02
#  -4.18555857e-03 -2.35961324e-03 -3.32720691e-03 -2.69257094e-03
#   1.68233853e-02  5.54932330e-02 -5.28321493e-02 -1.01631470e-03
#  -1.08714673e-02  3.60874824e-04  3.31314625e-02]

# %%
scores = {}
for idx, name1 in enumerate(housing_factor_dummified1.columns):
        myColumns = housing_factor_dummified1.columns[(idx+1):]
        pass

# %%
from itertools import combinations 

scores = {}

combos = combinations(housing_factor_dummified1.columns, 3)

for c in combos:
    X = housing_factor_dummified1[list(c)]
    Y = log_SalePrice
    reg = LinearRegression().fit(X,Y)
    scores[c] = reg.score (X,Y)

# %%
sorted(scores.items(), key=lambda features_score: abs(features_score [1]), reverse = True)
# Out:
# [(('GrLivArea', 'TotalBsmtSF', 'YearBuilt'), 0.7714551451333254),
#  (('GrLivArea', 'YearBuilt', 'OverallQual'), 0.7604729424467696),
#  (('GrLivArea', 'YearBuilt', 'OverallCond'), 0.7586200588631286),
#  (('GrLivArea', 'TotalBsmtSF', 'OverallQual'), 0.7579387156580107),
#  (('GrLivArea', 'BsmtFinSF1', 'YearBuilt'), 0.7560063000859526),
#  (('GrLivArea', 'BsmtFinSF1', 'OverallQual'), 0.7555270792257379),
#  (('1stFlrSF', '2ndFlrSF', 'YearBuilt'), 0.7505689977295026),
#  (('GrLivArea', '1stFlrSF', 'YearBuilt'), 0.7502545592276775),
#  (('GrLivArea', 'TotalBsmtSF', 'YearRemodAdd'), 0.749848485569653),
#  (('GrLivArea', '2ndFlrSF', 'YearBuilt'), 0.7481493441965616),
#  (('GrLivArea', 'GarageArea', 'YearBuilt'), 0.7444299703937638),
#  (('GrLivArea', 'GarageCars', 'YearBuilt'), 0.7403132563307049),
#  (('GrLivArea', 'Fireplaces', 'YearBuilt'), 0.7388960359402381),
#  (('GrLivArea', 'YearBuilt', 'KitchenQual'), 0.7382692175027734),
#  (('GrLivArea', 'BsmtFullBath', 'YearBuilt'), 0.7376513780196292),
#  (('GrLivArea', 'GarageArea', 'OverallQual'), 0.7367680405229939),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageYrBlt'), 0.7360069912797057),
#  (('GrLivArea', 'YearBuilt', 'BsmtExposure'), 0.7355245824578512),
#  (('1stFlrSF', '2ndFlrSF', 'OverallQual'), 0.7354706698239977),
#  (('GrLivArea', '1stFlrSF', 'OverallQual'), 0.7337752976267584),
#  (('GrLivArea', 'KitchenAbvGr', 'YearBuilt'), 0.7335592101729265),
#  (('GrLivArea', 'YearBuilt', 'ExterQual'), 0.7331817784578025),
#  (('GrLivArea', 'YearBuilt', 'YearRemodAdd'), 0.7330474274633443),
#  (('GrLivArea', 'GarageCars', 'OverallQual'), 0.7327260532343414),
#  (('GrLivArea', 'BedroomAbvGr', 'YearBuilt'), 0.7313598802563661),
#  (('GrLivArea', '2ndFlrSF', 'OverallQual'), 0.7301083651306802),
#  (('GrLivArea', 'YearBuilt', 'CentralAir'), 0.7299887530262347),
#  (('GrLivArea', 'YearBuilt', 'GarageType'), 0.7288431624225895),
#  (('GrLivArea', 'YearBuilt', 'BsmtFinType1'), 0.7269922368123383),
#  (('GrLivArea', 'GarageYrBlt', 'OverallQual'), 0.7265381392896082),
#  (('GrLivArea', 'OverallQual', 'GarageType'), 0.7265365162967031),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageCars'), 0.7264815079071882),
#  (('GrLivArea', 'YearBuilt', 'GarageCond'), 0.7262517246500384),
#  (('GrLivArea', 'BsmtFinSF1', 'YearRemodAdd'), 0.7248110360533251),
#  (('GrLivArea', 'LotFrontage', 'YearBuilt'), 0.7244369475892276),
#  (('GrLivArea', 'YearRemodAdd', 'OverallQual'), 0.7243689906153545),
#  (('GrLivArea', 'YearBuilt', 'HeatingQC'), 0.7241091399828394),
#  (('GrLivArea', 'BsmtFullBath', 'OverallQual'), 0.7236400927871545),
#  (('GrLivArea', 'HalfBath', 'YearBuilt'), 0.7232464997559678),
#  (('GrLivArea', 'LotArea', 'YearBuilt'), 0.7231029565332233),
#  (('GrLivArea', 'YearBuilt', 'Functional'), 0.7215062407970082),
#  (('GrLivArea', 'YearBuilt', 'BldgType'), 0.7214729965579904),
#  (('GrLivArea', 'YearBuilt', 'HouseStyle'), 0.721182622247297),
#  (('GrLivArea', 'YearBuilt', 'RoofStyle'), 0.7208058214121722),
#  (('GrLivArea', 'OverallQual', 'ExterQual'), 0.7207562249678174),
#  (('GrLivArea', 'WoodDeckSF', 'YearBuilt'), 0.7202678205233866),
#  (('GrLivArea', 'YearBuilt', 'SaleCondition'), 0.7201371520982408),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtQual'), 0.7195874485294766),
#  (('GrLivArea', 'ScreenPorch', 'YearBuilt'), 0.7195123433962239),
#  (('GrLivArea', 'YearBuilt', 'PavedDrive'), 0.7195100571719835),
#  (('GrLivArea', 'YearBuilt', 'LotShape'), 0.719457347175742),
#  (('GrLivArea', 'YearBuilt', 'FireplaceQu'), 0.7185034423661774),
#  (('GrLivArea', 'YearBuilt', 'MSSubClass'), 0.718401444152587),
#  (('GrLivArea', 'MasVnrArea', 'YearBuilt'), 0.717941132795469),
#  (('GrLivArea', 'YearBuilt', 'BsmtQual'), 0.7178923189519884),
#  (('GrLivArea', 'TotRmsAbvGrd', 'YearBuilt'), 0.7178390256679192),
#  (('GrLivArea', 'OverallQual', 'BsmtExposure'), 0.7173747168714051),
#  (('GrLivArea', 'YearBuilt', 'Exterior2nd'), 0.7167349511849233),
#  (('GrLivArea', 'YearBuilt', 'LandSlope'), 0.7166342261369724),
#  (('GrLivArea', 'YearBuilt', 'GarageQual'), 0.716546329698073),
#  (('GrLivArea', 'OverallQual', 'BsmtFinType1'), 0.7165054544171572),
#  (('GrLivArea', 'YearBuilt', 'Electrical'), 0.7164406232947212),
#  (('GrLivArea', 'YearBuilt', 'Exterior1st'), 0.7161063728988228),
#  (('GrLivArea', 'YearBuilt', 'Neighborhood'), 0.7159338001382768),
#  (('GrLivArea', 'YearBuilt', 'LandContour'), 0.7157878621671101),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageYrBlt'), 0.7157758152291231),
#  (('GrLivArea', 'YearBuilt', 'BsmtCond'), 0.7156619153990823),
#  (('GrLivArea', 'BsmtFinSF2', 'YearBuilt'), 0.7153523403583566),
#  (('GrLivArea', 'GarageArea', 'YearRemodAdd'), 0.7152720329376769),
#  (('GrLivArea', 'OverallQual', 'CentralAir'), 0.7152163287697983),
#  (('GrLivArea', 'FullBath', 'YearBuilt'), 0.7149510320302357),
#  (('GrLivArea', 'YearBuilt', 'Heating'), 0.714485048106708),
#  (('GrLivArea', 'YearBuilt', 'GarageFinish'), 0.714480062629164),
#  (('GrLivArea', 'OpenPorchSF', 'YearBuilt'), 0.7143524693037613),
#  (('GrLivArea', 'LowQualFinSF', 'YearBuilt'), 0.7142410937008408),
#  (('GrLivArea', 'YearBuilt', 'LotConfig'), 0.7140456474064721),
#  (('GrLivArea', 'EnclosedPorch', 'YearBuilt'), 0.7139510404950564),
#  (('GrLivArea', 'YearBuilt', 'RoofMatl'), 0.7139422335849239),
#  (('GrLivArea', '3SsnPorch', 'YearBuilt'), 0.713933317060236),
#  (('1stFlrSF', '2ndFlrSF', 'YearRemodAdd'), 0.7138689429902974),
#  (('GrLivArea', 'YearBuilt', 'Foundation'), 0.7138209272656457),
#  (('GrLivArea', 'GarageYrBlt', 'YearBuilt'), 0.7137378481374494),
#  (('GrLivArea', 'BsmtHalfBath', 'YearBuilt'), 0.7137058712120746),
#  (('GrLivArea', 'GarageCars', 'YearRemodAdd'), 0.7136675036101208),
#  (('GrLivArea', 'YearBuilt', 'Utilities'), 0.7136362995164058),
#  (('GrLivArea', 'YearBuilt', 'SaleType'), 0.7136090581111403),
#  (('GrLivArea', 'YearBuilt', 'MasVnrType'), 0.713510165514291),
#  (('GrLivArea', 'YearBuilt', 'PoolQC'), 0.713485780883063),
#  (('GrLivArea', 'YearBuilt', 'Fence'), 0.7134743689017098),
#  (('GrLivArea', 'BsmtUnfSF', 'YearBuilt'), 0.7133608783080287),
#  (('GrLivArea', 'YearBuilt', 'Street'), 0.7132877669235939),
#  (('GrLivArea', 'YearBuilt', 'Condition2'), 0.7132619252297544),
#  (('GrLivArea', 'YearBuilt', 'BsmtFinType2'), 0.7132483007575448),
#  (('GrLivArea', 'YearBuilt', 'Alley'), 0.7132428057915694),
#  (('GrLivArea', 'YearBuilt', 'MiscFeature'), 0.7132206295807773),
#  (('GrLivArea', 'YearBuilt', 'Condition1'), 0.7132134506069563),
#  (('GrLivArea', 'PoolArea', 'YearBuilt'), 0.7131843939473628),
#  (('GrLivArea', 'YrSold', 'YearBuilt'), 0.7131834190056447),
#  (('GrLivArea', 'YearBuilt', 'ExterCond'), 0.7131615624851788),
#  (('GrLivArea', 'MiscVal', 'YearBuilt'), 0.7131564000844628),
#  (('GrLivArea', 'MoSold', 'YearBuilt'), 0.7131559693085133),
#  (('GrLivArea', 'YearBuilt', 'MSZoning'), 0.7131558365057338),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageArea'), 0.7130843873978767),
#  (('GrLivArea', 'OverallQual', 'KitchenQual'), 0.713084059807622),
#  (('GrLivArea', '1stFlrSF', 'YearRemodAdd'), 0.7112740378333278),
#  (('GrLivArea', 'YearRemodAdd', 'GarageType'), 0.7103994766977337),
#  (('GrLivArea', 'TotalBsmtSF', 'Foundation'), 0.7100725579060088),
#  (('GrLivArea', 'OverallQual', 'BsmtQual'), 0.7093124979605487),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageType'), 0.7092904504246644),
#  (('GrLivArea', 'TotalBsmtSF', 'KitchenQual'), 0.7080067755207802),
#  (('GrLivArea', 'OverallQual', 'PavedDrive'), 0.7078041292838659),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageCars'), 0.7072019630230865),
#  (('1stFlrSF', '2ndFlrSF', 'GarageYrBlt'), 0.7069206126720702),
#  (('GrLivArea', '2ndFlrSF', 'YearRemodAdd'), 0.706319037469171),
#  (('TotalBsmtSF', '2ndFlrSF', 'OverallQual'), 0.7039850842270816),
#  (('GrLivArea', 'TotalBsmtSF', 'CentralAir'), 0.7039103317280433),
#  (('GrLivArea', 'GarageYrBlt', 'GarageType'), 0.703734845961171),
#  (('GrLivArea', 'TotalBsmtSF', 'ExterQual'), 0.70366625672115),
#  (('GrLivArea', '1stFlrSF', 'GarageYrBlt'), 0.7033819631822662),
#  (('GrLivArea', 'OverallQual', 'GarageCond'), 0.703247905064668),
#  (('1stFlrSF', 'HalfBath', 'OverallQual'), 0.7017264833753909),
#  (('1stFlrSF', 'GarageCars', 'OverallQual'), 0.7016026100934485),
#  (('GrLivArea', 'BedroomAbvGr', 'OverallQual'), 0.7011565491050014),
#  (('TotalBsmtSF', '2ndFlrSF', 'YearBuilt'), 0.7005363411294118),
#  (('GrLivArea', 'TotalBsmtSF', 'HeatingQC'), 0.7005315853920804),
#  (('GrLivArea', 'OverallQual', 'Foundation'), 0.6997443491455151),
#  (('GrLivArea', 'OverallQual', 'HeatingQC'), 0.6983902648263818),
#  (('GrLivArea', '2ndFlrSF', 'GarageYrBlt'), 0.6982370039624086),
#  (('GrLivArea', 'GarageCars', 'KitchenQual'), 0.6975876248650139),
#  (('GrLivArea', 'KitchenAbvGr', 'OverallQual'), 0.6975527777461317),
#  (('GrLivArea', 'GarageCars', 'GarageYrBlt'), 0.6969129160927496),
#  (('GrLivArea', 'LotFrontage', 'OverallQual'), 0.6969102208850628),
#  (('GrLivArea', 'Fireplaces', 'OverallQual'), 0.6967928993038034),
#  (('GrLivArea', 'OverallQual', 'GarageQual'), 0.6966654816702343),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageCond'), 0.6965355402473855),
#  (('GrLivArea', 'OverallQual', 'GarageFinish'), 0.6959447648488),
#  (('GrLivArea', 'KitchenQual', 'GarageType'), 0.6959372267178536),
#  (('GrLivArea', 'ExterQual', 'GarageType'), 0.6957348323728971),
#  (('GrLivArea', 'MasVnrArea', 'OverallQual'), 0.695313799567326),
#  (('1stFlrSF', 'GarageArea', 'OverallQual'), 0.6951222070037247),
#  (('GrLivArea', 'TotalBsmtSF', 'KitchenAbvGr'), 0.6949193940552573),
#  (('TotalBsmtSF', 'GarageCars', 'OverallQual'), 0.6942620254961517),
#  (('GrLivArea', 'GarageCars', 'ExterQual'), 0.6939099255307257),
#  (('GrLivArea', 'TotalBsmtSF', 'PavedDrive'), 0.6937701504623223),
#  (('GrLivArea', 'WoodDeckSF', 'OverallQual'), 0.6937575801129643),
#  (('GrLivArea', 'LotShape', 'OverallQual'), 0.6934665775980845),
#  (('GrLivArea', 'OverallQual', 'Electrical'), 0.6934536954569832),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageArea'), 0.6930835587139255),
#  (('1stFlrSF', 'YearRemodAdd', 'OverallQual'), 0.6928248825518956),
#  (('GrLivArea', 'GarageArea', 'GarageYrBlt'), 0.692517808436627),
#  (('GrLivArea', 'LotArea', 'OverallQual'), 0.6923599390335136),
#  (('GrLivArea', 'MSSubClass', 'OverallQual'), 0.6918826487287293),
#  (('TotalBsmtSF', '2ndFlrSF', 'GarageCars'), 0.69179465449366),
#  (('TotalBsmtSF', '2ndFlrSF', 'YearRemodAdd'), 0.6911593672463866),
#  (('GrLivArea', 'GarageCars', 'GarageType'), 0.6908232284779651),
#  (('GrLivArea', 'GarageArea', 'KitchenQual'), 0.6907547416771735),
#  (('GrLivArea', 'BsmtFinSF1', 'ExterQual'), 0.6897626708023163),
#  (('GrLivArea', 'ExterQual', 'CentralAir'), 0.6895352879645646),
#  (('GrLivArea', 'Fireplaces', 'GarageYrBlt'), 0.6894205147067738),
#  (('GrLivArea', 'OverallQual', 'SaleCondition'), 0.688546470093786),
#  (('GrLivArea', 'YearRemodAdd', 'PavedDrive'), 0.6884419750560917),
#  (('TotalBsmtSF', 'GarageArea', 'OverallQual'), 0.6882740218366601),
#  (('GrLivArea', 'BsmtFinSF1', 'KitchenQual'), 0.6882735133072845),
#  (('GrLivArea', 'EnclosedPorch', 'OverallQual'), 0.6879043360549094),
#  (('GrLivArea', 'OverallQual', 'Functional'), 0.6875239984096306),
#  (('GrLivArea', 'YearRemodAdd', 'BsmtExposure'), 0.6874056119759338),
#  (('GrLivArea', 'TotRmsAbvGrd', 'OverallQual'), 0.6873948410171106),
#  (('GrLivArea', 'OverallQual', 'BsmtCond'), 0.6871302137501449),
#  (('1stFlrSF', '2ndFlrSF', 'GarageCars'), 0.6871121754522561),
#  (('GrLivArea', 'GarageArea', 'ExterQual'), 0.6870333251950955),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageFinish'), 0.6864774261041005),
#  (('GrLivArea', 'GarageYrBlt', 'CentralAir'), 0.6863022774028755),
#  (('GrLivArea', 'BsmtFullBath', 'YearRemodAdd'), 0.6862674197552836),
#  (('GrLivArea', 'TotalBsmtSF', 'GarageQual'), 0.686033892918265),
#  (('GrLivArea', 'OverallQual', 'RoofStyle'), 0.6860116831691594),
#  (('GrLivArea', 'GarageArea', 'GarageType'), 0.6859909798859218),
#  (('1stFlrSF', 'YearBuilt', 'OverallQual'), 0.6859680523452838),
#  (('GrLivArea', 'MSZoning', 'OverallQual'), 0.6855981144333144),
#  (('GrLivArea', 'BsmtFullBath', 'GarageYrBlt'), 0.6853555528274398),
#  (('GrLivArea', 'Alley', 'OverallQual'), 0.6850944426344381),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'OverallQual'), 0.6850464823571234),
#  (('GrLivArea', 'ScreenPorch', 'OverallQual'), 0.6847843264114812),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtExposure'), 0.6845895191232164),
#  (('GrLivArea', 'TotalBsmtSF', 'BedroomAbvGr'), 0.6844856619231632),
#  (('GrLivArea', 'GarageCars', 'BsmtExposure'), 0.6844199869937513),
#  (('GrLivArea', '1stFlrSF', 'GarageCars'), 0.6842093813418255),
#  (('GrLivArea', 'Fireplaces', 'YearRemodAdd'), 0.6841902442119701),
#  (('GrLivArea', 'BsmtFinSF1', 'BsmtQual'), 0.6839779131053225),
#  (('GrLivArea', 'OverallQual', 'Heating'), 0.6838698144841042),
#  (('GrLivArea', 'BsmtFinSF1', 'TotalBsmtSF'), 0.6836618240242283),
#  (('GrLivArea', 'YearRemodAdd', 'CentralAir'), 0.6835898480983559),
#  (('GrLivArea', 'LandSlope', 'OverallQual'), 0.6834171836861629),
#  (('GrLivArea', 'GarageCars', 'CentralAir'), 0.6833229919413105),
#  (('GrLivArea', 'GarageArea', 'BsmtQual'), 0.6832488115340936),
#  (('GrLivArea', 'BsmtUnfSF', 'OverallQual'), 0.6831988392988961),
#  (('GrLivArea', 'BsmtFinSF2', 'OverallQual'), 0.6831927672615079),
#  (('GrLivArea', 'GarageYrBlt', 'BsmtExposure'), 0.6831242800981467),
#  (('GrLivArea', 'CentralAir', 'KitchenQual'), 0.6830551415999826),
#  (('GrLivArea', 'LowQualFinSF', 'OverallQual'), 0.6829867289553972),
#  (('GrLivArea', 'BsmtQual', 'GarageType'), 0.6829659979871499),
#  (('GrLivArea', 'BsmtFullBath', 'GarageCars'), 0.6826776706672602),
#  (('GrLivArea', 'OverallQual', 'ExterCond'), 0.6825428684500072),
#  (('GrLivArea', 'OpenPorchSF', 'OverallQual'), 0.6823126503671468),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageType'), 0.6821141779856175),
#  (('GrLivArea', 'FullBath', 'OverallQual'), 0.6820179347519646),
#  (('GrLivArea', 'TotalBsmtSF', 'Electrical'), 0.6819991934527301),
#  (('GrLivArea', 'Neighborhood', 'OverallQual'), 0.6819562875607834),
#  (('GrLivArea', 'Condition1', 'OverallQual'), 0.6819323243398008),
#  (('GrLivArea', 'OverallQual', 'OverallCond'), 0.6819092541154836),
#  (('GrLivArea', 'BldgType', 'OverallQual'), 0.6818005493544211),
#  (('GrLivArea', 'OverallQual', 'FireplaceQu'), 0.6817155358306028),
#  (('GrLivArea', 'GarageYrBlt', 'KitchenQual'), 0.681525146078809),
#  (('GrLivArea', 'GarageCars', 'BsmtQual'), 0.681488306290706),
#  (('GrLivArea', 'GarageYrBlt', 'YearRemodAdd'), 0.6814457039429469),
#  (('GrLivArea', 'OverallQual', 'PoolQC'), 0.6813265852990087),
#  (('GrLivArea', 'OverallQual', 'BsmtFinType2'), 0.681060662437647),
#  (('GrLivArea', 'BsmtUnfSF', 'TotalBsmtSF'), 0.68105897015942),
#  (('GrLivArea', 'HalfBath', 'OverallQual'), 0.6809932699371695),
#  (('GrLivArea', 'TotalBsmtSF', 'HouseStyle'), 0.6809921492791984),
#  (('GrLivArea', 'OverallQual', 'RoofMatl'), 0.6808759368841519),
#  (('GrLivArea', 'BsmtHalfBath', 'OverallQual'), 0.680787351131686),
#  (('GrLivArea', '3SsnPorch', 'OverallQual'), 0.6806740798478146),
#  (('GrLivArea', 'Utilities', 'OverallQual'), 0.6805946862448511),
#  (('GrLivArea', 'OverallQual', 'Exterior2nd'), 0.6805792411116105),
#  (('GrLivArea', 'HouseStyle', 'OverallQual'), 0.6805310320631417),
#  (('GrLivArea', 'YearRemodAdd', 'ExterQual'), 0.6805030971267794),
#  (('GrLivArea', 'YearRemodAdd', 'GarageCond'), 0.6804165704128491),
#  (('GrLivArea', 'Condition2', 'OverallQual'), 0.6804151382185977),
#  (('GrLivArea', 'LotConfig', 'OverallQual'), 0.6802629456657516),
#  (('GrLivArea', 'LandContour', 'OverallQual'), 0.6802275022422889),
#  (('GrLivArea', 'OverallQual', 'Exterior1st'), 0.6802231947474744),
#  (('GrLivArea', 'OverallQual', 'Fence'), 0.6802226502316653),
#  (('GrLivArea', 'MoSold', 'OverallQual'), 0.6802056466690646),
#  (('GrLivArea', 'Street', 'OverallQual'), 0.6801870785410045),
#  (('GrLivArea', '2ndFlrSF', 'GarageCars'), 0.6801788129699127),
#  (('GrLivArea', 'OverallQual', 'SaleType'), 0.6801720670666849),
#  (('GrLivArea', 'OverallQual', 'MiscFeature'), 0.6801507710527579),
#  (('GrLivArea', 'OverallQual', 'MasVnrType'), 0.6801393539891942),
#  (('GrLivArea', 'PoolArea', 'OverallQual'), 0.6801233568153314),
#  (('GrLivArea', 'YrSold', 'OverallQual'), 0.6800978326684067),
#  (('GrLivArea', 'MiscVal', 'OverallQual'), 0.6800803455700801),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtFinType1'), 0.6793383503411143),
#  (('TotalBsmtSF', '2ndFlrSF', 'GarageArea'), 0.6791632787198987),
#  (('GrLivArea', 'YearRemodAdd', 'BsmtFinType1'), 0.6786595618819729),
#  (('1stFlrSF', 'GarageYrBlt', 'OverallQual'), 0.6783646122937325),
#  (('GrLivArea', 'TotalBsmtSF', 'LotShape'), 0.6782670564759693),
#  (('GrLivArea', 'GarageYrBlt', 'PavedDrive'), 0.6775895918386978),
#  (('GrLivArea', 'KitchenAbvGr', 'GarageYrBlt'), 0.6775785031631885),
#  (('GrLivArea', 'BsmtQual', 'CentralAir'), 0.6772945672154174),
#  (('1stFlrSF', 'OverallQual', 'ExterQual'), 0.6771643478633806),
#  (('GrLivArea', 'TotalBsmtSF', 'Fireplaces'), 0.6770946284998653),
#  (('GrLivArea', 'ExterQual', 'PavedDrive'), 0.6770352381968945),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtFullBath'), 0.6769877837339497),
#  (('1stFlrSF', 'TotRmsAbvGrd', 'OverallQual'), 0.6768324854136627),
#  (('GrLivArea', 'GarageYrBlt', 'ExterQual'), 0.6766259549791378),
#  (('GrLivArea', 'GarageCars', 'GarageFinish'), 0.6760317669755778),
#  (('GrLivArea', 'GarageYrBlt', 'GarageCond'), 0.675843074227849),
#  (('GrLivArea', 'GarageYrBlt', 'BsmtFinType1'), 0.6757740225468121),
#  (('GrLivArea', 'GarageCars', 'HeatingQC'), 0.6756379745063994),
#  (('GrLivArea', 'KitchenAbvGr', 'GarageCars'), 0.6755671932784183),
#  (('GrLivArea', 'GarageArea', 'GarageFinish'), 0.6755339129123938),
#  (('GrLivArea', 'GarageArea', 'CentralAir'), 0.6754167004110307),
#  (('GrLivArea', 'GarageCars', 'PavedDrive'), 0.6751906031060708),
#  (('GrLivArea', 'TotalBsmtSF', 'Functional'), 0.6748859382622245),
#  (('1stFlrSF', 'FullBath', 'OverallQual'), 0.6745351989662614),
#  (('1stFlrSF', '2ndFlrSF', 'BsmtQual'), 0.6745261355702638),
#  (('TotalBsmtSF', 'HalfBath', 'OverallQual'), 0.6744238659766542),
#  (('GrLivArea', 'GarageArea', 'BsmtExposure'), 0.6744005759598215),
#  (('TotalBsmtSF', 'GarageCars', 'YearRemodAdd'), 0.6741684887805397),
#  (('GrLivArea', 'BsmtFinSF1', 'HeatingQC'), 0.6738505412495739),
#  (('1stFlrSF', 'HouseStyle', 'OverallQual'), 0.6737519255076998),
#  (('1stFlrSF', 'OverallQual', 'KitchenQual'), 0.673624155290891),
#  (('GrLivArea', 'YearRemodAdd', 'BsmtQual'), 0.673514700187519),
#  (('GrLivArea', 'KitchenQual', 'PavedDrive'), 0.6732674714839316),
#  (('GrLivArea', 'TotalBsmtSF', 'HalfBath'), 0.673161298444076),
#  (('GrLivArea', 'GarageCars', 'BsmtFinType1'), 0.6731115265267774),
#  (('GrLivArea', 'TotalBsmtSF', 'SaleCondition'), 0.6728552935292114),
#  (('1stFlrSF', 'GarageCars', 'YearRemodAdd'), 0.6725086419978064),
#  (('GrLivArea', 'TotalBsmtSF', 'WoodDeckSF'), 0.6724519798889154),
#  (('1stFlrSF', '2ndFlrSF', 'GarageArea'), 0.6724444625377655),
#  (('GrLivArea', 'GarageArea', 'HeatingQC'), 0.6721699651555832),
#  (('GrLivArea', 'TotalBsmtSF', 'FullBath'), 0.6717464216406279),
#  (('GrLivArea', '1stFlrSF', 'BsmtQual'), 0.6717446663531146),
#  (('GrLivArea', 'BsmtFinSF1', 'CentralAir'), 0.6716765099637483),
#  (('TotalBsmtSF', 'FullBath', 'OverallQual'), 0.6716754569598311),
#  (('GrLivArea', 'TotalBsmtSF', 'MSZoning'), 0.6712086813981484),
#  (('GrLivArea', 'BsmtFullBath', 'GarageArea'), 0.6711679650947165),
#  (('TotalBsmtSF', '2ndFlrSF', 'GarageYrBlt'), 0.6709584663506835),
#  (('GrLivArea', 'YearRemodAdd', 'GarageQual'), 0.6707443519979343),
#  (('GrLivArea', 'TotalBsmtSF', 'EnclosedPorch'), 0.6706876790137761),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'YearBuilt'), 0.6703263247569253),
#  (('GrLivArea', 'YearRemodAdd', 'KitchenQual'), 0.6701872516809408),
#  (('TotalBsmtSF', 'YearRemodAdd', 'OverallQual'), 0.6698385046653301),
#  (('1stFlrSF', 'OverallQual', 'BsmtQual'), 0.6698092316734029),
#  (('BsmtFinSF1', 'TotRmsAbvGrd', 'OverallQual'), 0.6696354872874155),
#  (('GrLivArea', 'BsmtExposure', 'GarageType'), 0.6695837672376264),
#  (('GrLivArea', 'BedroomAbvGr', 'GarageYrBlt'), 0.669528544169494),
#  (('GrLivArea', 'TotalBsmtSF', 'Alley'), 0.6692782496682474),
#  (('GrLivArea', 'HeatingQC', 'GarageType'), 0.6689339386306612),
#  (('GrLivArea', '1stFlrSF', 'GarageArea'), 0.6688618566631064),
#  (('GrLivArea', 'TotalBsmtSF', 'Exterior2nd'), 0.6682805020907447),
#  (('1stFlrSF', '2ndFlrSF', 'ExterQual'), 0.668274995346503),
#  (('1stFlrSF', 'OverallQual', 'HeatingQC'), 0.668229567883172),
#  (('GrLivArea', 'MasVnrArea', 'YearRemodAdd'), 0.6676965677311526),
#  (('1stFlrSF', '2ndFlrSF', 'KitchenQual'), 0.6675127226848575),
#  (('GrLivArea', 'TotalBsmtSF', 'Exterior1st'), 0.6674778303529991),
#  (('TotalBsmtSF', '2ndFlrSF', 'BsmtQual'), 0.6674516113312763),
#  (('GrLivArea', 'TotalBsmtSF', 'TotRmsAbvGrd'), 0.6673555013415994),
#  (('GrLivArea', 'MasVnrArea', 'TotalBsmtSF'), 0.667327802911424),
#  (('GrLivArea', 'KitchenAbvGr', 'YearRemodAdd'), 0.6670152208423332),
#  (('GrLivArea', '2ndFlrSF', 'BsmtQual'), 0.6670094143880018),
#  (('GrLivArea', 'GarageYrBlt', 'OverallCond'), 0.6669086455838441),
#  (('GrLivArea', 'TotalBsmtSF', 'OverallCond'), 0.666860084180389),
#  (('GrLivArea', 'GarageCars', 'Foundation'), 0.6667824324327231),
#  (('GrLivArea', 'GarageArea', 'PavedDrive'), 0.666438293174693),
#  (('GrLivArea', 'BsmtFinSF1', 'Foundation'), 0.6664062047938959),
#  (('GrLivArea', 'BedroomAbvGr', 'GarageCars'), 0.6663236598372999),
#  (('GrLivArea', 'BedroomAbvGr', 'YearRemodAdd'), 0.6662887261831687),
#  (('GrLivArea', 'TotalBsmtSF', 'ExterCond'), 0.6660490785021902),
#  (('TotRmsAbvGrd', 'GarageArea', 'OverallQual'), 0.6659122076532742),
#  (('GrLivArea', 'BsmtQual', 'PavedDrive'), 0.6658857613739941),
#  (('GrLivArea', 'TotalBsmtSF', 'LowQualFinSF'), 0.6658176596052903),
#  (('GrLivArea', 'Fireplaces', 'GarageCars'), 0.6657130345306932),
#  (('GrLivArea', 'GarageYrBlt', 'BsmtQual'), 0.665350217563526),
#  (('GrLivArea', 'KitchenAbvGr', 'GarageArea'), 0.6653091457107813),
#  (('TotalBsmtSF', '1stFlrSF', '2ndFlrSF'), 0.6651048427373112),
#  (('GrLivArea', '2ndFlrSF', 'GarageArea'), 0.6647595095011736),
#  (('GrLivArea', 'YearRemodAdd', 'LotShape'), 0.6646465725464272),
#  (('GrLivArea', 'ExterQual', 'GarageCond'), 0.6643428208470405),
#  (('GrLivArea', 'GarageCars', 'MSSubClass'), 0.664220288762531),
#  (('GrLivArea', 'BsmtFinSF1', 'BsmtUnfSF'), 0.664162031422212),
#  (('GrLivArea', '1stFlrSF', 'ExterQual'), 0.6641434231324311),
#  (('TotalBsmtSF', '2ndFlrSF', 'GarageType'), 0.6640418847352345),
#  (('1stFlrSF', 'HalfBath', 'YearRemodAdd'), 0.6639786408015036),
#  (('GrLivArea', 'GarageArea', 'Foundation'), 0.6639377552857079),
#  (('GrLivArea', 'LotFrontage', 'GarageYrBlt'), 0.6639293572836535),
#  (('BsmtFinSF1', 'GarageCars', 'OverallQual'), 0.6638773682582713),
#  (('GrLivArea', 'TotalBsmtSF', 'Condition1'), 0.6637356835383448),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtCond'), 0.6636286530995898),
#  (('GrLivArea', '1stFlrSF', 'KitchenQual'), 0.6633595376897123),
#  (('GrLivArea', 'TotalBsmtSF', 'Heating'), 0.6633018165448894),
#  (('BsmtFinSF1', '1stFlrSF', 'OverallQual'), 0.6631019653537336),
#  (('GrLivArea', 'KitchenQual', 'GarageCond'), 0.6630948703920474),
#  (('GrLivArea', 'ExterQual', 'BsmtExposure'), 0.6628943296089498),
#  (('GrLivArea', 'TotalBsmtSF', 'MSSubClass'), 0.6627790762372255),
#  (('GrLivArea', 'GarageYrBlt', 'HeatingQC'), 0.6626215039104963),
#  (('1stFlrSF', 'TotRmsAbvGrd', 'YearBuilt'), 0.6625039574426371),
#  (('1stFlrSF', 'Fireplaces', 'OverallQual'), 0.6624541579693807),
#  (('GrLivArea', 'LotFrontage', 'TotalBsmtSF'), 0.6624277185818204),
#  (('GrLivArea', 'TotalBsmtSF', 'OpenPorchSF'), 0.6624048834139418),
#  (('GrLivArea', 'GarageArea', 'BsmtFinType1'), 0.6623939944822445),
#  (('TotalBsmtSF', 'GarageArea', 'YearRemodAdd'), 0.6622495678833646),
#  (('TotalBsmtSF', 'Fireplaces', 'OverallQual'), 0.6622284981369875),
#  (('Fireplaces', 'GarageArea', 'OverallQual'), 0.6621757996132915),
#  (('1stFlrSF', '2ndFlrSF', 'GarageType'), 0.6621040417791917),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'YearRemodAdd'), 0.661984765176933),
#  (('GrLivArea', 'LotFrontage', 'YearRemodAdd'), 0.6618795599626879),
#  (('1stFlrSF', 'OverallQual', 'CentralAir'), 0.6618740974344046),
#  (('GrLivArea', 'GarageCars', 'Functional'), 0.661731068635379),
#  (('GrLivArea', 'TotalBsmtSF', 'SaleType'), 0.6616501857733214),
#  (('GrLivArea', 'YearRemodAdd', 'Functional'), 0.6614501199713728),
#  (('GrLivArea', 'GarageYrBlt', 'LotShape'), 0.6614498040494339),
#  (('GrLivArea', 'BsmtFullBath', 'GarageType'), 0.6612753508013522),
#  (('TotalBsmtSF', '2ndFlrSF', 'Foundation'), 0.6611483841467187),
#  (('GrLivArea', 'TotalBsmtSF', 'Utilities'), 0.6610777701832331),
#  (('1stFlrSF', '2ndFlrSF', 'CentralAir'), 0.6610668370332045),
#  (('GrLivArea', 'TotalBsmtSF', 'ScreenPorch'), 0.6609973102717686),
#  (('GrLivArea', 'MasVnrArea', 'GarageYrBlt'), 0.6608394821456763),
#  (('GrLivArea', 'TotalBsmtSF', 'Fence'), 0.6607578383292392),
#  (('GrLivArea', 'LotArea', 'TotalBsmtSF'), 0.6606936113989382),
#  (('GrLivArea', 'TotalBsmtSF', 'Street'), 0.6606696224034334),
#  (('GrLivArea', 'TotalBsmtSF', 'LandSlope'), 0.6606263536318054),
#  (('BsmtFinSF1', 'GarageArea', 'OverallQual'), 0.660612008823904),
#  (('GrLivArea', 'TotalBsmtSF', 'MasVnrType'), 0.6605508630499474),
#  (('GrLivArea', 'Fireplaces', 'GarageArea'), 0.6605144368747934),
#  (('GrLivArea', 'YearRemodAdd', 'MSSubClass'), 0.6603643633209751),
#  (('GrLivArea', 'TotalBsmtSF', 'Condition2'), 0.6603349965565739),
#  (('GrLivArea', 'TotalBsmtSF', 'Neighborhood'), 0.6603220666744956),
#  (('GrLivArea', 'GarageCars', 'LotShape'), 0.6603035219116945),
#  (('GrLivArea', 'TotalBsmtSF', '3SsnPorch'), 0.6602739201816187),
#  (('GrLivArea', 'TotalBsmtSF', 'PoolQC'), 0.6602119191205515),
#  (('GrLivArea', 'TotalBsmtSF', 'BldgType'), 0.660186728256442),
#  (('GrLivArea', 'TotalBsmtSF', 'LandContour'), 0.6600983859233331),
#  (('GrLivArea', 'TotalBsmtSF', 'LotConfig'), 0.6600948730779569),
#  (('GrLivArea', 'TotalBsmtSF', 'MiscFeature'), 0.660092692467952),
#  (('GrLivArea', 'TotalBsmtSF', 'RoofStyle'), 0.6600766254294412),
#  (('GrLivArea', 'TotalBsmtSF', '2ndFlrSF'), 0.6600747124382402),
#  (('GrLivArea', 'BsmtExposure', 'KitchenQual'), 0.6600261142899523),
#  (('GrLivArea', 'TotalBsmtSF', 'MiscVal'), 0.6599920852993616),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtHalfBath'), 0.6599656665717107),
#  (('GrLivArea', 'TotalBsmtSF', 'RoofMatl'), 0.6599514759446499),
#  (('GrLivArea', 'BsmtFinSF2', 'TotalBsmtSF'), 0.6599500121844297),
#  (('GrLivArea', 'TotalBsmtSF', 'YrSold'), 0.6599477196652148),
#  (('GrLivArea', 'TotalBsmtSF', 'MoSold'), 0.659947627734296),
#  (('GrLivArea', 'GarageYrBlt', 'GarageQual'), 0.6599434177368799),
#  (('GrLivArea', 'TotalBsmtSF', '1stFlrSF'), 0.6599360553789927),
#  (('GrLivArea', 'TotalBsmtSF', 'BsmtFinType2'), 0.6599355920569032),
#  (('GrLivArea', 'TotalBsmtSF', 'PoolArea'), 0.6599354409928715),
#  (('GrLivArea', 'TotalBsmtSF', 'FireplaceQu'), 0.6599255466222267),
#  (('GrLivArea', 'BsmtFullBath', 'ExterQual'), 0.659899823773062),
#  (('GrLivArea', 'CentralAir', 'GarageType'), 0.6598795750122233),
#  (('TotalBsmtSF', 'Fireplaces', 'YearRemodAdd'), 0.659864897403496),
#  (('GrLivArea', 'GarageCars', 'Electrical'), 0.6598370508200774),
#  (('GrLivArea', 'GarageYrBlt', 'Functional'), 0.6595631324371043),
#  (('1stFlrSF', 'GarageArea', 'YearRemodAdd'), 0.6595412421531965),
#  (('1stFlrSF', 'OverallQual', 'Foundation'), 0.6595401096306274),
#  (('GrLivArea', '1stFlrSF', 'GarageType'), 0.6591863906144058),
#  (('GrLivArea', 'BsmtQual', 'GarageCond'), 0.6591016261468474),
#  (('GrLivArea', 'LotArea', 'GarageYrBlt'), 0.6590276175126577),
#  (('GrLivArea', '2ndFlrSF', 'ExterQual'), 0.6589409908237722),
#  (('GrLivArea', 'ExterQual', 'BsmtFinType1'), 0.6588058504623537),
#  (('GrLivArea', 'GarageCars', 'GarageCond'), 0.6587013908202897),
#  (('GrLivArea', 'YearRemodAdd', 'Foundation'), 0.6586790188224727),
#  (('GrLivArea', 'GarageYrBlt', 'MSSubClass'), 0.658575008991297),
#  (('GrLivArea', 'YearRemodAdd', 'GarageFinish'), 0.6582226652029961),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageCond'), 0.6580278258485217),
#  (('GrLivArea', '2ndFlrSF', 'KitchenQual'), 0.6578381581773103),
#  (('TotalBsmtSF', '2ndFlrSF', 'KitchenQual'), 0.6578122208066151),
#  (('GrLivArea', 'BedroomAbvGr', 'GarageArea'), 0.6577917273374874),
#  (('GrLivArea', 'GarageYrBlt', 'RoofStyle'), 0.6577355825940687),
#  (('GrLivArea', 'BsmtFinSF1', 'PavedDrive'), 0.657565718096728),
#  (('GrLivArea', 'YearRemodAdd', 'RoofStyle'), 0.6572943986726164),
#  (('GrLivArea', 'WoodDeckSF', 'GarageYrBlt'), 0.6572705906749319),
#  (('TotRmsAbvGrd', 'GarageCars', 'OverallQual'), 0.6570182048646908),
#  (('MasVnrArea', '1stFlrSF', 'OverallQual'), 0.6566391349370959),
#  (('GrLivArea', 'WoodDeckSF', 'YearRemodAdd'), 0.6564531751085393),
#  (('GrLivArea', 'GarageCars', 'WoodDeckSF'), 0.6564480972558537),
#  (('GrLivArea', 'GarageYrBlt', 'Electrical'), 0.6562302016308819),
#  (('1stFlrSF', '2ndFlrSF', 'HeatingQC'), 0.6562230284947912),
#  (('TotalBsmtSF', 'OverallQual', 'KitchenQual'), 0.6562138322747093),
#  (('1stFlrSF', 'OverallQual', 'GarageFinish'), 0.6561317954061776),
#  (('TotalBsmtSF', 'GarageCars', 'KitchenQual'), 0.6560380315376998),
#  (('GrLivArea', '1stFlrSF', 'CentralAir'), 0.6559026888015185),
#  (('GrLivArea', 'TotRmsAbvGrd', 'GarageYrBlt'), 0.6557748905599854),
#  (('GrLivArea', '2ndFlrSF', 'GarageType'), 0.6556571239556639),
#  (('GrLivArea', 'LotArea', 'YearRemodAdd'), 0.6555005280282089),
#  (('TotalBsmtSF', 'OverallQual', 'ExterQual'), 0.6554423274133838),
#  (('GrLivArea', 'GarageArea', 'MSSubClass'), 0.6553825539619064),
#  (('GrLivArea', 'YearRemodAdd', 'ExterCond'), 0.6552980871499778),
#  (('TotalBsmtSF', 'HalfBath', 'GarageCars'), 0.6552758479638372),
#  (('GrLivArea', 'GarageYrBlt', 'SaleCondition'), 0.6552273832796118),
#  (('GrLivArea', 'MasVnrArea', 'GarageCars'), 0.6549790907375346),
#  (('GrLivArea', 'ExterQual', 'GarageQual'), 0.654649093757677),
#  (('GrLivArea', 'BedroomAbvGr', 'GarageType'), 0.654595111128103),
#  (('GrLivArea', 'YearRemodAdd', 'BsmtCond'), 0.6545549727702493),
#  (('GrLivArea', 'YearRemodAdd', 'HeatingQC'), 0.6544744326762839),
#  (('GrLivArea', 'TotRmsAbvGrd', 'GarageCars'), 0.6544367550506205),
#  (('1stFlrSF', 'OverallQual', 'GarageType'), 0.6543588917450163),
#  (('TotalBsmtSF', 'YearBuilt', 'OverallQual'), 0.6540904267264385),
#  (('GrLivArea', 'TotRmsAbvGrd', 'YearRemodAdd'), 0.6540261994753289),
#  (('GrLivArea', 'ScreenPorch', 'GarageYrBlt'), 0.6539083209259655),
#  (('TotalBsmtSF', 'OverallQual', 'BsmtQual'), 0.653805984360503),
#  (('Fireplaces', 'GarageCars', 'OverallQual'), 0.6537138604801573),
#  (('GrLivArea', 'GarageArea', 'LotShape'), 0.653680097732086),
#  (('GrLivArea', 'GarageArea', 'Functional'), 0.6536714955163077),
#  (('1stFlrSF', 'MSSubClass', 'OverallQual'), 0.6536479628447497),
#  (('GrLivArea', 'BsmtFullBath', 'KitchenQual'), 0.653440432962799),
#  (('GrLivArea', 'GarageYrBlt', 'BsmtCond'), 0.6534371788181996),
#  (('GrLivArea', 'GarageCars', 'GarageQual'), 0.6533797923630946),
#  (('TotRmsAbvGrd', 'YearBuilt', 'OverallQual'), 0.6533685516398251),
#  (('GrLivArea', 'YearRemodAdd', 'SaleCondition'), 0.6531387719975725),
#  (('TotalBsmtSF', 'HouseStyle', 'OverallQual'), 0.6530611886502838),
#  (('GrLivArea', 'YearRemodAdd', 'Electrical'), 0.6529960106401391),
#  (('GrLivArea', 'BsmtFullBath', 'BsmtQual'), 0.6529196189823447),
#  (('1stFlrSF', 'OverallQual', 'PavedDrive'), 0.6528921508308737),
#  (('1stFlrSF', 'WoodDeckSF', 'OverallQual'), 0.652879879144336),
#  (('GrLivArea', 'BsmtQual', 'BsmtExposure'), 0.6528366545078743),
#  (('GrLivArea', 'BsmtQual', 'BsmtFinType1'), 0.6528036145776974),
#  (('GrLivArea', 'LowQualFinSF', 'GarageYrBlt'), 0.6527031941807733),
#  (('GrLivArea', 'GarageArea', 'Electrical'), 0.6526493081702698),
#  (('GrLivArea', 'GarageCars', 'BsmtCond'), 0.65259017243148),
#  (('1stFlrSF', 'OverallQual', 'GarageCond'), 0.6525271402663488),
#  (('GrLivArea', 'BsmtQual', 'KitchenQual'), 0.6521491589207121),
#  (('GrLivArea', 'Foundation', 'GarageType'), 0.6521125098929168),
#  (('GrLivArea', 'GarageCars', 'SaleCondition'), 0.652076256087982),
#  (('GrLivArea', 'KitchenQual', 'GarageQual'), 0.6520212423695546),
#  (('GrLivArea', 'GarageYrBlt', 'GarageFinish'), 0.6519860230613783),
#  (('GrLivArea', '1stFlrSF', 'HeatingQC'), 0.6519000889772848),
#  (('GrLivArea', 'BsmtFinSF1', 'BsmtExposure'), 0.6518845202086843),
#  (('GarageArea', 'OverallQual', 'KitchenQual'), 0.6518522259737654),
#  (('GrLivArea', 'BsmtExposure', 'CentralAir'), 0.6517669943776294),
#  (('GrLivArea', 'GarageArea', 'GarageCond'), 0.6516526522591566),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'GarageCars'), 0.6514591571708748),
#  (('GarageArea', 'OverallQual', 'ExterQual'), 0.6513596083578301),
#  (('TotalBsmtSF', '1stFlrSF', 'OverallQual'), 0.6513325026067291),
#  (('GrLivArea', 'GarageCars', 'Alley'), 0.6512108497693734),
#  (('GrLivArea', 'GarageCars', 'EnclosedPorch'), 0.6510955946679431),
#  (('TotalBsmtSF', 'FullBath', 'GarageCars'), 0.6510668993968505),
#  (('GrLivArea', 'GarageCars', 'MSZoning'), 0.6510310008981832),
#  (('FullBath', 'GarageArea', 'OverallQual'), 0.6509694760540159),
#  (('TotalBsmtSF', 'OverallQual', 'Foundation'), 0.6509142300027186),
#  (('GrLivArea', 'GarageCars', 'OverallCond'), 0.650824198474033),
#  (('GrLivArea', 'GarageYrBlt', 'LandSlope'), 0.6507927981708501),
#  (('GrLivArea', 'GarageYrBlt', 'BldgType'), 0.6507841578114009),
#  (('GrLivArea', 'BsmtFinType1', 'KitchenQual'), 0.650599854563354),
#  (('GrLivArea', 'ScreenPorch', 'YearRemodAdd'), 0.6505540715837426),
#  (('GrLivArea', 'BsmtFinSF2', 'GarageYrBlt'), 0.6504396269168159),
#  (('BsmtFinSF1', '1stFlrSF', '2ndFlrSF'), 0.6504386160483944),
#  (('GrLivArea', 'GarageYrBlt', 'Heating'), 0.6503966129550496),
#  (('GrLivArea', 'HalfBath', 'GarageYrBlt'), 0.650392916115974),
#  (('GrLivArea', 'BsmtFinSF1', 'KitchenAbvGr'), 0.6502558456980285),
#  (('GrLivArea', 'GarageYrBlt', 'Foundation'), 0.6502326784257204),
#  (('GrLivArea', 'YearRemodAdd', 'Alley'), 0.6501795122194877),
#  (('TotalBsmtSF', '2ndFlrSF', 'ExterQual'), 0.650173800314997),
#  (('TotalBsmtSF', 'GarageYrBlt', 'OverallQual'), 0.6499448642447305),
#  (('GrLivArea', 'GarageYrBlt', 'FireplaceQu'), 0.64993732399983),
#  (('GrLivArea', 'GarageYrBlt', 'Neighborhood'), 0.649753330656266),
#  (('1stFlrSF', '2ndFlrSF', 'KitchenAbvGr'), 0.6496910979283721),
#  (('GrLivArea', 'GarageCars', 'Heating'), 0.6496499423604157),
#  (('GrLivArea', 'GarageYrBlt', 'ExterCond'), 0.6496051855781584),
#  (('GrLivArea', '2ndFlrSF', 'CentralAir'), 0.649289618511522),
#  (('GrLivArea', 'GarageYrBlt', 'HouseStyle'), 0.649275377531471),
#  (('GrLivArea', 'GarageYrBlt', 'Alley'), 0.6492168831969692),
#  (('GarageCars', 'OverallQual', 'KitchenQual'), 0.6491889241393527),
#  (('GrLivArea', 'LowQualFinSF', 'YearRemodAdd'), 0.6491864160654476),
#  (('GrLivArea', 'GarageCars', 'GarageArea'), 0.6489992402271904),
#  (('GrLivArea', 'YearRemodAdd', 'MSZoning'), 0.6489946063698153),
#  (('GrLivArea', 'GarageType', 'PavedDrive'), 0.64897008575844),
#  (('GrLivArea', 'ExterQual', 'BsmtQual'), 0.6487794515247446),
#  (('GarageArea', 'YearRemodAdd', 'OverallQual'), 0.6487414407652321),
#  (('1stFlrSF', 'GarageCars', 'YearBuilt'), 0.6487392922578246),
#  (('1stFlrSF', '2ndFlrSF', 'Foundation'), 0.6487340200856363),
#  (('GarageCars', 'OverallQual', 'ExterQual'), 0.6486787148756619),
#  (('GrLivArea', 'KitchenAbvGr', 'GarageType'), 0.6486565063456851),
#  (('GrLivArea', 'GarageCars', 'RoofStyle'), 0.6484699330271742),
#  (('GrLivArea', 'EnclosedPorch', 'YearRemodAdd'), 0.648453722503531),
#  (('GrLivArea', 'GarageYrBlt', 'Exterior2nd'), 0.6483176018524572),
#  (('GrLivArea', 'BsmtFinSF2', 'YearRemodAdd'), 0.6483111638458301),
#  (('1stFlrSF', '2ndFlrSF', 'PavedDrive'), 0.6482813828406504),
#  (('GrLivArea', 'GarageYrBlt', 'MSZoning'), 0.6482757083069457),
#  (('GrLivArea', 'GarageCars', 'OpenPorchSF'), 0.6482675404701419),
#  (('GrLivArea', 'OpenPorchSF', 'GarageYrBlt'), 0.6481899174459413),
#  (('GrLivArea', 'EnclosedPorch', 'GarageYrBlt'), 0.6481550054913292),
#  (('GrLivArea', 'GarageCars', 'ExterCond'), 0.6480787242813122),
#  (('GrLivArea', 'YearRemodAdd', 'LandSlope'), 0.6479823972007481),
#  (('GrLivArea', 'GarageYrBlt', 'Exterior1st'), 0.6479461403481706),
#  (('GrLivArea', 'GarageYrBlt', 'Utilities'), 0.6479234471184961),
#  (('GrLivArea', 'LowQualFinSF', 'GarageCars'), 0.6478814543849006),
#  (('1stFlrSF', 'OverallQual', 'Electrical'), 0.6478463397329222),
#  (('GrLivArea', 'YearRemodAdd', 'Neighborhood'), 0.6477931818799124),
#  (('GrLivArea', 'GarageYrBlt', 'Condition1'), 0.6477875740214829),
#  (('GrLivArea', 'BsmtHalfBath', 'GarageYrBlt'), 0.6477667286066002),
#  (('GrLivArea', 'GarageYrBlt', 'LandContour'), 0.6477229437369767),
#  (('GrLivArea', 'GarageYrBlt', 'RoofMatl'), 0.64767460994771),
#  (('GrLivArea', 'GarageYrBlt', 'LotConfig'), 0.6476729273425743),
#  (('1stFlrSF', 'BsmtFullBath', 'OverallQual'), 0.64763811366388),
#  (('1stFlrSF', 'HalfBath', 'GarageCars'), 0.6476131274067869),
#  (('1stFlrSF', 'GarageCars', 'KitchenQual'), 0.6475884549970741),
#  (('GrLivArea', '3SsnPorch', 'GarageYrBlt'), 0.6475832287512948),
#  (('Fireplaces', 'GarageArea', 'YearRemodAdd'), 0.6475626987658945),
#  (('GrLivArea', 'YearRemodAdd', 'Heating'), 0.6475342126696945),
#  (('GrLivArea', 'Fireplaces', 'ExterQual'), 0.6474922296788503),
#  (('GrLivArea', 'GarageArea', 'WoodDeckSF'), 0.6474432455982451),
#  (('GrLivArea', 'BsmtUnfSF', 'GarageYrBlt'), 0.6473922917187298),
#  (('LotFrontage', '1stFlrSF', 'OverallQual'), 0.6473716773005538),
#  (('GrLivArea', 'LotFrontage', 'GarageCars'), 0.6473613500996643),
#  (('GrLivArea', 'GarageYrBlt', 'MiscFeature'), 0.6473590599037465),
#  (('1stFlrSF', 'OverallQual', 'BsmtFinType1'), 0.6473000753322167),
#  (('GrLivArea', 'GarageYrBlt', 'Street'), 0.6472910805220846),
#  (('GrLivArea', 'GarageYrBlt', 'PoolQC'), 0.6472859600456751),
#  (('GrLivArea', 'GarageYrBlt', 'BsmtFinType2'), 0.64721123028042),
#  (('GrLivArea', 'FullBath', 'GarageCars'), 0.6471643223233529),
#  (('GrLivArea', 'GarageYrBlt', 'SaleType'), 0.647135758653866),
#  (('GrLivArea', 'GarageYrBlt', 'MasVnrType'), 0.6470897002253766),
#  (('BsmtFinSF1', 'FullBath', 'OverallQual'), 0.6470821527293764),
#  (('1stFlrSF', 'OpenPorchSF', 'OverallQual'), 0.6470489332634815),
#  (('GrLivArea', 'GarageYrBlt', 'Fence'), 0.6469288110885589),
#  (('GrLivArea', 'YrSold', 'GarageYrBlt'), 0.6469104566482865),
#  (('GrLivArea', 'FullBath', 'GarageYrBlt'), 0.6469081235962686),
#  (('GrLivArea', 'GarageYrBlt', 'Condition2'), 0.6468711361834414),
#  (('GrLivArea', 'GarageYrBlt', 'MoSold'), 0.6468659902437532),
#  (('LotArea', '1stFlrSF', 'OverallQual'), 0.6468629323326214),
#  (('GrLivArea', 'MiscVal', 'GarageYrBlt'), 0.6468566805773264),
#  (('GrLivArea', 'PoolArea', 'GarageYrBlt'), 0.6468500853097987),
#  (('GrLivArea', 'LotArea', 'GarageCars'), 0.6467400967010014),
#  (('TotalBsmtSF', 'HalfBath', 'YearRemodAdd'), 0.6467159071205948),
#  (('1stFlrSF', 'LotShape', 'OverallQual'), 0.6466077108296233),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageFinish'), 0.6464829199325168),
#  (('GrLivArea', 'GarageArea', 'GarageQual'), 0.6464425852822374),
#  (('GrLivArea', 'BsmtQual', 'GarageQual'), 0.6464199677123779),
#  (('1stFlrSF', 'BedroomAbvGr', 'OverallQual'), 0.6463656933855467),
#  (('GrLivArea', 'GarageCars', 'ScreenPorch'), 0.6463144764223566),
#  (('GrLivArea', 'GarageCars', 'Exterior2nd'), 0.6463105472117101),
#  (('GrLivArea', 'HalfBath', 'YearRemodAdd'), 0.646299632230501),
#  (('GrLivArea', 'YearRemodAdd', 'Condition1'), 0.6462567612026477),
#  (('GrLivArea', 'Fireplaces', 'BsmtQual'), 0.6461992757692125),
#  (('GrLivArea', 'YearRemodAdd', 'FireplaceQu'), 0.6461782358579176),
#  (('GrLivArea', 'YearRemodAdd', 'MasVnrType'), 0.6461514068428149),
#  (('GrLivArea', 'YearRemodAdd', 'HouseStyle'), 0.6460906049260791),
#  (('TotalBsmtSF', 'Fireplaces', 'GarageCars'), 0.6460716611688455),
#  (('GrLivArea', 'BsmtFinType1', 'GarageType'), 0.6460516211982161),
#  (('GrLivArea', 'BsmtFinSF1', '1stFlrSF'), 0.6460072936424126),
#  (('GrLivArea', 'BsmtFinSF1', 'GarageQual'), 0.6459825140533539),
#  (('1stFlrSF', 'OverallQual', 'BsmtExposure'), 0.6459162991558702),
#  (('1stFlrSF', '2ndFlrSF', 'BsmtExposure'), 0.6458703309513694),
#  (('GrLivArea', 'GarageCars', 'Exterior1st'), 0.6458300892759821),
#  (('GrLivArea', 'MasVnrArea', 'GarageArea'), 0.64579521357194),
#  (('GrLivArea', 'YearRemodAdd', 'RoofMatl'), 0.6457528327041646),
#  (('GrLivArea', 'OpenPorchSF', 'YearRemodAdd'), 0.6457330431514514),
#  (('GrLivArea', 'GarageCars', 'LandSlope'), 0.6456068364508243),
#  (('GrLivArea', '1stFlrSF', 'Foundation'), 0.6455921909776363),
#  (('1stFlrSF', 'OverallQual', 'GarageQual'), 0.6454758578552184),
#  (('GrLivArea', 'GarageType', 'GarageFinish'), 0.6454098507332762),
#  (('GrLivArea', 'KitchenAbvGr', 'ExterQual'), 0.6453867857075325),
#  (('GrLivArea', 'GarageCars', 'Condition1'), 0.6453689389778612),
#  (('GrLivArea', 'BsmtHalfBath', 'YearRemodAdd'), 0.645310083354658),
#  (('GrLivArea', 'Functional', 'GarageType'), 0.6452494397574013),
#  (('GrLivArea', 'BsmtFinSF2', 'GarageCars'), 0.6452230864361146),
#  (('GrLivArea', 'FullBath', 'YearRemodAdd'), 0.6452123760024675),
#  (('GrLivArea', 'YearRemodAdd', 'BldgType'), 0.6451957846077558),
#  (('GrLivArea', 'YearRemodAdd', 'LotConfig'), 0.6451575138967155),
#  (('GrLivArea', 'GarageCars', 'FireplaceQu'), 0.6451338426008484),
#  (('GrLivArea', 'YearRemodAdd', 'BsmtFinType2'), 0.6450718181305186),
#  (('GrLivArea', '2ndFlrSF', 'HeatingQC'), 0.6450543791446337),
#  (('GrLivArea', 'YrSold', 'YearRemodAdd'), 0.6450347393785086),
#  (('GrLivArea', 'YearRemodAdd', 'Utilities'), 0.6450130163170564),
#  (('GrLivArea', 'YearRemodAdd', 'MiscFeature'), 0.6450117824758592),
#  (('GrLivArea', '3SsnPorch', 'YearRemodAdd'), 0.6449859633338155),
#  (('GrLivArea', 'YearRemodAdd', 'PoolQC'), 0.6449775637695856),
#  (('GrLivArea', 'BsmtUnfSF', 'YearRemodAdd'), 0.6448807655900106),
#  (('GrLivArea', 'Electrical', 'GarageType'), 0.6448645388557206),
#  (('GrLivArea', 'GarageCars', 'Utilities'), 0.6448049222097076),
#  (('GrLivArea', 'YearRemodAdd', 'Exterior2nd'), 0.6447502605762785),
#  (('TotalBsmtSF', 'OverallQual', 'HeatingQC'), 0.6447342308723206),
#  (('GrLivArea', 'GarageCars', 'Street'), 0.6447282250515365),
#  (('GrLivArea', 'YearRemodAdd', 'LandContour'), 0.6446772997382328),
#  (('GrLivArea', 'YearRemodAdd', 'OverallCond'), 0.6446615518239719),
#  (('GrLivArea', 'YearRemodAdd', 'Exterior1st'), 0.6446129604231698),
#  (('GrLivArea', 'GarageCars', 'Neighborhood'), 0.6446037639190232),
#  (('GrLivArea', 'YearRemodAdd', 'Street'), 0.6445844677562507),
#  (('GrLivArea', 'YearRemodAdd', 'Fence'), 0.6445652488795335),
#  (('GrLivArea', 'MiscVal', 'YearRemodAdd'), 0.6445462359408498),
#  (('GrLivArea', 'YearRemodAdd', 'Condition2'), 0.6445461054511794),
#  (('GrLivArea', 'MoSold', 'YearRemodAdd'), 0.6445454918527828),
#  (('GrLivArea', 'PoolArea', 'YearRemodAdd'), 0.6445416057070121),
#  (('GrLivArea', 'YearRemodAdd', 'SaleType'), 0.6445218667455499),
#  (('1stFlrSF', 'HalfBath', 'YearBuilt'), 0.6444248324697356),
#  (('GrLivArea', 'GarageCars', 'SaleType'), 0.6442939681181961),
#  (('GrLivArea', 'GarageCars', 'PoolQC'), 0.6442765501278889),
#  (('GrLivArea', 'GarageCars', '3SsnPorch'), 0.6440703212869625),
#  (('1stFlrSF', 'OverallQual', 'SaleCondition'), 0.6440323176903082),
#  (('GrLivArea', 'GarageCars', 'Fence'), 0.6439313087328569),
#  (('GrLivArea', 'GarageArea', 'EnclosedPorch'), 0.6439167911723911),
#  (('GrLivArea', 'GarageArea', 'BsmtCond'), 0.6438435021417643),
#  (('GrLivArea', 'GarageCars', 'MoSold'), 0.6437427230223289),
#  (('GrLivArea', 'BsmtHalfBath', 'GarageCars'), 0.6437365696041928),
#  (('GrLivArea', 'GarageCars', 'MasVnrType'), 0.6437358930415511),
#  (('GrLivArea', 'HalfBath', 'GarageCars'), 0.6437248570261709),
#  (('GrLivArea', 'BsmtUnfSF', 'GarageCars'), 0.6437099798170731),
#  (('GrLivArea', 'GarageCars', 'RoofMatl'), 0.6437021518604941),
#  (('GrLivArea', 'GarageArea', 'SaleCondition'), 0.6436922233181139),
#  (('GrLivArea', 'GarageCars', 'MiscFeature'), 0.6436599207336839),
#  (('GrLivArea', 'GarageCars', 'Condition2'), 0.6435811075794651),
#  (('GrLivArea', 'GarageCars', 'HouseStyle'), 0.643563420888387),
#  (('GrLivArea', 'GarageCars', 'PoolArea'), 0.6434998883853638),
#  (('GrLivArea', 'GarageCars', 'LandContour'), 0.6434991391096063),
#  (('GrLivArea', 'GarageCars', 'LotConfig'), 0.643494548048583),
#  (('GrLivArea', 'GarageCars', 'MiscVal'), 0.6434707250924508),
#  (('GrLivArea', 'GarageCars', 'BldgType'), 0.6434688286854622),
#  (('GrLivArea', 'GarageCars', 'BsmtFinType2'), 0.6434631530170881),
#  (('1stFlrSF', 'KitchenAbvGr', 'OverallQual'), 0.643450518778937),
#  (('GrLivArea', 'GarageCars', 'YrSold'), 0.64344758886534),
#  (('1stFlrSF', '2ndFlrSF', 'GarageCond'), 0.6433994700404162),
#  (('LotFrontage', 'TotalBsmtSF', 'OverallQual'), 0.6433883912292783),
#  (('GrLivArea', '1stFlrSF', 'KitchenAbvGr'), 0.6431344166937352),
#  (('1stFlrSF', 'Fireplaces', 'YearRemodAdd'), 0.6431086229972256),
#  (('GrLivArea', 'TotRmsAbvGrd', 'GarageArea'), 0.6430739839814091),
#  (('GarageArea', 'OverallQual', 'GarageFinish'), 0.6430119922392652),
#  (('GrLivArea', 'FullBath', 'GarageArea'), 0.6429965420849033),
#  (('GrLivArea', 'GarageArea', 'Alley'), 0.642962910283186),
#  (('GrLivArea', 'Fireplaces', 'KitchenQual'), 0.6429545826331707),
#  (('BsmtUnfSF', '1stFlrSF', 'OverallQual'), 0.6429488844192717),
#  (('GrLivArea', 'KitchenAbvGr', 'BsmtQual'), 0.6427979549660451),
#  (('TotalBsmtSF', 'MSSubClass', 'OverallQual'), 0.6427718133081395),
#  (('GrLivArea', 'BsmtFullBath', 'CentralAir'), 0.6427557868921135),
#  (('GrLivArea', '1stFlrSF', 'PavedDrive'), 0.642584695382261),
#  (('GrLivArea', 'BsmtFinSF1', 'BedroomAbvGr'), 0.6425120319655354),
#  (('GrLivArea', 'BsmtFinSF1', 'Electrical'), 0.642439161870214),
#  (('1stFlrSF', 'BldgType', 'OverallQual'), 0.6423560506340208),
#  (('GrLivArea', 'MasVnrArea', 'GarageType'), 0.6422356383932564),
#  (('TotalBsmtSF', 'FullBath', 'GarageArea'), 0.6422091986921996),
#  (('GrLivArea', 'BsmtFinSF1', '2ndFlrSF'), 0.6421030504913708),
#  (('GrLivArea', 'GarageArea', 'ExterCond'), 0.6420459661857727),
#  (('1stFlrSF', 'OverallQual', 'Functional'), 0.6419723973071793),
#  (('GrLivArea', 'BsmtFinSF1', 'FullBath'), 0.6418778251084929),
#  (('GrLivArea', 'BsmtExposure', 'PavedDrive'), 0.6415863616597307),
#  (('GrLivArea', 'GarageType', 'GarageCond'), 0.6415574703982491),
#  (('TotalBsmtSF', 'OverallQual', 'GarageType'), 0.6415442950118794),
#  (('1stFlrSF', 'MSZoning', 'OverallQual'), 0.6413346389506738),
#  (('1stFlrSF', 'ScreenPorch', 'OverallQual'), 0.6411029532785866),
#  (('MasVnrArea', 'TotalBsmtSF', 'OverallQual'), 0.6409651203475731),
#  (('GrLivArea', 'ExterQual', 'Electrical'), 0.6409389982027287),
#  (('TotalBsmtSF', 'GarageCars', 'ExterQual'), 0.6408973019362932),
#  (('GrLivArea', '1stFlrSF', 'BsmtExposure'), 0.6407402625030401),
#  (('TotalBsmtSF', 'GarageCars', 'YearBuilt'), 0.6407068108637975),
#  (('GrLivArea', 'GarageArea', 'MSZoning'), 0.6406219603491912),
#  (('GrLivArea', 'BsmtFinSF1', 'Functional'), 0.6405268971646929),
#  (('Fireplaces', 'GarageCars', 'YearRemodAdd'), 0.640525783763612),
#  (('GrLivArea', 'BsmtExposure', 'HeatingQC'), 0.6403957733492996),
#  (('TotalBsmtSF', 'HalfBath', 'GarageArea'), 0.6403274672590304),
#  (('1stFlrSF', 'OverallQual', 'BsmtCond'), 0.6402132353986933),
#  (('GrLivArea', '2ndFlrSF', 'Foundation'), 0.6402058158134476),
#  (('1stFlrSF', 'OverallQual', 'OverallCond'), 0.6401614583009803),
#  (('GrLivArea', 'MSSubClass', 'GarageType'), 0.6399666606567058),
#  (('GrLivArea', 'LotShape', 'GarageType'), 0.6399463053983712),
#  (('GrLivArea', 'BsmtExposure', 'GarageCond'), 0.6399412827235798),
#  (('GrLivArea', 'Fireplaces', 'GarageType'), 0.6397166797767634),
#  (('GrLivArea', 'LowQualFinSF', 'GarageArea'), 0.6395244810276066),
#  (('GrLivArea', 'ExterQual', 'Foundation'), 0.6394983184719432),
#  (('GrLivArea', 'GarageArea', 'OverallCond'), 0.6394562868592546),
#  (('GrLivArea', 'Foundation', 'CentralAir'), 0.6393378038614792),
#  (('GarageCars', 'YearRemodAdd', 'OverallQual'), 0.6392931700084902),
#  (('GrLivArea', 'GarageArea', 'Heating'), 0.6391965947342612),
#  (('TotRmsAbvGrd', 'GarageArea', 'YearBuilt'), 0.6391858197323684),
#  (('GrLivArea', 'LotShape', 'ExterQual'), 0.6391795731396331),
#  (('TotalBsmtSF', 'FullBath', 'HalfBath'), 0.639134362442743),
#  (('TotalBsmtSF', 'GarageCars', 'HeatingQC'), 0.6390784334773899),
#  (('GrLivArea', 'ExterQual', 'KitchenQual'), 0.6390683305270243),
#  (('TotalBsmtSF', 'GarageCars', 'BsmtQual'), 0.6386939632049153),
#  (('TotalBsmtSF', '2ndFlrSF', 'Fireplaces'), 0.6386889805143522),
#  (('TotalBsmtSF', 'OverallQual', 'GarageFinish'), 0.6386854865698527),
#  (('GrLivArea', 'GarageArea', 'RoofStyle'), 0.6386846325520431),
#  (('1stFlrSF', 'OverallQual', 'Exterior2nd'), 0.6386325214089964),
#  (('GrLivArea', '1stFlrSF', 'GarageCond'), 0.638631880934599),
#  (('TotalBsmtSF', '2ndFlrSF', 'HeatingQC'), 0.6385789457437071),
# ...
#  (('1stFlrSF', 'Neighborhood', 'OverallQual'), 0.636488875488356),
#  (('GrLivArea', 'WoodDeckSF', 'GarageType'), 0.6364804889505077),
#  (('1stFlrSF', 'Fireplaces', 'YearBuilt'), 0.6364798361525745),
#  (('1stFlrSF', 'GarageCars', 'ExterQual'), 0.6364261704545564),
#  (('GrLivArea', 'LotArea', 'GarageArea'), 0.6364213855710193),
#  (('1stFlrSF', 'OverallQual', 'ExterCond'), 0.6363735703904866),
#  (('1stFlrSF', 'OverallQual', 'FireplaceQu'), 0.6363732840010455),
#  (('1stFlrSF', 'OverallQual', 'Fence'), 0.6363618199876757),
#  (('1stFlrSF', 'Street', 'OverallQual'), 0.6363528374887868),
#  (('GrLivArea', 'BsmtQual', 'HeatingQC'), 0.6363203028043094),
#  (('BsmtFinSF1', 'TotalBsmtSF', 'OverallQual'), 0.6362774959861187),
#  (('1stFlrSF', 'Condition2', 'OverallQual'), 0.6362055745511757),
#  (('GrLivArea', 'GarageArea', 'ScreenPorch'), 0.6361956960591049),
#  (('1stFlrSF', 'OverallQual', 'BsmtFinType2'), 0.6360983565600389),
#  (('GrLivArea', 'BsmtFinSF1', 'SaleCondition'), 0.636081993788419),
#  (('1stFlrSF', 'LotConfig', 'OverallQual'), 0.6360170722229636),
#  (('1stFlrSF', 'YrSold', 'OverallQual'), 0.6359861268684349),
#  (('1stFlrSF', '3SsnPorch', 'OverallQual'), 0.6359819743589117),
#  (('1stFlrSF', 'MoSold', 'OverallQual'), 0.6359750628827772),
#  (('GrLivArea', 'ExterQual', 'HeatingQC'), 0.6359579411042583),
#  (('BsmtFinSF2', '1stFlrSF', 'OverallQual'), 0.6359548618217681),
#  (('1stFlrSF', 'PoolArea', 'OverallQual'), 0.6359473496592949),
#  (('GrLivArea', 'GarageArea', 'LandSlope'), 0.6359470028036655),
#  (('1stFlrSF', 'BsmtHalfBath', 'OverallQual'), 0.635942432892233),
#  (('1stFlrSF', 'LowQualFinSF', 'OverallQual'), 0.6359411918104642),
#  (('1stFlrSF', 'LandContour', 'OverallQual'), 0.6359407758175005),
#  (('1stFlrSF', 'OverallQual', 'MiscFeature'), 0.6359392050341963),
#  (('1stFlrSF', 'OverallQual', 'RoofStyle'), 0.6359380169038851),
#  (('1stFlrSF', 'MiscVal', 'OverallQual'), 0.6359318200271309),
#  (('GrLivArea', 'GarageArea', 'Street'), 0.6358490069827322),
#  (('TotalBsmtSF', 'WoodDeckSF', 'OverallQual'), 0.6358054259085295),
#  (('GrLivArea', 'GarageType', 'SaleCondition'), 0.6358031075711335),
#  (('GrLivArea', '2ndFlrSF', 'PavedDrive'), 0.6357228589787536),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'BsmtQual'), 0.6356535498026876),
#  (('MasVnrArea', 'GarageArea', 'OverallQual'), 0.6355888211654426),
#  (('GrLivArea', 'Exterior2nd', 'GarageType'), 0.6355787777636218),
#  (('GrLivArea', 'GarageArea', 'SaleType'), 0.6355667191945249),
#  (('GrLivArea', 'GarageArea', 'Utilities'), 0.6355242194585515),
#  (('GrLivArea', 'TotRmsAbvGrd', 'GarageType'), 0.6354989637923645),
#  (('GrLivArea', 'BsmtFinSF2', 'GarageArea'), 0.6353853668462094),
#  (('GrLivArea', 'GarageArea', 'Fence'), 0.6353052043517754),
#  (('1stFlrSF', '2ndFlrSF', 'GarageFinish'), 0.6351852478139927),
#  (('TotalBsmtSF', 'Fireplaces', 'YearBuilt'), 0.6351579576567445),
#  (('GrLivArea', 'GarageArea', 'BldgType'), 0.635156816156323),
#  (('GrLivArea', '2ndFlrSF', 'BsmtExposure'), 0.6351378996221184),
#  (('GrLivArea', 'GarageArea', 'FireplaceQu'), 0.6351354650787506),
#  (('TotalBsmtSF', 'FullBath', 'YearRemodAdd'), 0.6351053691362141),
#  (('GrLivArea', 'LotShape', 'KitchenQual'), 0.6350972346740856),
#  (('GrLivArea', 'KitchenAbvGr', 'KitchenQual'), 0.6350741461230758),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'GarageYrBlt'), 0.6350073156846562),
#  (('GrLivArea', 'GarageArea', 'MasVnrType'), 0.6349074237860632),
#  (('GrLivArea', 'GarageArea', 'PoolQC'), 0.6348286200639275),
#  (('GrLivArea', 'GarageArea', '3SsnPorch'), 0.6347553589441113),
#  (('GrLivArea', '2ndFlrSF', 'KitchenAbvGr'), 0.6347355804531696),
#  (('GrLivArea', 'GarageArea', 'Neighborhood'), 0.6347295773518453),
#  (('GrLivArea', 'GarageArea', 'MiscFeature'), 0.6346131200807401),
#  (('GrLivArea', 'BsmtFinSF1', 'MSSubClass'), 0.6345665420711553),
#  (('GrLivArea', 'HeatingQC', 'CentralAir'), 0.6344915233935977),
#  (('GrLivArea', 'GarageArea', 'Condition2'), 0.634452689353505),
#  (('GrLivArea', 'GarageArea', 'MoSold'), 0.634434947189707),
#  (('GrLivArea', 'BsmtHalfBath', 'GarageArea'), 0.6343830687653407),
#  (('GrLivArea', 'GarageArea', 'RoofMatl'), 0.6343613092523291),
#  (('BsmtUnfSF', 'TotalBsmtSF', 'OverallQual'), 0.6343540751669012),
#  (('GrLivArea', 'GarageArea', 'HouseStyle'), 0.634343960230848),
#  (('GrLivArea', 'BsmtUnfSF', 'GarageArea'), 0.6343255129239238),
#  (('GrLivArea', 'GarageArea', 'PoolArea'), 0.634292778947579),
#  (('GrLivArea', 'HalfBath', 'GarageArea'), 0.6342462044229391),
#  (('GrLivArea', 'GarageArea', 'LandContour'), 0.6342432360316623),
#  (('GrLivArea', 'GarageArea', 'BsmtFinType2'), 0.6342431561110828),
#  (('GrLivArea', 'GarageArea', 'YrSold'), 0.6342133496567643),
#  (('GrLivArea', 'GarageArea', 'LotConfig'), 0.6342130837203401),
#  (('GrLivArea', 'GarageArea', 'MiscVal'), 0.6342128254264146),
#  (('GrLivArea', 'BsmtQual', 'Electrical'), 0.6341500231527701),
#  (('GrLivArea', 'WoodDeckSF', 'ExterQual'), 0.6340800255371087),
#  (('TotalBsmtSF', 'OverallQual', 'GarageCond'), 0.6340698635429435),
#  (('1stFlrSF', 'YearBuilt', 'YearRemodAdd'), 0.6339518468639906),
#  (('GrLivArea', 'FullBath', 'GarageType'), 0.6338665030588015),
#  (('TotalBsmtSF', 'GarageCars', 'HouseStyle'), 0.6338627400739901),
#  (('GrLivArea', 'ExterQual', 'GarageFinish'), 0.6335267809310101),
#  (('GrLivArea', 'Exterior1st', 'GarageType'), 0.6335255164197513),
#  (('TotalBsmtSF', 'GarageArea', 'KitchenQual'), 0.6335150860021725),
#  (('GrLivArea', 'BsmtFinSF1', 'Fireplaces'), 0.6334982039636544),
#  (('GrLivArea', 'MSZoning', 'GarageType'), 0.6334081239695633),
#  (('GrLivArea', 'ExterQual', 'BsmtCond'), 0.6332147954238376),
#  (('1stFlrSF', 'GarageCars', 'HeatingQC'), 0.6330904594032104),
#  (('TotalBsmtSF', 'TotRmsAbvGrd', 'GarageArea'), 0.6329660993561033),
#  (('GrLivArea', 'BsmtCond', 'GarageType'), 0.6329255613446387),
#  (('GrLivArea', 'HeatingQC', 'PavedDrive'), 0.632923955569778),
#  (('LotArea', 'GarageArea', 'OverallQual'), 0.6329010286481618),
#  (('TotRmsAbvGrd', 'OverallQual', 'ExterQual'), 0.6326925940225593),
#  (('1stFlrSF', '2ndFlrSF', 'BsmtFullBath'), 0.6326831728804265),
#  (('1stFlrSF', '2ndFlrSF', 'Functional'), 0.6326749873647837),
#  (('GrLivArea', 'EnclosedPorch', 'GarageType'), 0.6326509621142442),
#  (('1stFlrSF', '2ndFlrSF', 'GarageQual'), 0.6326404954794385),
#  (('GrLivArea', 'BsmtFinSF1', 'MSZoning'), 0.6325390741628549),
#  (('GrLivArea', 'KitchenQual', 'GarageFinish'), 0.6325070208956229),
#  (('TotalBsmtSF', 'BedroomAbvGr', 'OverallQual'), 0.6324623869711036),
#  (('MasVnrArea', 'GarageCars', 'OverallQual'), 0.6324282238003698),
#  (('GrLivArea', 'BsmtQual', 'Functional'), 0.6323558774215987),
#  (('GrLivArea', 'Alley', 'GarageType'), 0.632241215303038),
#  (('GrLivArea', '2ndFlrSF', 'GarageCond'), 0.6321861286608406),
#  (('1stFlrSF', 'HalfBath', 'GarageYrBlt'), 0.6319933509387272),
#  (('TotalBsmtSF', 'GarageCars', 'Foundation'), 0.6319323954302412),
#  (('1stFlrSF', 'GarageCars', 'GarageYrBlt'), 0.6317600469460132),
#  (('GarageArea', 'OverallQual', 'BsmtQual'), 0.6316574403014155),
#  (('GrLivArea', 'CentralAir', 'GarageFinish'), 0.6316154321637422),
#  (('GrLivArea', 'FireplaceQu', 'GarageType'), 0.6315957081569769),
#  (('GrLivArea', 'BsmtFullBath', 'HeatingQC'), 0.631557856445722),
#  (('GrLivArea', 'OverallCond', 'GarageType'), 0.6315530222336436),
#  (('1stFlrSF', '2ndFlrSF', 'Electrical'), 0.631476676614366),
#  (('LotFrontage', 'GarageArea', 'OverallQual'), 0.6314651109295898),
#  (('GarageCars', 'OverallQual', 'GarageFinish'), 0.6314509691215746),
#  (('GarageArea', 'OverallQual', 'HeatingQC'), 0.6314061383811247),
#  (('GrLivArea', 'RoofStyle', 'GarageType'), 0.6313316708794044),
#  (('GarageArea', 'OverallQual', 'GarageType'), 0.631283013001573),
#  (('GrLivArea', 'BsmtFinSF1', 'Exterior2nd'), 0.6310519964142575),
#  (('LotFrontage', 'GarageCars', 'OverallQual'), 0.6310511479643381),
#  (('LotArea', 'GarageCars', 'OverallQual'), 0.6310354552475894),
#  (('TotalBsmtSF', 'Fireplaces', 'GarageYrBlt'), 0.6308008773006897),
#  (('GrLivArea', '1stFlrSF', 'GarageFinish'), 0.630782366260624),
#  (('1stFlrSF', 'HalfBath', 'GarageArea'), 0.6307662719437142),
#  (('TotalBsmtSF', 'GarageCars', 'GarageYrBlt'), 0.6307191727573775),
#  (('GrLivArea', 'MSSubClass', 'BsmtExposure'), 0.6306574932877378),
#  (('GrLivArea', 'BsmtQual', 'BsmtCond'), 0.6304791358994866),
#  (('GrLivArea', 'MasVnrArea', 'BsmtQual'), 0.6304589631217108),
#  (('GrLivArea', 'LotShape', 'BsmtQual'), 0.6304290604805185),
#  (('GrLivArea', 'BedroomAbvGr', 'ExterQual'), 0.6303750016907277),
#  (('TotRmsAbvGrd', 'GarageCars', 'YearBuilt'), 0.6302755761381458),
#  (('GrLivArea', 'BsmtFullBath', 'PavedDrive'), 0.6301958433809376),
#  (('TotalBsmtSF', '2ndFlrSF', 'FullBath'), 0.6301726593686763),
#  (('TotalBsmtSF', '2ndFlrSF', 'GarageFinish'), 0.6301685003939894),
#  (('TotalBsmtSF', 'OverallQual', 'PavedDrive'), 0.6301649541953919),
#  (('GrLivArea', 'BsmtFinSF1', 'WoodDeckSF'), 0.6300811011105198),
#  (('TotalBsmtSF', '2ndFlrSF', 'PavedDrive'), 0.6300359443476065),
#  (('GrLivArea', 'ExterCond', 'GarageType'), 0.630007644397803),
#  (('GrLivArea', 'MSSubClass', 'BsmtQual'), 0.6300043458053468),
#  (('GrLivArea', 'BsmtFinSF1', 'ExterCond'), 0.6299934104148608),
#  (('GrLivArea', 'BsmtFinSF1', 'Exterior1st'), 0.6298980061222801),
#  (('GrLivArea', 'HeatingQC', 'KitchenQual'), 0.6298755681481834),
#  (('BsmtFullBath', 'GarageArea', 'OverallQual'), 0.629825130631287),
#  (('GrLivArea', 'BsmtFinSF1', 'EnclosedPorch'), 0.6297761069327319),
#  (('GrLivArea', 'ExterQual', 'ExterCond'), 0.6296396145333722),
#  (('GrLivArea', 'MasVnrArea', 'BsmtFinSF1'), 0.6294237466694946),
#  (('1stFlrSF', 'YearBuilt', 'KitchenQual'), 0.6293671463756653),
#  (('TotalBsmtSF', 'OpenPorchSF', 'OverallQual'), 0.6292668161780028),
#  (('TotalBsmtSF', 'LotShape', 'OverallQual'), 0.6292646561301923),
#  (('TotalBsmtSF', 'GarageArea', 'YearBuilt'), 0.6290112859606052),
#  (('GrLivArea', 'HeatingQC', 'GarageCond'), 0.628990334854354),
#  (('Fireplaces', 'GarageArea', 'YearBuilt'), 0.628961560601559),
#  (('GrLivArea', 'LowQualFinSF', 'GarageType'), 0.6289138973159845),
#  (('GrLivArea', 'BedroomAbvGr', 'KitchenQual'), 0.628892001864165),
#  (('GrLivArea', 'OpenPorchSF', 'GarageType'), 0.6288539465203271),
#  (('GrLivArea', 'BsmtFinSF1', 'Alley'), 0.6288065586539704),
#  (('Fireplaces', 'GarageCars', 'KitchenQual'), 0.6288039747648142),
#  (('GrLivArea', '1stFlrSF', 'Functional'), 0.628786684439032),
#  (('GrLivArea', 'BsmtFinSF1', 'BsmtCond'), 0.6286136529270498),
#  (('GrLivArea', 'Heating', 'GarageType'), 0.6285568358809888),
#  (('GrLivArea', 'BsmtFullBath', 'Foundation'), 0.6285484118513649),
#  (('GrLivArea', 'KitchenQual', 'Functional'), 0.6285239594287162),
#  (('GrLivArea', 'Neighborhood', 'GarageType'), 0.6285131086550699),
#  (('BsmtFullBath', 'GarageCars', 'OverallQual'), 0.6284885358917492),
#  (('GrLivArea', 'Condition1', 'GarageType'), 0.6284616628586652),
#  (('BsmtFinSF1', 'TotRmsAbvGrd', 'YearBuilt'), 0.6284038357148801),
#  (('GrLivArea', 'BedroomAbvGr', 'PavedDrive'), 0.6283398512234808),
#  (('GarageCars', 'YearBuilt', 'OverallQual'), 0.628307812536923),
#  (('GrLivArea', 'BedroomAbvGr', 'BsmtQual'), 0.6282614950177526),
#  (('1stFlrSF', '2ndFlrSF', 'BsmtFinType1'), 0.6281761444619048),
#  (('1stFlrSF', '2ndFlrSF', 'BedroomAbvGr'), 0.6281161989871509),
#  (('GrLivArea', '1stFlrSF', 'GarageQual'), 0.6280557802704121),
#  (('GrLivArea', 'LotFrontage', 'ExterQual'), 0.6280132598930419),
#  (('GrLivArea', 'MasVnrArea', 'KitchenQual'), 0.6279494339587777),
#  (('GrLivArea', 'GarageType', 'Fence'), 0.627946690272605),
#  (('GrLivArea', 'LotFrontage', 'GarageType'), 0.6276844529586743),
#  (('GrLivArea', 'WoodDeckSF', 'KitchenQual'), 0.6276087245369937),
#  (('GrLivArea', 'MSSubClass', 'ExterQual'), 0.6274755085617278),
#  (('1stFlrSF', 'FullBath', 'GarageCars'), 0.6274750023795769),
#  (('GrLivArea', 'BsmtExposure', 'GarageQual'), 0.6273866319637353),
#  (('GrLivArea', 'LotFrontage', 'BsmtQual'), 0.627351559667648),
#  (('GrLivArea', '1stFlrSF', 'BsmtFullBath'), 0.627297515699216),
#  (('GrLivArea', 'LotArea', 'GarageType'), 0.6271428534389234),
#  (('GrLivArea', 'MasVnrArea', 'ExterQual'), 0.6270119630270491),
#  (('1stFlrSF', 'GarageCars', 'BsmtQual'), 0.6268933281640459),
#  (('TotalBsmtSF', 'Fireplaces', 'GarageArea'), 0.6268816630706999),
#  (('1stFlrSF', 'YearBuilt', 'OverallCond'), 0.6268614265479795),
#  (('GrLivArea', 'KitchenAbvGr', 'BsmtExposure'), 0.6268068823467229),
#  (('GrLivArea', 'GarageType', 'MiscFeature'), 0.626794062748508),
#  (('GrLivArea', 'LandSlope', 'GarageType'), 0.6266924809580932),
#  (('GrLivArea', 'Utilities', 'GarageType'), 0.6266659994843239),
#  (('GrLivArea', 'WoodDeckSF', 'BsmtQual'), 0.6266136506581235),
#  (('GarageCars', 'OverallQual', 'GarageType'), 0.6265957991092088),
#  (('TotalBsmtSF', 'GarageArea', 'BsmtQual'), 0.6264903031469422),
#  (('GrLivArea', 'BsmtFullBath', 'GarageCond'), 0.6261647782645812),
#  (('GrLivArea', 'EnclosedPorch', 'ExterQual'), 0.6261082755766847),
#  (('GrLivArea', 'ScreenPorch', 'GarageType'), 0.6260504890098855),
#  (('GarageArea', 'WoodDeckSF', 'OverallQual'), 0.6260433901503386),
#  (('GrLivArea', 'Foundation', 'BsmtQual'), 0.6260397331771402),
#  (('GrLivArea', '1stFlrSF', 'Electrical'), 0.6260329912020299),
#  (('TotalBsmtSF', 'OverallQual', 'GarageQual'), 0.6259740037902828),
#  (('GrLivArea', '3SsnPorch', 'GarageType'), 0.6258545659955294),
#  (('GrLivArea', 'HalfBath', 'GarageType'), 0.6258351437177817),
#  (('GrLivArea', 'PoolArea', 'GarageType'), 0.6257833810786747),
#  (('GrLivArea', 'GarageType', 'PoolQC'), 0.6257809328159709),
#  (('GrLivArea', 'Street', 'GarageType'), 0.6257650830573269),
#  (('GrLivArea', 'BsmtQual', 'GarageFinish'), 0.6257415915769408),
#  (('GrLivArea', 'GarageType', 'SaleType'), 0.6257102389090343),
#  (('GrLivArea', 'BsmtFinType2', 'GarageType'), 0.6256820488210475),
#  (('TotalBsmtSF', 'OverallQual', 'Electrical'), 0.6256817546869641),
#  (('GrLivArea', 'BsmtFinSF2', 'GarageType'), 0.625661294125437),
#  (('GrLivArea', 'MiscVal', 'GarageType'), 0.6256511147019821),
#  (('GrLivArea', 'BldgType', 'GarageType'), 0.6256083258238319),
#  (('GrLivArea', 'BsmtUnfSF', 'GarageType'), 0.6255352412228277),
#  (('GrLivArea', 'MasVnrType', 'GarageType'), 0.6255105338468535),
#  (('GrLivArea', 'LotConfig', 'GarageType'), 0.6255044058259845),
#  (('GrLivArea', 'RoofMatl', 'GarageType'), 0.6254535454197829),
#  (('GrLivArea', 'HouseStyle', 'GarageType'), 0.6254358384940493),
#  (('GrLivArea', 'YrSold', 'GarageType'), 0.6254329926853541),
#  (('GrLivArea', 'LandContour', 'GarageType'), 0.6254200585477465),
#  (('TotalBsmtSF', 'BldgType', 'OverallQual'), 0.6253927318565191),
#  (('GrLivArea', 'Condition2', 'GarageType'), 0.6253822114664686),
#  (('GrLivArea', 'BsmtHalfBath', 'GarageType'), 0.6253819727216112),
#  (('GrLivArea', 'MoSold', 'GarageType'), 0.6253804227872934),
#  (('GrLivArea', 'LotFrontage', 'BsmtFinSF1'), 0.6252562058885791),
#  (('GrLivArea', 'Foundation', 'PavedDrive'), 0.6250491114950063),
#  (('GrLivArea', 'BsmtFinSF1', 'Heating'), 0.6250474054944167),
#  (('GrLivArea', 'ExterQual', 'SaleCondition'), 0.6249951303807575),
#  (('GrLivArea', 'OverallCond', 'BsmtQual'), 0.6249484243100376),
#  (('1stFlrSF', 'FullBath', 'YearRemodAdd'), 0.6247939765878108),
#  (('GrLivArea', 'BsmtFullBath', 'BsmtExposure'), 0.624666285588648),
#  (('GrLivArea', 'LotArea', 'ExterQual'), 0.6245739386653926),
#  (('TotalBsmtSF', 'OverallQual', 'SaleCondition'), 0.6245288359474606),
#  (('Fireplaces', 'YearBuilt', 'OverallQual'), 0.6245231499401952),
#  (('GrLivArea', 'BsmtFinSF1', 'LowQualFinSF'), 0.624478651180939),
#  (('GrLivArea', '2ndFlrSF', 'GarageFinish'), 0.6244542072152849),
#  (('TotRmsAbvGrd', 'GarageArea', 'YearRemodAdd'), 0.624439898693458),
#  (('1stFlrSF', 'YearRemodAdd', 'HouseStyle'), 0.6244307286409281),
#  (('GarageArea', 'OverallQual', 'CentralAir'), 0.6243336512204389),
#  (('GrLivArea', 'BsmtFinType1', 'HeatingQC'), 0.6242946695737077),
#  (('GrLivArea', 'BsmtFinSF1', 'TotRmsAbvGrd'), 0.6242936761428709),
#  (('GrLivArea', 'BsmtCond', 'KitchenQual'), 0.6242105807194196),
#  (('1stFlrSF', 'HalfBath', 'KitchenQual'), 0.6241403810854826),
#  (('GrLivArea', 'MSSubClass', 'KitchenQual'), 0.6241358247262356),
#  (('BsmtFinSF1', 'OverallQual', 'ExterQual'), 0.6240933213741977),
#  ...]

# %%
import statsmodels.api as sm
x = sm.add_constant(housing_factor_dummified1)
model = sm.OLS(log_SalePrice, x.astype(float))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     323.5
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):               0.00
# Time:                        17:06:35   Log-Likelihood:                 1874.8
# No. Observations:                2580   AIC:                            -3594.
# Df Residuals:                    2502   BIC:                            -3137.
# Df Model:                          77
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            14.4179      3.715      3.881      0.000       7.132      21.704
# GrLivArea         0.0002   1.63e-05     10.659      0.000       0.000       0.000
# LotFrontage       0.0004      0.000      2.816      0.005       0.000       0.001
# LotArea        2.135e-06   3.57e-07      5.978      0.000    1.43e-06    2.84e-06
# MasVnrArea     3.899e-05   1.76e-05      2.213      0.027    4.44e-06    7.35e-05
# BsmtFinSF1     6.426e-05   8.18e-06      7.853      0.000    4.82e-05    8.03e-05
# BsmtFinSF2      3.96e-05   1.51e-05      2.615      0.009     9.9e-06    6.93e-05
# BsmtUnfSF     -1.126e-07   7.79e-06     -0.014      0.988   -1.54e-05    1.52e-05
# TotalBsmtSF       0.0001   9.37e-06     11.072      0.000    8.54e-05       0.000
# 1stFlrSF          0.0001   1.68e-05      7.322      0.000    9.01e-05       0.000
# 2ndFlrSF       8.833e-05   1.56e-05      5.651      0.000    5.77e-05       0.000
# LowQualFinSF  -3.771e-05   4.17e-05     -0.904      0.366      -0.000     4.4e-05
# BsmtFullBath      0.0247      0.007      3.689      0.000       0.012       0.038
# BsmtHalfBath      0.0059      0.011      0.553      0.580      -0.015       0.027
# FullBath          0.0153      0.007      2.058      0.040       0.001       0.030
# HalfBath          0.0098      0.007      1.368      0.171      -0.004       0.024
# BedroomAbvGr     -0.0201      0.005     -4.277      0.000      -0.029      -0.011
# KitchenAbvGr     -0.0823      0.016     -4.989      0.000      -0.115      -0.050
# TotRmsAbvGrd      0.0111      0.003      3.350      0.001       0.005       0.018
# Fireplaces        0.0346      0.005      7.441      0.000       0.026       0.044
# GarageCars        0.0300      0.008      3.841      0.000       0.015       0.045
# GarageArea     4.548e-05   2.76e-05      1.651      0.099   -8.55e-06    9.95e-05
# WoodDeckSF     3.797e-05   2.06e-05      1.839      0.066   -2.51e-06    7.85e-05
# OpenPorchSF   -2.766e-06   3.97e-05     -0.070      0.944   -8.06e-05    7.51e-05
# EnclosedPorch     0.0002   4.08e-05      4.597      0.000       0.000       0.000
# 3SsnPorch      7.457e-05   9.39e-05      0.794      0.427      -0.000       0.000
# ScreenPorch       0.0003   4.37e-05      5.828      0.000       0.000       0.000
# PoolArea         -0.0001   8.79e-05     -1.703      0.089      -0.000    2.27e-05
# MiscVal        1.178e-06   4.91e-06      0.240      0.810   -8.45e-06    1.08e-05
# YrSold           -0.0047      0.002     -2.547      0.011      -0.008      -0.001
# GarageYrBlt       0.0002      0.000      1.278      0.202      -0.000       0.001
# MoSold           -0.0011      0.001     -1.205      0.228      -0.003       0.001
# YearBuilt         0.0020      0.000      9.039      0.000       0.002       0.002
# YearRemodAdd      0.0007      0.000      3.616      0.000       0.000       0.001
# MSSubClass        0.0029      0.001      2.543      0.011       0.001       0.005
# MSZoning         -0.0125      0.003     -3.698      0.000      -0.019      -0.006
# Street            0.1284      0.041      3.168      0.002       0.049       0.208
# Alley             0.0182      0.010      1.753      0.080      -0.002       0.039
# LotShape         -0.0048      0.002     -2.581      0.010      -0.008      -0.001
# LandContour      -0.0035      0.004     -0.891      0.373      -0.011       0.004
# Utilities        -0.0635      0.088     -0.720      0.472      -0.237       0.110
# LotConfig         0.0014      0.002      0.880      0.379      -0.002       0.004
# LandSlope         0.0086      0.012      0.742      0.458      -0.014       0.031
# Neighborhood      0.0001      0.000      0.277      0.782      -0.001       0.001
# Condition1        0.0005      0.003      0.173      0.862      -0.005       0.006
# Condition2       -0.0300      0.011     -2.618      0.009      -0.053      -0.008
# BldgType         -0.0071      0.003     -2.272      0.023      -0.013      -0.001
# HouseStyle       -0.0041      0.002     -2.203      0.028      -0.008      -0.000
# OverallQual       0.0376      0.002     15.446      0.000       0.033       0.042
# OverallCond       0.0491      0.003     17.087      0.000       0.043       0.055
# RoofStyle         0.0030      0.003      0.920      0.358      -0.003       0.009
# RoofMatl          0.0089      0.005      1.935      0.053      -0.000       0.018
# Exterior1st      -0.0026      0.001     -1.750      0.080      -0.005       0.000
# Exterior2nd       0.0043      0.001      3.235      0.001       0.002       0.007
# MasVnrType        0.0093      0.005      1.994      0.046       0.000       0.018
# ExterQual        -0.0355      0.005     -6.460      0.000      -0.046      -0.025
# ExterCond         0.0144      0.003      4.316      0.000       0.008       0.021
# Foundation        0.0065      0.005      1.422      0.155      -0.002       0.016
# BsmtQual         -0.0054      0.002     -2.611      0.009      -0.010      -0.001
# BsmtCond          0.0009      0.003      0.343      0.732      -0.004       0.006
# BsmtExposure     -0.0096      0.003     -3.669      0.000      -0.015      -0.004
# BsmtFinType1     -0.0023      0.001     -1.589      0.112      -0.005       0.001
# BsmtFinType2      0.0006      0.003      0.207      0.836      -0.005       0.006
# Heating           0.0165      0.011      1.557      0.120      -0.004       0.037
# HeatingQC        -0.0075      0.002     -4.460      0.000      -0.011      -0.004
# CentralAir        0.0768      0.013      6.060      0.000       0.052       0.102
# Electrical        0.0017      0.003      0.506      0.613      -0.005       0.008
# KitchenQual      -0.0124      0.003     -4.414      0.000      -0.018      -0.007
# Functional        0.0192      0.003      6.974      0.000       0.014       0.025
# FireplaceQu      -0.0042      0.002     -1.935      0.053      -0.008    5.69e-05
# GarageType       -0.0024      0.002     -1.377      0.169      -0.006       0.001
# GarageFinish     -0.0033      0.002     -1.342      0.180      -0.008       0.002
# GarageQual       -0.0027      0.003     -0.854      0.393      -0.009       0.003
# GarageCond        0.0168      0.004      4.420      0.000       0.009       0.024
# PavedDrive        0.0555      0.012      4.810      0.000       0.033       0.078
# PoolQC           -0.0528      0.024     -2.192      0.028      -0.100      -0.006
# Fence            -0.0010      0.002     -0.447      0.655      -0.005       0.003
# MiscFeature      -0.0109      0.007     -1.626      0.104      -0.024       0.002
# SaleType          0.0004      0.002      0.236      0.814      -0.003       0.003
# SaleCondition     0.0331      0.004      8.960      0.000       0.026       0.040
# ==============================================================================
# Omnibus:                     1249.295   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            49821.630
# Skew:                          -1.602   Prob(JB):                         0.00
# Kurtosis:                      24.288   Cond. No.                     1.22e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.18e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
pValues = results.pvalues
print('The significant coefficients')
pValues[pValues < .05].sort_values()
# Out:
# The significant coefficients
# OverallCond      5.321098e-62
# OverallQual      1.772705e-51
# TotalBsmtSF      7.504272e-28
# GrLivArea        5.649917e-26
# YearBuilt        3.077108e-19
# SaleCondition    6.186082e-19
# BsmtFinSF1       5.993099e-15
# Fireplaces       1.361580e-13
# 1stFlrSF         3.270336e-13
# Functional       3.939083e-12
# ExterQual        1.253207e-10
# CentralAir       1.570432e-09
# LotArea          2.581841e-09
# ScreenPorch      6.320603e-09
# 2ndFlrSF         1.770946e-08
# KitchenAbvGr     6.475868e-07
# PavedDrive       1.599109e-06
# EnclosedPorch    4.495701e-06
# HeatingQC        8.556424e-06
# GarageCond       1.031048e-05
# KitchenQual      1.059962e-05
# ExterCond        1.649634e-05
# BedroomAbvGr     1.965074e-05
# const            1.069183e-04
# GarageCars       1.254324e-04
# MSZoning         2.224002e-04
# BsmtFullBath     2.295378e-04
# BsmtExposure     2.488707e-04
# YearRemodAdd     3.054915e-04
# TotRmsAbvGrd     8.191396e-04
# Exterior2nd      1.232505e-03
# Street           1.550811e-03
# LotFrontage      4.897234e-03
# Condition2       8.903051e-03
# BsmtFinSF2       8.978047e-03
# BsmtQual         9.075308e-03
# LotShape         9.904844e-03
# YrSold           1.091241e-02
# MSSubClass       1.104748e-02
# BldgType         2.318572e-02
# MasVnrArea       2.697671e-02
# HouseStyle       2.767205e-02
# PoolQC           2.849087e-02
# FullBath         3.968498e-02
# MasVnrType       4.620875e-02
# dtype: float64

# %%
print('The insignificant coefficients')
pValues[pValues > .05].sort_values(ascending=False)
# Out:
# The insignificant coefficients
# BsmtUnfSF       0.988478
# OpenPorchSF     0.944456
# Condition1      0.862291
# BsmtFinType2    0.836090
# SaleType        0.813722
# MiscVal         0.810322
# Neighborhood    0.781728
# BsmtCond        0.731701
# Fence           0.654655
# Electrical      0.612990
# BsmtHalfBath    0.580295
# Utilities       0.471880
# LandSlope       0.458453
# 3SsnPorch       0.427188
# GarageQual      0.393263
# LotConfig       0.378711
# LandContour     0.372921
# LowQualFinSF    0.365857
# RoofStyle       0.357785
# MoSold          0.228199
# GarageYrBlt     0.201522
# GarageFinish    0.179811
# HalfBath        0.171371
# GarageType      0.168582
# Foundation      0.155015
# Heating         0.119663
# BsmtFinType1    0.112230
# MiscFeature     0.104077
# GarageArea      0.098933
# PoolArea        0.088707
# Exterior1st     0.080238
# Alley           0.079807
# WoodDeckSF      0.065995
# FireplaceQu     0.053153
# RoofMatl        0.053090
# dtype: float64
